# %% [markdown]
# ## Evaluate MCQ generation errors

# %% [markdown]
# ## Imports

# %%
import sys
import os
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_community.vectorstores.utils import DistanceStrategy
import torch
from transformers import AutoTokenizer, AutoModel
from langchain.docstore.document import Document as LangchainDocument
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_community.vectorstores.utils import DistanceStrategy
import pandas as pd
import numpy as np 
from tqdm import tqdm
from typing import List
import json
import glob
import ollama
from ollama import chat
import re

# %% [markdown]
# ## Functions

# %%
model = 'qwen2.5:7b'

# %% [markdown]
# ### clean

# %%
def validate_json_format_mcq(llm_output, type):
    """
    Attempts to extract and validate a JSON structure from the LLM output.

    Parameters:
    llm_output (str): Raw output from the LLM.
    type (str): question or answer

    Returns:
    dict: A valid JSON object if found and correctly formatted, otherwise None.
    """

    if type == 'question':
        try:
            json_match = re.search(r'\{.*\}', llm_output, re.DOTALL)
            if json_match:
                cleaned_json = json.loads(json_match.group())
                if "question" in cleaned_json and "options" in cleaned_json:
                    return cleaned_json
        except json.JSONDecodeError:
            pass
        return None
    
    elif type == 'answer':
        try:
            json_match = re.search(r'\{.*\}', llm_output, re.DOTALL)
            if json_match:
                cleaned_json = json.loads(json_match.group())
                if "Answer" in cleaned_json and "Justification" in cleaned_json:
                    answer = cleaned_json["Answer"]
                    # Check if answer in 'A', 'B', 'C', or 'D'.
                    if answer not in {'A', 'B', 'C', 'D'}:
                        # check for a valid letter isolated
                        match = re.search(r'\b[A-D]\b', answer)
                        if match:
                            cleaned_json["Answer"] = match.group()
                        else:
                            return None
                    return cleaned_json
        except json.JSONDecodeError:
            pass
        return None

# %%
def call_formatting_llm_mcq(llm_output, type):
    """
    Calls an LLM specialized in formatting text into the correct JSON format.

    Parameters:
    llm_output (str): Raw output from the initial LLM.
    type (str): question or answer

    Returns:
    dict: A valid JSON object containing the question and options.
    """
    if type == 'question':
        system_prompt = """You are an AI specialized in converting multiple-choice legal questions into JSON format.
        Ensure the output strictly follows this structure:
        ```json
        {"question": "...", "options": ["A ....", "B ...", "C ...", "D ..."]}
        """

    elif type == 'answer':
        system_prompt = """You are an AI specialized in converting legal answer into JSON format.
        Ensure the output strictly follows this structure:
        ```json
        {
        "Answer": "...", 
        "Justification": "..."
        }
        """

    user_prompt = f"""
        The following text needs to be formatted as a valid JSON:
        {llm_output}
        
        Please convert it into the required JSON format.
        """

    response = chat(model=model, messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt},
    ])
    
    if type == 'answer':
        return response['message']['content']
    elif type == 'question':
        return validate_json_format_mcq(response['message']['content'], type)

# %%
def clean_generate_mcq_output(llm_output, type):
    """
    Cleans and extracts a valid JSON multiple-choice question from the LLM output.
    If the initial output is not valid JSON, a specialized LLM is called to correct it.

    Parameters:
    llm_output (str): Raw output from the LLM.

    Returns:
    dict: A properly formatted multiple-choice question.
    """
    result = validate_json_format_mcq(llm_output, type)
    if result:
        return result
    
    # If not valid, call formatting LLM
    formatted_result = call_formatting_llm_mcq(llm_output, type)
    if formatted_result:
        return formatted_result
    
    raise ValueError("Failed to convert LLM output into valid JSON format.")

# %% [markdown]
# ### get context

# %%
def get_context(query: str, k: int, knowledge_vector_db: FAISS):
    """ 
    Retrieves relevant context for a given query.

    Parameters:
    query (str): The input query for which context is needed.
    k (int, optional): The number of relevant context elements to retrieve (default is 5).

    Returns:
    list: A list containing relevant context elements.
    """
    retrieved_docs = knowledge_vector_db.similarity_search(query=query, k=k)
    return retrieved_docs

# %% [markdown]
# ### embeddings loader

# %%
def load_rag_embeddings(path, embeddings_model, device='cuda'):

    embedding_model = HuggingFaceEmbeddings(
        model_name=embeddings_model,
        multi_process=True,
        model_kwargs={"device": device, "trust_remote_code":True},  # replace 'cpu' by 'cuda' if you have Nvidia gpu
        encode_kwargs={"normalize_embeddings": True},  # Set `True` for cosine similarity
    )
    
    knowledge_vector_db = FAISS.load_local(path, embedding_model, allow_dangerous_deserialization=True)
    print("embedding load")
    return knowledge_vector_db

# %% [markdown]
# ### generate mcq

# %%
MAX_OUTPUT_TOKENS = 3000

# %%
def generate_mcq(questions: str, knowledge_vector_db: FAISS) -> dict:
    """
    Generates an MCQ question.

    Parameters:
    questions (str): String of validated mcq questions from one subcategory as exemple.

    Returns:
    question (dict): {'question': '...',
                      'options': ['A ....', 'B ...', ...]}
    """
    # Retrieve context
    retrieved_docs = get_context(questions, 3, knowledge_vector_db)
    context = "\nExtracted documents:\n"
    context += "".join([f'Content: {doc.page_content} \nSource: {doc.metadata['ref']}\n\n' for i, doc in enumerate(retrieved_docs)])
    # context_sources = "".join([f'\nSource: {doc.metadata['ref']}, Url: {doc.metadata.get('url', 'N/A')}' for i, doc in enumerate(retrieved_docs)])


    # Build prompt
    system_prompt = f"""
    You are an AI specialized in generating multiple-choice legal questions based on given legal texts.
    ### Instructions:
    - Generate a new legal multiple-choice question based on the provided context.
    - Ensure the question aligns with the style and complexity of the given examples.
    - Provide four answer options (A, B, C, D), with only one being correct.
    - Format the output strictly as a JSON object with the following structure:
        ```json
        {{'question': '...', 'options': ['A ....', 'B ...', 'C ...', 'D ...']}}
    """

    user_prompt = f"""
    ### Context:
    {context}

    ### Examples of Previous Questions:
    {questions}

    Generate a new question that follows the same format and is correct based on the context. Write it in a json.
    """

    # Initial attempt to get the answer
    attempt_count = 0
    max_attempts = 5  # Limit number of attempts to prevent infinite loops

    while attempt_count < max_attempts:
        question_mcq = chat(model=model,
                            messages=[{"role":"system", "content":system_prompt},
                                      {"role":"user","content":user_prompt}],
                            options = {"num_predict":MAX_OUTPUT_TOKENS}
                            )
        
        # Put question in correct json format
        try:
            cleaned_question_mcq = clean_generate_mcq_output(question_mcq['message']['content'], type='question')
            return cleaned_question_mcq, attempt_count  # If valid, return it
        except ValueError:
            attempt_count += 1  # Increment attempt count
            print(f"Attempt {attempt_count} failed. Retrying...")
    
    # If all attempts fail, raise an exception or return None
    return 'Error', '>5'
    raise ValueError("Failed to generate a valid MCQ after multiple attempts.")

# %% [markdown]
# ## Evaluation

# %%
import random

def evaluate_generate_mcq_question(save_dir: str, data_dir: str, test_name: str, model, knowledge_vector_db: FAISS, n):
    """
    Evaluate generation_mcq_answer.

    Parameters:
    save_dir (str): Path to save the evaluation file.
    data_dir (str): Folder to load the json mcq and mcs_solutions files.
    test_name (str): Name of the test, used to save file.

    Returns:
    Nothing but save a json file in save_dir.
    """

    # Get questions from mcq json files
    questions = []
    
    for filename in os.listdir(data_dir):
        # Ignore file containing solution or MOCK
        if "solution" in filename or "json" not in filename or "MOCK" in filename or 'open' in filename or 'categories' in filename:
            continue

        # Load doc
        filepath = os.path.join(data_dir, filename)
        with open(filepath, 'r', encoding='utf-8') as file:
            doc = json.load(file)
        for elt in doc.values():
            questions.append(elt)
        
    ai_questions = []
    attempt_counts = []
    # Generate n AI Questions
    for i in range(n):
        # Get 3 random question from questions
        questions_for_generation = random.sample(questions, 3)
        questions_for_generation_str = json.dumps(questions_for_generation, indent=4)
        print(questions_for_generation_str)

        # Generate new question
        new_question, attempt_count = generate_mcq(questions_for_generation_str, knowledge_vector_db)
        print(f'Question {i}: {new_question}')
        ai_questions.append(new_question)
        attempt_counts.append(attempt_count)
            
    
    result = {'ai_questions': ai_questions,'attempt_counts': attempt_counts}
    
    # Save json
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    output_path = os.path.join(save_dir, f"{test_name}.json")
    with open(output_path, 'w', encoding='utf-8') as file:
        json.dump(result, file, indent=4, ensure_ascii=False)

# %%
# knowledge_vector_db = load_rag_embeddings(path=f'../embeddings/rag_embeddings_sentence-transformers_all-MiniLM-L6-v2_chunk512',
#                                             embeddings_model='sentence-transformers/all-MiniLM-L6-v2', 
#                                             device='cuda')
# Out:
# embedding load

# %%
# evaluate_generate_mcq_question(save_dir='../outputs/evaluation2/', data_dir='../outputs/',
#                             test_name=f'evaluate_mcq_questions_generation', model=model,
#                             knowledge_vector_db=knowledge_vector_db, n=100)
# Out:
# [
#     {
#         "question": "Which of the following statements about filing third- party observations is correct?",
#         "options": [
#             "A. The person that filed third- party observations will be a party to the proceedings before the EPO, and the applicant is obliged to respond to third- party observations",
#             "B. Third -party observations must be filed in writing and may not be filed anonymously",
#             "C. Third -party observations are considered by the examining division only if they include a statement of the grounds on which they are based, and an official fee is paid",
#             "D. Third -party observations can be filed after the publication of a European patent application and must be filed in an official language of the EPO"
#         ]
#     },
#     {
#         "question": "During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?",
#         "options": [
#             "A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.",
#             "B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.",
#             "C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.",
#             "D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months."
#         ]
#     },
#     {
#         "question": "The opposition division revoked European patent EP -B1. The patent proprietor filed an appeal  in time . The b oard of appeal forwarded a copy of the appeal to the o pponent/ respondent with a communication dated 1 June 2023 giving it an opportunity to file comments within a period of four  months.  The opponent/respondent files comments today, 12 October 2023. What further action has to be taken ?",
#         "options": [
#             "A. The opponent/ respondent needs  to request an extension of the period for comment.",
#             "B. The opponent/respondent needs to pay a fee for further processing.",
#             "C. The opponent/respondent needs to file a substantiated request for reestablishment of rights and pay the associated fee.",
#             "D. None of the above."
#         ]
#     }
# ]
# Question 0: {'question': 'When must the patent proprietor file translations of any amended claims into the two official languages other than the language of the proceedings?', 'options': ["A. Within three months after receiving the formalities officer's request.", 'B. Within one month after the interlocutory decision becomes final or the amended text is drawn up.', 'C. Immediately upon amending the claims, regardless of any requests from the formalities officer.', 'D. At the same time as filing the amended claims with the European Patent Office.']}
# [
#     {
#         "question": "In which of the following cases is the applicant entitled to a reduction of the filing fee  under Rule  6 EPC ? A declaration of such entitlement has  been made by crossing the relevant box on Form  1001.",
#         "options": [
#             "A. A Spanish European patent attorney files a European patent application in Spanish for a natural person who is resident in Andorra and of Andorra n nationality .",
#             "B. A firm whose principal place of business is in Germany and a natural person who is resident in Germany  and of Dutch nationality  jointly file a European patent application in Dutch. The German firm employs 200 people with an annual turnover of EUR 60 million.",
#             "C. A natural person resident in the USA and of Belgian nationality files a European patent application in French.",
#             "D. A natural person resident in the USA and of Swiss nationality files a European patent application in Italian."
#         ]
#     },
#     {
#         "question": "In which of the following situations does the EPO recommend using the EPO Contingency Upload Service?",
#         "options": [
#             "A. When you submit documents after business hours",
#             "B. When the EPO filing systems are functioning correctly, but you encounter a technical issue at your end",
#             "C. When there is a system outage at the EPO that prevents document submission via the standard filing systems",
#             "D. When the EPO is closed due to an official holiday"
#         ]
#     },
#     {
#         "question": "A European patent application was filed on 20 March 2020. Proceedings were interrupted under  Rule 142 EPC on 10  March 2022. The applicant was informed that proceedings would be resumed today, 12 October 2023. No renewal fee has been paid so far . Which of the following statements is correct?",
#         "options": [
#             "A. As no renewal fees have been paid, the application is deemed to be withdrawn .",
#             "B. The renewal fees for the third and fourth years can be validly paid without any additional fee on 12 October 2023 at the latest .",
#             "C. The renewal fees for the third and fourth years can be validly paid with an additional  fee by 30  April 2024 at the latest .",
#             "D. The renewal fees for the third and fourth years can be validly paid without any additional fee by 31  October 2023 at the latest ."
#         ]
#     }
# ]
# Attempt 1 failed. Retrying...
# Question 1: {'question': 'According to Article 14(4) EPC, which of the following individuals or entities would be required to file documents in an official language other than English, French, or German, and also provide a translation into an official EPO language?', 'options': ['A. A natural person resident in Spain who files a document for an invention conceived while they were working in France.', 'B. An Italian legal entity with its principal place of business in Italy that files a document for a technical innovation related to their business operations.', 'C. A German individual resident in the UK and filing a document about a new software algorithm.', 'D. A Swiss company whose primary activities are conducted in Switzerland, but one of its employees is resident in Germany when they file a document.']}
# [
#     {
#         "question": "A European patent was granted to a German company on 4  January 2023. No opposition was filed. Mr Li and Ms Smith were designated as inventors. On 12 October 2023,  the patent proprietor not ices that Ms Smith was erroneously designated as inventor and that Mr Li is the sole inventor.  Which of the following statements is correct?",
#         "options": [
#             "A. Ms Smith will be deleted as inventor if the patent proprietor requests this in writing .",
#             "B. Ms Smith can no longer  be deleted as inventor because no proceedings are pending before the EPO .",
#             "C. The patent proprietor can request that  Ms Smith be deleted as inventor but needs Mr Li 's consent  for this .",
#             "D. Ms Smith can only be deleted as inventor with her consent ."
#         ]
#     },
#     {
#         "question": "On 10 October 2021, European patent attorney X filed European patent application EP -A with the EPO on the applicant's behalf. Application EP -A was published on 12 April 2023, together  with the extended European search report. On 6  October 2023, the applicant contacts a new European patent attorney  Y to replace X as representative and issues Y with its instructions to reply to the extended European search report. The applicant did not inform X that he would be replaced.  What are the steps necessary to validly appoint representative Y and to avoid any loss of rights for European patent application EP -A?",
#         "options": [
#             "A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant .",
#             "B. New representative Y requests a change of representative and files a response to the extended European search report with  the EPO by 12 October 2023 at the latest .",
#             "C. New representative Y requests a change of representative and files a response to the extended European search report with the EPO by 23 October 2023 at the latest.",
#             "D. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 23 October 2023 at the latest and files in good time an authorisation signed by the applicant ."
#         ]
#     },
#     {
#         "question": "Mr Linguist filed a European patent application in Dutch and used English as language of the proceedings. When requesting unitary effect on 10 October 2024, Mr Linguist must provide a translation of the specification. Mr Linguist would like to obtain immediate registration of the unitary effect. Which of the following statements is correct?",
#         "options": [
#             "A. Mr Linguist must provide a translation of the specification into Dutch",
#             "B. Mr Linguist must provide a translation of the specification into an official language of any of the 18 states to which the unitary effect extends",
#             "C. Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA",
#             "D. Mr Linguist may provide a translation of the specification into Spanish"
#         ]
#     }
# ]
# Question 2: {'question': 'A European patent application was filed with the EPO on 15 January 2023, and the applicant named Mr. Smith as the inventor without his knowledge or consent. If Mr. Smith later discovers this and wishes to have his name removed from the designation of inventors, which of the following statements is correct according to the provided context?', 'options': ['A. Mr. Smith can request his name be deleted if no opposition proceedings are pending.', "B. The applicant must seek Mr. Smith's consent to remove his name as an inventor.", 'C. Mr. Smith cannot have his name removed once the patent is granted, even if he was not involved in the invention.', "D. Mr. Smith can request his name be deleted after notifying the EPO, but needs the current applicant's consent."]}
# [
#     {
#         "question": "Which functionalities or services can be accessed directly from MyEPO Portfolio?",
#         "options": [
#             "A. A shared area with examiners, European Patent Register, filing via the EPO's online filing software eOLF",
#             "B. Mailbox, a shared area with examiners, replying to a communication under Article  94(3) EPC",
#             "C. Mailbox, patent search via publication server, a shared area with examiners",
#             "D. Filing via the EPO's Online Filing 2.0, patent search via publication server, Mailbox"
#         ]
#     },
#     {
#         "question": "European patent application EP -X was filed on 1  October 2020, claiming the priority of a Belgian application filed on 16 October 2019. The mention of the grant of European patent EP -X was published on 2  October 2024. The proprietor filed a request for unitary effect and was informed by communication dated 10  October 2024, that unitary effect had been registered for EP -X-C0 on the same date. Which of the following statements is correct?",
#         "options": [
#             "A. A renewal fee still has to be paid by 31 October 2024 in respect of the 5th year for EP -X",
#             "B. A renewal fee is due on 31 October 2024 in respect of the 5th year for EP -X-C0",
#             "C. A renewal fee is due on 31 October 2024 in respect of the 6th year for EP -X-C0",
#             "D. No renewal fee has to be paid on 31 October 2024"
#         ]
#     },
#     {
#         "question": "The applicant received a communication pursuant to Article 90(3) EPC and Rule  60 EPC, requesting them to file a designation of inventor but missed the time limit for filing a response. After expiry of the time limit, the Receiving Section issued a decision to refuse the European patent application, dated 10  October 2024. What can the applicant do to remedy the situation?",
#         "options": [
#             "A. File a notice of appeal against the decision within four months of notification of the decision",
#             "B. File a request for further processing within two months of notification of the decision",
#             "C. File, within two months of notification of the decision, a request for re-establishment of rights in respect of the time limit for filing the designation of inventor",
#             "D. A, B and C are correct"
#         ]
#     }
# ]
# Question 3: {'question': 'A European patent application EP-Y was filed on 25 June 2018, claiming priority from a U.S. application filed on 26 June 2017. The decision to grant EP-Y was issued on 30 November 2024. If the applicant wishes to file a request for unitary effect, by what latest date must they do so?', 'options': ['A. 31 December 2024', 'B. 30 May 2025', 'C. 30 November 2024', 'D. 30 June 2025']}
# [
#     {
#         "question": "Last week Greta validly filed the international patent application PCT -G with the German Patent and Trade mark Office ( DPMA ) and appointed Hassan to represent her. Hassan is entitled to act before the DPMA  but he is not a European patent attorney. Greta and Hassan are resident in Germany.  Which of the following statements is not correct?",
#         "options": [
#             "A. Hassan can represent Greta before the EPO acting as the International Searching Authority for PCT -G.",
#             "B. In order for Hassan to be able to act before the EPO acting as the International Searching Authority , he needs to submit a power of attorney signed by Greta.",
#             "C. According to the provisions of the PCT, it is mandatory that the d emand for international preliminary examination is signed by Greta or Hassan.",
#             "D. According to the provisions of the PCT, an international application can only be withdrawn by the applicant or an agent appointed by a power of attorney."
#         ]
#     },
#     {
#         "question": "On 10 October 2024, an applicant files a request for entry into the European phase, together with a debit order, according to which the filing fee, the designation fee, the examination fee and the renewal fee for the third year are to be debited from the applicant's deposit account. It is specified that the debit order is to be executed on 18 October 2024. On the evening of 10 October 2024, the applicant notices that the renewal fee is not yet due and should not be debited from the deposit account. What is the latest point in time for revoking the order to debit the renewal fee in Central Fee Payment (CFP)?",
#         "options": [
#             "A. 10 October 2024",
#             "B. 17 October 2024",
#             "C. 18 October 2024",
#             "D. A debit order cannot be revoked in part"
#         ]
#     },
#     {
#         "question": "Applicants may request processing of their international application under PCT Direct by filing a letter (\"PCT Direct letter\") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?",
#         "options": [
#             "A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing",
#             "B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0",
#             "C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0",
#             "D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document"
#         ]
#     }
# ]
# Question 4: {'question': "In the case described by J 4/94, which of the following statements accurately reflects the Legal Board's decision regarding the interpretation of the demand for international preliminary examination (IPEA) and the European Patent Office (EPO)?", 'options': ['A. The EPO was considered an elected Office in this case due to its involvement in the interpretation of the demand.', "B. The IPEA's interpretation of the demand took precedence over any subsequent interpretation by the EPO, as per Art. 31(4)(a) PCT principles.", 'C. The Legal Board held that the EPO did not become an elected Office in this case because it interpreted the demand differently from the IPEA.', "D. The applicant was required to formally correct the deficiency in the demand by adding 'EP' next to the handwritten indication, before the IPEA could proceed."]}
# [
#     {
#         "question": "Which functionalities or services can be accessed directly from MyEPO Portfolio?",
#         "options": [
#             "A. A shared area with examiners, European Patent Register, filing via the EPO's online filing software eOLF",
#             "B. Mailbox, a shared area with examiners, replying to a communication under Article  94(3) EPC",
#             "C. Mailbox, patent search via publication server, a shared area with examiners",
#             "D. Filing via the EPO's Online Filing 2.0, patent search via publication server, Mailbox"
#         ]
#     },
#     {
#         "question": "You filed an international patent application on 6 June 2024, claiming the priority of a European patent application filed on 7  July 2023. You received a communication dated 25 September 2024 from the EPO acting as International Searching Authority (ISA), stating that the requirement of unity of invention has not been complied with. The ISA identifies three inventions. You are invited to pay two additional search fees. Which of the following statements is correct?",
#         "options": [
#             "A. You must pay two additional search fees by 25 October 2024",
#             "B. You do not need to file a response to the provisional opinion accompanying the partial search results",
#             "C. If you pay two additional search fees under protest, you must pay two protest fees within the time limit",
#             "D. If you do not pay any additional search fees within the time limit, the international patent application will be deemed to be withdrawn"
#         ]
#     },
#     {
#         "question": "A European patent application was filed on 6 February 2023. The search, filing and designation fees were paid within a month of the date of filing. What is the latest point in time for withdrawing the application, if the applicant wishes to obtain a refund of the designation fee?",
#         "options": [
#             "A. Six months after the date of mention of the publication of the European search report",
#             "B. Date of mention of the publication of the European search report",
#             "C. The designation fee was validly paid and can no longer be refunded",
#             "D. Date of the start of substantive examination"
#         ]
#     }
# ]
# Attempt 1 failed. Retrying...
# Question 5: {'question': 'For an international application filed before 1 July 2005, which authority can dispense with drawing up a supplementary European search report?', 'options': ['A. Swedish Intellectual Property Office', 'B. Austrian Patent Office', 'C. Spanish Patent and Trademark Office', 'D. European Patent Office as ISA or SISA']}
# [
#     {
#         "question": "A European patent application was filed on 6 February 2023. The search, filing and designation fees were paid within a month of the date of filing. What is the latest point in time for withdrawing the application, if the applicant wishes to obtain a refund of the designation fee?",
#         "options": [
#             "A. Six months after the date of mention of the publication of the European search report",
#             "B. Date of mention of the publication of the European search report",
#             "C. The designation fee was validly paid and can no longer be refunded",
#             "D. Date of the start of substantive examination"
#         ]
#     },
#     {
#         "question": "A European patent was granted to a German company on 4  January 2023. No opposition was filed. Mr Li and Ms Smith were designated as inventors. On 12 October 2023,  the patent proprietor not ices that Ms Smith was erroneously designated as inventor and that Mr Li is the sole inventor.  Which of the following statements is correct?",
#         "options": [
#             "A. Ms Smith will be deleted as inventor if the patent proprietor requests this in writing .",
#             "B. Ms Smith can no longer  be deleted as inventor because no proceedings are pending before the EPO .",
#             "C. The patent proprietor can request that  Ms Smith be deleted as inventor but needs Mr Li 's consent  for this .",
#             "D. Ms Smith can only be deleted as inventor with her consent ."
#         ]
#     },
#     {
#         "question": "Applicant Korhonen is a Finnish national resident in Finland. He filed a European patent application in Finnish and provided an English translation in time. In response to the extended European search report (EESR), Korhonen wishes to file amended claims t ogether with a request for examination. Which of the following statements is correct?",
#         "options": [
#             "A. Korhonen must file the amended claims in Finnish and must then  provide a translation into English, in time",
#             "B. Korhonen is allowed to file the amended claims in Finnish if he then provides a",
#             "translation into any official language of the EPO, in time C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time",
#             "D. Korhonen is not allowed to file the amended claims in Finnish"
#         ]
#     }
# ]
# Question 6: {'question': 'If an application for a European patent was erroneously filed with incorrect documents, under what circumstances can the applicant withdraw the correct application documents or parts to avoid having them deemed not to have been made?', 'options': ['A. The withdrawal must be made within one month of the notification by the European Patent Office.', 'B. Within one month of the notification from the European Patent Office, the applicant can withdraw the correct documents and it will not be redated.', 'C. The application cannot be withdrawn once incorrect documents are filed.', 'D. Withdrawal is only possible if the application has been published in the European Patent Bulletin.']}
# [
#     {
#         "question": "The applicant received a communication pursuant to Article 90(3) EPC and Rule  60 EPC, requesting them to file a designation of inventor but missed the time limit for filing a response. After expiry of the time limit, the Receiving Section issued a decision to refuse the European patent application, dated 10  October 2024. What can the applicant do to remedy the situation?",
#         "options": [
#             "A. File a notice of appeal against the decision within four months of notification of the decision",
#             "B. File a request for further processing within two months of notification of the decision",
#             "C. File, within two months of notification of the decision, a request for re-establishment of rights in respect of the time limit for filing the designation of inventor",
#             "D. A, B and C are correct"
#         ]
#     },
#     {
#         "question": "On 16  November 2020, you filed a European patent application EP -A, which did not claim priority. Today, 12  October 2023, you receive a communication from the EPO entitled \" Decision to grant a European patent pursuant to Article  97(1) EPC \". This communication state s that the mention of the grant You wish to validate the patent in only two contracting states  to the EPC . Which of the following statements is correct?",
#         "options": [
#             "A. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 16 November 2023.",
#             "B. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 30 November 2023.",
#             "C. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 9 January 2024 at the latest .",
#             "D. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 16 January 2024 at the latest ."
#         ]
#     },
#     {
#         "question": "Under the PCT, what is the time limit for filing a request for rectification of an obvious mistake made in the international application?",
#         "options": [
#             "A. 18 months from the earliest priority date",
#             "B. 30 months from the earliest priority date",
#             "C. 22 months from the earliest priority date",
#             "D. 26 months from the earliest priority date"
#         ]
#     }
# ]
# Question 7: {'question': 'If an applicant fails to reply within the time limit set by Rule 100(2) EPC after receiving a communication requesting the designation of additional Member States for a European patent application, and subsequently receives a decision refusing the application, what action can the applicant take to seek reconsideration?', 'options': ['A. File a notice of appeal against the decision within four months of notification of the decision', 'B. Submit a request for further processing within two months of notification of the decision', 'C. Request re-establishment of rights in respect of the time limit for designation, within one month of notification of the decision', 'D. A and B are correct']}
# [
#     {
#         "question": "Mr Van Holland is a Dutch citizen resident in the Netherlands. He filed a European patent application EP -parent in Dutch, together with  a translation into English. Whil e EP-parent was pending, Mr Van Holland filed a divisional application EP -div in Dutch and requested examination in Dutch. He paid all fees due for EP -div. He has not filed an English translation of EP -div. The Receiving Section has now issued a noting of l oss of rights.  Which of the following statements is correct?",
#         "options": [
#             "A. The deficiency cannot be remedied.",
#             "B. Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication  under Rule 112(1) EPC .",
#             "C. Mr Van Holland needs to file an English translation of EP -div together with a request for f urther processing.",
#             "D. Mr Van Holland needs to file an English translation of EP -div together with a request for re- establishment of rights."
#         ]
#     },
#     {
#         "question": "Applicants may request processing of their international application under PCT Direct by filing a letter (\"PCT Direct letter\") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?",
#         "options": [
#             "A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing",
#             "B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0",
#             "C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0",
#             "D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document"
#         ]
#     },
#     {
#         "question": "A European patent application was filed on 20 March 2020. Proceedings were interrupted under  Rule 142 EPC on 10  March 2022. The applicant was informed that proceedings would be resumed today, 12 October 2023. No renewal fee has been paid so far . Which of the following statements is correct?",
#         "options": [
#             "A. As no renewal fees have been paid, the application is deemed to be withdrawn .",
#             "B. The renewal fees for the third and fourth years can be validly paid without any additional fee on 12 October 2023 at the latest .",
#             "C. The renewal fees for the third and fourth years can be validly paid with an additional  fee by 30  April 2024 at the latest .",
#             "D. The renewal fees for the third and fourth years can be validly paid without any additional fee by 31  October 2023 at the latest ."
#         ]
#     }
# ]
# Question 8: {'question': 'An applicant has filed an international PCT application with priority claiming documents originally filed in German, now wishing to have the application examined in English. According to Rule 159(1)(a) of the EPC, which of the following actions is required within 31 months from the earliest priority date to ensure that the language of proceedings can be changed to English?', 'options': ['A. No action is needed as the language change can occur automatically.', 'B. The applicant must file a translation into German within 31 months.', 'C. The applicant must provide a translation into English within 31 months.', 'D. The applicant should request examination in English directly with no need for translations.']}
# [
#     {
#         "question": "A European patent application was filed on 6 February 2023. The search, filing and designation fees were paid within a month of the date of filing. What is the latest point in time for withdrawing the application, if the applicant wishes to obtain a refund of the designation fee?",
#         "options": [
#             "A. Six months after the date of mention of the publication of the European search report",
#             "B. Date of mention of the publication of the European search report",
#             "C. The designation fee was validly paid and can no longer be refunded",
#             "D. Date of the start of substantive examination"
#         ]
#     },
#     {
#         "question": "Company M, which has  its principal place of business in Tijuana, Mexico, validly filed an international patent application PCT -M with the Mexican Institute of Industrial Property. The application was filed in Spanish. A few days later, the applicant files an English translati on of the application.  Which of the following statements is correct?",
#         "options": [
#             "A. The applicant can choose the EPO as ISA and the USPTO as IPEA.",
#             "B. The applicant can choose the USPTO as ISA and the EPO as IPEA.",
#             "C. The applicant can choose the Austrian Patent Offic e as ISA and the",
#             "EPO as IPEA.",
#             "D. The applicant can choose the EPO as ISA and the Intellectual Property",
#             "Office of Singapore as IPEA."
#         ]
#     },
#     {
#         "question": "An international application is published , together  with the search report drawn up by the CNIPA , 18 m onths + 1 day after the filing date (no priority claimed). The application has no more than 35 pages and 15 claims. Which statement reflects all actions the CN  applicant  needs to take for entry into the EP phase 25 months  after the filing date ? A request for early processing has been filed.",
#         "options": [
#             "A. Complete and file Form 1200 and pay the filing fee and the search fee",
#             "B. Complete and file Form 1200 and pay the filing fee, the search fee and the renewal fee for the third year",
#             "C. Complete and file Form 1200, pay the filing fee and the search fee and appoint a representative",
#             "D. None of the above statements"
#         ]
#     }
# ]
# Question 9: {'question': 'An international application was filed in French and has now entered the European phase under Art. 153(7) of the EPO regulations. The applicant wishes to amend the application documents before receiving the search report. Under which circumstance can this amendment be made?', 'options': ['A. The applicant cannot make any amendments until after receiving the search report.', 'B. The applicant can make amendments if they pay an additional processing fee and request early examination.', 'C. The applicant can make minor amendments before receiving the search report to correct typographical errors or improve clarity.', 'D. The applicant can make substantial amendments before receiving the search report as part of the filing process.']}
# [
#     {
#         "question": "Mr Linguist filed a European patent application in Dutch and used English as language of the proceedings. When requesting unitary effect on 10 October 2024, Mr Linguist must provide a translation of the specification. Mr Linguist would like to obtain immediate registration of the unitary effect. Which of the following statements is correct?",
#         "options": [
#             "A. Mr Linguist must provide a translation of the specification into Dutch",
#             "B. Mr Linguist must provide a translation of the specification into an official language of any of the 18 states to which the unitary effect extends",
#             "C. Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA",
#             "D. Mr Linguist may provide a translation of the specification into Spanish"
#         ]
#     },
#     {
#         "question": "On 10 October 2021, European patent attorney X filed European patent application EP -A with the EPO on the applicant's behalf. Application EP -A was published on 12 April 2023, together  with the extended European search report. On 6  October 2023, the applicant contacts a new European patent attorney  Y to replace X as representative and issues Y with its instructions to reply to the extended European search report. The applicant did not inform X that he would be replaced.  What are the steps necessary to validly appoint representative Y and to avoid any loss of rights for European patent application EP -A?",
#         "options": [
#             "A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant .",
#             "B. New representative Y requests a change of representative and files a response to the extended European search report with  the EPO by 12 October 2023 at the latest .",
#             "C. New representative Y requests a change of representative and files a response to the extended European search report with the EPO by 23 October 2023 at the latest.",
#             "D. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 23 October 2023 at the latest and files in good time an authorisation signed by the applicant ."
#         ]
#     },
#     {
#         "question": "Mr Van Holland is a Dutch citizen resident in the Netherlands. He filed a European patent application EP -parent in Dutch, together with  a translation into English. Whil e EP-parent was pending, Mr Van Holland filed a divisional application EP -div in Dutch and requested examination in Dutch. He paid all fees due for EP -div. He has not filed an English translation of EP -div. The Receiving Section has now issued a noting of l oss of rights.  Which of the following statements is correct?",
#         "options": [
#             "A. The deficiency cannot be remedied.",
#             "B. Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication  under Rule 112(1) EPC .",
#             "C. Mr Van Holland needs to file an English translation of EP -div together with a request for f urther processing.",
#             "D. Mr Van Holland needs to file an English translation of EP -div together with a request for re- establishment of rights."
#         ]
#     }
# ]
# Question 10: {'question': 'Ms. Green filed a European patent application EP-app in German, but requested examination in French. She did not file a French translation of the application. The Receiving Section has now issued a noting of loss of rights. Which of the following statements is correct?', 'options': ['A. Ms. Green can remedy the deficiency by filing a French translation of EP-app within two months of notification of the communication under Rule 112(1) EPC.', 'B. The deficiency cannot be remedied, and Ms. Green will lose her rights.', 'C. Ms. Green needs to file a French translation of EP-app together with a request for further processing.', 'D. Ms. Green needs to file a French translation of EP-app together with a request for re-establishment of rights.']}
# [
#     {
#         "question": "During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?",
#         "options": [
#             "A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.",
#             "B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.",
#             "C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.",
#             "D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months."
#         ]
#     },
#     {
#         "question": "In which of the following situations does the EPO recommend using the EPO Contingency Upload Service?",
#         "options": [
#             "A. When you submit documents after business hours",
#             "B. When the EPO filing systems are functioning correctly, but you encounter a technical issue at your end",
#             "C. When there is a system outage at the EPO that prevents document submission via the standard filing systems",
#             "D. When the EPO is closed due to an official holiday"
#         ]
#     },
#     {
#         "question": "Firm A owns a European patent, EP . Firm B filed an opposition against EP, requesting its revocation. Firm B argued that the subject -matter of the granted claims was not new in view of document D1. During the opposition proceedings, firm C filed observations under Art.  115 EPC, arguing that the subject -matter of the granted claims was not new in view of document D2. Firm A requested maintenance of the patent as granted, or maintenance in amended Which of the following statements is correct?",
#         "options": [
#             "A. At the end of the opposition proceedings, the opposition division decided to revoke the patent. Firm B is entitled to file an appeal against the opposition division's decision.",
#             "B. At the end of the opposition proceedings, the opposition division decided to and firm B are entitled to file an appeal against the opposition division's decision.",
#             "C. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm C is entitled to file an appeal against the opposition division's decision.",
#             "D. During the opposition proceedings, firm B withdrew its opposition. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm B is entitled to file an appeal against the opposition division's decision."
#         ]
#     }
# ]
# Question 11: {'question': 'During opposition proceedings, the proprietor of the patent received an annotated copy suggesting amendments to address objections raised by the examining division. According to the guidelines, which of the following actions is required from the proprietor?', 'options': ['A. The proprietor must submit a completely retyped document containing all suggested amendments.', 'B. The proprietor can choose to indicate any desired amendments on the annotated copy separately from the comments of the examining division.', 'C. The proprietor should only resubmit the said copy if the amendments are extensive and affect the legibility of the copies, otherwise, no action is needed.', 'D. The proprietor must file a formally compliant version of the entire document within one month.']}
# [
#     {
#         "question": "A European patent application was filed on 6 February 2023. The search, filing and designation fees were paid within a month of the date of filing. What is the latest point in time for withdrawing the application, if the applicant wishes to obtain a refund of the designation fee?",
#         "options": [
#             "A. Six months after the date of mention of the publication of the European search report",
#             "B. Date of mention of the publication of the European search report",
#             "C. The designation fee was validly paid and can no longer be refunded",
#             "D. Date of the start of substantive examination"
#         ]
#     },
#     {
#         "question": "Firm A owns a European patent, EP . Firm B filed an opposition against EP, requesting its revocation. Firm B argued that the subject -matter of the granted claims was not new in view of document D1. During the opposition proceedings, firm C filed observations under Art.  115 EPC, arguing that the subject -matter of the granted claims was not new in view of document D2. Firm A requested maintenance of the patent as granted, or maintenance in amended Which of the following statements is correct?",
#         "options": [
#             "A. At the end of the opposition proceedings, the opposition division decided to revoke the patent. Firm B is entitled to file an appeal against the opposition division's decision.",
#             "B. At the end of the opposition proceedings, the opposition division decided to and firm B are entitled to file an appeal against the opposition division's decision.",
#             "C. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm C is entitled to file an appeal against the opposition division's decision.",
#             "D. During the opposition proceedings, firm B withdrew its opposition. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm B is entitled to file an appeal against the opposition division's decision."
#         ]
#     },
#     {
#         "question": "You filed an international patent application on 6 June 2024, claiming the priority of a European patent application filed on 7  July 2023. You received a communication dated 25 September 2024 from the EPO acting as International Searching Authority (ISA), stating that the requirement of unity of invention has not been complied with. The ISA identifies three inventions. You are invited to pay two additional search fees. Which of the following statements is correct?",
#         "options": [
#             "A. You must pay two additional search fees by 25 October 2024",
#             "B. You do not need to file a response to the provisional opinion accompanying the partial search results",
#             "C. If you pay two additional search fees under protest, you must pay two protest fees within the time limit",
#             "D. If you do not pay any additional search fees within the time limit, the international patent application will be deemed to be withdrawn"
#         ]
#     }
# ]
# Question 12: {'question': 'According to EPC Rule 56a, if the applicant files correct application documents or parts under paragraph 3 after the European Patent Office has begun to draw up the search report, what is required within one month?', 'options': ['A. The applicant must withdraw the correct application documents or parts filed.', 'B. The European Patent Office shall inform the applicant that no further action is needed.', 'C. The applicant may pay a further search fee and the application will continue as normal.', "D. The applicant must file an appeal against the European Patent Office's decision."]}
# [
#     {
#         "question": "On 10 October 2024, an applicant files a request for entry into the European phase, together with a debit order, according to which the filing fee, the designation fee, the examination fee and the renewal fee for the third year are to be debited from the applicant's deposit account. It is specified that the debit order is to be executed on 18 October 2024. On the evening of 10 October 2024, the applicant notices that the renewal fee is not yet due and should not be debited from the deposit account. What is the latest point in time for revoking the order to debit the renewal fee in Central Fee Payment (CFP)?",
#         "options": [
#             "A. 10 October 2024",
#             "B. 17 October 2024",
#             "C. 18 October 2024",
#             "D. A debit order cannot be revoked in part"
#         ]
#     },
#     {
#         "question": "Which of the following statements about filing third- party observations is correct?",
#         "options": [
#             "A. The person that filed third- party observations will be a party to the proceedings before the EPO, and the applicant is obliged to respond to third- party observations",
#             "B. Third -party observations must be filed in writing and may not be filed anonymously",
#             "C. Third -party observations are considered by the examining division only if they include a statement of the grounds on which they are based, and an official fee is paid",
#             "D. Third -party observations can be filed after the publication of a European patent application and must be filed in an official language of the EPO"
#         ]
#     },
#     {
#         "question": "Firm A owns a European patent, EP . Firm B filed an opposition against EP, requesting its revocation. Firm B argued that the subject -matter of the granted claims was not new in view of document D1. During the opposition proceedings, firm C filed observations under Art.  115 EPC, arguing that the subject -matter of the granted claims was not new in view of document D2. Firm A requested maintenance of the patent as granted, or maintenance in amended Which of the following statements is correct?",
#         "options": [
# ...
#         "options": [
#             "A. Request the Luxembourg Intellectual Property Office to prepare and send a certified copy of the Luxembourg patent application to the EPO",
#             "B. Submit a valid DAS code (Digital Access Service) to the International Bureau to enable it to obtain a certified copy of the Luxembourg patent application",
#             "C. File an electronic certified copy of the Luxembourg patent application with the EPO",
#             "D. File a certified copy of the Luxembourg patent application with the International Bureau"
#         ]
#     },
#     {
#         "question": "The applicant received a communication pursuant to Article 90(3) EPC and Rule  60 EPC, requesting them to file a designation of inventor but missed the time limit for filing a response. After expiry of the time limit, the Receiving Section issued a decision to refuse the European patent application, dated 10  October 2024. What can the applicant do to remedy the situation?",
#         "options": [
#             "A. File a notice of appeal against the decision within four months of notification of the decision",
#             "B. File a request for further processing within two months of notification of the decision",
#             "C. File, within two months of notification of the decision, a request for re-establishment of rights in respect of the time limit for filing the designation of inventor",
#             "D. A, B and C are correct"
#         ]
#     },
#     {
#         "question": "Applicant Korhonen is a Finnish national resident in Finland. He filed a European patent application in Finnish and provided an English translation in time. In response to the extended European search report (EESR), Korhonen wishes to file amended claims t ogether with a request for examination. Which of the following statements is correct?",
#         "options": [
#             "A. Korhonen must file the amended claims in Finnish and must then  provide a translation into English, in time",
#             "B. Korhonen is allowed to file the amended claims in Finnish if he then provides a",
#             "translation into any official language of the EPO, in time C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time",
#             "D. Korhonen is not allowed to file the amended claims in Finnish"
#         ]
#     }
# ]
# Question 96: {'question': 'An applicant has filed a European patent application claiming priority from an earlier U.S. application, but did not submit the certified copy of the U.S. application within sixteen months of the earliest priority date as required by Rule 53(1). Which of the following actions can be taken to comply with this requirement?', 'options': ['A. Request the U.S. Patent and Trademark Office (USPTO) to prepare and send a certified copy of the U.S. application to the EPO', 'B. Submit a valid DAS code to obtain an electronic copy of the U.S. application from the International Bureau, which can be used as a substitute for the certified copy', 'C. File a request with the Receiving Section at the EPO to extend the time limit for filing the certified copy due to exceptional circumstances', 'D. Provide a sworn statement explaining why the certified copy was not filed in time and hope that it will be accepted']}
# [
#     {
#         "question": "On 10 October 2021, European patent attorney X filed European patent application EP -A with the EPO on the applicant's behalf. Application EP -A was published on 12 April 2023, together  with the extended European search report. On 6  October 2023, the applicant contacts a new European patent attorney  Y to replace X as representative and issues Y with its instructions to reply to the extended European search report. The applicant did not inform X that he would be replaced.  What are the steps necessary to validly appoint representative Y and to avoid any loss of rights for European patent application EP -A?",
#         "options": [
#             "A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant .",
#             "B. New representative Y requests a change of representative and files a response to the extended European search report with  the EPO by 12 October 2023 at the latest .",
#             "C. New representative Y requests a change of representative and files a response to the extended European search report with the EPO by 23 October 2023 at the latest.",
#             "D. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 23 October 2023 at the latest and files in good time an authorisation signed by the applicant ."
#         ]
#     },
#     {
#         "question": "During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?",
#         "options": [
#             "A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.",
#             "B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.",
#             "C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.",
#             "D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months."
#         ]
#     },
#     {
#         "question": "A European patent application was filed on 20 March 2020. Proceedings were interrupted under  Rule 142 EPC on 10  March 2022. The applicant was informed that proceedings would be resumed today, 12 October 2023. No renewal fee has been paid so far . Which of the following statements is correct?",
#         "options": [
#             "A. As no renewal fees have been paid, the application is deemed to be withdrawn .",
#             "B. The renewal fees for the third and fourth years can be validly paid without any additional fee on 12 October 2023 at the latest .",
#             "C. The renewal fees for the third and fourth years can be validly paid with an additional  fee by 30  April 2024 at the latest .",
#             "D. The renewal fees for the third and fourth years can be validly paid without any additional fee by 31  October 2023 at the latest ."
#         ]
#     }
# ]
# Question 97: {'question': 'If European Patent Attorney Y is appointed as the new representative for European patent application EP -A, which of the following actions must be taken to ensure that there is no loss of rights and that the change is validly recorded with the EPO?', 'options': ['A. The applicant should notify the EPO of the change in representation, file a response to the extended European search report by 12 October 2023 at the latest, and ensure an authorisation signed by the applicant is submitted.', 'B. Attorney Y must file a request for a change of representative with the EPO, reply to the extended European search report within 6 months from the date of filing the request, and obtain an authorisation signed by the applicant.', 'C. The new representative should only notify the EPO of the change in representation and reply to the extended European search report within 30 days after receiving instructions from the applicant.', 'D. Attorney Y needs to inform X that he is no longer representing EP -A, file a response to the extended European search report by 12 October 2023 at the latest, and submit an authorisation signed by the applicant.']}
# [
#     {
#         "question": "Company M, which has  its principal place of business in Tijuana, Mexico, validly filed an international patent application PCT -M with the Mexican Institute of Industrial Property. The application was filed in Spanish. A few days later, the applicant files an English translati on of the application.  Which of the following statements is correct?",
#         "options": [
#             "A. The applicant can choose the EPO as ISA and the USPTO as IPEA.",
#             "B. The applicant can choose the USPTO as ISA and the EPO as IPEA.",
#             "C. The applicant can choose the Austrian Patent Offic e as ISA and the",
#             "EPO as IPEA.",
#             "D. The applicant can choose the EPO as ISA and the Intellectual Property",
#             "Office of Singapore as IPEA."
#         ]
#     },
#     {
#         "question": "An international patent application filed with the EPO as receiving Office on 10 September 2024, claims the priority of a Luxembourg patent application filed on 11 October 2023. No certified copy of the Luxembourg patent application was filed at the time of filing of the international patent application. Which of the following actions can be taken to file a certified copy of the Luxembourg patent application for this international patent application?",
#         "options": [
#             "A. Request the Luxembourg Intellectual Property Office to prepare and send a certified copy of the Luxembourg patent application to the EPO",
#             "B. Submit a valid DAS code (Digital Access Service) to the International Bureau to enable it to obtain a certified copy of the Luxembourg patent application",
#             "C. File an electronic certified copy of the Luxembourg patent application with the EPO",
#             "D. File a certified copy of the Luxembourg patent application with the International Bureau"
#         ]
#     },
#     {
#         "question": "Firm A owns a European patent, EP . Firm B filed an opposition against EP, requesting its revocation. Firm B argued that the subject -matter of the granted claims was not new in view of document D1. During the opposition proceedings, firm C filed observations under Art.  115 EPC, arguing that the subject -matter of the granted claims was not new in view of document D2. Firm A requested maintenance of the patent as granted, or maintenance in amended Which of the following statements is correct?",
#         "options": [
#             "A. At the end of the opposition proceedings, the opposition division decided to revoke the patent. Firm B is entitled to file an appeal against the opposition division's decision.",
#             "B. At the end of the opposition proceedings, the opposition division decided to and firm B are entitled to file an appeal against the opposition division's decision.",
#             "C. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm C is entitled to file an appeal against the opposition division's decision.",
#             "D. During the opposition proceedings, firm B withdrew its opposition. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm B is entitled to file an appeal against the opposition division's decision."
#         ]
#     }
# ]
# Question 98: {'question': 'A company, XYZ, has its principal place of business in Paris, France, and filed an international patent application PCT-FR with the French National Institute for Industrial Property (INPI). The application was originally written in French. After filing, the applicant realizes that a translation into English is necessary. Which of the following actions should the applicant take to ensure compliance with EPO requirements for translations of the application?', 'options': ['A. File the English translation directly with the EPO as the receiving Office.', 'B. Request the INPI to prepare and send an English translation to the EPO.', 'C. Submit a valid DAS code (Digital Access Service) to the International Bureau to obtain an English translation of the application.', 'D. File a request for examination with the EPO, specifying that an English translation is required.']}
# [
#     {
#         "question": "On 10 October 2024, an applicant files a request for entry into the European phase, together with a debit order, according to which the filing fee, the designation fee, the examination fee and the renewal fee for the third year are to be debited from the applicant's deposit account. It is specified that the debit order is to be executed on 18 October 2024. On the evening of 10 October 2024, the applicant notices that the renewal fee is not yet due and should not be debited from the deposit account. What is the latest point in time for revoking the order to debit the renewal fee in Central Fee Payment (CFP)?",
#         "options": [
#             "A. 10 October 2024",
#             "B. 17 October 2024",
#             "C. 18 October 2024",
#             "D. A debit order cannot be revoked in part"
#         ]
#     },
#     {
#         "question": "In which of the following situations does the EPO recommend using the EPO Contingency Upload Service?",
#         "options": [
#             "A. When you submit documents after business hours",
#             "B. When the EPO filing systems are functioning correctly, but you encounter a technical issue at your end",
#             "C. When there is a system outage at the EPO that prevents document submission via the standard filing systems",
#             "D. When the EPO is closed due to an official holiday"
#         ]
#     },
#     {
#         "question": "During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?",
#         "options": [
#             "A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.",
#             "B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.",
#             "C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.",
#             "D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months."
#         ]
#     }
# ]
# Question 99: {'question': 'On 15 July 2023, an applicant wishes to pay the renewal fee for a European patent application using a debit order under Rule 51(1). If they receive a validation rejection due to payment being too early, what is their latest option to validly pay the renewal fee without incurring additional charges?', 'options': ['A. Pay the renewal fee on 30 June 2024', 'B. Pay the renewal fee between 1 August 2023 and 30 September 2023', 'C. Pay the renewal fee by 31 July 2023', 'D. No additional options are available if the initial payment was rejected']}

# %% [markdown]
# ## Pour vérifier que les nouveaux embeddings font pas de bêtises

# %%
model = 'qwen2.5:7b'

knowledge_vector_db = load_rag_embeddings(path='../embeddings/gte_large_en_v1_5/rag_embeddings_Alibaba-NLP_gte-large-en-v1.5', 
                                          embeddings_model='Alibaba-NLP/gte-large-en-v1.5', 
                                          device='cuda')

evaluate_generate_mcq_question(save_dir='../outputs/evaluation2/', data_dir='../outputs/',
                            test_name=f'evaluate_mcq_questions_generation_newembeddings', model=model,
                            knowledge_vector_db=knowledge_vector_db, n=100)
# Out:
# embedding load
# [
#     {
#         "question": "During the examination proceedings the applicant notes that claim 1 contains a typographical error. What is the last point in time for requesting correction of the error under Rule 139 EPC?",
#         "options": [
#             "A. One day before the decision to grant a European patent is handed over to the EPO postal service",
#             "B. Date  of publication of the mention of the grant of the European patent",
#             "C. Date of notification of the decision to grant",
#             "D. Date of the communication under Rule 71(3) EPC"
#         ]
#     },
#     {
#         "question": "A British company buys a French firm with an IP portfolio which includes an international application that claims priority of a British national application. The international application is in French. The British company wants to pursue the invention as a European patent application. However, they would prefer that the language of the European proceedings be English.   Which of the following statements is correct?",
#         "options": [
#             "A.  Upon entry into the European phase before the EPO, the applicant can file a translation into English and English will become the language of the proceedings",
#             "B.  The applicant can enter the European phase with the application in French and then validly file a European divisional application in English",
#             "C.  The applicant can select English as the language of the proceedings in the request form for entry into the European phase (EPO Form 1200) and English will become the language of the proceedings",
#             "D.  None of  the above"
#         ]
#     },
#     {
#         "question": "European patent application EP-1 is filed on 10 December 2020, but the inventor is not designated. The designation of the inventor is filed on 25 February 2022. Will the application be refused?",
#         "options": [
#             "A. No. The designation of the inventor was filed in due time.",
#             "B. Yes. The designation of the inventor was not filed in due time."
#         ]
#     }
# ]
# Question 0: {'question': 'If a European patent application is filed in a language other than English, French, or German, what must be provided within two months of filing according to the EPC?', 'options': ['A. A translation into any non-official EPO language', 'B. A translation into one of the official languages of the EPO (English, French, or German)', 'C. An additional fee for using a non-official language', "D. A declaration stating the applicant's preference for the language used"]}
# [
#     {
#         "question": "International application PCT-1 enters the European regional phase as EP-1 today. Independent claims 1 and 10 of the international application were considered to lack unity in the international phase and a partial search report was drawn up by the EPO as ISA in respect of the invention of claim 1. The applicant wishes to have the opportunity to protect the invention of claim 10 during the EPO regional phase, but wants to keep costs to a minimum, at least at the beginning. What can the applicant do?",
#         "options": [
#             "A. File a divisional application to the invention of independent claim 10 after entry into the EPO regional phase.",
#             "B. Pay an additional search fee in respect of the invention of independent claim 10 within two months of entry into the EPO regional phase.",
#             "C. Pay an additional search fee in respect of the invention of independent claim 10 within two months of notification by the EPO."
#         ]
#     },
#     {
#         "question": "Entry into the European phase of an international application can be effected early provided an express request for early processing is made at the time the requirements of Rule 159(1) EPC are complied with. International application PCT-1 was filed 28 months ago with no claim to priority. The application consists of 20 pages, including 16 claims. The international search was carried out by the EPO acting as ISA and the international search report was published with the international application. Which of the following fees must be paid in order to effect early entry into the European phase?",
#         "options": [
#             "A. The filing fee.",
#             "B. The filing fee, the examination fee and the designation fee.",
#             "C. The filing fee, the examination fee, the designation fee and the renewal fee.",
#             "D. The filing fee, the claims fee, the examination fee, the designation fee and the renewal fee."
#         ]
#     },
#     {
#         "question": "Your Client, A Inc, is a sub-licensee under European patent application EP-1. Can the sub-licence be recorded in the European Patent Register?",
#         "options": [
#             "A. No, it is not possible to record sub-licences in the European Patent Register.",
#             "B. Yes, any sub-licence can be recorded in the European Patent Register.",
#             "C. Yes, provided the licensee granting the sub-licence has recorded its licence in the European Patent Register."
#         ]
#     }
# ]
# Question 1: {'question': 'An international application PCT-2 enters the European regional phase as EP-2, and the applicant wishes to obtain a search report for an additional invention claimed in the application that was not searched by the EPO in the international phase. According to the guidelines, what is the correct course of action?', 'options': ['A. File a request for supplementary European search without any additional fees.', 'B. Pay an additional search fee within 31 months from the filing date or the earliest priority claim to obtain a supplementary European search report.', 'C. Wait for the EPO to conduct a full search automatically.']}
# [
#     {
#         "question": "On receipt of the decision to grant its European patent application EP-1 under Rule 71a(1) EPC the applicant realizes that they have made a significant typographical error in claim 1. \nWhat action can they take before the EPO to correct the error?",
#         "options": [
#             "A. None",
#             "B. Seek correction under Rule 140 EPC",
#             "C. Seek correction under Rule 139 EPC"
#         ]
#     },
#     {
#         "question": "Applicant Korhonen is a Finnish national resident in Finland. He filed a European patent application in Finnish and provided an English translation in time. In response to the extended European search report (EESR), Korhonen wishes to file amended claims t ogether with a request for examination. Which of the following statements is correct?",
#         "options": [
#             "A. Korhonen must file the amended claims in Finnish and must then  provide a translation into English, in time",
#             "B. Korhonen is allowed to file the amended claims in Finnish if he then provides a",
#             "translation into any official language of the EPO, in time C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time",
#             "D. Korhonen is not allowed to file the amended claims in Finnish"
#         ]
#     },
#     {
#         "question": "During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?",
#         "options": [
#             "A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.",
#             "B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.",
#             "C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.",
#             "D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months."
#         ]
#     }
# ]
# Question 2: {'question': 'If a patent proprietor receives an interlocutory decision to maintain their European patent in amended form, which of the following actions must they take within three months?', 'options': ['A. File translations of any amended claims in all official languages of the EPO other than the language of the proceedings.', 'B. Pay the fee for publishing a new specification of the European patent.', 'C. Provide a formally compliant version of amended text passages if based on documents not complying with Rule 50(1).', 'D. None of the above.']}
# [
#     {
#         "question": "On receipt of the decision to grant its European patent application EP-1 under Rule 71a(1) EPC the applicant realizes that they have made a significant typographical error in claim 1. \nWhat action can they take before the EPO to correct the error?",
#         "options": [
#             "A. None",
#             "B. Seek correction under Rule 140 EPC",
#             "C. Seek correction under Rule 139 EPC"
#         ]
#     },
#     {
#         "question": "It is permitted to file observations under Article 115 EPC in respect of a patent undergoing limitation proceedings. However, there is no provision under Article 105b EPC or Rule 95 EPC for examination as to patentability, \nand Article 115 EPC specifically refers to observations concerning patentability. \nIs there any reason why a third party might nevertheless file observations under Article 115 EPC in respect of a patent undergoing limitation proceedings?",
#         "options": [
#             "A. Yes, the examining division may be persuaded to consider patentability as part of the limitation proceedings.",
#             "B. Yes, patentability can be considered in the broader sense as including issues relating to Articles 84 and 123(2) EPC.",
#             "C. No, there is no point in filing observations on patentability because they will not be taken into consideration."
#         ]
#     },
#     {
#         "question": "A European patent application EP-A is refused in a decision dated 1 June 2023. Today is 15 July 2023. Is it still possible to file a divisional application from EP-A?",
#         "options": [
#             "A. Yes.",
#             "B. No.",
#             "C. Only if the decision to refuse the application is appealed."
#         ]
#     }
# ]
# Question 3: {'question': 'According to Article 115 EPC, which of the following statements about third-party observations is true?', 'options': ['A. Third parties must pay a fee to present their observations.', 'B. Third parties can present observations in any language they choose.', 'C. Third parties are considered as parties to the proceedings when presenting observations.', "D. Third parties' observations must be filed in an official language of the EPO."]}
# [
#     {
#         "question": "On 10 October 2021, European patent attorney X filed European patent application EP -A with the EPO on the applicant's behalf. Application EP -A was published on 12 April 2023, together  with the extended European search report. On 6  October 2023, the applicant contacts a new European patent attorney  Y to replace X as representative and issues Y with its instructions to reply to the extended European search report. The applicant did not inform X that he would be replaced.  What are the steps necessary to validly appoint representative Y and to avoid any loss of rights for European patent application EP -A?",
#         "options": [
#             "A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant .",
#             "B. New representative Y requests a change of representative and files a response to the extended European search report with  the EPO by 12 October 2023 at the latest .",
#             "C. New representative Y requests a change of representative and files a response to the extended European search report with the EPO by 23 October 2023 at the latest.",
#             "D. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 23 October 2023 at the latest and files in good time an authorisation signed by the applicant ."
#         ]
#     },
#     {
#         "question": "International patent application PCT-1 is filed on 16 June 2019 without any claim to priority. Steps are taken to enter the EPO regional phase on 26 December 2021. When should the renewal fee in respect of the third year be paid (without surcharge)?",
#         "options": [
#             "A. 30 June 2021",
#             "B. 26 December 2021",
#             "C. 2 January 2022",
#             "D. 17 January 2022"
#         ]
#     },
#     {
#         "question": "Most fees for European patent applications cannot be paid before their due date. One exception is renewal fees, which can always be paid up to:",
#         "options": [
#             "A. Three months before the due date.",
#             "B. Six months before the due date.",
#             "C. One year before the due date."
#         ]
#     }
# ]
# Question 4: {'question': 'For a European patent application EP-1, which was filed on 5 February 2023, what are the deadlines for paying the filing and search fees if the application falls under type (i) or (ii)?', 'options': ['A. Filing fee within one month of filing, no specific deadline for the search fee.', 'B. Both filing and search fees within one month of filing EP-1.', 'C. Filing fee within one month of filing, search fee within 31 months of filing EP-1.', 'D. Both filing and search fees within 31 months of filing EP-1.']}
# [
#     {
#         "question": "What is the last point in time for an effective withdrawal of a European patent application?",
#         "options": [
#             "4 A.  Date of receipt of the communication under Rule 71(3) EPC",
#             "B.  The latest of the date of payment of the fee for grant and publishing and the date of filing of the translations of the claims in the two other official languages of the EPO",
#             "C.  Date of publication of the mention of the grant in the European Patent Bulletin",
#             "D.  One day before the date of publication of the mention of the grant in the European Patent Bulletin"
#         ]
#     },
#     {
#         "question": "A French patent application FP2, including claim 1 related to subject-matter A and claim 2 related to A+B, is filed validly claiming priority from an earlier French patent application FP1 related to subject-matter A and filed ten months earlier.\nFP1 is still pending. No relevant prior art has been discovered regarding subject-matter A or A+B. Ten months after the filing of FP2, the applicant instructs you to file a European patent application EP1 identical to and claiming priority from FP2 and if possible from FP1. They also ask about the likely outcome of the EP1. What do you tell them, based on our current knowledge of the situation?",
#         "options": [
#             "A. Both priority claims are valid and EP1 may be granted with both claims 1 and 2.",
#             "B. EP1 cannot validly claim priority from FP1 but the priority from FP2 is valid and EP1 may be granted with both claims 1 and 2.",
#             "C. EP1 cannot validly claim priority from FP1, which becomes prior art for subject-matter A. Claim 1 will not be granted in EP1."
#         ]
#     },
#     {
#         "question": "European patent EP-B is granted with a claim directed to a method of operating a heart pacemaker in dependence upon the required cardiac output while a person is exercising, the pacemaker including a pressure sensing means mounted on a pacing lead and adapted to be implanted in a heart and used to sense the right ventricular systolic pressure, which pressure is used to control the pacer rate. Is it permissible in opposition or opposition appeal proceedings to amend the claim to be directed to a heart pacemaker in order to address problems relating to Article 53(c) EPC?",
#         "options": [
#             "A. Yes, a change in claim category is permitted.",
#             "B. No, a change in claim category would contravene Article 123(3) EPC."
#         ]
#     }
# ]
# Question 5: {'question': 'Given the European patent application EP1, which claims priority from FP2 for subject-matter A+B but not from FP1, and considering that FP1 has been published 18 months after its filing, what is the status of claim 1 in EP1 related to subject-matter A, assuming no other relevant prior art?', 'options': ['A. Claim 1 will be granted as it benefits from a valid priority claim.', 'B. Claim 1 will not be granted due to lack of a valid priority claim and FP1 being prior art for subject-matter A.', 'C. The status of claim 1 cannot be determined without further information.']}
# [
#     {
#         "question": "A European patent application was filed on 6 February 2023. The search, filing and designation fees were paid within a month of the date of filing. What is the latest point in time for withdrawing the application, if the applicant wishes to obtain a refund of the designation fee?",
#         "options": [
#             "A. Six months after the date of mention of the publication of the European search report",
#             "B. Date of mention of the publication of the European search report",
#             "C. The designation fee was validly paid and can no longer be refunded",
#             "D. Date of the start of substantive examination"
#         ]
#     },
#     {
#         "question": "European patent application EP -X was filed on 1  October 2020, claiming the priority of a Belgian application filed on 16 October 2019. The mention of the grant of European patent EP -X was published on 2  October 2024. The proprietor filed a request for unitary effect and was informed by communication dated 10  October 2024, that unitary effect had been registered for EP -X-C0 on the same date. Which of the following statements is correct?",
#         "options": [
#             "A. A renewal fee still has to be paid by 31 October 2024 in respect of the 5th year for EP -X",
#             "B. A renewal fee is due on 31 October 2024 in respect of the 5th year for EP -X-C0",
#             "C. A renewal fee is due on 31 October 2024 in respect of the 6th year for EP -X-C0",
#             "D. No renewal fee has to be paid on 31 October 2024"
#         ]
#     },
#     {
#         "question": "You are monitoring the progress of an international application and on reviewing the details of the international search report you realize that you know of relevant prior art that has not been cited in the search report, but which is likely to be novelty-destroying in respect of at least some of the claims. \nYou believe that the international application will enter the national or regional phase in a significant number of countries or regions and it would therefore be time-consuming and costly to file separate observations in respect of each of \nthe national or regional applications. What can you do?",
#         "options": [
#             "A. File observations online using ePCT.",
#             "B. Send a letter with your observations to the receiving office or the International Bureau.",
#             "C. File observations by letter.",
#             "D. It is not possible to file observations on international applications."
#         ]
#     }
# ]
# Question 6: {'question': 'If a divisional application of second or subsequent generations is filed, what additional fee must be paid according to the guidelines?', 'options': ['A. The filing fee and search fee for the divisional application must be paid within one month of filing the European patent application.', 'B. The additional fee due for any pages in excess of 35 should be paid as specified under A-III, 13.2.', 'C. No additional fees are required for divisional applications beyond the initial filing and search fees.', 'D. The designation fee(s) must be paid within six months of the date on which the European Patent Bulletin mentions the publication of the European search report.']}
# [
#     {
#         "question": "The applicant for European patent application EP-1 has granted an exclusive license under the application. The exclusive licensee wishes to make its rights known by recording the license in the European Patent Register. \nIs it possible to record the exclusive license?",
#         "options": [
#             "A. No, exclusive licenses cannot be recorded in the European Patent Register.",
#             "B. Yes, exclusive licenses can be recorded in the European Patent Register at the joint request of both the applicant and the licensee.",
#             "C. Yes, exclusive licenses can be recorded in the European Patent Register, but only by the applicant.",
#             "D. Yes, exclusive licences can be recorded in the European Patent Register by either the applicant or the licensee."
#         ]
#     },
#     {
#         "question": "A European patent application EP-A is refused in a decision dated 1 June 2023. Today is 15 July 2023. Is it still possible to file a divisional application from EP-A?",
#         "options": [
#             "A. Yes.",
#             "B. No.",
#             "C. Only if the decision to refuse the application is appealed."
#         ]
#     },
#     {
#         "question": "Firm A owns a European patent, EP . Firm B filed an opposition against EP, requesting its revocation. Firm B argued that the subject -matter of the granted claims was not new in view of document D1. During the opposition proceedings, firm C filed observations under Art.  115 EPC, arguing that the subject -matter of the granted claims was not new in view of document D2. Firm A requested maintenance of the patent as granted, or maintenance in amended Which of the following statements is correct?",
#         "options": [
#             "A. At the end of the opposition proceedings, the opposition division decided to revoke the patent. Firm B is entitled to file an appeal against the opposition division's decision.",
#             "B. At the end of the opposition proceedings, the opposition division decided to and firm B are entitled to file an appeal against the opposition division's decision.",
#             "C. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm C is entitled to file an appeal against the opposition division's decision.",
#             "D. During the opposition proceedings, firm B withdrew its opposition. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm B is entitled to file an appeal against the opposition division's decision."
#         ]
#     }
# ]
# Question 7: {'question': 'If a licensee wishes to record an exclusive license under a European patent application in the European Patent Register, which of the following conditions must be met according to EPC Rule 24(a)?', 'options': ["A. Only the licensee's request is necessary.", "B. The applicant's and the licensee's joint request is required.", "C. Only the applicant's request is necessary.", 'D. No request is needed as long as the license is exclusive.']}
# [
#     {
#         "question": "Where an assumed infringer intervenes in opposition appeal proceedings, which of the following fees are payable?",
#         "options": [
#             "A. The opposition fee.",
#             "B. The appeal fee.",
#             "C. The opposition fee and the appeal fee.",
#             "D. The assumed infringer must pay the opposition fee and may choose whether to pay the appeal fee."
#         ]
#     },
#     {
#         "question": "In response to an opposition, the patentee introduces the features of claim 12 as granted into claim 1. Claim 12 was dependent on claim 1 and is phrased as a result to be achieved. The opponent argues that the amendment introduces a lack of clarity. Will the opposition division agree with the opponent?",
#         "options": [
#             "A. Yes. A claim feature may not be phrased as a result to be achieved.",
#             "B. Perhaps. It depends on whether or not the feature phrased as a result to be achieved is considered to be clear.",
#             "C. No. Since the feature was already in the claims set the amendment does not introduce a lack of clarity."
#         ]
#     },
#     {
#         "question": "A European patent was granted to a German company on 4  January 2023. No opposition was filed. Mr Li and Ms Smith were designated as inventors. On 12 October 2023,  the patent proprietor not ices that Ms Smith was erroneously designated as inventor and that Mr Li is the sole inventor.  Which of the following statements is correct?",
#         "options": [
#             "A. Ms Smith will be deleted as inventor if the patent proprietor requests this in writing .",
#             "B. Ms Smith can no longer  be deleted as inventor because no proceedings are pending before the EPO .",
#             "C. The patent proprietor can request that  Ms Smith be deleted as inventor but needs Mr Li 's consent  for this .",
#             "D. Ms Smith can only be deleted as inventor with her consent ."
#         ]
#     }
# ]
# Question 8: {'question': 'According to the guidelines, which of the following amendments is admissible during opposition proceedings without invoking actual grounds for opposition?', 'options': ['A. Adding new claims that improve the disclosure in the patent specification.', 'B. Deleting an independent claim with its dependent claims but not amending other parts of the patent.', 'C. Replacing one independent claim as granted by multiple independent claims each directed to a specific embodiment covered by the independent claim as granted, if such replacement is occasioned by a ground for opposition.', 'D. Simply tidying up and improving the disclosure in the patent specification.']}
# [
#     {
#         "question": "A communication pursuant to Article 94(3) EPC is dated 7 December 2022. In the communication a time limit of four months is set for replying to objections raised by the examining division.  Which of the following statements is not  correct?",
#         "options": [
#             "A.  The communication is deemed to be delivered on 17 December 2022",
#             "B. The time limit for replying to the communication expires on 17 April 2023",
#             "C.  Further processing for replying to the communication can be validly requested on 19 June 2023 at the latest",
#             "D.  An extension of the time limit for filing the reply can be validly requested on 14 April 2023"
#         ]
#     },
#     {
#         "question": "You filed a European patent application which discloses a new amino acid sequence. This sequence is however only used in a single example and is not part of the claims. No sequence listing was filed.  Which of the following statements is correct?",
#         "options": [
#             "A. If you are invited by the EPO to file a sequence listing, you need to file it and pay a late furnishing fee to the EPO",
#             "B. If you are invited by the EPO to file a sequence listing and do not react to this invitation in due time, the application is deemed to be withdrawn",
#             "C. If you are invited by the EPO to file a sequence listing, you need to file it in PDF format",
#             "D. You do not need to file any sequence listing because the amino acid sequence is not claimed"
#         ]
#     },
#     {
#         "question": "Applicants may request processing of their international application under PCT Direct by filing a letter (\"PCT Direct letter\") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?",
#         "options": [
#             "A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing",
#             "B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0",
#             "C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0",
#             "D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document"
#         ]
#     }
# ]
# Question 9: {'question': 'An applicant files a European patent application disclosing nucleotide sequences without providing a sequence listing as required by Rule 30(1) EPC. According to Case Law II, C.7.5 and the Guidelines for Examination in the EPO, what must the applicant do after receiving an invitation from the EPO?', 'options': ['A. The application is automatically withdrawn if no response is given within the time limit', 'B. File a sequence listing and pay any applicable late furnishing fee within the set time limit', 'C. Only provide a written explanation why a sequence listing is not necessary', 'D. Wait for the EPO to incorporate the sequences into the application']}
# [
#     {
#         "question": "You are monitoring the progress of an international application and on reviewing the details of the international search report you realize that you know of relevant prior art that has not been cited in the search report, but which is likely to be novelty-destroying in respect of at least some of the claims. \nYou believe that the international application will enter the national or regional phase in a significant number of countries or regions and it would therefore be time-consuming and costly to file separate observations in respect of each of \nthe national or regional applications. What can you do?",
#         "options": [
#             "A. File observations online using ePCT.",
#             "B. Send a letter with your observations to the receiving office or the International Bureau.",
#             "C. File observations by letter.",
#             "D. It is not possible to file observations on international applications."
#         ]
#     },
#     {
#         "question": "Is the following statement true or false?\n\nWhen proceedings for grant of a European patent application are stayed following the institution of entitlement proceedings, renewal fees which fall due during the period of stay can be paid up to the date of resumption of the proceedings for grant.",
#         "options": [
#             "A. True",
#             "B. False"
#         ]
#     },
#     {
#         "question": "Applicants may request processing of their international application under PCT Direct by filing a letter (\"PCT Direct letter\") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?",
#         "options": [
#             "A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing",
#             "B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0",
#             "C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0",
#             "D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document"
#         ]
#     }
# ]
# Question 10: {'question': 'If an applicant wishes to enter their Euro-PCT application into the European phase, which of the following steps must they take within two months from the international filing date or the date of designation/election as receiving Office?', 'options': ['A. Request the International Bureau to send copies of documents in the files promptly to the EPO and pay the filing fee under Rule 159(1)(c) PCT.', 'B. File a letter with informal comments aimed at overcoming objections raised in the search opinion established by the EPO for the priority application using PCT Direct.', 'C. Send a letter with your observations to the receiving office or the International Bureau regarding relevant prior art not cited in the international search report.', 'D. Pay the renewal fees which fall due during the period of stay following the institution of entitlement proceedings.']}
# [
#     {
#         "question": "On 16  November 2020, you filed a European patent application EP -A, which did not claim priority. Today, 12  October 2023, you receive a communication from the EPO entitled \" Decision to grant a European patent pursuant to Article  97(1) EPC \". This communication state s that the mention of the grant You wish to validate the patent in only two contracting states  to the EPC . Which of the following statements is correct?",
#         "options": [
#             "A. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 16 November 2023.",
#             "B. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 30 November 2023.",
#             "C. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 9 January 2024 at the latest .",
#             "D. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 16 January 2024 at the latest ."
#         ]
#     },
#     {
#         "question": "Company X wishes to file an opposition to European patent EP-B, which was recently granted to its main competitor, company Y. To avoid retaliation, company X would prefer not to file the opposition in its own name. It therefore asks a European patent attorney to file the opposition in her name. Will the EPO accept this?",
#         "options": [
#             "A. Yes",
#             "B. No",
#             "C. Only if the patentee does not object"
#         ]
#     },
#     {
#         "question": "A European patent application EP-A is refused in a decision dated 1 June 2023. Today is 15 July 2023. Is it still possible to file a divisional application from EP-A?",
#         "options": [
#             "A. Yes.",
#             "B. No.",
#             "C. Only if the decision to refuse the application is appealed."
#         ]
#     }
# ]
# Question 11: {'question': 'A European patent application EP-A was filed on 5 May 2023, and a divisional application from this parent application was filed on 15 November 2023. The search report for the divisional application was published in the European Patent Bulletin on 1 February 2024. By when must the designation fee(s) be paid to avoid losing rights according to Rule 36(3) and Rule 36(4) of the EPC?', 'options': ['A. Within six months from 5 May 2023.', 'B. Within six months from 15 November 2023.', 'C. Within six months from 1 February 2024.', 'D. The designation fee is not applicable for divisional applications.']}
# [
#     {
#         "question": "Under the PCT, what is the time limit for filing a request for rectification of an obvious mistake made in the international application?",
#         "options": [
#             "A. 18 months from the earliest priority date",
#             "B. 30 months from the earliest priority date",
#             "C. 22 months from the earliest priority date",
#             "D. 26 months from the earliest priority date"
#         ]
#     },
#     {
#         "question": "Your client filed an international patent application in 2021. In which of the following countries can they (directly) enter the national phase?",
#         "options": [
#             "A. Lithuania",
#             "B. France",
#             "C. Italy",
#             "D. None of the above"
#         ]
#     },
#     {
#         "question": "Company X wishes to file an opposition to European patent EP-B, which was recently granted to its main competitor, company Y. To avoid retaliation, company X would prefer not to file the opposition in its own name. It therefore asks a European patent attorney to file the opposition in her name. Will the EPO accept this?",
#         "options": [
#             "A. Yes",
#             "B. No",
#             "C. Only if the patentee does not object"
#         ]
#     }
# ]
# Question 12: {'question': 'According to Article 26 PCT, how long after entry into the regional phase must the applicant be given the opportunity to correct an international application before the EPO can reject it?', 'options': ['A. Before the application is entered into the regional phase', 'B. Within 16 months from the priority date', 'C. After the application has been rejected for non-compliance with PCT requirements', 'D. At any time during the international phase']}
# [
#     {
#         "question": "The applicant for European patent application EP-1 has granted an exclusive license under the application. The exclusive licensee wishes to make its rights known by recording the license in the European Patent Register. \nIs it possible to record the exclusive license?",
#         "options": [
#             "A. No, exclusive licenses cannot be recorded in the European Patent Register.",
#             "B. Yes, exclusive licenses can be recorded in the European Patent Register at the joint request of both the applicant and the licensee.",
#             "C. Yes, exclusive licenses can be recorded in the European Patent Register, but only by the applicant.",
#             "D. Yes, exclusive licences can be recorded in the European Patent Register by either the applicant or the licensee."
#         ]
#     },
#     {
#         "question": "European patent application EP -X was filed on 1  October 2020, claiming the priority of a Belgian application filed on 16 October 2019. The mention of the grant of European patent EP -X was published on 2  October 2024. The proprietor filed a request for unitary effect and was informed by communication dated 10  October 2024, that unitary effect had been registered for EP -X-C0 on the same date. Which of the following statements is correct?",
#         "options": [
#             "A. A renewal fee still has to be paid by 31 October 2024 in respect of the 5th year for EP -X",
#             "B. A renewal fee is due on 31 October 2024 in respect of the 5th year for EP -X-C0",
#             "C. A renewal fee is due on 31 October 2024 in respect of the 6th year for EP -X-C0",
#             "D. No renewal fee has to be paid on 31 October 2024"
#         ]
#     },
#     {
#         "question": "On 27 October 2022 you filed European patent application EP -A claiming priority from FR -A filed on 29 October 2021. Your intention was that both applications would have the same content. On 3 November 2022, however, you noticed that page 3 of the description and claims 7 -12 are missing in EP -A. The fees have not been paid yet.  Which statement is correct?",
#         "options": [
#             "A. If the EPO notes that page 3 of the description and claims 7 -12 are missing, it will invite you to file these missing parts within a time limit of two months",
#             "B. You may of your own volition file page 3 of the description at any time up to 2 January 2023 without the application being re -dated",
#             "C. If the subject -matter of claims 7 -12 is also present in the description, you may add claims 7 -12 at any time",
#             "D. The best solution is to withdraw EP -A and refile it, claiming priority from FR -A"
#         ]
#     }
# ]
# Question 13: {'question': 'If an exclusive license has been granted under a European patent application, can it be recorded in the European Patent Register?', 'options': ['A. No, because exclusive licenses cannot be registered once the patent is granted.', 'B. Yes, but only if both the applicant and the licensee request it before the grant of the patent.', 'C. Yes, but only after the patent has been granted by a request to the national offices.', 'D. Yes, as long as both the applicant and the licensee so request.']}
# [
#     {
#         "question": "European patent application EP-1 is filed on 10 December 2020, but the inventor is not designated. The designation of the inventor is filed on 25 February 2022. Will the application be refused?",
#         "options": [
#             "A. No. The designation of the inventor was filed in due time.",
#             "B. Yes. The designation of the inventor was not filed in due time."
#         ]
#     },
#     {
#         "question": "You receive an email on 30 October 2023 from a United States patent attorney asking you to enter the regional phase before the EPO in respect of international application PCT-1. The international application was filed at the United States Patent and Trademark Office on 14 March 2022 claiming priority from United States patent application US-1 filed 14 March 2021. Can you effect entry into the EPO regional phase?",
#         "options": [
#             "A. No, the 31-month period has expired.",
#             "B. Yes, provided the priority of US-1 is withdrawn.",
#             "C. Yes, provided use is made of the provisions for further processing."
#         ]
#     },
#     {
#         "question": "Antonia, an applicant living in Argentina and having Argentinian nationality, intends to file a European patent application EP -A and an international patent application PCT- A.  Which of the following statements is correct?",
#         "options": [
#             "A. Antonia can validly file PCT- A with the International Bureau of WIPO",
#             "B. Antonia can validly file PCT -A with the EPO",
#             "C. Antonia can validly file EP -A with the EPO",
#             "D. None of the above"
#         ]
#     }
# ]
# Question 14: {'question': "If an inventor has not been named in the international application by the 31-month time limit from the filing date, what action must the applicant take within two months to comply with the EPO's requirements?", 'options': ['A. Pay the designation fee.', 'B. File a notice correcting the priority claim.', 'C. Submit a declaration of inventorship.', 'D. Request further processing according to Rule 135.']}
# [
#     {
#         "question": "Which of the following statements about filing third- party observations is correct?",
#         "options": [
#             "A. The person that filed third- party observations will be a party to the proceedings before the EPO, and the applicant is obliged to respond to third- party observations",
#             "B. Third -party observations must be filed in writing and may not be filed anonymously",
#             "C. Third -party observations are considered by the examining division only if they include a statement of the grounds on which they are based, and an official fee is paid",
#             "D. Third -party observations can be filed after the publication of a European patent application and must be filed in an official language of the EPO"
#         ]
#     },
#     {
#         "question": "Today is 28 March 2023. Following national proceedings for entitlement of European patent application EP-1, the successful party has elected to file a new application under Article 61(1)(b) EPC. EP-1 was filed on 12 April 2019 and the new application, EP-2, was filed on 10 January 2023.  What is the last day for paying the first renewal fee that is payable for the new application, without surcharge (i.e. not including the fees for past renewals)?",
#         "options": [
#             "A. 31 January 2023.",
#             "B. 2 May 2023."
#         ]
#     },
#     {
#         "question": "You receive an email on 30 October 2023 from a United States patent attorney asking you to enter the regional phase before the EPO in respect of international application PCT-1. The international application was filed at the United States Patent and Trademark Office on 14 March 2022 claiming priority from United States patent application US-1 filed 14 March 2021. Can you effect entry into the EPO regional phase?",
#         "options": [
#             "A. No, the 31-month period has expired.",
#             "B. Yes, provided the priority of US-1 is withdrawn.",
#             "C. Yes, provided use is made of the provisions for further processing."
#         ]
#     }
# ]
# Question 15: {'question': 'According to the guidelines, which of the following statements about third-party observations is correct?', 'options': ['A. Third-party observations must be filed by an official language of the EPO and can only be made available for file inspection if proceedings become pending again.', 'B. Any third party may present, in written form, observations concerning the patentability of the invention to which the application or patent relates without any fees or deadlines.', 'C. The examining division will make every effort to issue a next office action within three months of receipt of all third-party observations regardless of their content and mode of filing.', 'D. Third-party observations are not considered by the EPO unless they have been filed non-anonymously, substantiated, and the applicant has replied.']}
# [
#     {
#         "question": "Mr Linguist filed a European patent application in Dutch and used English as language of the proceedings. When requesting unitary effect on 10 October 2024, Mr Linguist must provide a translation of the specification. Mr Linguist would like to obtain immediate registration of the unitary effect. Which of the following statements is correct?",
#         "options": [
#             "A. Mr Linguist must provide a translation of the specification into Dutch",
#             "B. Mr Linguist must provide a translation of the specification into an official language of any of the 18 states to which the unitary effect extends",
#             "C. Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA",
#             "D. Mr Linguist may provide a translation of the specification into Spanish"
#         ]
#     },
#     {
#         "question": "The applicant received a communication pursuant to Article 90(3) EPC and Rule  60 EPC, requesting them to file a designation of inventor but missed the time limit for filing a response. After expiry of the time limit, the Receiving Section issued a decision to refuse the European patent application, dated 10  October 2024. What can the applicant do to remedy the situation?",
#         "options": [
#             "A. File a notice of appeal against the decision within four months of notification of the decision",
#             "B. File a request for further processing within two months of notification of the decision",
#             "C. File, within two months of notification of the decision, a request for re-establishment of rights in respect of the time limit for filing the designation of inventor",
#             "D. A, B and C are correct"
#         ]
#     },
#     {
# ...
#             "D. Date of the start of substantive examination"
#         ]
#     },
#     {
#         "question": "The opposition division revoked European patent EP -B1. The patent proprietor filed an appeal  in time . The b oard of appeal forwarded a copy of the appeal to the o pponent/ respondent with a communication dated 1 June 2023 giving it an opportunity to file comments within a period of four  months.  The opponent/respondent files comments today, 12 October 2023. What further action has to be taken ?",
#         "options": [
#             "A. The opponent/ respondent needs  to request an extension of the period for comment.",
#             "B. The opponent/respondent needs to pay a fee for further processing.",
#             "C. The opponent/respondent needs to file a substantiated request for reestablishment of rights and pay the associated fee.",
#             "D. None of the above."
#         ]
#     },
#     {
#         "question": "Company C files a European patent application for an invention which has been displayed at an officially recognised international exhibition. The exhibition closes two weeks after the invention was first displayed. Rule 25(d) EPC states that a suitable certificate must be filed within four months of the filing of the European patent application. Three months after filing the application, the applicant approaches the authority responsible for the protection of industrial property at the exhibition and obtains a certificate stating the information required according to Rule 25 EPC. The certificate is filed within the four-month period together with the authenticated identification of the invention. Will the certificate be accepted by the EPO?",
#         "options": [
#             "A. No, the certificate was not issued at the exhibition.",
#             "B. Yes, the certificate was filed within the specified four-month period."
#         ]
#     }
# ]
# Question 95: {'question': 'If an entitled person files a new European patent application under Article 61, paragraph 1(b), how long does the applicant have to pay the filing fee and search fee after filing the new application?', 'options': ['A. Within one month of filing the new application', 'B. Within six months of filing the new application', 'C. Within two months of filing the new application', 'D. There is no specific time limit mentioned']}
# [
#     {
#         "question": "Mr Van Holland is a Dutch citizen resident in the Netherlands. He filed a European patent application EP -parent in Dutch, together with  a translation into English. Whil e EP-parent was pending, Mr Van Holland filed a divisional application EP -div in Dutch and requested examination in Dutch. He paid all fees due for EP -div. He has not filed an English translation of EP -div. The Receiving Section has now issued a noting of l oss of rights.  Which of the following statements is correct?",
#         "options": [
#             "A. The deficiency cannot be remedied.",
#             "B. Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication  under Rule 112(1) EPC .",
#             "C. Mr Van Holland needs to file an English translation of EP -div together with a request for f urther processing.",
#             "D. Mr Van Holland needs to file an English translation of EP -div together with a request for re- establishment of rights."
#         ]
#     },
#     {
#         "question": "Entry into the European phase of an international application can be effected early provided an express request for early processing is made at the time the requirements of Rule 159(1) EPC are complied with. International application PCT-1 was filed 28 months ago with no claim to priority. The application consists of 20 pages, including 16 claims. The international search was carried out by the EPO acting as ISA and the international search report was published with the international application. Which of the following fees must be paid in order to effect early entry into the European phase?",
#         "options": [
#             "A. The filing fee.",
#             "B. The filing fee, the examination fee and the designation fee.",
#             "C. The filing fee, the examination fee, the designation fee and the renewal fee.",
#             "D. The filing fee, the claims fee, the examination fee, the designation fee and the renewal fee."
#         ]
#     },
#     {
#         "question": "International patent application PCT-1 is filed on 16 June 2019 without any claim to priority. Steps are taken to enter the EPO regional phase on 26 December 2021. When should the renewal fee in respect of the third year be paid (without surcharge)?",
#         "options": [
#             "A. 30 June 2021",
#             "B. 26 December 2021",
#             "C. 2 January 2022",
#             "D. 17 January 2022"
#         ]
#     }
# ]
# Question 96: {'question': 'An international PCT application, PCT-App, was filed in Chinese 30 months ago without claiming any priority. The applicant wishes to enter the European phase early by complying with Rule 159(1) EPC requirements. Which of the following steps must the applicant take immediately after filing the request for early processing?', 'options': ['A. Pay only the filing fee.', 'B. Submit a translation of PCT-App into an EPO official language, if not already published in one of them, and pay the filing fee.', 'C. Pay the examination fee, the designation fee, and file the request for examination.', 'D. File the request for early processing, submit a translation of PCT-App into English or another official language (if necessary), and pay the filing fee.']}
# [
#     {
#         "question": "Last week Greta validly filed the international patent application PCT -G with the German Patent and Trade mark Office ( DPMA ) and appointed Hassan to represent her. Hassan is entitled to act before the DPMA  but he is not a European patent attorney. Greta and Hassan are resident in Germany.  Which of the following statements is not correct?",
#         "options": [
#             "A. Hassan can represent Greta before the EPO acting as the International Searching Authority for PCT -G.",
#             "B. In order for Hassan to be able to act before the EPO acting as the International Searching Authority , he needs to submit a power of attorney signed by Greta.",
#             "C. According to the provisions of the PCT, it is mandatory that the d emand for international preliminary examination is signed by Greta or Hassan.",
#             "D. According to the provisions of the PCT, an international application can only be withdrawn by the applicant or an agent appointed by a power of attorney."
#         ]
#     },
#     {
#         "question": "On 27 October 2022 you filed European patent application EP -A claiming priority from FR -A filed on 29 October 2021. Your intention was that both applications would have the same content. On 3 November 2022, however, you noticed that page 3 of the description and claims 7 -12 are missing in EP -A. The fees have not been paid yet.  Which statement is correct?",
#         "options": [
#             "A. If the EPO notes that page 3 of the description and claims 7 -12 are missing, it will invite you to file these missing parts within a time limit of two months",
#             "B. You may of your own volition file page 3 of the description at any time up to 2 January 2023 without the application being re -dated",
#             "C. If the subject -matter of claims 7 -12 is also present in the description, you may add claims 7 -12 at any time",
#             "D. The best solution is to withdraw EP -A and refile it, claiming priority from FR -A"
#         ]
#     },
#     {
#         "question": "Firm A owns a European patent, EP . Firm B filed an opposition against EP, requesting its revocation. Firm B argued that the subject -matter of the granted claims was not new in view of document D1. During the opposition proceedings, firm C filed observations under Art.  115 EPC, arguing that the subject -matter of the granted claims was not new in view of document D2. Firm A requested maintenance of the patent as granted, or maintenance in amended Which of the following statements is correct?",
#         "options": [
#             "A. At the end of the opposition proceedings, the opposition division decided to revoke the patent. Firm B is entitled to file an appeal against the opposition division's decision.",
#             "B. At the end of the opposition proceedings, the opposition division decided to and firm B are entitled to file an appeal against the opposition division's decision.",
#             "C. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm C is entitled to file an appeal against the opposition division's decision.",
#             "D. During the opposition proceedings, firm B withdrew its opposition. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm B is entitled to file an appeal against the opposition division's decision."
#         ]
#     }
# ]
# Question 97: {'question': 'On 15 March 2023, you filed an international patent application PCT-X claiming priority from US-A filed on 15 March 2022. The international preliminary examination was requested and conducted by the International Bureau. Subsequently, you wish to enter the national phase in Japan and have appointed a Japanese patent attorney, Ms. Tanaka, as your representative. According to the PCT rules, which of the following statements is correct?', 'options': ['A. You must file the national phase entry form with the Japanese Patent Office (JPO) before 15 September 2023.', 'B. Ms. Tanaka does not need to submit a power of attorney from you, as she can represent you in the Japanese national phase proceedings.', 'C. The international preliminary report will be forwarded to JPO and can be used during the Japanese examination process.', 'D. You are required to pay the priority claim fee for the Japanese national application within 2 months from the filing date of PCT-X.']}
# [
#     {
#         "question": "Applicants may request processing of their international application under PCT Direct by filing a letter (\"PCT Direct letter\") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?",
#         "options": [
#             "A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing",
#             "B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0",
#             "C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0",
#             "D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document"
#         ]
#     },
#     {
#         "question": "Company X wishes to file an opposition to European patent EP-B, which was recently granted to its main competitor, company Y. To avoid retaliation, company X would prefer not to file the opposition in its own name. It therefore asks a European patent attorney to file the opposition in her name. Will the EPO accept this?",
#         "options": [
#             "A. Yes",
#             "B. No",
#             "C. Only if the patentee does not object"
#         ]
#     },
#     {
#         "question": "The applicants for international application PCT-1 are based in Japan. Having regard to the provisions of the EPC and the PCT, can the applicants themselves comply with the requirements of Rule 159(1) EPC?",
#         "options": [
#             "A. No, a professional representative must be appointed.",
#             "B. No, a professional representative or appropriate legal representative must be appointed.",
#             "C. Yes, the applicants can themselves comply with the requirements of Rule 159(1) EPC."
#         ]
#     }
# ]
# Question 98: {'question': 'If an international application filed under the PCT has not been accorded a filing date or deemed withdrawn, which of the following steps must be taken to allow the EPO to review and potentially proceed with the European phase under Art. 25 PCT?', 'options': ['A. The applicant should request the International Bureau to send copies of documents in the files promptly to the EPO as designated Office.', 'B. The applicant must pay a supplementary filing fee, but no translation is required.', 'C. The application can proceed directly without any additional steps being taken by the applicant.', 'D. Both A and B are necessary steps.']}
# [
#     {
#         "question": "The applicants for international application PCT-1 are based in Japan. Having regard to the provisions of the EPC and the PCT, can the applicants themselves comply with the requirements of Rule 159(1) EPC?",
#         "options": [
#             "A. No, a professional representative must be appointed.",
#             "B. No, a professional representative or appropriate legal representative must be appointed.",
#             "C. Yes, the applicants can themselves comply with the requirements of Rule 159(1) EPC."
#         ]
#     },
#     {
#         "question": "During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?",
#         "options": [
#             "A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.",
#             "B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.",
#             "C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.",
#             "D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months."
#         ]
#     },
#     {
#         "question": "The applicant for international application PCT-1 wishes to prevent publication of the application. What is the last day for withdrawing the application and \npreventing publication?",
#         "options": [
#             "A. The 15th day prior to the date of publication.",
#             "B. Any time prior to the date of publication.",
#             "C. The end of the day five weeks before the end of the 18th month from the priority or filing date as appropriate."
#         ]
#     }
# ]
# Question 99: {'question': 'If the interlocutory decision of the opposition division under Article 101(3)(a) EPC or Article 106(2) EPC has been based on documents not complying with Rule 50(1), what is required from the patent proprietor?', 'options': ['A. To file translations of any amended claims in the two official languages of the EPO other than the language of the proceedings.', 'B. To pay, within three months, the fee for publishing a new specification of the European patent.', 'C. To file a formally compliant version of the entire description.', 'D. To file a formally compliant version of the paragraph upon which the interlocutory decision was based.']}
