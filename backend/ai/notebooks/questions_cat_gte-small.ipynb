# %%
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np 
import json
# Charger le modèle et le tokenizer
MODEL_NAME = "thenlper/gte-small"

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def get_embeddings(text, method="cls"):
    """Extrait l'embedding d'une phrase selon la méthode spécifiée."""
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    with torch.no_grad():
        outputs = model(**inputs)
    
    last_hidden_state = outputs.last_hidden_state  # (batch_size, seq_len, hidden_dim)
    
    if method == "cls":
        return last_hidden_state[:, 0, :]  # Embedding du token [CLS]
    elif method == "mean":
        attention_mask = inputs["attention_mask"].unsqueeze(-1)
        embeddings = (last_hidden_state * attention_mask).sum(dim=1) / attention_mask.sum(dim=1)

        embeddings = torch.nn.functional.normalize(embeddings, p=2, dim=1)
        return embeddings  # Moyenne des embeddings des tokens
    else:
        raise ValueError("Méthode non reconnue : choisir 'cls' ou 'mean'.")

# %%
# Charger le JSON avec un encodage spécifique
with open('../outputs/categories.json', 'r', encoding='utf-8-sig') as f:
    data = json.load(f)

# Créer un dictionnaire pour stocker les embeddings
embeddings_dict = {}

# Extraire les embeddings pour chaque catégorie
for category, subcategories in data.items():
    for subcategory, details in subcategories.items():
        text = f"{category} {subcategory} {details['Scope']} {details['sentences']}"
        embedding = get_embeddings(text, method="mean")  # Ou "cls" selon ce que tu préfères
        embeddings_dict[f"{category}_{subcategory}"] = embedding.numpy()

# %%
# Sauvegarder les embeddings dans un fichier .npy
np.save('../outputs/category_gte-Qwen2-1.5B-instruct.npy', embeddings_dict)

# %%
category_embeddings = np.load('../outputs/category_gte-Qwen2-1.5B-instruct.npy', allow_pickle=True).item()

# %%
from sklearn.metrics.pairwise import cosine_similarity

def classify_question_top_5(question, category_embeddings, method="mean"):
    """Classifie la question et retourne les 5 catégories les plus similaires."""
    # Extraire l'embedding de la question
    question_embedding = get_embeddings(question, method=method)
    
    # Comparer la question avec chaque catégorie
    similarities = {}
    for category, category_embedding in category_embeddings.items():
        similarity = cosine_similarity(question_embedding.numpy().reshape(1, -1), category_embedding.reshape(1, -1))[0][0]
        similarities[category.split("_")[-1]] = similarity
    
    # Trier les catégories par similarité décroissante et récupérer les 5 meilleures
    sorted_categories = sorted(similarities.items(), key=lambda x: x[1], reverse=True)[:5]
    
    return sorted_categories

# %%
with open('../outputs/test_categories.json', 'r', encoding='utf-8') as f:
    test_categoies = json.load(f)

with open('../outputs/2022_PreEx_open.json', 'r', encoding='utf-8') as f:
    PreEx_open = json.load(f)

score_1 = 0
score_other = 0
failed = 0  # Corrected typo: faild -> failed

global_score_1 = 0
global_score_other = 0
global_failed = 0

for question_id, question_text in PreEx_open.items():
    subcategory = test_categoies.get("2022_PreEx_open", {}).get(f"{question_id}", {}).get("Subcategory")

    if subcategory is None:
        print(f"Warning: Subcategory not found for question ID: {question_id}")
        failed +=1
        continue

    top_5_categories = classify_question_top_5(question_text, category_embeddings, method="mean")

    # Extract the category names from the tuples
    top_5_category_names = [item[0] for item in top_5_categories]
    print(subcategory)
    print(top_5_category_names)
    if top_5_category_names[0] == subcategory:
        score_1 += 1
    elif subcategory in top_5_category_names[1:5]:
        score_other += 1
    else:
        failed += 1

    print(score_1, score_other, failed)

print(f"Score 1: {score_1}")
print(f"Score Other: {score_other}")
print(f"Failed: {failed}")
global_score_1 += score_1
global_score_other += score_other
global_failed += failed
# Out:
# Entitlement disputes (article 61 EPC)
# ['Entitlement disputes (article 61 EPC)', 'Grounds for opposition (article 100 epc)', 'Opposition procedure and admissibility', 'Claim amendments and article 123 epc', 'Re-establishment of rights (article 122 epc)']
# 1 0 0
# Opposition procedure and admissibility
# ['Grounds for opposition (article 100 epc)', 'Subject-matter and scope', 'Claim amendments and article 123 epc', 'Opposition procedure and admissibility', 'Novelty analysis']
# 1 1 0
# Appeal proceedings
# ['Appeal proceedings', 'Examination procedure and communications', 'Further processing (rule 135 epc)', 'Opposition procedure and admissibility', 'Re-establishment of rights (article 122 epc)']
# 2 1 0
# Transfers and assignments
# ['Entitlement disputes (article 61 EPC)', 'Transfers and assignments', 'International filing and search', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Preliminary examination and amendments']
# 2 2 0
# Language of filing and procedural language
# ['Language of filing and procedural language', 'Minimum requirements for a filing date', 'Substantive requirements for priority', 'International filing and search', 'Subject-matter and scope']
# 3 2 0
# Filing requirements
# ['Filing requirements', 'Language of filing and procedural language', 'Subject-matter and scope', 'Preliminary examination and amendments', 'Minimum requirements for a filing date']
# 4 2 0
# Special forms of claims (e.g., medical use)
# ['Special forms of claims (e.g., medical use)', 'Added subject-matter in biotech claims', 'Subject-matter and scope', 'Novelty analysis', 'Claim amendments and article 123 epc']
# 5 2 0
# International filing and search
# ['International filing and search', 'Minimum requirements for a filing date', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Formality examination', 'Language of filing and procedural language']
# 6 2 0
# Formality examination
# ['Minimum requirements for a filing date', 'International filing and search', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Preliminary examination and amendments', 'Language of filing and procedural language']
# 6 2 1
# Opposition procedure and admissibility
# ['Claim amendments and article 123 epc', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Grounds for opposition (article 100 epc)', 'Subject-matter and scope', 'Examination procedure and communications']
# 6 2 2
# Score 1: 6
# Score Other: 2
# Failed: 2

# %%
with open('../outputs/2021_PreEx_open.json', 'r', encoding='utf-8') as f:
    PreEx_open = json.load(f)

score_1 = 0
score_other = 0
failed = 0  # Corrected typo: faild -> failed

for question_id, question_text in PreEx_open.items():
    subcategory = test_categoies.get("2021_PreEx_open", {}).get(f"{question_id}", {}).get("Subcategory")

    if subcategory is None:
        print(f"Warning: Subcategory not found for question ID: {question_id}")
        failed +=1
        continue

    top_5_categories = classify_question_top_5(question_text, category_embeddings, method="mean")

    # Extract the category names from the tuples
    top_5_category_names = [item[0] for item in top_5_categories]
    print(subcategory)
    print(top_5_category_names)
    if top_5_category_names[0] == subcategory:
        score_1 += 1
    elif subcategory in top_5_category_names[1:5]:
        score_other += 1
    else:
        failed += 1

    print(score_1, score_other, failed)


print(f"Score 1: {score_1}")
print(f"Score Other: {score_other}")
print(f"Failed: {failed}")
global_score_1 += score_1
global_score_other += score_other
global_failed += failed
# Out:
# Fee deadlines and late payment consequences
# ['Grant stage (rule 71(3) epc) and post-grant publication', 'Language of filing and procedural language', 'Preliminary examination and amendments', 'International filing and search', 'Minimum requirements for a filing date']
# 0 0 1
# Time limits and restoration
# ['Substantive requirements for priority', 'Preliminary examination and amendments', 'Minimum requirements for a filing date', 'International filing and search', 'Filing requirements']
# 0 0 2
# Filing requirements
# ['Subject-matter and scope', 'Preliminary examination and amendments', 'Filing requirements', 'Claim amendments and article 123 epc', 'Minimum requirements for a filing date']
# 0 1 2
# International filing and search
# ['Preliminary examination and amendments', 'International filing and search', 'Minimum requirements for a filing date', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Claim amendments and article 123 epc']
# 0 2 2
# Opposition procedure and admissibility
# ['Opposition procedure and admissibility', 'Grounds for opposition (article 100 epc)', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Claim amendments and article 123 epc', 'Entitlement disputes (article 61 EPC)']
# 1 2 2
# Examination procedure and communications
# ['Grounds for opposition (article 100 epc)', 'Subject-matter and scope', 'Claim amendments and article 123 epc', 'Minimum requirements for a filing date', 'Unity of invention']
# 1 2 3
# Examination procedure and communications
# ['Examination procedure and communications', 'Claim amendments and article 123 epc', 'Grounds for opposition (article 100 epc)', 'Opposition procedure and admissibility', 'Appeal proceedings']
# 2 2 3
# Appeal proceedings
# ['Grounds for opposition (article 100 epc)', 'Opposition procedure and admissibility', 'Appeal proceedings', 'Claim amendments and article 123 epc', 'Subject-matter and scope']
# 2 3 3
# Language of filing and procedural language
# ['Language of filing and procedural language', 'Translation requirements on grant or other stages', 'Examination procedure and communications', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Preliminary examination and amendments']
# 3 3 3
# International filing and search
# ['International filing and search', 'Preliminary examination and amendments', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Subject-matter and scope', 'Unity in pct applications']
# 4 3 3
# Score 1: 4
# Score Other: 3
# Failed: 3

# %%
with open('../outputs/OEB_SUP_mcq.json', 'r', encoding='utf-8') as f:
    PreEx_open = json.load(f)

score_1 = 0
score_other = 0
failed = 0  # Corrected typo: faild -> failed

for question_id, question in PreEx_open.items():
    subcategory = test_categoies.get("OEB_SUP_mcq", {}).get(f"{question_id}", {}).get("Subcategory")

    if subcategory is None:
        print(f"Warning: Subcategory not found for question ID: {question_id}")
        failed +=1
        continue
    question_text = f"{question.get("question", {})} {question.get("options", {})}" 
    top_5_categories = classify_question_top_5(question_text, category_embeddings, method="mean")

    # Extract the category names from the tuples
    top_5_category_names = [item[0] for item in top_5_categories]
    print(subcategory)
    print(top_5_category_names)
    if top_5_category_names[0] == subcategory:
        score_1 += 1
    elif subcategory in top_5_category_names[1:5]:
        score_other += 1
    else:
        failed += 1

    print(score_1, score_other, failed)


print(f"Score 1: {score_1}")
print(f"Score Other: {score_other}")
print(f"Failed: {failed}")
global_score_1 += score_1
global_score_other += score_other
global_failed += failed


print(f"Score 1: {global_score_1}")
print(f"Score Other: {global_score_other}")
print(f"Failed: {global_failed}")
# Out:
# Effects of language on costs and procedural rights
# ['Grant stage (rule 71(3) epc) and post-grant publication', 'Preliminary examination and amendments', 'Formality examination', 'Examination procedure and communications', 'Claim amendments and article 123 epc']
# 0 0 1
# Loss of rights and remedies
# ['Entitlement disputes (article 61 EPC)', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Re-establishment of rights (article 122 epc)', 'Further processing (rule 135 epc)', 'Procedural consequences']
# 0 0 2
# Loss of rights and remedies
# ['Grant stage (rule 71(3) epc) and post-grant publication', 'Claim amendments and article 123 epc', 'Re-establishment of rights (article 122 epc)', 'Preliminary examination and amendments', 'Further processing (rule 135 epc)']
# 0 0 3
# International filing and search
# ['Grant stage (rule 71(3) epc) and post-grant publication', 'Filing requirements', 'Claim amendments and article 123 epc', 'Strategies for overcoming lack of unity', 'Minimum requirements for a filing date']
# 0 0 4
# Transfers and assignments
# ['Transfers and assignments', 'Entitlement disputes (article 61 EPC)', 'Subject-matter and scope', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Claim amendments and article 123 epc']
# 1 0 4
# Substantive requirements for priority
# ['Grant stage (rule 71(3) epc) and post-grant publication', 'Minimum requirements for a filing date', 'Re-establishment of rights (article 122 epc)', 'Entitlement disputes (article 61 EPC)', 'Preliminary examination and amendments']
# 1 0 5
# Payment mechanisms
# ['Fee deadlines and late payment consequences', 'Payment mechanisms', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Further processing (rule 135 epc)', 'Procedural consequences']
# 1 1 5
# Filing requirements
# ['Preliminary examination and amendments', 'Claim amendments and article 123 epc', 'Grounds for opposition (article 100 epc)', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Entitlement disputes (article 61 EPC)']
# 1 1 6
# Fee deadlines and late payment consequences
# ['Fee deadlines and late payment consequences', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Formality examination', 'Types and calculation of fees', 'Minimum requirements for a filing date']
# 2 1 6
# Fee deadlines and late payment consequences
# ['Grant stage (rule 71(3) epc) and post-grant publication', 'Preliminary examination and amendments', 'Claim amendments and article 123 epc', 'Entitlement disputes (article 61 EPC)', 'International filing and search']
# 2 1 7
# Time limits and restoration
# ['Minimum requirements for a filing date', 'Substantive requirements for priority', 'Preliminary examination and amendments', 'International filing and search', 'Time limits and restoration']
# 2 2 7
# Time limits and restoration
# ['Minimum requirements for a filing date', 'Substantive requirements for priority', 'Time limits and restoration', 'Re-establishment of rights (article 122 epc)', 'Further processing (rule 135 epc)']
# 2 3 7
# Formality examination
# ['Minimum requirements for a filing date', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Substantive requirements for priority', 'International filing and search', 'Claim amendments and article 123 epc']
# 2 3 8
# Opposition procedure and admissibility
# ['Claim amendments and article 123 epc', 'Inventive step analysis', 'Strategies for overcoming lack of unity', 'Subject-matter and scope', 'Novelty analysis']
# 2 3 9
# Opposition procedure and admissibility
# ['Entitlement disputes (article 61 EPC)', 'Re-establishment of rights (article 122 epc)', 'Opposition procedure and admissibility', 'Grounds for opposition (article 100 epc)', 'Claim amendments and article 123 epc']
# 2 4 9
# Opposition procedure and admissibility
# ['Claim amendments and article 123 epc', 'Grounds for opposition (article 100 epc)', 'Subject-matter and scope', 'Strategies for overcoming lack of unity', 'Opposition procedure and admissibility']
# 2 5 9
# Appeal proceedings
# ['Opposition procedure and admissibility', 'Appeal proceedings', 'Formality examination', 'Grounds for opposition (article 100 epc)', 'Entitlement disputes (article 61 EPC)']
# 2 6 9
# Appeal proceedings
# ['Opposition procedure and admissibility', 'Grounds for opposition (article 100 epc)', 'Appeal proceedings', 'Claim amendments and article 123 epc', 'Entitlement disputes (article 61 EPC)']
# 2 7 9
# Opposition procedure and admissibility
# ['Entitlement disputes (article 61 EPC)', 'Re-establishment of rights (article 122 epc)', 'Grounds for opposition (article 100 epc)', 'Claim amendments and article 123 epc', 'Opposition procedure and admissibility']
# 2 8 9
# Transfers and assignments
# ['Transfers and assignments', 'Entitlement disputes (article 61 EPC)', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Subject-matter and scope', 'International filing and search']
# 3 8 9
# Examination procedure and communications
# ['Grant stage (rule 71(3) epc) and post-grant publication', 'Preliminary examination and amendments', 'Further processing (rule 135 epc)', 'Examination procedure and communications', 'International filing and search']
# 3 9 9
# Opposition procedure and admissibility
# ['Claim amendments and article 123 epc', 'Grounds for opposition (article 100 epc)', 'Opposition procedure and admissibility', 'Examination procedure and communications', 'Preliminary examination and amendments']
# 3 10 9
# Filing requirements
# ['Grant stage (rule 71(3) epc) and post-grant publication', 'Examination procedure and communications', 'Time limits and restoration', 'Filing requirements', 'Claim amendments and article 123 epc']
# 3 11 9
# Effects of language on costs and procedural rights
# ['Grant stage (rule 71(3) epc) and post-grant publication', 'Examination procedure and communications', 'Types and calculation of fees', 'Formality examination', 'Claim amendments and article 123 epc']
# 3 11 10
# Claim amendments and article 123 epc
# ['Subject-matter and scope', 'Claim amendments and article 123 epc', 'Added subject-matter in biotech claims', 'Special forms of claims (e.g., medical use)', 'Grounds for opposition (article 100 epc)']
# 3 12 10
# Claim amendments and article 123 epc
# ['Grant stage (rule 71(3) epc) and post-grant publication', 'Examination procedure and communications', 'Further processing (rule 135 epc)', 'Claim amendments and article 123 epc', 'Preliminary examination and amendments']
# 3 13 10
# Claim amendments and article 123 epc
# ['Claim amendments and article 123 epc', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Re-establishment of rights (article 122 epc)', 'Grounds for opposition (article 100 epc)', 'Examination procedure and communications']
# 4 13 10
# Opposition procedure and admissibility
# ['Opposition procedure and admissibility', 'Entitlement disputes (article 61 EPC)', 'Grounds for opposition (article 100 epc)', 'Filing requirements', 'Preliminary examination and amendments']
# 5 13 10
# Opposition procedure and admissibility
# ['Claim amendments and article 123 epc', 'Subject-matter and scope', 'Special forms of claims (e.g., medical use)', 'Grounds for opposition (article 100 epc)', 'Inventive step analysis']
# 5 13 11
# Types and calculation of fees
# ['Examination procedure and communications', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Further processing (rule 135 epc)', 'Entitlement disputes (article 61 EPC)', 'Preliminary examination and amendments']
# 5 13 12
# International filing and search
# ['Fee deadlines and late payment consequences', 'Formality examination', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Types and calculation of fees', 'Minimum requirements for a filing date']
# 5 13 13
# International filing and search
# ['International filing and search', 'Language of filing and procedural language', 'Filing methods and locations', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Filing requirements']
# 6 13 13
# International filing and search
# ['Grant stage (rule 71(3) epc) and post-grant publication', 'International filing and search', 'Preliminary examination and amendments', 'Minimum requirements for a filing date', 'Claim amendments and article 123 epc']
# 6 14 13
# International filing and search
# ['International filing and search', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Preliminary examination and amendments', 'Minimum requirements for a filing date', 'Further processing (rule 135 epc)']
# 7 14 13
# International filing and search
# ['International filing and search', 'Minimum requirements for a filing date', 'Strategies for overcoming lack of unity', 'Subject-matter and scope', 'Preliminary examination and amendments']
# 8 14 13
# International filing and search
# ['Grant stage (rule 71(3) epc) and post-grant publication', 'Further processing (rule 135 epc)', 'Examination procedure and communications', 'Claim amendments and article 123 epc', 'Preliminary examination and amendments']
# 8 14 14
# Time limits and restoration
# ['Substantive requirements for priority', 'Time limits and restoration', 'Re-establishment of rights (article 122 epc)', 'Preliminary examination and amendments', 'Claim amendments and article 123 epc']
# 8 15 14
# European phase entry and requirements
# ['International filing and search', 'Preliminary examination and amendments', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Minimum requirements for a filing date', 'Filing requirements']
# 8 15 15
# Fee deadlines and late payment consequences
# ['Grant stage (rule 71(3) epc) and post-grant publication', 'Preliminary examination and amendments', 'International filing and search', 'Claim amendments and article 123 epc', 'Time limits and restoration']
# 8 15 16
# Novelty analysis
# ['Preliminary examination and amendments', 'International filing and search', 'Claim amendments and article 123 epc', 'Subject-matter and scope', 'European phase entry and requirements']
# 8 15 17
# Unity in pct applications
# ['Preliminary examination and amendments', 'International filing and search', 'Subject-matter and scope', 'Claim amendments and article 123 epc', 'Strategies for overcoming lack of unity']
# 8 15 18
# Examination procedure and communications
# ['Examination procedure and communications', 'Appeal proceedings', 'Further processing (rule 135 epc)', 'Opposition procedure and admissibility', 'Grant stage (rule 71(3) epc) and post-grant publication']
# 9 15 18
# European phase entry and requirements
# ['International filing and search', 'Preliminary examination and amendments', 'Grant stage (rule 71(3) epc) and post-grant publication', 'European phase entry and requirements', 'Minimum requirements for a filing date']
# 9 16 18
# Time limits and restoration
# ['Time limits and restoration', 'Preliminary examination and amendments', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Re-establishment of rights (article 122 epc)', 'International filing and search']
# 10 16 18
# Time limits and restoration
# ['Language of filing and procedural language', 'Preliminary examination and amendments', 'International filing and search', 'Translation requirements on grant or other stages', 'European phase entry and requirements']
# 10 16 19
# European phase entry and requirements
# ['Preliminary examination and amendments', 'Grant stage (rule 71(3) epc) and post-grant publication', 'Language of filing and procedural language', 'International filing and search', 'Further processing (rule 135 epc)']
# 10 16 20
# Formality examination
# ['Preliminary examination and amendments', 'Translation requirements on grant or other stages', 'Grant stage (rule 71(3) epc) and post-grant publication', 'International filing and search', 'Subject-matter and scope']
# 10 16 21
# Multiple priorities and partial priority
# ['Substantive requirements for priority', 'Subject-matter and scope', 'Multiple priorities and partial priority', 'Claim amendments and article 123 epc', 'Strategies for overcoming lack of unity']
# 10 17 21
# Score 1: 10
# Score Other: 17
# Failed: 21
# Score 1: 20
# Score Other: 22
# Failed: 26
