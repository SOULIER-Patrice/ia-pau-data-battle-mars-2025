# %% [markdown]
# # Road to 100% Accuracy

# %% [markdown]
# ## Imports

# %%
import sys
import os
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_community.vectorstores.utils import DistanceStrategy
import torch
from transformers import AutoTokenizer, AutoModel
from langchain.docstore.document import Document as LangchainDocument
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_community.vectorstores.utils import DistanceStrategy
import pandas as pd
import numpy as np 
from tqdm import tqdm
from typing import List
import json
import glob
import ollama
from ollama import chat
import re

# os.chdir(os.path.abspath('../../'))
# sys.path.append(os.getcwd())
# print("Working Directory:", os.getcwd())
# # from ai.src.create_embeddings import split_documents, load_exam_solutions, load_csv
# from ai.src.embedding_loader import load_rag_embeddings
# data_dir = os.path.abspath('ai/outputs/')
# output_dir = os.path.abspath('ai/embeddings/')

data_dir = '../outputs'
output_dir = '../embeddings'

# %% [markdown]
# ## Functions imported

# %% [markdown]
# ### create_embeddings.py

# %%
markdown_separators = [
"\n\n",
"\n",
".",
" ",
"",
]

def load_csv(data_dir):
    # Load all CSV
    csv_files = glob.glob(f"{data_dir}/*.csv")
    df_list = [pd.read_csv(file) for file in csv_files]
    df = pd.concat(df_list, ignore_index=True) if df_list else pd.DataFrame(columns=["ref", "url", "content"])

    # List of documents for LangChain
    return  [
        LangchainDocument(page_content=row["content"], metadata={"ref": row["ref"], "url": row["url"]})
        for _, row in tqdm(df.iterrows(), total=len(df))
    ]


def load_exam_solutions(data_dir):
    # Load JSON with "solution" in their name
    json_files = glob.glob(f"{data_dir}/*solution*.json")

    json_documents = []
    for file in json_files:
        with open(file, "r", encoding="utf-8") as f:
            data = json.load(f)
        
        # Extract justification and create Langchain documents
        filename = os.path.basename(file)  # Nom du fichier sans le chemin

        # Si le fichier contient "open" dans son nom, on récupère tout
        if "open" in filename:
            for key, entry in data.items():
                json_documents.append(
                    LangchainDocument(
                        page_content=entry,
                        metadata={"ref": filename}
                    )
                )
            
        else:
            for key, entry in data.items():
                if "Justification" in entry:
                    json_documents.append(
                        LangchainDocument(
                            page_content=entry["Justification"],
                            metadata={"ref": filename}  # ref = Nom du fichier
                        )
                    )
    return json_documents


def split_documents(chunk_size: int, knowledge_base: List[LangchainDocument], tokenizer_name: str, markdown_separators) -> List[LangchainDocument]:
    """
    Split documents into chunks of maximum size `chunk_size` tokens and return a list of documents.
    """
    text_splitter = RecursiveCharacterTextSplitter.from_huggingface_tokenizer(
        AutoTokenizer.from_pretrained(tokenizer_name),
        chunk_size=chunk_size,
        chunk_overlap=int(chunk_size / 10),
        add_start_index=True,
        strip_whitespace=True,
        separators=markdown_separators,
    )

    docs_processed = []
    for doc in knowledge_base:
        docs_processed += text_splitter.split_documents([doc])

    # Remove duplicates
    unique_texts = {}
    docs_processed_unique = []
    for doc in docs_processed:
        if doc.page_content not in unique_texts:
            unique_texts[doc.page_content] = True
            docs_processed_unique.append(doc)

    return docs_processed_unique


def create_rag_embeddings(model_name, chunk_size, markdown_separators, data_dir, output_dir, device="cuda"):
    
    csv_raw_knowledge = load_csv(data_dir)
    exam_raw_knowledge = load_exam_solutions(data_dir)
    raw_knowledge_base = csv_raw_knowledge + exam_raw_knowledge
    
    docs_processed = split_documents(
    chunk_size,  # We choose a chunk size adapted to our model
    raw_knowledge_base,
    model_name,
    markdown_separators
    )

    embedding_model = HuggingFaceEmbeddings(
    model_name=model_name,
    multi_process=True,
    model_kwargs={"device": device,  "trust_remote_code":True},  # replace 'cpu' by 'cuda' if you have Nvidia gpu
    encode_kwargs={"normalize_embeddings": True},  # Set `True` for cosine similarity
    )

    # Compute embeddings (can take time ~7min on my laptop)
    knowledge_vector_database = FAISS.from_documents(
        docs_processed, embedding_model, distance_strategy=DistanceStrategy.COSINE
    )
    # Save embeddings
    knowledge_vector_database.save_local(f"{output_dir}/rag_embeddings_{model_name.replace('/', '_')}_chunk{chunk_size}")

# %% [markdown]
# ### embeddings loader

# %%
def load_rag_embeddings(path, embeddings_model, device='cuda'):

    embedding_model = HuggingFaceEmbeddings(
        model_name=embeddings_model,
        multi_process=True,
        model_kwargs={"device": device},  # replace 'cpu' by 'cuda' if you have Nvidia gpu
        encode_kwargs={"normalize_embeddings": True},  # Set `True` for cosine similarity
    )
    
    knowledge_vector_db = FAISS.load_local(path, embedding_model, allow_dangerous_deserialization=True)
    print("embedding load")
    return knowledge_vector_db

# %% [markdown]
# ### generate_mcq_answer

# %%
MAX_OUTPUT_TOKENS = 3000

# %%
def get_context(query: str, k: int, knowledge_vector_db: FAISS):
    """ 
    Retrieves relevant context for a given query.

    Parameters:
    query (str): The input query for which context is needed.
    k (int, optional): The number of relevant context elements to retrieve (default is 5).

    Returns:
    list: A list containing relevant context elements.
    """
    retrieved_docs = knowledge_vector_db.similarity_search(query=query, k=k)
    return retrieved_docs

# %%
def call_formatting_llm_mcq(llm_output, type, model):
    """
    Calls an LLM specialized in formatting text into the correct JSON format.

    Parameters:
    llm_output (str): Raw output from the initial LLM.
    type (str): question or answer

    Returns:
    dict: A valid JSON object containing the question and options.
    """

    if type == 'question':
        SYSTEM_PROMPT = """You are an AI specialized in converting multiple-choice legal questions into JSON format.
        Ensure the output strictly follows this structure:
        ```json
        {"question": "...", "options": ["A ....", "B ...", "C ...", "D ..."]}
        """

    elif type == 'answer':
        SYSTEM_PROMPT = """You are an AI specialized in converting legal answer into JSON format.
        Ensure the output strictly follows this structure:
        ```json
        {
        "Answer": "...", 
        "Justification": "..."
        }
        """

    user_prompt = f"""
        The following text needs to be formatted as a valid JSON:
        {llm_output}
        
        Please convert it into the required JSON format.
        """

    response = chat(model=model, messages=[
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": user_prompt},
    ])
    
    # print(response['message']['content'])
    return response['message']['content']

# %%
def clean_output_v2(text, type, model):
    """ 
    Fist we call small model to translate in json style.
    If it's parsable we get the json. If not, we do regex.
    """

    if type == 'answer':
        print(f"Answer before 2nd model: {text}")
        text_json_like = call_formatting_llm_mcq(text, type, model)
        print(f"Answer after 2nd model: {text_json_like}")

        # Regex pattern to capture the content of "Answer" and "Justification"
        pattern = r'"Answer":\s*"([^"]+)"\s*,\s*"Justification":\s*"([^"]+)"'

        matches = re.search(pattern, text_json_like)

        if matches:
            answer = matches.group(1)
            # check for a valid letter isolated
            match = re.search(r'\b[A-D]\b', answer)
            if match:
                answer = match.group()
                print(f'Final answer: {answer}')

            justification = matches.group(2)
        else:
            print(f'Erreur parsing: {text_json_like}')
            raise ValueError("Can't extract data.")
        
        return {'Answer': answer, 'Justification': justification}
    
    # elif type == 'question':
    #     text_json_like = call_formatting_llm_mcq(text, type, model)

    #     return {'question': question, 'options': [optionA, optionB, optionC, optionD]}

# %%
def generate_mcq_answer(question_mcq: str, model, knowledge_vector_db, reranker=False) -> dict:
    """
    Generates an answer for a MCQ question.

    Parameters:
    question_mcq (str): The input question_mcq for which an answer is needed.

    Returns:
    answer (str): The generated response from the AI with the context used.
    """

    # Convert the question in string, in case the question is a json.
    question_mcq = str(question_mcq)

    # Retrieve context
    if reranker:
        retrieved_docs = get_context(question_mcq, k=20, knowledge_vector_db=knowledge_vector_db)
        retrieved_docs = reranker.rerank(question_mcq, retrieved_docs, k=5)
    else:
        retrieved_docs = get_context(question_mcq, k=5, knowledge_vector_db=knowledge_vector_db)

    context = "\nExtracted documents:\n"
    context += "".join([f'Content: {doc.page_content} \nSource: {doc.metadata['ref']}\n\n' for i, doc in enumerate(retrieved_docs)])
    context_sources = "".join([f'\nSource: {doc.metadata['ref']}, Url: {doc.metadata.get('url', 'N/A')}' for i, doc in enumerate(retrieved_docs)])

    # Build prompt
    SYSTEM_PROMPT = f"""
    You are an AI specialized in answering legal multiple-choice questions based on provided legal texts.
    ### Instructions:
    - When given a multiple-choice legal question, provide the correct answer followed by an explanation.
    - Your answer should begin with the correct choice (e.g., "Answer A").
    - After that, explain why this choice is correct based on the provided legal context.
    - Then, explain why the other choices (B, C, D) are incorrect, using relevant legal reasoning from the context.
    - Use the legal context provided to back up your reasoning.
    - Make sure to clearly distinguish between the correct answer and the incorrect ones.
    """

    user_prompt = f"""
    ### Context:
    {context}

    ### Legal Question:
    {question_mcq}

    Answer the question by:
    1. Starting with the correct answer (e.g., "Answer A").
    2. Explaining why this choice is correct according to the provided legal text.
    3. Explaining why the other options (B, C, D) are incorrect based on the legal context.
    """

    # Initial attempt to get the answer
    attempt_count = 0
    max_attempts = 3  # Limit number of attempts to prevent infinite loops

    while attempt_count < max_attempts:
        answer_mcq = chat(model=model,
                            messages=[{"role":"system", "content":SYSTEM_PROMPT},
                                      {"role":"user","content":user_prompt}],
                            options = {"num_predict":MAX_OUTPUT_TOKENS}
                            )

        # Put answer in correct json format
        try:      
            cleaned_answer_mcq = clean_output_v2(answer_mcq['message']['content'], type='answer', model=model)
            if cleaned_answer_mcq['Answer'] not in {'A', 'B', 'C', 'D'}:
                print(f"Erreur Answer est pas une lettre: Answer={cleaned_answer_mcq['Answer']}")
                raise ValueError("La réponse doit être 'A', 'B', 'C' ou 'D'.")
            
            cleaned_answer_mcq['Justification'] += f'\n\nSources:\n{context_sources}'
            return cleaned_answer_mcq  # If valid, return it

        except ValueError:
            attempt_count += 1  # Increment attempt count
            print(f"Attempt {attempt_count} failed. Retrying...")
            
    
    # If all attempts fail, raise an exception or return None
    return {'Answer': 'Error', 'Justirifation': 'Error parsing json.'}
    raise ValueError("Failed to generate a valid MCQ after multiple attempts.")

# %% [markdown]
# ### evaluate_mcq_answer

# %%
def evaluate_generate_mcq_answer(save_dir: str, data_dir: str, test_name: str, model, knowledge_vector_db: FAISS, reranker=False):
    """
    Evaluate generation_mcq_answer.

    Parameters:
    save_dir (str): Path to save the evaluation file.
    data_dir (str): Folder to load the json mcq and mcs_solutions files.
    test_name (str): Name of the test, used to save file.

    Returns:
    Nothing but save a json file in save_dir.
    """

    # Get questions/answers from mcq json files
    data = []
    
    # Initialise total answer and correct answer for evaluation
    total_answer = 0
    correct_answer =  0
    
    for filename in os.listdir(data_dir):
        # Ignore file containing solution or MOCK
        if "solution" in filename or "json" not in filename or "MOCK" in filename or 'open' in filename or 'categories' in filename:
            continue

        # Initialise filename lists
        questions = []
        answers = []
        ai_answers = []
        
        # Load doc
        filepath = os.path.join(data_dir, filename)
        with open(filepath, 'r', encoding='utf-8') as file:
            doc = json.load(file)
        for elt in doc.values():
            questions.append(elt)
        
        # Load solution doc
        solution_filepath = filepath.rsplit('.json', 1)[0] + "_solution.json"
        if os.path.exists(solution_filepath):
            with open(solution_filepath, 'r', encoding='utf-8') as file:
                solution_doc = json.load(file)
            for elt in solution_doc.values():
                answers.append(elt)
        
        # Generate AI Answer
        for i in range(len(questions)):

            question = str(questions[i])
            print(question)

            try:
                ai_answer = generate_mcq_answer(question, model, knowledge_vector_db, reranker)
            except json.JSONDecodeError:
                ai_aswer = {'Answer': 'None', 'Justification': 'Error when parsing json. {json.JSONDecodeError}'}
            # ai_answer = 
            ai_answers.append(ai_answer)
            
            # Check if correct answer
            total_answer += 1
            if answers[i]['Answer'] == ai_answer['Answer']:
                correct_answer += 1

        # Append to data
        data.append({'filename': filename, 'questions': questions,
        'answers': answers, 'ai_answers': ai_answers})
    
    # Save at each question
    informations = {'total_answer': total_answer, 'correct_answer': correct_answer}
    print(informations)
    final_evaluation = {'informations': informations,'data': data}
    
    # Save json
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    output_path = os.path.join(save_dir, f"{test_name}.json")
    with open(output_path, 'w', encoding='utf-8') as file:
        json.dump(final_evaluation, file, indent=4, ensure_ascii=False)

# %% [markdown]
# ## Tune chunk size

# %%
embeddings_model = 'thenlper/gte-small'
reader = 'qwen2.5:7b'

# %%
def test_chunk_size(chunk_size):
    create_rag_embeddings(embeddings_model, chunk_size, markdown_separators, data_dir, output_dir)
    knowledge_vector_db = load_rag_embeddings(path=f'../embeddings/rag_embeddings_{embeddings_model.replace('/', '_')}_chunk{chunk_size}',
                                            embeddings_model=embeddings_model, device='cuda')
    evaluate_generate_mcq_answer(save_dir='../outputs/evaluation2/', data_dir='../outputs/',
                             test_name=f'{embeddings_model.replace('/', '_')}_qwen2_5_7b_chunk{chunk_size}', model=reader,
                             knowledge_vector_db=knowledge_vector_db)

# %% [markdown]
# ### chunk_size = 256

# %%
# test_chunk_size(256)

# %% [markdown]
# ### chunk_size = 512

# %%
# test_chunk_size(512)

# %% [markdown]
# ### chunk_size = 768

# %%
# test_chunk_size(768)

# %%
# test_chunk_size(1024)

# %% [markdown]
# ## Test better embeddings model

# %%
chunk_size = 512
reader = 'qwen2.5:7b'

# %%
def test_embeddings_model(embeddings_model, chunk_size):
    create_rag_embeddings(embeddings_model, chunk_size, markdown_separators, data_dir, output_dir)
    knowledge_vector_db = load_rag_embeddings(path=f'../embeddings/rag_embeddings_{embeddings_model.replace('/', '_')}_chunk{chunk_size}',
                                            embeddings_model=embeddings_model, device='cuda')
    evaluate_generate_mcq_answer(save_dir='../outputs/evaluation2/', data_dir='../outputs/',
                             test_name=f'{embeddings_model.replace('/', '_')}_qwen2_5_7b_chunk{chunk_size}', model=reader,
                             knowledge_vector_db=knowledge_vector_db)

# %% [markdown]
# ### embeddings_model = nvidia/NV-Embed-v2 (NON CAR >30min pour créer un Embeddings)

# %% [markdown]
# ### embeddings_model = Alibaba-NLP/gte-Qwen2-7B-instruct   (NON CAR >1h pour créer un Embeddings)

# %% [markdown]
# ### embeddings_model = all-MiniLM-L6-v2

# %%
# test_embeddings_model(embeddings_model='sentence-transformers/all-MiniLM-L6-v2', chunk_size=512)
# Out:
# embedding load
# {'question': 'A European patent was granted to a German company on 4  January 2023. No opposition was filed. Mr Li and Ms Smith were designated as inventors. On 12 October 2023,  the patent proprietor not ices that Ms Smith was erroneously designated as inventor and that Mr Li is the sole inventor.  Which of the following statements is correct?', 'options': ['A. Ms Smith will be deleted as inventor if the patent proprietor requests this in writing .', 'B. Ms Smith can no longer  be deleted as inventor because no proceedings are pending before the EPO .', "C. The patent proprietor can request that  Ms Smith be deleted as inventor but needs Mr Li 's consent  for this .", 'D. Ms Smith can only be deleted as inventor with her consent .']}
# {'question': "On 10 October 2021, European patent attorney X filed European patent application EP -A with the EPO on the applicant's behalf. Application EP -A was published on 12 April 2023, together  with the extended European search report. On 6  October 2023, the applicant contacts a new European patent attorney  Y to replace X as representative and issues Y with its instructions to reply to the extended European search report. The applicant did not inform X that he would be replaced.  What are the steps necessary to validly appoint representative Y and to avoid any loss of rights for European patent application EP -A?", 'options': ['A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant .', 'B. New representative Y requests a change of representative and files a response to the extended European search report with  the EPO by 12 October 2023 at the latest .', 'C. New representative Y requests a change of representative and files a response to the extended European search report with the EPO by 23 October 2023 at the latest.', 'D. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 23 October 2023 at the latest and files in good time an authorisation signed by the applicant .']}
# {'question': 'EP-1 is a regular European patent application (Euro -direct application) .  Which one of the following missed time limits can be remedied for EP -1 before the EPO by requesting re- establishment of rights ?', 'options': ['A. T ime limit for pay ing the designation fee', 'B. T ime limit for requesting examination', 'C. T ime limit for filing the application within the priority period', 'D. T ime limit for paying the fee for re- establishment of rights']}
# {'question': 'Last week Greta validly filed the international patent application PCT -G with the German Patent and Trade mark Office ( DPMA ) and appointed Hassan to represent her. Hassan is entitled to act before the DPMA  but he is not a European patent attorney. Greta and Hassan are resident in Germany.  Which of the following statements is not correct?', 'options': ['A. Hassan can represent Greta before the EPO acting as the International Searching Authority for PCT -G.', 'B. In order for Hassan to be able to act before the EPO acting as the International Searching Authority , he needs to submit a power of attorney signed by Greta.', 'C. According to the provisions of the PCT, it is mandatory that the d emand for international preliminary examination is signed by Greta or Hassan.', 'D. According to the provisions of the PCT, an international application can only be withdrawn by the applicant or an agent appointed by a power of attorney.']}
# Erreur parsing: JSON formatted answer cannot be produced as the input does not contain any question or statement that requires evaluation. The provided text is an explanation and analysis of the statements without posing a specific question to answer. If you need to evaluate a particular statement or require a specific legal answer, please provide the necessary context or question.
#
# However, if you want to format your explanation as JSON, it would look something like this:
#
# ```json
# {
#     "Answer": "",
#     "Justification": "The input text does not contain a specific question or statement that needs evaluation. The provided content is an explanation and analysis of statements A, B, C, and D without posing any particular legal query to answer."
# }
# ```
#
# If you can provide a specific question or statement to evaluate, I would be happy to format it into the required JSON structure.
# Attempt 1 failed. Retrying...
# {'question': 'In which of the following cases is the applicant entitled to a reduction of the filing fee  under Rule  6 EPC ? A declaration of such entitlement has  been made by crossing the relevant box on Form  1001.', 'options': ['A. A Spanish European patent attorney files a European patent application in Spanish for a natural person who is resident in Andorra and of Andorra n nationality .', 'B. A firm whose principal place of business is in Germany and a natural person who is resident in Germany  and of Dutch nationality  jointly file a European patent application in Dutch. The German firm employs 200 people with an annual turnover of EUR 60 million.', 'C. A natural person resident in the USA and of Belgian nationality files a European patent application in French.', 'D. A natural person resident in the USA and of Swiss nationality files a European patent application in Italian.']}
# {'question': 'Mr Van Holland is a Dutch citizen resident in the Netherlands. He filed a European patent application EP -parent in Dutch, together with  a translation into English. Whil e EP-parent was pending, Mr Van Holland filed a divisional application EP -div in Dutch and requested examination in Dutch. He paid all fees due for EP -div. He has not filed an English translation of EP -div. The Receiving Section has now issued a noting of l oss of rights.  Which of the following statements is correct?', 'options': ['A. The deficiency cannot be remedied.', 'B. Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication  under Rule 112(1) EPC .', 'C. Mr Van Holland needs to file an English translation of EP -div together with a request for f urther processing.', 'D. Mr Van Holland needs to file an English translation of EP -div together with a request for re- establishment of rights.']}
# {'question': 'On 16  November 2020, you filed a European patent application EP -A, which did not claim priority. Today, 12  October 2023, you receive a communication from the EPO entitled " Decision to grant a European patent pursuant to Article  97(1) EPC ". This communication state s that the mention of the grant You wish to validate the patent in only two contracting states  to the EPC . Which of the following statements is correct?', 'options': ['A. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 16 November 2023.', 'B. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 30 November 2023.', 'C. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 9 January 2024 at the latest .', 'D. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 16 January 2024 at the latest .']}
# {'question': 'During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?', 'options': ['A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.', 'B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.', 'C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.', 'D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months.']}
# {'question': 'Under the PCT, what is the time limit for filing a request for rectification of an obvious mistake made in the international application?', 'options': ['A. 18 months from the earliest priority date', 'B. 30 months from the earliest priority date', 'C. 22 months from the earliest priority date', 'D. 26 months from the earliest priority date']}
# {'question': 'After receipt of a negative written opinion issued by the EPO acting as ISA, amendments under Art icle 19 PCT were filed during the international phase. No request for international preliminary examination was filed. Form  1200 was used,  and no further amendments were filed with the EPO upon entry into the regional phase.   What communication under Rules  161/162 EPC will be received in the regional phase?', 'options': ['A. Form 1226AA ;  if you do not reply to it in time, the application will be deemed to be withdrawn', 'B. Form 1226BB offering the opportunity to comment and file amendments', 'C. Form 1226CC offering the opportunity to file amendments before the supplementary European search report is drawn up', 'D. Form 1226AC stating that the examination has started']}
# {'question': 'Company M, which has  its principal place of business in Tijuana, Mexico, validly filed an international patent application PCT -M with the Mexican Institute of Industrial Property. The application was filed in Spanish. A few days later, the applicant files an English translati on of the application.  Which of the following statements is correct?', 'options': ['A. The applicant can choose the EPO as ISA and the USPTO as IPEA.', 'B. The applicant can choose the USPTO as ISA and the EPO as IPEA.', 'C. The applicant can choose the Austrian Patent Offic e as ISA and the', 'EPO as IPEA.', 'D. The applicant can choose the EPO as ISA and the Intellectual Property', 'Office of Singapore as IPEA.']}
# {'question': 'On 20  June 2023, applicant P validly filed an international patent application PCT-P, claiming priority from European patent application EP -I filed on 7 July 2022. Today, 12 October 2023, he discovers that he should also have claimed priority from EP -II filed on 3 July 2022. Can the missing priority claim still be validly added?', 'options': ['A. Yes, the time  limit for adding the priority claim expires on 3  November 2023.', 'B. Yes, the time limit for adding the priority claim expires on 7  November 2023.', 'C. Yes, the time  limit for adding the priority claim expires on 20 October 2023.', 'D. No, the time  limit for adding the priority claim expired on 3 July 2023.']}
# {'question': 'The opposition division revoked European patent EP -B1. The patent proprietor filed an appeal  in time . The b oard of appeal forwarded a copy of the appeal to the o pponent/ respondent with a communication dated 1 June 2023 giving it an opportunity to file comments within a period of four  months.  The opponent/respondent files comments today, 12 October 2023. What further action has to be taken ?', 'options': ['A. The opponent/ respondent needs  to request an extension of the period for comment.', 'B. The opponent/respondent needs to pay a fee for further processing.', 'C. The opponent/respondent needs to file a substantiated request for reestablishment of rights and pay the associated fee.', 'D. None of the above.']}
# {'question': 'A European patent application was filed on 20 March 2020. Proceedings were interrupted under  Rule 142 EPC on 10  March 2022. The applicant was informed that proceedings would be resumed today, 12 October 2023. No renewal fee has been paid so far . Which of the following statements is correct?', 'options': ['A. As no renewal fees have been paid, the application is deemed to be withdrawn .', 'B. The renewal fees for the third and fourth years can be validly paid without any additional fee on 12 October 2023 at the latest .', 'C. The renewal fees for the third and fourth years can be validly paid with an additional  fee by 30  April 2024 at the latest .', 'D. The renewal fees for the third and fourth years can be validly paid without any additional fee by 31  October 2023 at the latest .']}
# {'question': 'An international application is published , together  with the search report drawn up by the CNIPA , 18 m onths + 1 day after the filing date (no priority claimed). The application has no more than 35 pages and 15 claims. Which statement reflects all actions the CN  applicant  needs to take for entry into the EP phase 25 months  after the filing date ? A request for early processing has been filed.', 'options': ['A. Complete and file Form 1200 and pay the filing fee and the search fee', 'B. Complete and file Form 1200 and pay the filing fee, the search fee and the renewal fee for the third year', 'C. Complete and file Form 1200, pay the filing fee and the search fee and appoint a representative', 'D. None of the above statements']}
# {'question': 'A European patent application was filed on 6 February 2023. The search, filing and designation fees were paid within a month of the date of filing. What is the latest point in time for withdrawing the application, if the applicant wishes to obtain a refund of the designation fee?', 'options': ['A. Six months after the date of mention of the publication of the European search report', 'B. Date of mention of the publication of the European search report', 'C. The designation fee was validly paid and can no longer be refunded', 'D. Date of the start of substantive examination']}
# {'question': "On 10 October 2024, an applicant files a request for entry into the European phase, together with a debit order, according to which the filing fee, the designation fee, the examination fee and the renewal fee for the third year are to be debited from the applicant's deposit account. It is specified that the debit order is to be executed on 18 October 2024. On the evening of 10 October 2024, the applicant notices that the renewal fee is not yet due and should not be debited from the deposit account. What is the latest point in time for revoking the order to debit the renewal fee in Central Fee Payment (CFP)?", 'options': ['A. 10 October 2024', 'B. 17 October 2024', 'C. 18 October 2024', 'D. A debit order cannot be revoked in part']}
# {'question': 'The applicant received a communication pursuant to Article 90(3) EPC and Rule  60 EPC, requesting them to file a designation of inventor but missed the time limit for filing a response. After expiry of the time limit, the Receiving Section issued a decision to refuse the European patent application, dated 10  October 2024. What can the applicant do to remedy the situation?', 'options': ['A. File a notice of appeal against the decision within four months of notification of the decision', 'B. File a request for further processing within two months of notification of the decision', 'C. File, within two months of notification of the decision, a request for re-establishment of rights in respect of the time limit for filing the designation of inventor', 'D. A, B and C are correct']}
# {'question': 'Which of the following statements about filing third- party observations is correct?', 'options': ['A. The person that filed third- party observations will be a party to the proceedings before the EPO, and the applicant is obliged to respond to third- party observations', 'B. Third -party observations must be filed in writing and may not be filed anonymously', 'C. Third -party observations are considered by the examining division only if they include a statement of the grounds on which they are based, and an official fee is paid', 'D. Third -party observations can be filed after the publication of a European patent application and must be filed in an official language of the EPO']}
# {'question': 'You filed an international patent application on 6 June 2024, claiming the priority of a European patent application filed on 7  July 2023. You received a communication dated 25 September 2024 from the EPO acting as International Searching Authority (ISA), stating that the requirement of unity of invention has not been complied with. The ISA identifies three inventions. You are invited to pay two additional search fees. Which of the following statements is correct?', 'options': ['A. You must pay two additional search fees by 25 October 2024', 'B. You do not need to file a response to the provisional opinion accompanying the partial search results', 'C. If you pay two additional search fees under protest, you must pay two protest fees within the time limit', 'D. If you do not pay any additional search fees within the time limit, the international patent application will be deemed to be withdrawn']}
# {'question': 'An international patent application filed with the EPO as receiving Office on 10 September 2024, claims the priority of a Luxembourg patent application filed on 11 October 2023. No certified copy of the Luxembourg patent application was filed at the time of filing of the international patent application. Which of the following actions can be taken to file a certified copy of the Luxembourg patent application for this international patent application?', 'options': ['A. Request the Luxembourg Intellectual Property Office to prepare and send a certified copy of the Luxembourg patent application to the EPO', 'B. Submit a valid DAS code (Digital Access Service) to the International Bureau to enable it to obtain a certified copy of the Luxembourg patent application', 'C. File an electronic certified copy of the Luxembourg patent application with the EPO', 'D. File a certified copy of the Luxembourg patent application with the International Bureau']}
# Erreur parsing:
# <|im_start|><|im_start|>user
#
# It seems there was a misunderstanding. Could you please provide the correct JSON format based on the given text, ensuring all necessary details are included within the structure?
# Attempt 1 failed. Retrying...
# Erreur Answer est pas une lettre: Answer=Request the Luxembourg Intellectual Property Office to prepare and send a certified copy of the Luxembourg patent application to the EPO
# Attempt 2 failed. Retrying...
# {'question': 'Firm A owns a European patent, EP . Firm B filed an opposition against EP, requesting its revocation. Firm B argued that the subject -matter of the granted claims was not new in view of document D1. During the opposition proceedings, firm C filed observations under Art.  115 EPC, arguing that the subject -matter of the granted claims was not new in view of document D2. Firm A requested maintenance of the patent as granted, or maintenance in amended Which of the following statements is correct?', 'options': ["A. At the end of the opposition proceedings, the opposition division decided to revoke the patent. Firm B is entitled to file an appeal against the opposition division's decision.", "B. At the end of the opposition proceedings, the opposition division decided to and firm B are entitled to file an appeal against the opposition division's decision.", "C. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm C is entitled to file an appeal against the opposition division's decision.", "D. During the opposition proceedings, firm B withdrew its opposition. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm B is entitled to file an appeal against the opposition division's decision."]}
# {'question': 'European patent application EP -X was filed on 1  October 2020, claiming the priority of a Belgian application filed on 16 October 2019. The mention of the grant of European patent EP -X was published on 2  October 2024. The proprietor filed a request for unitary effect and was informed by communication dated 10  October 2024, that unitary effect had been registered for EP -X-C0 on the same date. Which of the following statements is correct?', 'options': ['A. A renewal fee still has to be paid by 31 October 2024 in respect of the 5th year for EP -X', 'B. A renewal fee is due on 31 October 2024 in respect of the 5th year for EP -X-C0', 'C. A renewal fee is due on 31 October 2024 in respect of the 6th year for EP -X-C0', 'D. No renewal fee has to be paid on 31 October 2024']}
# {'question': 'A communication under Article 94(3) EPC, setting a four -month time limit for reply is dated 12 September 2024. The applicant receives the letter on 21 September 2024, as evidenced by the postal receipt signed by him.  What is the last day for replying to the communication?', 'options': ['A. 13 January 2025', 'B. 12 January 2025', 'C. 22 January 2025', 'D. 14 January 2025']}
# Erreur Answer est pas une lettre: Answer=22 January 2025
# Attempt 1 failed. Retrying...
# {'question': 'Which functionalities or services can be accessed directly from MyEPO Portfolio?', 'options': ["A. A shared area with examiners, European Patent Register, filing via the EPO's online filing software eOLF", 'B. Mailbox, a shared area with examiners, replying to a communication under Article  94(3) EPC', 'C. Mailbox, patent search via publication server, a shared area with examiners', "D. Filing via the EPO's Online Filing 2.0, patent search via publication server, Mailbox"]}
# {'question': 'In which of the following situations does the EPO recommend using the EPO Contingency Upload Service?', 'options': ['A. When you submit documents after business hours', 'B. When the EPO filing systems are functioning correctly, but you encounter a technical issue at your end', 'C. When there is a system outage at the EPO that prevents document submission via the standard filing systems', 'D. When the EPO is closed due to an official holiday']}
# {'question': 'Applicant Korhonen is a Finnish national resident in Finland. He filed a European patent application in Finnish and provided an English translation in time. In response to the extended European search report (EESR), Korhonen wishes to file amended claims t ogether with a request for examination. Which of the following statements is correct?', 'options': ['A. Korhonen must file the amended claims in Finnish and must then  provide a translation into English, in time', 'B. Korhonen is allowed to file the amended claims in Finnish if he then provides a', 'translation into any official language of the EPO, in time C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time', 'D. Korhonen is not allowed to file the amended claims in Finnish']}
# {'question': 'Applicants may request processing of their international application under PCT Direct by filing a letter ("PCT Direct letter") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?', 'options': ['A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing', 'B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0', 'C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0', 'D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document']}
# {'question': 'Mr Linguist filed a European patent application in Dutch and used English as language of the proceedings. When requesting unitary effect on 10 October 2024, Mr Linguist must provide a translation of the specification. Mr Linguist would like to obtain immediate registration of the unitary effect. Which of the following statements is correct?', 'options': ['A. Mr Linguist must provide a translation of the specification into Dutch', 'B. Mr Linguist must provide a translation of the specification into an official language of any of the 18 states to which the unitary effect extends', 'C. Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA', 'D. Mr Linguist may provide a translation of the specification into Spanish']}
# {'total_answer': 29, 'correct_answer': 11}

# %% [markdown]
# ### embeddings_model = bge-large-en

# %%
# test_embeddings_model(embeddings_model='BAAI/bge-large-en-v1.5', chunk_size=512)
# Out:
# embedding load
# {'question': 'A European patent was granted to a German company on 4  January 2023. No opposition was filed. Mr Li and Ms Smith were designated as inventors. On 12 October 2023,  the patent proprietor not ices that Ms Smith was erroneously designated as inventor and that Mr Li is the sole inventor.  Which of the following statements is correct?', 'options': ['A. Ms Smith will be deleted as inventor if the patent proprietor requests this in writing .', 'B. Ms Smith can no longer  be deleted as inventor because no proceedings are pending before the EPO .', "C. The patent proprietor can request that  Ms Smith be deleted as inventor but needs Mr Li 's consent  for this .", 'D. Ms Smith can only be deleted as inventor with her consent .']}
# {'question': "On 10 October 2021, European patent attorney X filed European patent application EP -A with the EPO on the applicant's behalf. Application EP -A was published on 12 April 2023, together  with the extended European search report. On 6  October 2023, the applicant contacts a new European patent attorney  Y to replace X as representative and issues Y with its instructions to reply to the extended European search report. The applicant did not inform X that he would be replaced.  What are the steps necessary to validly appoint representative Y and to avoid any loss of rights for European patent application EP -A?", 'options': ['A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant .', 'B. New representative Y requests a change of representative and files a response to the extended European search report with  the EPO by 12 October 2023 at the latest .', 'C. New representative Y requests a change of representative and files a response to the extended European search report with the EPO by 23 October 2023 at the latest.', 'D. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 23 October 2023 at the latest and files in good time an authorisation signed by the applicant .']}
# {'question': 'EP-1 is a regular European patent application (Euro -direct application) .  Which one of the following missed time limits can be remedied for EP -1 before the EPO by requesting re- establishment of rights ?', 'options': ['A. T ime limit for pay ing the designation fee', 'B. T ime limit for requesting examination', 'C. T ime limit for filing the application within the priority period', 'D. T ime limit for paying the fee for re- establishment of rights']}
# {'question': 'Last week Greta validly filed the international patent application PCT -G with the German Patent and Trade mark Office ( DPMA ) and appointed Hassan to represent her. Hassan is entitled to act before the DPMA  but he is not a European patent attorney. Greta and Hassan are resident in Germany.  Which of the following statements is not correct?', 'options': ['A. Hassan can represent Greta before the EPO acting as the International Searching Authority for PCT -G.', 'B. In order for Hassan to be able to act before the EPO acting as the International Searching Authority , he needs to submit a power of attorney signed by Greta.', 'C. According to the provisions of the PCT, it is mandatory that the d emand for international preliminary examination is signed by Greta or Hassan.', 'D. According to the provisions of the PCT, an international application can only be withdrawn by the applicant or an agent appointed by a power of attorney.']}
# {'question': 'In which of the following cases is the applicant entitled to a reduction of the filing fee  under Rule  6 EPC ? A declaration of such entitlement has  been made by crossing the relevant box on Form  1001.', 'options': ['A. A Spanish European patent attorney files a European patent application in Spanish for a natural person who is resident in Andorra and of Andorra n nationality .', 'B. A firm whose principal place of business is in Germany and a natural person who is resident in Germany  and of Dutch nationality  jointly file a European patent application in Dutch. The German firm employs 200 people with an annual turnover of EUR 60 million.', 'C. A natural person resident in the USA and of Belgian nationality files a European patent application in French.', 'D. A natural person resident in the USA and of Swiss nationality files a European patent application in Italian.']}
# {'question': 'Mr Van Holland is a Dutch citizen resident in the Netherlands. He filed a European patent application EP -parent in Dutch, together with  a translation into English. Whil e EP-parent was pending, Mr Van Holland filed a divisional application EP -div in Dutch and requested examination in Dutch. He paid all fees due for EP -div. He has not filed an English translation of EP -div. The Receiving Section has now issued a noting of l oss of rights.  Which of the following statements is correct?', 'options': ['A. The deficiency cannot be remedied.', 'B. Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication  under Rule 112(1) EPC .', 'C. Mr Van Holland needs to file an English translation of EP -div together with a request for f urther processing.', 'D. Mr Van Holland needs to file an English translation of EP -div together with a request for re- establishment of rights.']}
# {'question': 'On 16  November 2020, you filed a European patent application EP -A, which did not claim priority. Today, 12  October 2023, you receive a communication from the EPO entitled " Decision to grant a European patent pursuant to Article  97(1) EPC ". This communication state s that the mention of the grant You wish to validate the patent in only two contracting states  to the EPC . Which of the following statements is correct?', 'options': ['A. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 16 November 2023.', 'B. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 30 November 2023.', 'C. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 9 January 2024 at the latest .', 'D. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 16 January 2024 at the latest .']}
# {'question': 'During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?', 'options': ['A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.', 'B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.', 'C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.', 'D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months.']}
# {'question': 'Under the PCT, what is the time limit for filing a request for rectification of an obvious mistake made in the international application?', 'options': ['A. 18 months from the earliest priority date', 'B. 30 months from the earliest priority date', 'C. 22 months from the earliest priority date', 'D. 26 months from the earliest priority date']}
# {'question': 'After receipt of a negative written opinion issued by the EPO acting as ISA, amendments under Art icle 19 PCT were filed during the international phase. No request for international preliminary examination was filed. Form  1200 was used,  and no further amendments were filed with the EPO upon entry into the regional phase.   What communication under Rules  161/162 EPC will be received in the regional phase?', 'options': ['A. Form 1226AA ;  if you do not reply to it in time, the application will be deemed to be withdrawn', 'B. Form 1226BB offering the opportunity to comment and file amendments', 'C. Form 1226CC offering the opportunity to file amendments before the supplementary European search report is drawn up', 'D. Form 1226AC stating that the examination has started']}
# {'question': 'Company M, which has  its principal place of business in Tijuana, Mexico, validly filed an international patent application PCT -M with the Mexican Institute of Industrial Property. The application was filed in Spanish. A few days later, the applicant files an English translati on of the application.  Which of the following statements is correct?', 'options': ['A. The applicant can choose the EPO as ISA and the USPTO as IPEA.', 'B. The applicant can choose the USPTO as ISA and the EPO as IPEA.', 'C. The applicant can choose the Austrian Patent Offic e as ISA and the', 'EPO as IPEA.', 'D. The applicant can choose the EPO as ISA and the Intellectual Property', 'Office of Singapore as IPEA.']}
# {'question': 'On 20  June 2023, applicant P validly filed an international patent application PCT-P, claiming priority from European patent application EP -I filed on 7 July 2022. Today, 12 October 2023, he discovers that he should also have claimed priority from EP -II filed on 3 July 2022. Can the missing priority claim still be validly added?', 'options': ['A. Yes, the time  limit for adding the priority claim expires on 3  November 2023.', 'B. Yes, the time limit for adding the priority claim expires on 7  November 2023.', 'C. Yes, the time  limit for adding the priority claim expires on 20 October 2023.', 'D. No, the time  limit for adding the priority claim expired on 3 July 2023.']}
# {'question': 'The opposition division revoked European patent EP -B1. The patent proprietor filed an appeal  in time . The b oard of appeal forwarded a copy of the appeal to the o pponent/ respondent with a communication dated 1 June 2023 giving it an opportunity to file comments within a period of four  months.  The opponent/respondent files comments today, 12 October 2023. What further action has to be taken ?', 'options': ['A. The opponent/ respondent needs  to request an extension of the period for comment.', 'B. The opponent/respondent needs to pay a fee for further processing.', 'C. The opponent/respondent needs to file a substantiated request for reestablishment of rights and pay the associated fee.', 'D. None of the above.']}
# {'question': 'A European patent application was filed on 20 March 2020. Proceedings were interrupted under  Rule 142 EPC on 10  March 2022. The applicant was informed that proceedings would be resumed today, 12 October 2023. No renewal fee has been paid so far . Which of the following statements is correct?', 'options': ['A. As no renewal fees have been paid, the application is deemed to be withdrawn .', 'B. The renewal fees for the third and fourth years can be validly paid without any additional fee on 12 October 2023 at the latest .', 'C. The renewal fees for the third and fourth years can be validly paid with an additional  fee by 30  April 2024 at the latest .', 'D. The renewal fees for the third and fourth years can be validly paid without any additional fee by 31  October 2023 at the latest .']}
# {'question': 'An international application is published , together  with the search report drawn up by the CNIPA , 18 m onths + 1 day after the filing date (no priority claimed). The application has no more than 35 pages and 15 claims. Which statement reflects all actions the CN  applicant  needs to take for entry into the EP phase 25 months  after the filing date ? A request for early processing has been filed.', 'options': ['A. Complete and file Form 1200 and pay the filing fee and the search fee', 'B. Complete and file Form 1200 and pay the filing fee, the search fee and the renewal fee for the third year', 'C. Complete and file Form 1200, pay the filing fee and the search fee and appoint a representative', 'D. None of the above statements']}
# {'question': 'A European patent application was filed on 6 February 2023. The search, filing and designation fees were paid within a month of the date of filing. What is the latest point in time for withdrawing the application, if the applicant wishes to obtain a refund of the designation fee?', 'options': ['A. Six months after the date of mention of the publication of the European search report', 'B. Date of mention of the publication of the European search report', 'C. The designation fee was validly paid and can no longer be refunded', 'D. Date of the start of substantive examination']}
# {'question': "On 10 October 2024, an applicant files a request for entry into the European phase, together with a debit order, according to which the filing fee, the designation fee, the examination fee and the renewal fee for the third year are to be debited from the applicant's deposit account. It is specified that the debit order is to be executed on 18 October 2024. On the evening of 10 October 2024, the applicant notices that the renewal fee is not yet due and should not be debited from the deposit account. What is the latest point in time for revoking the order to debit the renewal fee in Central Fee Payment (CFP)?", 'options': ['A. 10 October 2024', 'B. 17 October 2024', 'C. 18 October 2024', 'D. A debit order cannot be revoked in part']}
# Erreur Answer est pas une lettre: Answer=October 17, 2024
# Attempt 1 failed. Retrying...
# {'question': 'The applicant received a communication pursuant to Article 90(3) EPC and Rule  60 EPC, requesting them to file a designation of inventor but missed the time limit for filing a response. After expiry of the time limit, the Receiving Section issued a decision to refuse the European patent application, dated 10  October 2024. What can the applicant do to remedy the situation?', 'options': ['A. File a notice of appeal against the decision within four months of notification of the decision', 'B. File a request for further processing within two months of notification of the decision', 'C. File, within two months of notification of the decision, a request for re-establishment of rights in respect of the time limit for filing the designation of inventor', 'D. A, B and C are correct']}
# {'question': 'Which of the following statements about filing third- party observations is correct?', 'options': ['A. The person that filed third- party observations will be a party to the proceedings before the EPO, and the applicant is obliged to respond to third- party observations', 'B. Third -party observations must be filed in writing and may not be filed anonymously', 'C. Third -party observations are considered by the examining division only if they include a statement of the grounds on which they are based, and an official fee is paid', 'D. Third -party observations can be filed after the publication of a European patent application and must be filed in an official language of the EPO']}
# {'question': 'You filed an international patent application on 6 June 2024, claiming the priority of a European patent application filed on 7  July 2023. You received a communication dated 25 September 2024 from the EPO acting as International Searching Authority (ISA), stating that the requirement of unity of invention has not been complied with. The ISA identifies three inventions. You are invited to pay two additional search fees. Which of the following statements is correct?', 'options': ['A. You must pay two additional search fees by 25 October 2024', 'B. You do not need to file a response to the provisional opinion accompanying the partial search results', 'C. If you pay two additional search fees under protest, you must pay two protest fees within the time limit', 'D. If you do not pay any additional search fees within the time limit, the international patent application will be deemed to be withdrawn']}
# {'question': 'An international patent application filed with the EPO as receiving Office on 10 September 2024, claims the priority of a Luxembourg patent application filed on 11 October 2023. No certified copy of the Luxembourg patent application was filed at the time of filing of the international patent application. Which of the following actions can be taken to file a certified copy of the Luxembourg patent application for this international patent application?', 'options': ['A. Request the Luxembourg Intellectual Property Office to prepare and send a certified copy of the Luxembourg patent application to the EPO', 'B. Submit a valid DAS code (Digital Access Service) to the International Bureau to enable it to obtain a certified copy of the Luxembourg patent application', 'C. File an electronic certified copy of the Luxembourg patent application with the EPO', 'D. File a certified copy of the Luxembourg patent application with the International Bureau']}
# {'question': 'Firm A owns a European patent, EP . Firm B filed an opposition against EP, requesting its revocation. Firm B argued that the subject -matter of the granted claims was not new in view of document D1. During the opposition proceedings, firm C filed observations under Art.  115 EPC, arguing that the subject -matter of the granted claims was not new in view of document D2. Firm A requested maintenance of the patent as granted, or maintenance in amended Which of the following statements is correct?', 'options': ["A. At the end of the opposition proceedings, the opposition division decided to revoke the patent. Firm B is entitled to file an appeal against the opposition division's decision.", "B. At the end of the opposition proceedings, the opposition division decided to and firm B are entitled to file an appeal against the opposition division's decision.", "C. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm C is entitled to file an appeal against the opposition division's decision.", "D. During the opposition proceedings, firm B withdrew its opposition. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm B is entitled to file an appeal against the opposition division's decision."]}
# {'question': 'European patent application EP -X was filed on 1  October 2020, claiming the priority of a Belgian application filed on 16 October 2019. The mention of the grant of European patent EP -X was published on 2  October 2024. The proprietor filed a request for unitary effect and was informed by communication dated 10  October 2024, that unitary effect had been registered for EP -X-C0 on the same date. Which of the following statements is correct?', 'options': ['A. A renewal fee still has to be paid by 31 October 2024 in respect of the 5th year for EP -X', 'B. A renewal fee is due on 31 October 2024 in respect of the 5th year for EP -X-C0', 'C. A renewal fee is due on 31 October 2024 in respect of the 6th year for EP -X-C0', 'D. No renewal fee has to be paid on 31 October 2024']}
# {'question': 'A communication under Article 94(3) EPC, setting a four -month time limit for reply is dated 12 September 2024. The applicant receives the letter on 21 September 2024, as evidenced by the postal receipt signed by him.  What is the last day for replying to the communication?', 'options': ['A. 13 January 2025', 'B. 12 January 2025', 'C. 22 January 2025', 'D. 14 January 2025']}
# Erreur Answer est pas une lettre: Answer=12 January 2025
# Attempt 1 failed. Retrying...
# Erreur Answer est pas une lettre: Answer=12 January 2025
# Attempt 2 failed. Retrying...
# Erreur Answer est pas une lettre: Answer=12 January 2025
# Attempt 3 failed. Retrying...
# {'question': 'Which functionalities or services can be accessed directly from MyEPO Portfolio?', 'options': ["A. A shared area with examiners, European Patent Register, filing via the EPO's online filing software eOLF", 'B. Mailbox, a shared area with examiners, replying to a communication under Article  94(3) EPC', 'C. Mailbox, patent search via publication server, a shared area with examiners', "D. Filing via the EPO's Online Filing 2.0, patent search via publication server, Mailbox"]}
# {'question': 'In which of the following situations does the EPO recommend using the EPO Contingency Upload Service?', 'options': ['A. When you submit documents after business hours', 'B. When the EPO filing systems are functioning correctly, but you encounter a technical issue at your end', 'C. When there is a system outage at the EPO that prevents document submission via the standard filing systems', 'D. When the EPO is closed due to an official holiday']}
# {'question': 'Applicant Korhonen is a Finnish national resident in Finland. He filed a European patent application in Finnish and provided an English translation in time. In response to the extended European search report (EESR), Korhonen wishes to file amended claims t ogether with a request for examination. Which of the following statements is correct?', 'options': ['A. Korhonen must file the amended claims in Finnish and must then  provide a translation into English, in time', 'B. Korhonen is allowed to file the amended claims in Finnish if he then provides a', 'translation into any official language of the EPO, in time C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time', 'D. Korhonen is not allowed to file the amended claims in Finnish']}
# {'question': 'Applicants may request processing of their international application under PCT Direct by filing a letter ("PCT Direct letter") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?', 'options': ['A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing', 'B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0', 'C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0', 'D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document']}
# {'question': 'Mr Linguist filed a European patent application in Dutch and used English as language of the proceedings. When requesting unitary effect on 10 October 2024, Mr Linguist must provide a translation of the specification. Mr Linguist would like to obtain immediate registration of the unitary effect. Which of the following statements is correct?', 'options': ['A. Mr Linguist must provide a translation of the specification into Dutch', 'B. Mr Linguist must provide a translation of the specification into an official language of any of the 18 states to which the unitary effect extends', 'C. Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA', 'D. Mr Linguist may provide a translation of the specification into Spanish']}
# Erreur parsing:
# <|im_start|><|im_start|>user
#
# It seems there was a misunderstanding. Here is the corrected text to be formatted as JSON:
#
# Answer: C.
#
# Explanation: According to Article 6(1) of Regulation (EU) No 1260/2012 and Unitary Patent Guide, para. 65, a translation may be in any of the 24 official languages of the EU, except English, irrespective of the language in which the application was filed or the geographical extent of the unitary effect. This means that Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA (Unified Patent Court Agreement). Hence, option C is correct.
#
# Explanation for why other options are incorrect:
# - Option A: While Dutch might be one of the languages in which the application was filed, the requirement is to provide a translation into an official language of any state with unitary effect, not necessarily the same as the language of filing. Therefore, it's not exclusive to Dutch.
# - Option B: This statement is too narrow as it only considers 18 states and does not cover all 24 EU member states that have signed the UPCA.
# - Option D: Spanish is one of the official languages of the EPC (European Patent Convention) but was not mentioned in the context provided for the unitary effect, making it an incorrect choice.
#
# Please convert this into JSON format.
# Attempt 1 failed. Retrying...
# {'total_answer': 29, 'correct_answer': 9}

# %% [markdown]
# ### embeddings_model = all-mpnet-base-v2

# %%
# test_embeddings_model(embeddings_model='sentence-transformers/all-mpnet-base-v2', chunk_size=512)

# %% [markdown]
# ## Test New Prompt without model 2 for json parsing
#
# C'est pas terrible donc  on a remise l'ancien système. Peut-être avec un meilleur prompt ?

# %%
# def generate_mcq_answer(question_mcq: str, model, knowledge_vector_db, reranker=False) -> dict:
#     """
#     Generates an answer for a MCQ question.

#     Parameters:
#     question_mcq (str): The input question_mcq for which an answer is needed.

#     Returns:
#     answer (str): The generated response from the AI with the context used.
#     """

#     # Convert the question in string, in case the question is a json.
#     question_mcq = str(question_mcq)

#     # Retrieve context
#     if reranker:
#         retrieved_docs = get_context(question_mcq, k=20, knowledge_vector_db=knowledge_vector_db)
#         retrieved_docs = reranker.rerank(question_mcq, retrieved_docs, k=5)
#     else:
#         retrieved_docs = get_context(question_mcq, k=5, knowledge_vector_db=knowledge_vector_db)

#     context = "\nExtracted documents:\n"
#     context += "".join([f'Content: {doc.page_content} \nSource: {doc.metadata['ref']}\n\n' for i, doc in enumerate(retrieved_docs)])
#     context_sources = "".join([f'\nSource: {doc.metadata['ref']}, Url: {doc.metadata.get('url', 'N/A')}' for i, doc in enumerate(retrieved_docs)])

#     # Build prompt
#     SYSTEM_PROMPT = f"""You are an AI specialized in answering multiple-choice legal questions based on given legal texts.
#     ### Instructions:
#     - Provide the correct answer.
#     - After that, explain why this choice is correct based on the provided legal context.
#     - Then, explain why the other choices (B, C, D) are incorrect, using relevant legal reasoning from the context.
#     - Format the output strictly as a JSON object with the following structure exemple:
#         ```json
#         {{"Answer": "A", "Justification": "..."}}
#     The Answer field must only contain the letter of the answer which is A, B, C or D. All other explainations have to be in Justification.
#     """

#     user_prompt = f"""
#     ### Context:
#     {context}

#     ### Legal Question:
#     {question_mcq}

#     Answer the question by:
#     1. Starting with the correct answer (e.g., "Answer A").
#     2. Explaining why this choice is correct according to the provided legal text.
#     3. Explaining why the other options (B, C, D) are incorrect based on the legal context.
#     Make sure to answer with the correct json format:
#     ```json
#         {{"Answer": "...", "Justification": "..."}}
#     The Answer field must only contain the letter of the answer which is A, B, C or D. All other explainations have to be in Justification.
#     """

#     # Initial attempt to get the answer
#     attempt_count = 0
#     max_attempts = 3  # Limit number of attempts to prevent infinite loops

#     while attempt_count < max_attempts:
#         answer_mcq = chat(model=model,
#                             messages=[{"role":"system", "content":SYSTEM_PROMPT},
#                                       {"role":"user","content":user_prompt}],
#                             options = {"num_predict":MAX_OUTPUT_TOKENS}
#                             )
#         try:
#             # Put answer in correct json format
#             # Regex pattern to capture the content of "Answer" and "Justification"
#             pattern = r'"Answer":\s*"([^"]+)"\s*,\s*"Justification":\s*"([^"]+)"'
#             matches = re.search(pattern, answer_mcq['message']['content'])

#             if matches:
#                 answer = matches.group(1)
#                 # check for a valid letter isolated
#                 match = re.search(r'\b[A-D]\b', answer)
#                 if match:
#                     answer = match.group()
#                     print(f'Final answer: {answer}')

#                 justification = matches.group(2)
                
#                 # Add context
#                 justification += f'\n\nSources:{context_sources}'
#                 print(f'Answer: {answer}, Justification: {justification}')
#                 return {'Answer': answer, 'Justification': justification}
            
#             else:
#                 print(f'Erreur parsing: {answer_mcq['message']['content']}')
#                 raise ValueError("Can't extract data.")
            

        
#         except:
#             attempt_count += 1  # Increment attempt count
#             print(f"Attempt {attempt_count} failed. Retrying...")
    
#     # If all attempts fail, raise an exception or return None
#     return {'Answer': 'Error', 'Justirifation': 'Error parsing json.'}
#     raise ValueError("Failed to generate a valid MCQ after multiple attempts.")

# %%
# Temp pour voir si second modèle bousille réponse
# import sys
# # Ouvrir un fichier pour enregistrer les prints
# log_file = open("logs/test_if_model_2_is_wrong.log", "w")
# # Sauvegarder l'ancien stdout
# old_stdout = sys.stdout  
# # Rediriger stdout vers le fichier
# sys.stdout = log_file 

knowledge_vector_db = load_rag_embeddings(path=f'../embeddings/rag_embeddings_sentence-transformers_all-MiniLM-L6-v2_chunk512',
                                            embeddings_model='sentence-transformers/all-MiniLM-L6-v2', 
                                            device='cuda')
evaluate_generate_mcq_answer(save_dir='../outputs/evaluation2/', data_dir='../outputs/',
                             test_name=f'sentence-transformers_all-MiniLM-L6-v2_qwen2_5_7b_chunk512_newPromptWithout2ndModel', model=reader,
                             knowledge_vector_db=knowledge_vector_db)

# sys.stdout = old_stdout  
# log_file.close()
# Out:
# embedding load
# {'question': 'A European patent was granted to a German company on 4  January 2023. No opposition was filed. Mr Li and Ms Smith were designated as inventors. On 12 October 2023,  the patent proprietor not ices that Ms Smith was erroneously designated as inventor and that Mr Li is the sole inventor.  Which of the following statements is correct?', 'options': ['A. Ms Smith will be deleted as inventor if the patent proprietor requests this in writing .', 'B. Ms Smith can no longer  be deleted as inventor because no proceedings are pending before the EPO .', "C. The patent proprietor can request that  Ms Smith be deleted as inventor but needs Mr Li 's consent  for this .", 'D. Ms Smith can only be deleted as inventor with her consent .']}
# {'question': 'A European patent was granted to a German company on 4  January 2023. No opposition was filed. Mr Li and Ms Smith were designated as inventors. On 12 October 2023,  the patent proprietor not ices that Ms Smith was erroneously designated as inventor and that Mr Li is the sole inventor.  Which of the following statements is correct?', 'options': ['A. Ms Smith will be deleted as inventor if the patent proprietor requests this in writing .', 'B. Ms Smith can no longer  be deleted as inventor because no proceedings are pending before the EPO .', "C. The patent proprietor can request that  Ms Smith be deleted as inventor but needs Mr Li 's consent  for this .", 'D. Ms Smith can only be deleted as inventor with her consent .']}
# Final answer: C
# Answer: C, Justification: According to Rule 21(1) EPC as stated in one of the legal bases provided, a wrong designation of an inventor can be corrected if requested by the patent proprietor. However, it also states that where the name of the inventor is not the same as recorded in the Register, the formalities officer will inform the patentee of the correct name. In this case, Ms Smith was erroneously designated as an inventor and Mr Li needs to give his consent for her deletion from the record. Therefore, option C is correct.
#
# Option A is incorrect because it does not mention the requirement of obtaining consent from Mr Li. The correction process must involve both the patentee and the person whose name is being corrected.
# Option B is incorrect because there can still be proceedings to correct the inventor's details even if no opposition has been filed against the European patent.
# Option D is incorrect as it suggests that only Ms Smith's consent is required, whereas according to Rule 21(1) EPC, Mr Li needs to give his consent for her deletion.
#
# Sources:
# Source: Case Law IV, C.2.2.5, Url: https://www.epo.org/en/legal/case-law/2022/clr_iv_c_2_2_5.html
# Source: 2023_EPAC_mcq_solution.json, Url: N/A
# Source: Guidelines for Examination in the EPO, D-IV, 5.5, Url: https://www.epo.org/en/legal/guidelines-epc/2024/d_iv_5_5.html
# Source: Guidelines for Examination in the EPO, D-IV, 1.2.2.2, Url: https://www.epo.org/en/legal/guidelines-epc/2024/d_iv_1_2_2_2.html
# Source: Case Law III, A.3.7, Url: https://www.epo.org/en/legal/case-law/2022/clr_iii_a_3_7.html
# {'question': "On 10 October 2021, European patent attorney X filed European patent application EP -A with the EPO on the applicant's behalf. Application EP -A was published on 12 April 2023, together  with the extended European search report. On 6  October 2023, the applicant contacts a new European patent attorney  Y to replace X as representative and issues Y with its instructions to reply to the extended European search report. The applicant did not inform X that he would be replaced.  What are the steps necessary to validly appoint representative Y and to avoid any loss of rights for European patent application EP -A?", 'options': ['A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant .', 'B. New representative Y requests a change of representative and files a response to the extended European search report with  the EPO by 12 October 2023 at the latest .', 'C. New representative Y requests a change of representative and files a response to the extended European search report with the EPO by 23 October 2023 at the latest.', 'D. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 23 October 2023 at the latest and files in good time an authorisation signed by the applicant .']}
# {'question': "On 10 October 2021, European patent attorney X filed European patent application EP -A with the EPO on the applicant's behalf. Application EP -A was published on 12 April 2023, together  with the extended European search report. On 6  October 2023, the applicant contacts a new European patent attorney  Y to replace X as representative and issues Y with its instructions to reply to the extended European search report. The applicant did not inform X that he would be replaced.  What are the steps necessary to validly appoint representative Y and to avoid any loss of rights for European patent application EP -A?", 'options': ['A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant .', 'B. New representative Y requests a change of representative and files a response to the extended European search report with  the EPO by 12 October 2023 at the latest .', 'C. New representative Y requests a change of representative and files a response to the extended European search report with the EPO by 23 October 2023 at the latest.', 'D. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 23 October 2023 at the latest and files in good time an authorisation signed by the applicant .']}
# Final answer: A
# Answer: A, Justification: According to Rule 142(3) (i) from the Guidelines for Examination in the EPO, if Article 133(2) is applicable (mandatory appointment of a representative), the European patent application will be deemed withdrawn or the European patent revoked if information about the new representative is not submitted within two months after this communication. In this scenario, the earliest date to submit the change of representative and response would be on or before 12 October 2023 (two months from 6 October), thus Option A is correct.
#
# Option B is incorrect because it omits the requirement for an authorisation signed by the applicant, which is necessary as per Rule 142(3) (i).
#
# Option C is incorrect because it extends the deadline to 23 October 2023, which is beyond the two-month period specified in Rule 142(3) (i), leading to potential revocation of the application or patent.
#
# Option D is also incorrect for the same reason as Option B - it includes a date that exceeds the allowable time frame and adds an unnecessary step by mentioning 'in good time' which is not explicitly required but could imply exceeding the two-month period.
#
# Sources:
# Source: 2023_EPAC_mcq_solution.json, Url: N/A
# Source: EPC Rule 143, Url: https://www.epo.org/en/legal/epc/2020/r143.html
# Source: EPC Rule 151, Url: https://www.epo.org/en/legal/epc/2020/r151.html
# Source: Guidelines for Examination in the EPO, E-VII, 1.4, Url: https://www.epo.org/en/legal/guidelines-epc/2024/e_vii_1_4.html
# Source: Guidelines for Examination in the EPO, E-X, 2.2, Url: https://www.epo.org/en/legal/guidelines-epc/2024/e_x_2_2.html
# {'question': 'EP-1 is a regular European patent application (Euro -direct application) .  Which one of the following missed time limits can be remedied for EP -1 before the EPO by requesting re- establishment of rights ?', 'options': ['A. T ime limit for pay ing the designation fee', 'B. T ime limit for requesting examination', 'C. T ime limit for filing the application within the priority period', 'D. T ime limit for paying the fee for re- establishment of rights']}
# {'question': 'EP-1 is a regular European patent application (Euro -direct application) .  Which one of the following missed time limits can be remedied for EP -1 before the EPO by requesting re- establishment of rights ?', 'options': ['A. T ime limit for pay ing the designation fee', 'B. T ime limit for requesting examination', 'C. T ime limit for filing the application within the priority period', 'D. T ime limit for paying the fee for re- establishment of rights']}
# Final answer: A
# Answer: A, Justification: The correct answer is A. According to the provided legal text, an applicant for a European patent can apply to have their rights re-established if they were unable to observe a time limit vis-à-vis the EPO despite taking all due care required by the circumstances (see Guidelines for Examination in the EPO, E-VIII, 3). This includes missed payment deadlines such as the designation fee. The text does not specifically mention that re-establishment of rights can be used for other time limits like requesting examination, filing within the priority period, or paying a fee for re-establishment (options B, C, and D).
#
# Option B is incorrect because the text outlines specific procedures for requesting further processing, which are different from re-establishment of rights. The process for re-establishing rights does not cover missed deadlines for actions like requesting examination.
#
# Option C is incorrect as there is no mention of using re-establishment of rights for filing within the priority period. Generally, such issues would be resolved by re-filing the application or other means, but this specific context in the text does not indicate that re-establishment of rights can be used here.
#
# Option D is incorrect because paying a fee for re-establishment itself cannot be remedied through re-establishment of rights; it’s the missed payment deadline that could potentially be resolved by applying for re-establishment. The process of requesting re-establishment of rights does not involve an additional fee payment.
#
# Sources:
# Source: Guidelines for Examination in the EPO, E-VIII, 2, Url: https://www.epo.org/en/legal/guidelines-epc/2024/e_viii_2.html
# Source: Guidelines for Examination in the EPO, E-VIII, 3, Url: https://www.epo.org/en/legal/guidelines-epc/2024/e_viii_3.html
# Source: Guidelines for Examination in the EPO, A-II, 4.1.4, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_ii_4_1_4.html
# Source: Guidelines for Examination in the EPO, A-III, 6.8, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_iii_6_8.html
# Source: Guidelines for Examination in the EPO, A-III, 11.3, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_iii_11_3.html
# {'question': 'Last week Greta validly filed the international patent application PCT -G with the German Patent and Trade mark Office ( DPMA ) and appointed Hassan to represent her. Hassan is entitled to act before the DPMA  but he is not a European patent attorney. Greta and Hassan are resident in Germany.  Which of the following statements is not correct?', 'options': ['A. Hassan can represent Greta before the EPO acting as the International Searching Authority for PCT -G.', 'B. In order for Hassan to be able to act before the EPO acting as the International Searching Authority , he needs to submit a power of attorney signed by Greta.', 'C. According to the provisions of the PCT, it is mandatory that the d emand for international preliminary examination is signed by Greta or Hassan.', 'D. According to the provisions of the PCT, an international application can only be withdrawn by the applicant or an agent appointed by a power of attorney.']}
# {'question': 'Last week Greta validly filed the international patent application PCT -G with the German Patent and Trade mark Office ( DPMA ) and appointed Hassan to represent her. Hassan is entitled to act before the DPMA  but he is not a European patent attorney. Greta and Hassan are resident in Germany.  Which of the following statements is not correct?', 'options': ['A. Hassan can represent Greta before the EPO acting as the International Searching Authority for PCT -G.', 'B. In order for Hassan to be able to act before the EPO acting as the International Searching Authority , he needs to submit a power of attorney signed by Greta.', 'C. According to the provisions of the PCT, it is mandatory that the d emand for international preliminary examination is signed by Greta or Hassan.', 'D. According to the provisions of the PCT, an international application can only be withdrawn by the applicant or an agent appointed by a power of attorney.']}
# Final answer: A
# Answer: A, Justification: According to PCT Article 16 (2), if several International Searching Authorities are involved, each receiving Office should specify the competent International Searching Authority or Authorities. However, it does not mention that a representative appointed for national proceedings can also act as an International Searching Authority. Thus, statement A is incorrect.
#
# Statement B is correct: According to PCT Article 18 (2), a power of attorney from the applicant is required before a representative can act on their behalf at the EPO or any other receiving Office, including in international searches.
#
# Regarding Statement C, according to PCT Article 34(1), an international preliminary examination is initiated by the International Preliminary Examining Authority and must be requested by the applicant (or their agent with a power of attorney). Therefore, it is not mandatory that the demand for international preliminary examination be signed solely by Greta or Hassan.
#
# Statement D is correct: According to PCT Rule 65(1), an application can only be withdrawn by the applicant or an authorized representative acting under a power of attorney. Hence, this statement aligns with the provided legal text.
#
# Sources:
# Source: Case Law VI, 3.1, Url: https://www.epo.org/en/legal/case-law/2022/clr_vi_3_1.html
# Source: Case Law VI, 1, Url: https://www.epo.org/en/legal/case-law/2022/clr_vi_1.html
# Source: PCT Article 34, Url: https://www.wipo.int/pct/en/texts//articles/a34.html
# Source: EPC Rule 161, Url: https://www.epo.org/en/legal/epc/2020/r161.html
# Source: PCT Article 16, Url: https://www.wipo.int/pct/en/texts//articles/a16.html
# {'question': 'In which of the following cases is the applicant entitled to a reduction of the filing fee  under Rule  6 EPC ? A declaration of such entitlement has  been made by crossing the relevant box on Form  1001.', 'options': ['A. A Spanish European patent attorney files a European patent application in Spanish for a natural person who is resident in Andorra and of Andorra n nationality .', 'B. A firm whose principal place of business is in Germany and a natural person who is resident in Germany  and of Dutch nationality  jointly file a European patent application in Dutch. The German firm employs 200 people with an annual turnover of EUR 60 million.', 'C. A natural person resident in the USA and of Belgian nationality files a European patent application in French.', 'D. A natural person resident in the USA and of Swiss nationality files a European patent application in Italian.']}
# {'question': 'In which of the following cases is the applicant entitled to a reduction of the filing fee  under Rule  6 EPC ? A declaration of such entitlement has  been made by crossing the relevant box on Form  1001.', 'options': ['A. A Spanish European patent attorney files a European patent application in Spanish for a natural person who is resident in Andorra and of Andorra n nationality .', 'B. A firm whose principal place of business is in Germany and a natural person who is resident in Germany  and of Dutch nationality  jointly file a European patent application in Dutch. The German firm employs 200 people with an annual turnover of EUR 60 million.', 'C. A natural person resident in the USA and of Belgian nationality files a European patent application in French.', 'D. A natural person resident in the USA and of Swiss nationality files a European patent application in Italian.']}
# Final answer: B
# Answer: B, Justification: According to Rule 6 EPC, a reduction in filing fees can be granted if the applicant is a resident of a country that provides for such reductions under national law or if they are a firm with at least 20 employees and an annual turnover of at least EUR 3 million. Option B describes a situation where a German firm, which employs over 200 people and has an annual turnover of more than EUR 60 million, files a European patent application in Dutch with a natural person resident in Germany as co-applicant. Both conditions are met, making this the correct scenario for a reduction in filing fees.
#
# Option A is incorrect because while a Spanish European patent attorney can file in Spanish, the applicant's nationality and residence (resident in Andorra and of Andorra nationality) do not qualify for a reduced fee under Rule 6 EPC as there is no specific provision for residents or nationals of Andorra.
#
# Option C is incorrect since a natural person resident in the USA and of Belgian nationality filing in French does not meet any criteria for reduced fees as per Rule 6 EPC.
#
# Option D is similarly incorrect, as a natural person resident in the USA and of Swiss nationality cannot qualify for a reduction under Rule 6 EPC due to neither their residence nor nationality fitting the specified conditions.
#
# Sources:
# Source: EPC Article 58, Url: https://www.epo.org/en/legal/epc/2020/a58.html
# Source: EPC Article 75, Url: https://www.epo.org/en/legal/epc/2020/a75.html
# Source: EPC Rule 152, Url: https://www.epo.org/en/legal/epc/2020/r152.html
# Source: Case Law IV, A.4, Url: https://www.epo.org/en/legal/case-law/2022/clr_iv_a_4.html
# Source: Case Law II, E.1.2.3, Url: https://www.epo.org/en/legal/case-law/2022/clr_ii_e_1_2_3.html
# {'question': 'Mr Van Holland is a Dutch citizen resident in the Netherlands. He filed a European patent application EP -parent in Dutch, together with  a translation into English. Whil e EP-parent was pending, Mr Van Holland filed a divisional application EP -div in Dutch and requested examination in Dutch. He paid all fees due for EP -div. He has not filed an English translation of EP -div. The Receiving Section has now issued a noting of l oss of rights.  Which of the following statements is correct?', 'options': ['A. The deficiency cannot be remedied.', 'B. Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication  under Rule 112(1) EPC .', 'C. Mr Van Holland needs to file an English translation of EP -div together with a request for f urther processing.', 'D. Mr Van Holland needs to file an English translation of EP -div together with a request for re- establishment of rights.']}
# {'question': 'Mr Van Holland is a Dutch citizen resident in the Netherlands. He filed a European patent application EP -parent in Dutch, together with  a translation into English. Whil e EP-parent was pending, Mr Van Holland filed a divisional application EP -div in Dutch and requested examination in Dutch. He paid all fees due for EP -div. He has not filed an English translation of EP -div. The Receiving Section has now issued a noting of l oss of rights.  Which of the following statements is correct?', 'options': ['A. The deficiency cannot be remedied.', 'B. Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication  under Rule 112(1) EPC .', 'C. Mr Van Holland needs to file an English translation of EP -div together with a request for f urther processing.', 'D. Mr Van Holland needs to file an English translation of EP -div together with a request for re- establishment of rights.']}
# Final answer: B
# Answer: B, Justification: The correct answer is B because according to the legal text provided in R.36(2), if a European divisional application is filed and it is not in an official EPO language, then within two months of filing, a translation into the language of the proceedings of the earlier (parent) application must be filed. In this case, since Mr Van Holland's parent application was filed in Dutch, which is an admissible non-EPO language under R.6(3)-(7), he needs to file an English translation of EP-div within two months of notification of the communication under Rule 112(1) EPC (as per B option).
#
# Option A states that the deficiency cannot be remedied, which is incorrect because a remedy exists as outlined in R.36(2).
#
# Option C suggests filing both an English translation and a request for further processing, but this is not necessary according to the legal text provided. Filing the required translation within two months suffices.
#
# Option D proposes filing an English translation and a request for re-establishment of rights. This is incorrect because there is no indication that Mr Van Holland has lost his rights due to non-compliance with language requirements, only that he needs to file the translation as per R.36(2). The process does not involve requesting re-establishment of rights.
#
# Sources:
# Source: Guidelines for Examination in the EPO, A-III, 6.8.3, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_iii_6_8_3.html
# Source: Guidelines for Examination in the EPO, A-III, 14, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_iii_14.html
# Source: Guidelines for Examination in the EPO, C-V, 1.3, Url: https://www.epo.org/en/legal/guidelines-epc/2024/c_v_1_3.html
# Source: Guidelines for Examination in the EPO, A-VII, 1.3, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_vii_1_3.html
# Source: Case Law III, F.1, Url: https://www.epo.org/en/legal/case-law/2022/clr_iii_f_1.html
# {'question': 'On 16  November 2020, you filed a European patent application EP -A, which did not claim priority. Today, 12  October 2023, you receive a communication from the EPO entitled " Decision to grant a European patent pursuant to Article  97(1) EPC ". This communication state s that the mention of the grant You wish to validate the patent in only two contracting states  to the EPC . Which of the following statements is correct?', 'options': ['A. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 16 November 2023.', 'B. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 30 November 2023.', 'C. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 9 January 2024 at the latest .', 'D. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 16 January 2024 at the latest .']}
# {'question': 'On 16  November 2020, you filed a European patent application EP -A, which did not claim priority. Today, 12  October 2023, you receive a communication from the EPO entitled " Decision to grant a European patent pursuant to Article  97(1) EPC ". This communication state s that the mention of the grant You wish to validate the patent in only two contracting states  to the EPC . Which of the following statements is correct?', 'options': ['A. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 16 November 2023.', 'B. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 30 November 2023.', 'C. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 9 January 2024 at the latest .', 'D. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 16 January 2024 at the latest .']}
# Final answer: B
# Answer: B, Justification: The correct answer is B. According to Rule 51(2) of the EPC, if a renewal fee is not paid on the due date, it may still be paid within six months from that date, provided an additional fee is also paid within that period. The legal consequence laid down in Article 86, paragraph 1, will ensue upon expiry of the six-month period.
#
# The communication states that the decision to grant a European patent was notified on 8 January 2014, which means the fourth year's renewal fee falls due on 30 November 2023 (as per Rule 51(1)). Thus, the renewal fee for the fourth year must be paid centrally to the EPO and the due date is 30 November 2023.
#
# Option A is incorrect because it states the due date is on 16 November 2023, which is not in accordance with Rule 51(1) of the EPC.
#
# Option C is incorrect because although it correctly identifies that the renewal fee must be paid separately in each state where the patent is validated (Article 87 and Article 141 EPC), it incorrectly states that the fourth year's renewal fee can be validly paid until January 9, 2024. According to Rule 51(2) of the EPC, the time limit for paying the additional fee within six months from the due date is 30 May 2024.
#
# Option D is incorrect because it also states the renewal fee can be paid until January 16, 2024. The same reasoning applies as with Option C: according to Rule 51(2) of the EPC, the time limit for paying the additional fee within six months from the due date is 30 May 2024.
#
# Sources:
# Source: Guidelines for Examination in the EPO, A-X, 5.2.4, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_x_5_2_4.html
# Source: Guidelines for Examination in the EPO, A-X, 5.2.4, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_x_5_2_4.html
# Source: Guidelines for Examination in the EPO, A-X, 5.2.4, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_x_5_2_4.html
# Source: EPC Rule 51, Url: https://www.epo.org/en/legal/epc/2020/r51.html
# Source: 2023_EPAC_mcq_solution.json, Url: N/A
# {'question': 'During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?', 'options': ['A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.', 'B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.', 'C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.', 'D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months.']}
# {'question': 'During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?', 'options': ['A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.', 'B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.', 'C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.', 'D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months.']}
# Final answer: C
# Answer: C, Justification: Option C is correct because according to the Guidelines for Examination in the EPO, H-III, 2.3, an invitation should be sent together with the interlocutory decision requesting payment of the fee for publishing a new specification, filing translations of the claims and providing a formally compliant version of the amended paragraph.
#
# Option A is incorrect because it states that the patent proprietor must request these actions upon submission of the request, which contradicts the guideline that an invitation should be sent with the interlocutory decision.
#
# Option B is incorrect since it implies that the patent proprietor would not have to comply during appeal proceedings when in fact, the EPO still requires such compliance even if no appeal is filed. The requirement for payment and submission of a formally compliant version remains regardless of whether there is an ongoing appeal or not as per H-III, 2.3.
#
# Option D is incorrect because it specifies that the deadline to comply should be four months after interlocutory decision, which is consistent with normal practice but contradicts the more specific directive in option C regarding the timing and form of compliance.
#
# Sources:
# Source: Guidelines for Examination in the EPO, D-VI, 7.2.3, Url: https://www.epo.org/en/legal/guidelines-epc/2024/d_vi_7_2_3.html
# Source: Guidelines for Examination in the EPO, H-III, 2.3, Url: https://www.epo.org/en/legal/guidelines-epc/2024/h_iii_2_3.html
# Source: Guidelines for Examination in the EPO, D-VI, 7.2.1, Url: https://www.epo.org/en/legal/guidelines-epc/2024/d_vi_7_2_1.html
# Source: Guidelines for Examination in the EPO, D-IV, 5.3, Url: https://www.epo.org/en/legal/guidelines-epc/2024/d_iv_5_3.html
# Source: Guidelines for Examination in the EPO, H-IV, 5.3, Url: https://www.epo.org/en/legal/guidelines-epc/2024/h_iv_5_3.html
# {'question': 'Under the PCT, what is the time limit for filing a request for rectification of an obvious mistake made in the international application?', 'options': ['A. 18 months from the earliest priority date', 'B. 30 months from the earliest priority date', 'C. 22 months from the earliest priority date', 'D. 26 months from the earliest priority date']}
# {'question': 'Under the PCT, what is the time limit for filing a request for rectification of an obvious mistake made in the international application?', 'options': ['A. 18 months from the earliest priority date', 'B. 30 months from the earliest priority date', 'C. 22 months from the earliest priority date', 'D. 26 months from the earliest priority date']}
# Final answer: A
# Answer: A, Justification: According to Rule 52(3) EPC as provided by the PCT legal text, an applicant may correct a declaration of priority within 'sixteen months from the earliest priority date claimed, or, where the correction would cause a change in the earliest priority date claimed, within sixteen months from the correct earliest priority date, whichever sixteen-month period expires first'. However, this rule is subject to the condition that such correction must be submitted until the expiry of four months from the date of filing accorded to the European patent application. Therefore, considering both periods together (16 + 4 = 20), and given that the options provided are all greater than 20 but only one matches the closest lower value in terms of the rule's context, it can be inferred that 'sixteen months' aligns with answer A. Other options B, C, D (30, 22, 26 months) do not match this period and thus are incorrect based on the provided text.
#
# Sources:
# Source: 2023_EPAC_mcq_solution.json, Url: N/A
# Source: PCT Rule 17, Url: https://www.wipo.int/pct/en/texts//rules/r17.html
# Source: PCT Rule 26, Url: https://www.wipo.int/pct/en/texts//rules/r26.html
# Source: PCT Rule 64, Url: https://www.wipo.int/pct/en/texts//rules/r64.html
# Source: Case Law IV, A.8.2.3, Url: https://www.epo.org/en/legal/case-law/2022/clr_iv_a_8_2_3.html
# {'question': 'After receipt of a negative written opinion issued by the EPO acting as ISA, amendments under Art icle 19 PCT were filed during the international phase. No request for international preliminary examination was filed. Form  1200 was used,  and no further amendments were filed with the EPO upon entry into the regional phase.   What communication under Rules  161/162 EPC will be received in the regional phase?', 'options': ['A. Form 1226AA ;  if you do not reply to it in time, the application will be deemed to be withdrawn', 'B. Form 1226BB offering the opportunity to comment and file amendments', 'C. Form 1226CC offering the opportunity to file amendments before the supplementary European search report is drawn up', 'D. Form 1226AC stating that the examination has started']}
# {'question': 'After receipt of a negative written opinion issued by the EPO acting as ISA, amendments under Art icle 19 PCT were filed during the international phase. No request for international preliminary examination was filed. Form  1200 was used,  and no further amendments were filed with the EPO upon entry into the regional phase.   What communication under Rules  161/162 EPC will be received in the regional phase?', 'options': ['A. Form 1226AA ;  if you do not reply to it in time, the application will be deemed to be withdrawn', 'B. Form 1226BB offering the opportunity to comment and file amendments', 'C. Form 1226CC offering the opportunity to file amendments before the supplementary European search report is drawn up', 'D. Form 1226AC stating that the examination has started']}
# Final answer: B
# Answer: B, Justification: According to the provided legal text and context, after receipt of a negative written opinion issued by the EPO acting as ISA (which corresponds with Article 19(1) PCT), amendments were filed during the international phase. Since no request for an International Preliminary Examination was filed and no further amendments were filed upon entry into the regional phase, Form 1226BB will be received in the regional phase. This form offers the opportunity to comment and file further amendments (Rule 161(2), E-IX, 3).
#
# Option A is incorrect because if there were no amendments filed with the EPO upon entry into the regional phase, it would not meet the criteria for a deemed withdrawal due to non-response.
#
# Option C is incorrect as no request for an International Preliminary Examination was filed, so the opportunity to file amendments before the supplementary European search report (Rule 161(2)) does not apply in this scenario.
#
# Option D is incorrect because the examination has not started yet since there are still opportunities for the applicant to provide comments and potentially file further amendments.
#
# Sources:
# Source: Guidelines for Examination in the EPO, C-III, 2.2, Url: https://www.epo.org/en/legal/guidelines-epc/2024/c_iii_2_2.html
# Source: Guidelines for Examination in the EPO, E-IX, 3.3.1, Url: https://www.epo.org/en/legal/guidelines-epc/2024/e_ix_3_3_1.html
# Source: Guidelines for Examination in the EPO, E-IX, 2.9.1, Url: https://www.epo.org/en/legal/guidelines-epc/2024/e_ix_2_9_1.html
# Source: Guidelines for Examination in the EPO, B-III, 3.3.2, Url: https://www.epo.org/en/legal/guidelines-epc/2024/b_iii_3_3_2.html
# Source: 2023_EPAC_mcq_solution.json, Url: N/A
# {'question': 'Company M, which has  its principal place of business in Tijuana, Mexico, validly filed an international patent application PCT -M with the Mexican Institute of Industrial Property. The application was filed in Spanish. A few days later, the applicant files an English translati on of the application.  Which of the following statements is correct?', 'options': ['A. The applicant can choose the EPO as ISA and the USPTO as IPEA.', 'B. The applicant can choose the USPTO as ISA and the EPO as IPEA.', 'C. The applicant can choose the Austrian Patent Offic e as ISA and the', 'EPO as IPEA.', 'D. The applicant can choose the EPO as ISA and the Intellectual Property', 'Office of Singapore as IPEA.']}
# {'question': 'Company M, which has  its principal place of business in Tijuana, Mexico, validly filed an international patent application PCT -M with the Mexican Institute of Industrial Property. The application was filed in Spanish. A few days later, the applicant files an English translati on of the application.  Which of the following statements is correct?', 'options': ['A. The applicant can choose the EPO as ISA and the USPTO as IPEA.', 'B. The applicant can choose the USPTO as ISA and the EPO as IPEA.', 'C. The applicant can choose the Austrian Patent Offic e as ISA and the', 'EPO as IPEA.', 'D. The applicant can choose the EPO as ISA and the Intellectual Property', 'Office of Singapore as IPEA.']}
# Final answer: A
# Answer: A, Justification: According to the provided legal text from the Guidelines for Examination in the EPO, A-VII, 1.3, a European divisional application must be filed in the language of the proceedings of the earlier (parent) application. Alternatively, if the parent application was not in an official EPO language, the divisional application may be filed in the language of the earlier (parent) application and then a translation into the language of the proceedings of the earlier application must be filed within two months.
#
# Option A: The applicant can choose the EPO as ISA (International Searching Authority) and the USPTO as IPEA (International Preliminary Examining Authority). This is possible because both the EPO and the USPTO are recognized international patent offices, allowing an applicant to file their application with either or both.
#
# Option B: The applicant can choose the USPTO as ISA and the EPO as IPEA. This option is also valid for similar reasons mentioned above.
#
# Option C and D: The provided text does not mention any specific conditions that would invalidate options involving Austrian Patent Office, Intellectual Property Office of Singapore or any other office, in relation to the filing requirements of Spanish translations into English under the context given.
#
# Therefore, options B, C, and D are all valid choices based on the information provided. However, since only one option must be selected from A to D as per the question structure, Option A is selected as it directly relates to the EPO being chosen alongside another international office, matching the format of the provided options.
#
# Sources:
# Source: Guidelines for Examination in the EPO, A-III, 14, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_iii_14.html
# Source: 2023_EPAC_mcq_solution.json, Url: N/A
# Source: Guidelines for Examination in the EPO, A-III, 4.2.1, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_iii_4_2_1.html
# Source: Guidelines for Examination in the EPO, A-III, 6.8.3, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_iii_6_8_3.html
# Source: Guidelines for Examination in the EPO, A-VII, 1.3, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_vii_1_3.html
# {'question': 'On 20  June 2023, applicant P validly filed an international patent application PCT-P, claiming priority from European patent application EP -I filed on 7 July 2022. Today, 12 October 2023, he discovers that he should also have claimed priority from EP -II filed on 3 July 2022. Can the missing priority claim still be validly added?', 'options': ['A. Yes, the time  limit for adding the priority claim expires on 3  November 2023.', 'B. Yes, the time limit for adding the priority claim expires on 7  November 2023.', 'C. Yes, the time  limit for adding the priority claim expires on 20 October 2023.', 'D. No, the time  limit for adding the priority claim expired on 3 July 2023.']}
# {'question': 'On 20  June 2023, applicant P validly filed an international patent application PCT-P, claiming priority from European patent application EP -I filed on 7 July 2022. Today, 12 October 2023, he discovers that he should also have claimed priority from EP -II filed on 3 July 2022. Can the missing priority claim still be validly added?', 'options': ['A. Yes, the time  limit for adding the priority claim expires on 3  November 2023.', 'B. Yes, the time limit for adding the priority claim expires on 7  November 2023.', 'C. Yes, the time  limit for adding the priority claim expires on 20 October 2023.', 'D. No, the time  limit for adding the priority claim expired on 3 July 2023.']}
# Final answer: B
# Answer: B, Justification: The correct answer is B because under Article 87(4) of the EPC as per the provided legal text, if multiple priorities are claimed for a European patent application, time limits which run from the date of priority will run from the earliest date of priority. In this case, EP-I was filed on July 7, 2022, and EP-II on July 3, 2022, with EP-II being earlier. The applicant originally claimed priority to EP-I in the international application PCT-P on June 20, 2023. According to Rule 19(1) of the EPC, the time limit for claiming a missing priority is two months from the filing date of the original application (in this case, PCT-P), which would end on August 20, 2023.
#
# However, since EP-II was filed earlier, the period to claim its priority should run from July 3, 2022. Therefore, the time limit for adding the priority claim expires two months after that date, or by November 3, 2023.
#
# Option A is incorrect because it suggests the period ends on November 3, not considering EP-II's filing date.
# Option C is incorrect as the period would end in August 2023, not October 2023.
# Option D is incorrect since the time limit for adding the priority claim did not expire until two months after July 3, 2023, which was on September 2, 2023.
#
# Sources:
# Source: Guidelines for Examination in the EPO, A-III, 6.6, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_iii_6_6.html
# Source: Case Law IV, A.8.2.3, Url: https://www.epo.org/en/legal/case-law/2022/clr_iv_a_8_2_3.html
# Source: Guidelines for Examination in the EPO, A-III, 6.9, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_iii_6_9.html
# Source: Guidelines for Examination in the EPO, E-IX, 2.3.5, Url: https://www.epo.org/en/legal/guidelines-epc/2024/e_ix_2_3_5.html
# Source: EPC Article 88, Url: https://www.epo.org/en/legal/epc/2020/a88.html
# {'question': 'The opposition division revoked European patent EP -B1. The patent proprietor filed an appeal  in time . The b oard of appeal forwarded a copy of the appeal to the o pponent/ respondent with a communication dated 1 June 2023 giving it an opportunity to file comments within a period of four  months.  The opponent/respondent files comments today, 12 October 2023. What further action has to be taken ?', 'options': ['A. The opponent/ respondent needs  to request an extension of the period for comment.', 'B. The opponent/respondent needs to pay a fee for further processing.', 'C. The opponent/respondent needs to file a substantiated request for reestablishment of rights and pay the associated fee.', 'D. None of the above.']}
# {'question': 'The opposition division revoked European patent EP -B1. The patent proprietor filed an appeal  in time . The b oard of appeal forwarded a copy of the appeal to the o pponent/ respondent with a communication dated 1 June 2023 giving it an opportunity to file comments within a period of four  months.  The opponent/respondent files comments today, 12 October 2023. What further action has to be taken ?', 'options': ['A. The opponent/ respondent needs  to request an extension of the period for comment.', 'B. The opponent/respondent needs to pay a fee for further processing.', 'C. The opponent/respondent needs to file a substantiated request for reestablishment of rights and pay the associated fee.', 'D. None of the above.']}
# Final answer: A
# Answer: A, Justification: According to EPC Rule 100(3), if the applicant fails to reply in due time to an invitation issued by the Board of Appeal, the European patent application is deemed to be withdrawn. In this case, the opponent/ respondent has filed comments beyond the four-month period specified in the communication from the board of appeal. Therefore, they need to request an extension of the period for comment.
#
# Option B (pay a fee for further processing) and Option C (file a substantiated request for reestablishment of rights and pay the associated fee) are incorrect because there is no indication that any procedural error has occurred or that the opponent/ respondent needs to reestablish their rights. The situation calls for an extension of time as per Rule 100(3).
#
# Option D (none of the above) is incorrect because Option A is a valid course of action based on the provided legal text.
#
# Sources:
# Source: Guidelines for Examination in the EPO, D-IV, 5.2, Url: https://www.epo.org/en/legal/guidelines-epc/2024/d_iv_5_2.html
# Source: EPC Rule 81, Url: https://www.epo.org/en/legal/epc/2020/r81.html
# Source: Guidelines for Examination in the EPO, D-IV, 5.5, Url: https://www.epo.org/en/legal/guidelines-epc/2024/d_iv_5_5.html
# Source: Case Law IV, C.4.3.1, Url: https://www.epo.org/en/legal/case-law/2022/clr_iv_c_4_3_1.html
# Source: EPC Rule 100, Url: https://www.epo.org/en/legal/epc/2020/r100.html
# {'question': 'A European patent application was filed on 20 March 2020. Proceedings were interrupted under  Rule 142 EPC on 10  March 2022. The applicant was informed that proceedings would be resumed today, 12 October 2023. No renewal fee has been paid so far . Which of the following statements is correct?', 'options': ['A. As no renewal fees have been paid, the application is deemed to be withdrawn .', 'B. The renewal fees for the third and fourth years can be validly paid without any additional fee on 12 October 2023 at the latest .', 'C. The renewal fees for the third and fourth years can be validly paid with an additional  fee by 30  April 2024 at the latest .', 'D. The renewal fees for the third and fourth years can be validly paid without any additional fee by 31  October 2023 at the latest .']}
# {'question': 'A European patent application was filed on 20 March 2020. Proceedings were interrupted under  Rule 142 EPC on 10  March 2022. The applicant was informed that proceedings would be resumed today, 12 October 2023. No renewal fee has been paid so far . Which of the following statements is correct?', 'options': ['A. As no renewal fees have been paid, the application is deemed to be withdrawn .', 'B. The renewal fees for the third and fourth years can be validly paid without any additional fee on 12 October 2023 at the latest .', 'C. The renewal fees for the third and fourth years can be validly paid with an additional  fee by 30  April 2024 at the latest .', 'D. The renewal fees for the third and fourth years can be validly paid without any additional fee by 31  October 2023 at the latest .']}
# Erreur parsing:
# ```json
#     {
#       "Answer": "B",
# ...
# Final answer: B
# Answer: B, Justification: The correct functionalities/services that can be accessed directly from MyEPO Portfolio are 'Mailbox' and a shared area with examiners, as stated by the text: \
#
# Sources:
# Source: 2024_EPAC_mcq_solution.json, Url: N/A
# Source: EPC Rule 2, Url: https://www.epo.org/en/legal/epc/2020/r2.html
# Source: Guidelines for Examination in the EPO, A-II, 1.1.1, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_ii_1_1_1.html
# Source: Guidelines for Examination in the EPO, A-X, 10.2.1, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_x_10_2_1.html
# Source: Guidelines for Examination in the EPO, A-XI, 2.5, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_xi_2_5.html
# {'question': 'In which of the following situations does the EPO recommend using the EPO Contingency Upload Service?', 'options': ['A. When you submit documents after business hours', 'B. When the EPO filing systems are functioning correctly, but you encounter a technical issue at your end', 'C. When there is a system outage at the EPO that prevents document submission via the standard filing systems', 'D. When the EPO is closed due to an official holiday']}
# {'question': 'In which of the following situations does the EPO recommend using the EPO Contingency Upload Service?', 'options': ['A. When you submit documents after business hours', 'B. When the EPO filing systems are functioning correctly, but you encounter a technical issue at your end', 'C. When there is a system outage at the EPO that prevents document submission via the standard filing systems', 'D. When the EPO is closed due to an official holiday']}
# Final answer: C
# Answer: C, Justification: The EPO Contingency Upload Service is mentioned in the context where it states that priority documents may not be filed using certain services, including the EPO web-form filing service or the EPO Contingency Upload Service. This implies that the use of such a contingency service would be recommended when there is a system outage at the EPO preventing document submission via standard means (option C).
#
# Option A ('When you submit documents after business hours') is incorrect because the EPO Contingency Upload Service is not specifically mentioned as a solution for late submissions.
#
# Option B ('When the EPO filing systems are functioning correctly, but you encounter a technical issue at your end') is also incorrect. The service is meant to be used in situations where there's an outage or when standard services cannot be used due to system issues, not because of personal technical problems.
#
# Option D ('When the EPO is closed due to an official holiday') is irrelevant as the service is designed for use during operational hours and in specific system-related contingencies rather than office closures.
#
#
# Sources:
# Source: 2024_EPAC_mcq_solution.json, Url: N/A
# Source: Guidelines for Examination in the EPO, A-III, 6.7, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_iii_6_7.html
# Source: Guidelines for Examination in the EPO, E-VIII, 7, Url: https://www.epo.org/en/legal/guidelines-epc/2024/e_viii_7.html
# Source: Guidelines for Examination in the EPO, C-III, 4.2, Url: https://www.epo.org/en/legal/guidelines-epc/2024/c_iii_4_2.html
# Source: Guidelines for Examination in the EPO, A-VIII, 2.5, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_viii_2_5.html
# {'question': 'Applicant Korhonen is a Finnish national resident in Finland. He filed a European patent application in Finnish and provided an English translation in time. In response to the extended European search report (EESR), Korhonen wishes to file amended claims t ogether with a request for examination. Which of the following statements is correct?', 'options': ['A. Korhonen must file the amended claims in Finnish and must then  provide a translation into English, in time', 'B. Korhonen is allowed to file the amended claims in Finnish if he then provides a', 'translation into any official language of the EPO, in time C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time', 'D. Korhonen is not allowed to file the amended claims in Finnish']}
# {'question': 'Applicant Korhonen is a Finnish national resident in Finland. He filed a European patent application in Finnish and provided an English translation in time. In response to the extended European search report (EESR), Korhonen wishes to file amended claims t ogether with a request for examination. Which of the following statements is correct?', 'options': ['A. Korhonen must file the amended claims in Finnish and must then  provide a translation into English, in time', 'B. Korhonen is allowed to file the amended claims in Finnish if he then provides a', 'translation into any official language of the EPO, in time C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time', 'D. Korhonen is not allowed to file the amended claims in Finnish']}
# Erreur parsing: ```json
#     {
#       "Answer": "C",
#       "Justification": "According to the Guidelines for Examination in the EPO, C-V, 1.3, amended claims should be filed in any of the official languages of the European Patent Office (EPO) and accompanied by a translation into another official language within the prescribed time limit if required. Since Korhonen originally filed his application in Finnish and provided an English translation, he is allowed to file the amended claims in Finnish as long as he provides a translation into English in time, which matches statement C.
#
# Option A is incorrect because while it correctly states that Korhonen must provide a translation of the amended claims, it incorrectly demands that the claims be filed initially in Finnish, whereas they can actually be submitted in any official language and translated if necessary.
#
# Options B and D are incorrect because they suggest filing the amended claims only in one specific language (Finnish or not in Finnish), which does not align with the practice of allowing claims to be filed in any EPO official language provided that a translation is then provided, as stated in C-V, 1.3.
#
# Option B's statement about 'any official language' is correct but it fails to specify that an English translation is necessary given that the initial application was in Finnish.
#     }
# ```
# Attempt 1 failed. Retrying...
# Final answer: C
# Answer: C, Justification: Option C is correct according to the provided legal text because it states that if an applicant files a European patent application in a language other than one of the official languages of the EPO, they must provide a translation into any official language of the EPO within four months (Rule 71(3) EPC). In this scenario, Korhonen filed his application in Finnish and provided an English translation in time. When amending claims, he is allowed to file them in the language of the application as long as he provides a translation into any official language of the EPO, such as English, within the specified period (Rule 71(3) EPC).
#
# Option A is incorrect because it suggests that Korhonen must file the amended claims in Finnish and then provide a translation into English. This would not be allowed since he can choose to file the amended claims in any official language of the EPO, as long as they are accompanied by a translation within four months.
#
# Option B is partially correct but misleading because it does not specify that Korhonen must provide a translation into an official language of the EPO. Therefore, option C better reflects the legal text since it requires filing a translation in any of the official languages of the EPO (in this case, English).
#
# Option D is incorrect because it suggests that Korhonen cannot file the amended claims in Finnish at all. The legal context allows for the possibility of amending claims in the language of the application as long as they are accompanied by an appropriate translation.
#
# Sources:
# Source: 2024_EPAC_mcq_solution.json, Url: N/A
# Source: Guidelines for Examination in the EPO, A-III, 14, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_iii_14.html
# Source: Case Law III, F.1, Url: https://www.epo.org/en/legal/case-law/2022/clr_iii_f_1.html
# Source: Guidelines for Examination in the EPO, C-V, 1.3, Url: https://www.epo.org/en/legal/guidelines-epc/2024/c_v_1_3.html
# Source: Guidelines for Examination in the EPO, A-III, 6.8.3, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_iii_6_8_3.html
# {'question': 'Applicants may request processing of their international application under PCT Direct by filing a letter ("PCT Direct letter") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?', 'options': ['A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing', 'B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0', 'C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0', 'D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document']}
# {'question': 'Applicants may request processing of their international application under PCT Direct by filing a letter ("PCT Direct letter") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?', 'options': ['A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing', 'B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0', 'C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0', 'D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document']}
# Final answer: B
# Answer: B, Justification: Option B is incorrect because PCT Direct does not apply when the priority application and the subsequent international application are filed in different languages, even if one of them is an EP application. According to G-VIII, 12.4, 'PCT Direct is available for a single-language application, i.e., where either (a) all national applications under Rule 35(1)(a) EPC were filed with the Receiving Office in the same language or (b) the international application was filed at the EPO and the search opinion was established by the International Searching Authority (ISA). In option B, although both the priority application and the subsequent international application are related to an EP application, they are not filed in the same language, which disqualifies PCT Direct.
#
# Option A is correct because a PCT Direct letter can be used for a Belgian application in French that has been searched by the EPO, as long as the international application is also filed in French.
#
# Option C is correct since it meets the criteria of a single-language application where both the priority and subsequent applications are filed with the same language (English).
#
# Option D is correct because filing amended claims with a PCT Direct letter is a requirement for its utilization.
#
# Sources:
# Source: PCT Rule 12, Url: https://www.wipo.int/pct/en/texts//rules/r12.html
# Source: PCT Rule 55, Url: https://www.wipo.int/pct/en/texts//rules/r55.html
# Source: Guidelines for Examination in the EPO, E-IX, 2.3.5.1, Url: https://www.epo.org/en/legal/guidelines-epc/2024/e_ix_2_3_5_1.html
# Source: Guidelines for Examination in the EPO, G-IV, 5.2, Url: https://www.epo.org/en/legal/guidelines-epc/2024/g_iv_5_2.html
# Source: Guidelines for Examination in the EPO, E-IX, 2.1.3, Url: https://www.epo.org/en/legal/guidelines-epc/2024/e_ix_2_1_3.html
# {'question': 'Mr Linguist filed a European patent application in Dutch and used English as language of the proceedings. When requesting unitary effect on 10 October 2024, Mr Linguist must provide a translation of the specification. Mr Linguist would like to obtain immediate registration of the unitary effect. Which of the following statements is correct?', 'options': ['A. Mr Linguist must provide a translation of the specification into Dutch', 'B. Mr Linguist must provide a translation of the specification into an official language of any of the 18 states to which the unitary effect extends', 'C. Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA', 'D. Mr Linguist may provide a translation of the specification into Spanish']}
# {'question': 'Mr Linguist filed a European patent application in Dutch and used English as language of the proceedings. When requesting unitary effect on 10 October 2024, Mr Linguist must provide a translation of the specification. Mr Linguist would like to obtain immediate registration of the unitary effect. Which of the following statements is correct?', 'options': ['A. Mr Linguist must provide a translation of the specification into Dutch', 'B. Mr Linguist must provide a translation of the specification into an official language of any of the 18 states to which the unitary effect extends', 'C. Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA', 'D. Mr Linguist may provide a translation of the specification into Spanish']}
# Final answer: C
# Answer: C, Justification: According to the Unitary Patent Guide, paragraph 65, the translation may be in any of the 24 official languages of the EU, except English. Therefore, Mr Linguist can provide a translation into Spanish (an official language of Spain) or another 23 official languages of other EU states that have signed the UPCA.
#
# Option A is incorrect because the application was not originally filed in Dutch but used it as the language of proceedings; thus, there is no obligation to translate back into Dutch.
# Option B is incorrect because the unitary effect extends only to certain member states of the European Union and not necessarily all 18 or more states that have signed the UPCA.
# Option D can be correct depending on which state Mr Linguist aims for immediate registration in, but since the question asks for a general statement and considering Spanish is one of the official EU languages, Option C is a broader and correct answer.
#
# Sources:
# Source: 2024_EPAC_mcq_solution.json, Url: N/A
# Source: Guidelines for Examination in the EPO, A-III, 6.8.3, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_iii_6_8_3.html
# Source: EPC Article 70, Url: https://www.epo.org/en/legal/epc/2020/a70.html
# Source: EPC Rule 3, Url: https://www.epo.org/en/legal/epc/2020/r3.html
# Source: Guidelines for Examination in the EPO, A-III, 14, Url: https://www.epo.org/en/legal/guidelines-epc/2024/a_iii_14.html
# {'total_answer': 29, 'correct_answer': 7}

# %% [markdown]
# ## Test Big Reader (qwen2.5-32B)

# %%
def test_reader_model(embeddings_model, chunk_size, reader):
    # create_rag_embeddings(embeddings_model, chunk_size, markdown_separators, data_dir, output_dir)
    knowledge_vector_db = load_rag_embeddings(path=f'../embeddings/rag_embeddings_{embeddings_model.replace('/', '_')}_chunk{chunk_size}',
                                            embeddings_model=embeddings_model, device='cuda')
    evaluate_generate_mcq_answer(save_dir='../outputs/evaluation2/', data_dir='../outputs/',
                             test_name=f'{embeddings_model.replace('/', '_')}_chunk{chunk_size}_{reader.replace('.', '_').replace(':', '_')}', model=reader,
                             knowledge_vector_db=knowledge_vector_db)

# %%
# test_reader_model(embeddings_model='sentence-transformers/all-MiniLM-L6-v2', chunk_size=512, reader='qwen2.5:32b')
# Out:
# embedding load
# {'question': 'A European patent was granted to a German company on 4  January 2023. No opposition was filed. Mr Li and Ms Smith were designated as inventors. On 12 October 2023,  the patent proprietor not ices that Ms Smith was erroneously designated as inventor and that Mr Li is the sole inventor.  Which of the following statements is correct?', 'options': ['A. Ms Smith will be deleted as inventor if the patent proprietor requests this in writing .', 'B. Ms Smith can no longer  be deleted as inventor because no proceedings are pending before the EPO .', "C. The patent proprietor can request that  Ms Smith be deleted as inventor but needs Mr Li 's consent  for this .", 'D. Ms Smith can only be deleted as inventor with her consent .']}
# Answer before 2nd model:
#
# ### Answer:
# **Answer: D**
#
# ### Explanation:
#
# According to Rule 21(1) EPC as mentioned in one of the sources provided ("Legal basis A n incorrect designation of inventor shall be rectified upon request and only with the consent of the wrongly designated person and, where such a request is filed by a third party, the consent of the applicant for or proprietor of the patent (R. 21(1) EPC)."), any correction to an incorrect inventorship requires the consent of the wrongly designated individual (in this case, Ms Smith).
#
# #### Why D is Correct:
# - **Rule 21(1) EPC** explicitly states that a rectification of an erroneous designation of an inventor can only be made with their consent.
#
# #### Why Other Options are Incorrect:
#
# - **Option A**: This option suggests that simply requesting in writing will suffice to delete Ms Smith as the inventor, which is incorrect. The rule clearly mandates consent from Ms Smith herself.
#
# - **Option B**: This implies that no changes can be made because there are no ongoing proceedings before the EPO. However, Rule 21(1) does not require any active proceeding; it only requires the proprietor’s request and the consent of the wrongly designated person.
#
# - **Option C**: Although it mentions that the patent proprietor can initiate a request to remove Ms Smith as an inventor, this statement is incomplete without mentioning the need for Ms Smith's consent. Thus, this option does not fully comply with Rule 21(1) EPC which mandates the consent of the wrongly designated person.
#
# In conclusion, Option D correctly captures that any rectification in the designation of inventors must be done with the explicit consent of the individual who was erroneously designated as an inventor (in this case, Ms Smith).
# Answer after 2nd model: ```json
# {
#   "Answer": "D",
#   "Justification": "According to Rule 21(1) EPC, any correction to incorrect inventorship requires the consent of the wrongly designated individual (in this case, Ms Smith). Option D correctly captures that any rectification in the designation of inventors must be done with the explicit consent of the individual who was erroneously designated as an inventor. Options A, B, and C are incorrect because they either suggest a process that does not require Ms Smith's consent or do not fully comply with Rule 21(1) EPC which mandates her consent."
# }
# ```
# Final answer: D
# {'question': "On 10 October 2021, European patent attorney X filed European patent application EP -A with the EPO on the applicant's behalf. Application EP -A was published on 12 April 2023, together  with the extended European search report. On 6  October 2023, the applicant contacts a new European patent attorney  Y to replace X as representative and issues Y with its instructions to reply to the extended European search report. The applicant did not inform X that he would be replaced.  What are the steps necessary to validly appoint representative Y and to avoid any loss of rights for European patent application EP -A?", 'options': ['A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant .', 'B. New representative Y requests a change of representative and files a response to the extended European search report with  the EPO by 12 October 2023 at the latest .', 'C. New representative Y requests a change of representative and files a response to the extended European search report with the EPO by 23 October 2023 at the latest.', 'D. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 23 October 2023 at the latest and files in good time an authorisation signed by the applicant .']}
# Answer before 2nd model:
#
# ### Answer:
# A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant.
#
# ### Explanation:
#
# #### Why Option A is Correct:
# To avoid any loss of rights for European patent application EP -A, new representative Y needs to take several steps according to Rule 142(3) (in relation to Art. 133(2)) and the Guidelines for Examination in the EPO:
#
# - **Request a Change of Representative:** A formal request to change the representative must be submitted by the applicant or through their new patent attorney Y.
#
# - **File a Response Promptly:** The response to the extended European search report needs to be filed within the prescribed time limit. According to Rule 51(4), the deadline for responding is two months from the date of publication, which would be 6 June 2023 in this case (extended European search report published on 12 April 2023). However, given that Y was only appointed in October 2023, we need to account for any potential interruptions or delays due to changing representatives.
#
# - **File an Authorization:** The applicant must provide a signed authorization for the new representative Y to act on their behalf. This ensures that all actions taken by Y are legally valid and binding.
#
# Option A correctly encompasses all these steps: requesting a change of representative, filing a timely response, and submitting the authorization.
#
# #### Why Other Options Are Incorrect:
# - **Option B:** It omits the requirement for the applicant to provide an authorization signed by them. Without such an authorization, new representative Y would not have valid authority to act on behalf of the applicant.
#
# - **Option C:** The deadline for filing a response is incorrect. As per Rule 51(4), the two-month deadline from publication (12 April 2023) would have expired well before October 2023, making any submission in late October too late unless there was an extension of time granted.
#
# - **Option D:** Similar to Option C, this option incorrectly sets the filing date for the response as 23 October 2023, which is beyond the original deadline and likely after any grace period. Also, it does not clarify that the authorization must be timely filed.
#
# In conclusion, Option A ensures all necessary steps are taken correctly within the required timeframe to avoid any loss of rights for European patent application EP -A.
# Answer after 2nd model: ```json
# {
#   "Answer": "Option A: New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant.",
#   "Justification": "To avoid any loss of rights for European patent application EP -A, new representative Y needs to take several steps according to Rule 142(3) (in relation to Art. 133(2)) and the Guidelines for Examination in the EPO: requesting a change of representative, filing a timely response by 12 October 2023 at the latest due to potential interruptions or delays from changing representatives, and submitting a signed authorization for new representative Y to act on behalf of the applicant. Option A correctly encompasses all these steps. Other options are incorrect either because they omit required actions (Option B) or set an incorrect deadline for filing a response (Options C & D)."
# }
# ```
# Final answer: A
# {'question': 'EP-1 is a regular European patent application (Euro -direct application) .  Which one of the following missed time limits can be remedied for EP -1 before the EPO by requesting re- establishment of rights ?', 'options': ['A. T ime limit for pay ing the designation fee', 'B. T ime limit for requesting examination', 'C. T ime limit for filing the application within the priority period', 'D. T ime limit for paying the fee for re- establishment of rights']}
# Answer before 2nd model:  Answer C.
#
# Explanation:
# The time limit for filing an application within the priority period can be remedied by requesting re-establishment of rights under Article 122(1). This is because re-establishment of rights is available when an applicant, despite taking all due care required by the circumstances, was unable to observe a time limit vis-à-vis the EPO. Filing within the priority period is critical for maintaining the claim to priority and thus falls under the scope where such a request can be made.
#
# Explanation why other options are incorrect:
# A. Time limit for paying the designation fee: The re-establishment of rights does not typically apply to administrative fees like the designation fee, which must generally be paid within specified deadlines without exception.
# B. Time limit for requesting examination: While there is provision for further processing in some cases (such as through E-VIII, 2), this option specifically relates to time limits that are tied more closely to procedural acts rather than substantive rights re-establishment under Article 122(1).
# D. Time limit for paying the fee for re-establishment of rights: This is a circular reference since it pertains to paying a fee associated with the very remedy being sought, which cannot be used to extend itself.
#
# Therefore, only option C aligns correctly with the provisions allowing for re-establishment of rights in the context provided by the legal text.
# Answer after 2nd model: ```json
# {
# "Answer": "C.",
# "Justification": "The time limit for filing an application within the priority period can be remedied by requesting re-establishment of rights under Article 122(1). This is because re-establishment of rights is available when an applicant, despite taking all due care required by the circumstances, was unable to observe a time limit vis-à-vis the EPO. Filing within the priority period is critical for maintaining the claim to priority and thus falls under the scope where such a request can be made."
# }
# ```
# Final answer: C
# {'question': 'Last week Greta validly filed the international patent application PCT -G with the German Patent and Trade mark Office ( DPMA ) and appointed Hassan to represent her. Hassan is entitled to act before the DPMA  but he is not a European patent attorney. Greta and Hassan are resident in Germany.  Which of the following statements is not correct?', 'options': ['A. Hassan can represent Greta before the EPO acting as the International Searching Authority for PCT -G.', 'B. In order for Hassan to be able to act before the EPO acting as the International Searching Authority , he needs to submit a power of attorney signed by Greta.', 'C. According to the provisions of the PCT, it is mandatory that the d emand for international preliminary examination is signed by Greta or Hassan.', 'D. According to the provisions of the PCT, an international application can only be withdrawn by the applicant or an agent appointed by a power of attorney.']}
# Answer before 2nd model:
#
# ### Legal Question Analysis:
# #### Correct Option:
# **Answer C**
#
# #### Explanation:
#
# - **Option A:** This is correct as long as Hassan has a valid power of attorney from Greta. According to the Patent Cooperation Treaty (PCT), an applicant can be represented by someone who has been appointed in writing.
#
# - **Option B:** This is also correct because typically, before a representative can act on behalf of an applicant, they need to submit a signed power of attorney from the applicant, as per usual procedural rules and requirements for representation.
#
# - **Option C:** According to PCT Article 16 and other relevant provisions of the PCT, it is not mandatory that the demand for international preliminary examination (PCT Rule 64) be signed by Hassan or Greta. The requirement for a signature generally applies to filing the application itself but does not necessarily apply in the same strict manner to subsequent requests such as for an international preliminary examination.
#
# - **Option D:** This is correct based on the PCT rules, which typically state that only the applicant or their appointed agent with a power of attorney can withdraw an application. The withdrawal needs to be authorized and generally requires a formal request signed by either the applicant (Greta) or their representative (Hassan).
#
# Therefore, the statement that is not correct is Option C because PCT rules do not mandate that demands for international preliminary examination need to be signed by Greta or Hassan.
#
# ### Conclusion:
# The incorrect statement is **Answer C**.
# Answer after 2nd model: ```json
# {
#   "Answer": "C",
#   "Justification": "According to PCT Article 16 and other relevant provisions of the PCT, it is not mandatory that the demand for international preliminary examination (PCT Rule 64) be signed by Hassan or Greta. The requirement for a signature generally applies to filing the application itself but does not necessarily apply in the same strict manner to subsequent requests such as for an international preliminary examination."
# }
# ```
# Final answer: C
# {'question': 'In which of the following cases is the applicant entitled to a reduction of the filing fee  under Rule  6 EPC ? A declaration of such entitlement has  been made by crossing the relevant box on Form  1001.', 'options': ['A. A Spanish European patent attorney files a European patent application in Spanish for a natural person who is resident in Andorra and of Andorra n nationality .', 'B. A firm whose principal place of business is in Germany and a natural person who is resident in Germany  and of Dutch nationality  jointly file a European patent application in Dutch. The German firm employs 200 people with an annual turnover of EUR 60 million.', 'C. A natural person resident in the USA and of Belgian nationality files a European patent application in French.', 'D. A natural person resident in the USA and of Swiss nationality files a European patent application in Italian.']}
# Answer before 2nd model:
#
# ### Answer:
# **Answer B**
#
# #### Explanation:
#
# According to Rule 6 EPC, a reduction in the filing fee is available for natural persons and small entities. Under Art. 58(2)(a) and (b) of the EPC, an applicant can be a natural person or a legal entity that qualifies as a small entity under the conditions set by Rule 3.14 EPC.
#
# **Option B** correctly identifies two applicants: a firm whose principal place of business is in Germany and a natural person resident in Germany but of Dutch nationality. The reduction applies to natural persons irrespective of their residence or nationality, provided they make the necessary declaration as stated in the question (crossing the relevant box on Form 1001). However, small entities must also meet certain criteria specified by Rule 3.14 EPC; typically, these relate to size and turnover.
#
# **Option A:** The Spanish European patent attorney filing for a natural person who is resident in Andorra and of Andorran nationality does not satisfy the condition that an applicant can only be entitled if they are a legal entity or individual residing within the territory of one of the contracting states. Andorra is not part of the EPC, so this option would fail the residency requirement.
#
# **Option C:** The natural person resident in the USA and of Belgian nationality does not meet the criterion that applicants must reside in the territory of one of the EPO's member states. Therefore, while they can still file a patent application, they cannot claim entitlement to reduced fees due to residence outside the contracting states' territories.
#
# **Option D:** The natural person resident in the USA and of Swiss nationality faces similar issues as option C: their residence outside the territory of one of the EPC’s member states disqualifies them from claiming the filing fee reduction under Rule 6 EPC.
#
# In summary, Option B is correct because it involves a natural person who meets the residency requirement within an EPO contracting state and has made the necessary declaration on Form 1001 to claim reduced fees.
# Answer after 2nd model: ```json
# {
#     "Answer": "B",
#     "Justification": "According to Rule 6 EPC, a reduction in the filing fee is available for natural persons and small entities. Under Art. 58(2)(a) and (b) of the EPC, an applicant can be a natural person or a legal entity that qualifies as a small entity under the conditions set by Rule 3.14 EPC. Option B correctly identifies two applicants: a firm whose principal place of business is in Germany and a natural person resident in Germany but of Dutch nationality. The reduction applies to natural persons irrespective of their residence or nationality, provided they make the necessary declaration as stated in the question (crossing the relevant box on Form 1001). However, small entities must also meet certain criteria specified by Rule 3.14 EPC; typically, these relate to size and turnover."
# }
# ```
# Final answer: B
# {'question': 'Mr Van Holland is a Dutch citizen resident in the Netherlands. He filed a European patent application EP -parent in Dutch, together with  a translation into English. Whil e EP-parent was pending, Mr Van Holland filed a divisional application EP -div in Dutch and requested examination in Dutch. He paid all fees due for EP -div. He has not filed an English translation of EP -div. The Receiving Section has now issued a noting of l oss of rights.  Which of the following statements is correct?', 'options': ['A. The deficiency cannot be remedied.', 'B. Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication  under Rule 112(1) EPC .', 'C. Mr Van Holland needs to file an English translation of EP -div together with a request for f urther processing.', 'D. Mr Van Holland needs to file an English translation of EP -div together with a request for re- establishment of rights.']}
# Answer before 2nd model:
#
# ### Answer B
#
# #### Explanation:
# According to Art. 61 and Rule 36(2), a European divisional application must be filed in the language of the proceedings of the earlier (parent) application. Since Mr Van Holland's parent application was not originally in an official EPO language but included a translation into English, his divisional application should also have been submitted with an equivalent translation into English within two months from filing.
#
# The Receiving Section issued a noting of loss of rights due to the missing English translation of EP-div. According to Rule 112(1) EPC, deficiencies in the application can be remedied by filing the necessary translations within the allowed time frame (two months).
#
# #### Why Other Options Are Incorrect:
#
# - **Option A**: "The deficiency cannot be remedied" is incorrect because Rule 112(1) EPC and Art. 61 provide for the possibility to remedy deficiencies, including missing translations.
#
# - **Option C**: "Mr Van Holland needs to file an English translation of EP -div together with a request for further processing" is not accurate as there's no need for a separate request for further processing. The deficiency can be remedied simply by filing the required translation within the given time frame (two months).
#
# - **Option D**: "Mr Van Holland needs to file an English translation of EP -div together with a request for re-establishment of rights" is incorrect because the issue at hand is not about re-establishing rights but rather about correcting a deficiency. Rule 112(1) EPC provides that filing a required translation within two months after notification can correct the noted deficiency, without needing to invoke re-establishment provisions.
#
# Hence, Mr Van Holland can remedy the deficiency by filing an English translation of EP-div within two months from the date of notification of the communication under Rule 112(1) EPC.
# Answer after 2nd model: ```json
# {
#     "Answer": "Mr Van Holland can remedy the deficiency by filing an English translation of EP-div within two months from the date of notification of the communication under Rule 112(1) EPC.",
#     "Justification": "According to Art. 61 and Rule 36(2), a European divisional application must be filed in the language of the proceedings of the earlier (parent) application. Since Mr Van Holland's parent application was not originally in an official EPO language but included a translation into English, his divisional application should also have been submitted with an equivalent translation into English within two months from filing. The Receiving Section issued a noting of loss of rights due to the missing English translation of EP-div. According to Rule 112(1) EPC, deficiencies in the application can be remedied by filing the necessary translations within the allowed time frame (two months)."
# }
# ```
# Erreur Answer est pas une lettre: Answer=Mr Van Holland can remedy the deficiency by filing an English translation of EP-div within two months from the date of notification of the communication under Rule 112(1) EPC.
# Attempt 1 failed. Retrying...
# Answer before 2nd model:
#
# ### Answer:
# **B. Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication under Rule 112(1) EPC.**
#
# ### Explanation:
#
# According to the provided text and relevant legal provisions:
# - **Art. 61 applications European divisional applications must be filed in the language of the proceedings of the earlier (parent) application**.
# - If the earlier (parent) application was not in an official EPO language, the divisional application may be filed in the same language as the earlier application but a translation into the language used for the parent application's proceedings is required within two months.
#
# Since Mr Van Holland’s European patent application EP-parent was originally filed in Dutch and translated into English (an official EPO language), the language of the proceedings has been established to be English. Therefore, under Rule 36(2)EPC, he must file an English translation for the divisional application EP-div within two months from its filing.
#
# - **Option A** is incorrect because there is a possible remedy by providing the required translation.
# - **Option B** is correct as it aligns with the requirement to file an English translation of EP-div within the prescribed time frame (two months). Rule 112(1) EPC is generally used for such communications regarding deficiencies that can be remedied.
# - **Option C** is incorrect because filing a request for further processing is not required or relevant in this context. The requirement under Art. 61 and Rule 36(2)EPC simply demands the submission of a translation within two months.
# - **Option D** is also incorrect because there is no necessity to file a request for re-establishment of rights if the deficiency can be remedied by timely compliance with procedural requirements.
#
# Therefore, the correct statement is option B: Mr Van Holland can remedy the deficiency by filing an English translation of EP-div within two months of notification under Rule 112(1) EPC.
# Answer after 2nd model: ```json
# {
#     "Answer": "Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication under Rule 112(1) EPC.",
#     "Justification": "According to Art. 61 and Rule 36(2)EPC, European divisional applications must be filed in the language of the proceedings of the earlier (parent) application. Since Mr Van Holland’s parent application EP-parent was originally filed in Dutch but translated into English (an official EPO language), the required translation for the divisional application EP-div is to be submitted within two months from its filing."
# }
# ```
# Erreur Answer est pas une lettre: Answer=Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication under Rule 112(1) EPC.
# Attempt 2 failed. Retrying...
# Answer before 2nd model:
#
# ### Answer B
#
# #### Explanation:
# - **Correct Statement**: According to Art. 61 and Rule 36(2) EPC, a European divisional application can be filed in the language of the earlier (parent) application if it is not an official EPO language. In this case, Mr Van Holland filed EP-parent in Dutch along with its translation into English. Hence, as per Art. 61 and Rule 36(2), he has two months from filing the divisional application to submit a translation of EP-div (the divisional) into the language used for the proceedings of the earlier (parent) application, which is English.
#
# #### Why Other Options Are Incorrect:
#
# - **Option A**: This statement is incorrect because it suggests that Mr Van Holland cannot remedy the deficiency. However, he can file an English translation within two months as per Rule 36(2).
#
# - **Option C**: This option incorrectly states that a request for further processing must be filed along with the translation. According to Rule 36(2), no additional formal request (such as for further processing) is required; only filing the translation in English within two months suffices.
#
# - **Option D**: The statement in Option D implies that Mr Van Holland needs to file an English translation and a request for re-establishment of rights. However, re-establishing rights under Rule 134 EPC would be necessary if he missed the deadline by more than one month (Art. 76(2) EPC), but given that only two months are provided for filing translations after divisional application filing, this is not relevant here.
#
# Thus, Mr Van Holland can remedy the deficiency by simply filing an English translation of EP-div within the prescribed time frame under Rule 112(1) EPC.
# Answer after 2nd model: ```json
# {
#     "Answer": "Mr Van Holland can remedy the deficiency by filing an English translation of the divisional application (EP-div) within two months from its filing, as per Art. 61 and Rule 36(2) EPC.",
#     "Justification": "According to Article 61 and Rule 36(2) EPC, a European divisional application can be filed in the language of the earlier (parent) application if it is not an official EPO language. In this case, Mr Van Holland initially filed his parent application in Dutch with an English translation; hence, he has two months from filing the divisional to submit an English translation as required by Rule 36(2). Options A and C are incorrect because they misinterpret the necessity of a remedy or additional formal requests. Option D incorrectly suggests the need for re-establishment of rights under Rule 134 EPC, which is not relevant given the two-month period to submit translations."
# }
# ```
# Erreur Answer est pas une lettre: Answer=Mr Van Holland can remedy the deficiency by filing an English translation of the divisional application (EP-div) within two months from its filing, as per Art. 61 and Rule 36(2) EPC.
# Attempt 3 failed. Retrying...
# {'question': 'On 16  November 2020, you filed a European patent application EP -A, which did not claim priority. Today, 12  October 2023, you receive a communication from the EPO entitled " Decision to grant a European patent pursuant to Article  97(1) EPC ". This communication state s that the mention of the grant You wish to validate the patent in only two contracting states  to the EPC . Which of the following statements is correct?', 'options': ['A. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 16 November 2023.', 'B. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 30 November 2023.', 'C. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 9 January 2024 at the latest .', 'D. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 16 January 2024 at the latest .']}
# Answer before 2nd model:
#
# **Answer: C**
#
# **Explanation:**
#
# 1. **Why Option C is Correct:**
#    - According to Rule 51(1), the renewal fee for each year of a European patent application is due by the end of the month containing the anniversary of the date of filing. For EP-A filed on November 16, 2020, the fourth-year renewal fee would be due by the last day in November 2023 (i.e., November 30, 2023).
#    - However, after a patent is granted and validated in specific contracting states, the payment of subsequent annual fees must be made to those national offices.
#    - The decision to grant was issued on October 12, 2023. According to Rule 51(4), renewal fees due within four months from that date (i.e., until February 9, 2024) can still be paid without an additional fee.
#    - Hence, the fourth-year renewal fee must be paid separately in each state where validation occurs, and it can be validly paid without any additional fee up to January 9, 2024.
#
# 2. **Why Other Options are Incorrect:**
#
#    - **Option A:** This is incorrect because the payment of subsequent annual fees must be made to national offices after grant, not centrally at the EPO.
#    - **Option B:** While it correctly states that the fourth-year fee would normally be due by November 30, 2023 (the last day in the month containing the anniversary), this does not account for the grace period provided under Rule 51(4) after the grant decision. Therefore, the payment can still be validly made without an additional fee up to January 9, 2024.
#    - **Option D:** This option is incorrect because it misstates the due date. The renewal fee for the fourth year must be paid separately in each state where validation occurs and can be validly paid until January 9, 2024 (not January 16, 2024).
#
# Thus, Option C correctly identifies that after grant and validation, the renewal fees are due to national offices with a specific deadline period.
# Answer after 2nd model: ```json
# {
#     "Answer": "C",
#     "Justification": "According to Rule 51(1), the renewal fee for each year of a European patent application is due by the end of the month containing the anniversary of the date of filing. For EP-A filed on November 16, 2020, the fourth-year renewal fee would be due by the last day in November 2023 (i.e., November 30, 2023). After a patent is granted and validated in specific contracting states, the payment of subsequent annual fees must be made to those national offices. The decision to grant was issued on October 12, 2023. According to Rule 51(4), renewal fees due within four months from that date (i.e., until February 9, 2024) can still be paid without an additional fee. Hence, the fourth-year renewal fee must be paid separately in each state where validation occurs and it can be validly paid without any additional fee up to January 9, 2024. Option C correctly identifies that after grant and validation, the renewal fees are due to national offices with a specific deadline period."
# }
# ```
# Final answer: C
# {'question': 'During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?', 'options': ['A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.', 'B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.', 'C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.', 'D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months.']}
# Answer before 2nd model:
#
# ### Legal Question Answer:
#
# **Answer:**
# A.
#
# **Explanation:**
#
# The correct statement is:
# "A. Upon request the patent proprietor must pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description."
#
# According to H-III, 2.3 in the Guidelines for Examination in the EPO, the filing of a completely retyped description should be avoided for reasons of procedural economy but is often necessary when handwritten amendments are made in the description during oral proceedings.
#
# **Why A is correct:**
# Option A correctly states that the patent proprietor will need to pay the fee for publishing a new specification, file translations of the claims, and file a formally compliant version of the entire description upon request. The requirement to submit a typed version of the amended paragraph ensures clarity and compliance with procedural norms.
#
# **Why B is incorrect:**
# Option B suggests that no formal actions are required if an appeal is filed. However, this statement overlooks the fact that regardless of pending appeals, formally compliant versions must eventually be submitted as part of the EPO's procedural requirements to maintain the patentability and clarity of the document.
#
# **Why C is incorrect:**
# Option C implies that together with the interlocutory decision, an invitation will be sent to pay fees for publishing a new specification and filing translations. However, while it may seem practical to include such invitations at this stage, the specific procedural steps detailed in the guidelines do not mandate immediate action by way of an invitation but rather upon request.
#
# **Why D is incorrect:**
# Option D suggests that these actions must be taken within four months if no appeal is filed, which is misleading. The guidelines emphasize that any amendments must be formally compliant and typed to maintain clarity and compliance with procedural norms, but do not specify a timeline for when these actions will be requested unless explicitly directed by the EPO upon request.
#
# In summary, while formal compliance is mandatory post-decision, the timing and specific details of such compliance are contingent on instructions from the EPO rather than being automatically assumed or tied to a fixed timeframe.
# Answer after 2nd model: ```json
# {
#   "Answer": "A.",
#   "Justification": "The correct statement is: A. Upon request the patent proprietor must pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description. According to H-III, 2.3 in the Guidelines for Examination in the EPO, the filing of a completely retyped description should be avoided for reasons of procedural economy but is often necessary when handwritten amendments are made in the description during oral proceedings."
# }
# ```
# Final answer: A
# {'question': 'Under the PCT, what is the time limit for filing a request for rectification of an obvious mistake made in the international application?', 'options': ['A. 18 months from the earliest priority date', 'B. 30 months from the earliest priority date', 'C. 22 months from the earliest priority date', 'D. 26 months from the earliest priority date']}
# Answer before 2nd model:
#
# **Correct Answer:**
#
# D. 26 months from the earliest priority date
#
# **Explanation:**
#
# According to the provided legal text:
#
# "The time limit for filing a request for rectification of an obvious mistake made in the international application is 26 months from the earliest priority date."
#
# This information is directly derived from the statement "Under the PCT, what is the time limit for filing a request for rectification of an obvious mistake made in the international application?" which specifies that it is 26 months from the earliest priority date.
#
# **Why Other Options Are Incorrect:**
#
# - **Option A (18 months):** The text does not indicate any time frame of 18 months for requesting rectification.
#
# - **Option B (30 months):** The text specifically states that the time limit is 26 months, and there's no mention of a 30-month period.
#
# - **Option C (22 months):** Similar to the other options, this time frame does not match with the specified 26 months for rectification under PCT rules.
# Answer after 2nd model: ```json
# {
#   "Answer": "D. 26 months from the earliest priority date",
#   "Justification": "According to the provided legal text: \"The time limit for filing a request for rectification of an obvious mistake made in the international application is 26 months from the earliest priority date.\" This information is directly derived from the statement \"Under the PCT, what is the time limit for filing a request for rectification of an obvious mistake made in the international application?\" which specifies that it is 26 months from the earliest priority date. Other options are incorrect because: Option A (18 months): The text does not indicate any time frame of 18 months for requesting rectification. Option B (30 months): The text specifically states that the time limit is 26 months, and there's no mention of a 30-month period. Option C (22 months): Similar to the other options, this time frame does not match with the specified 26 months for rectification under PCT rules."
# }
# ```
# Final answer: D
# {'question': 'After receipt of a negative written opinion issued by the EPO acting as ISA, amendments under Art icle 19 PCT were filed during the international phase. No request for international preliminary examination was filed. Form  1200 was used,  and no further amendments were filed with the EPO upon entry into the regional phase.   What communication under Rules  161/162 EPC will be received in the regional phase?', 'options': ['A. Form 1226AA ;  if you do not reply to it in time, the application will be deemed to be withdrawn', 'B. Form 1226BB offering the opportunity to comment and file amendments', 'C. Form 1226CC offering the opportunity to file amendments before the supplementary European search report is drawn up', 'D. Form 1226AC stating that the examination has started']}
# Answer before 2nd model: Answer: B.
#
# Explanation:
#
# Based on the information provided in the Guidelines for Examination in the EPO and Euro-PCT Guide, if an applicant has filed amendments under Article 19 PCT during the international phase (after receipt of a negative written opinion from the ISA/EPO), but no request for international preliminary examination was made, the application will enter the European regional phase with those amendments. Given that no further amendments were filed upon entry into the regional phase using Form 1200 and no IPER (International Preliminary Examination Report) was prepared, Rule 161(2) applies.
#
# Rule 161(2) allows for a communication to be issued under Rules 161/162 that offers an opportunity to file amendments before the application is taken forward. In this scenario, Form 1226BB would be sent out as it offers the applicant the chance to comment and potentially amend the application documents.
#
# Form 1226AA (Option A) typically indicates a more severe situation where failure to respond results in withdrawal of the application; this does not apply here since no specific time-sensitive deadline for amendments is mentioned beyond offering an opportunity.
#
# Form 1226CC (Option C) would be issued if there was a need for supplementary European search, but the text specifies that amendments under Rule 161(2) are being considered first. This suggests a preliminary step before any further examination or supplementary search steps.
#
# Form 1226AC (Option D) indicates the start of substantive examination, which does not apply here since the application is still in an amendment and preparation stage prior to any formal examination proceedings.
#
# In conclusion, the correct form issued under these circumstances is Form 1226BB, offering the opportunity to comment and file amendments. Therefore, option B is the correct answer.
# Answer after 2nd model: ```json
# {
#     "Answer": "B.",
#     "Justification": "Based on the information provided in the Guidelines for Examination in the EPO and Euro-PCT Guide, if an applicant has filed amendments under Article 19 PCT during the international phase (after receipt of a negative written opinion from the ISA/EPO), but no request for international preliminary examination was made, the application will enter the European regional phase with those amendments. Given that no further amendments were filed upon entry into the regional phase using Form 1200 and no IPER (International Preliminary Examination Report) was prepared, Rule 161(2) applies. \nRule 161(2) allows for a communication to be issued under Rules 161/162 that offers an opportunity to file amendments before the application is taken forward. In this scenario, Form 1226BB would be sent out as it offers the applicant the chance to comment and potentially amend the application documents.\nForm 1226AA (Option A) typically indicates a more severe situation where failure to respond results in withdrawal of the application; this does not apply here since no specific time-sensitive deadline for amendments is mentioned beyond offering an opportunity. Form 1226CC (Option C) would be issued if there was a need for supplementary European search, but the text specifies that amendments under Rule 161(2) are being considered first. This suggests a preliminary step before any further examination or supplementary search steps. \nForm 1226AC (Option D) indicates the start of substantive examination, which does not apply here since the application is still in an amendment and preparation stage prior to any formal examination proceedings.\nIn conclusion, the correct form issued under these circumstances is Form 1226BB, offering the opportunity to comment and file amendments. Therefore, option B is the correct answer."
# }
# ```
# Final answer: B
# {'question': 'Company M, which has  its principal place of business in Tijuana, Mexico, validly filed an international patent application PCT -M with the Mexican Institute of Industrial Property. The application was filed in Spanish. A few days later, the applicant files an English translati on of the application.  Which of the following statements is correct?', 'options': ['A. The applicant can choose the EPO as ISA and the USPTO as IPEA.', 'B. The applicant can choose the USPTO as ISA and the EPO as IPEA.', 'C. The applicant can choose the Austrian Patent Offic e as ISA and the', 'EPO as IPEA.', 'D. The applicant can choose the EPO as ISA and the Intellectual Property', 'Office of Singapore as IPEA.']}
# Answer before 2nd model:
#
# ### Answer:
# **A**
#
# ### Explanation:
#
# According to international patent laws and practices outlined in various guidelines such as those from the EPO, an applicant can typically choose any ISA (International Searching Authority) for their PCT application. The EPO is one of the widely recognized ISAs that handle many PCT applications filed worldwide.
#
# In this context:
# - **Option A** states that "The applicant can choose the EPO as ISA and the USPTO as IPEA." This option correctly reflects the situation where an applicant has flexibility to select different offices for international searching and preliminary examination. The EPO serves as a common ISA, and the USPTO frequently acts as an International Preliminary Examining Authority (IPEA).
#
# ### Incorrect Options:
#
# - **Option B**: "The applicant can choose the USPTO as ISA and the EPO as IPEA." This is incorrect because while the USPTO can act as both ISA and IPEA, the typical selection for an international application would not often include the EPO following a USPTO ISA role due to different language requirements and procedural nuances.
#
# - **Option C**: "The applicant can choose the Austrian Patent Office as ISA and the EPO as IPEA." This is incorrect because while the Austrian Patent Office (APO) does serve as an ISA, it is not a commonly selected ISA for PCT applications. Also, typically, applicants would not combine such specific and less frequently used offices with the more standard EPO.
#
# - **Option D**: "The applicant can choose the EPO as ISA and the Intellectual Property Office of Singapore (IPOS) as IPEA." This option is incorrect because while theoretically possible, it's very uncommon for an IPOS to be chosen as IPEA in such a context. The EPO is generally paired with other major patent offices like the USPTO or JPO.
#
# Thus, **Option A** accurately reflects the typical and feasible scenario of selecting the EPO as ISA and the USPTO as IPEA for an international application under PCT rules.
# Answer after 2nd model: ```json
# {
#   "Answer": "A",
#   "Justification": "According to international patent laws and practices outlined in various guidelines such as those from the EPO, an applicant can typically choose any ISA (International Searching Authority) for their PCT application. The EPO is one of the widely recognized ISAs that handle many PCT applications filed worldwide. In this context: - Option A states that \"The applicant can choose the EPO as ISA and the USPTO as IPEA.\" This option correctly reflects the situation where an applicant has flexibility to select different offices for international searching and preliminary examination. The EPO serves as a common ISA, and the USPTO frequently acts as an International Preliminary Examining Authority (IPEA)."
# }
# ```
# Final answer: A
# {'question': 'On 20  June 2023, applicant P validly filed an international patent application PCT-P, claiming priority from European patent application EP -I filed on 7 July 2022. Today, 12 October 2023, he discovers that he should also have claimed priority from EP -II filed on 3 July 2022. Can the missing priority claim still be validly added?', 'options': ['A. Yes, the time  limit for adding the priority claim expires on 3  November 2023.', 'B. Yes, the time limit for adding the priority claim expires on 7  November 2023.', 'C. Yes, the time  limit for adding the priority claim expires on 20 October 2023.', 'D. No, the time  limit for adding the priority claim expired on 3 July 2023.']}
# Answer before 2nd model:
#
# ### Answer:
# A. Yes, the time limit for adding the priority claim expires on 3 November 2023.
#
# ### Explanation:
#
# #### Correct Option: A
#
# The relevant provision is Rule 17.1 PCT and Rule 17.2 PCT which deal with claiming and adding priorities in international patent applications. According to Rule 17.2(b) of the Patent Cooperation Treaty (PCT), an applicant may add a priority claim at any time within thirty months from the earliest priority date claimed.
#
# In this scenario:
# - The earliest priority date is 3 July 2022 (from EP-II).
# - Thirty months after 3 July 2022 is 3 November 2024.
# - However, considering only up to today’s date of 12 October 2023 and the thirty-month rule from 3 July 2022, the claim can still be added up until 3 November 2023.
#
# Therefore, option A is correct as it states that P can still validly add a priority claim from EP-II on or before 3 November 2023.
#
# #### Incorrect Options:
#
# ...
#
# Option D is also incorrect because official holidays should not require special document submission methods. The regular processes and allowances for late submissions due to public holidays or non-working days are already established by EPO rules and do not necessitate using a contingency service specifically for such situations.
#
# In conclusion, the Contingency Upload Service is explicitly designed for use in specific technical outages at the EPO level that prevent standard document submission methods.
# Answer after 2nd model: ```json
# {
# "Answer": "C",
# "Justification": "The EPO Contingency Upload Service is recommended for use when there is a system outage at the EPO that prevents document submission via the standard filing systems. This can be inferred from the provided texts, particularly where it states that certain documents are excluded from being filed by fax or using the EPO web-form filing service but mentions the contingency upload service in relation to handling situations that require alternative means of submission. Option A is incorrect because there is no mention of the Contingency Upload Service for use outside regular business hours. The standard processes and systems should be sufficient during normal operations, including after-hours submissions through other electronic methods. Option B is incorrect as well. If only a technical issue at your end arises while the EPO filing systems are functioning correctly, you would typically resolve or work around that issue without needing to use the Contingency Upload Service, which implies broader system failure rather than individual user issues. Option D is also incorrect because official holidays should not require special document submission methods. The regular processes and allowances for late submissions due to public holidays or non-working days are already established by EPO rules and do not necessitate using a contingency service specifically for such situations."
# }
# ```
# Final answer: C
# {'question': 'Applicant Korhonen is a Finnish national resident in Finland. He filed a European patent application in Finnish and provided an English translation in time. In response to the extended European search report (EESR), Korhonen wishes to file amended claims t ogether with a request for examination. Which of the following statements is correct?', 'options': ['A. Korhonen must file the amended claims in Finnish and must then  provide a translation into English, in time', 'B. Korhonen is allowed to file the amended claims in Finnish if he then provides a', 'translation into any official language of the EPO, in time C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time', 'D. Korhonen is not allowed to file the amended claims in Finnish']}
# Answer before 2nd model:
#
# **Correct Answer:**
# A. Korhonen must file the amended claims in Finnish and must then provide a translation into English, in time.
#
# **Explanation:**
#
# According to the provided legal text (Guidelines for Examination in the EPO, C-V 1.3), if an applicant files claims in a language other than one of the official languages of the European Patent Office (English, French, or German), they must provide translations into the two remaining official languages within four months from the date of the communication under Rule 71(3). In this scenario, Korhonen, being a Finnish national and having filed his claims in Finnish, would need to provide an English translation within the stipulated time frame.
#
# **Why Other Options Are Incorrect:**
#
# - **Option B:** This option is incorrect because it suggests that Korhonen can provide a translation into any official language of the EPO. However, since the original filing was made in Finnish and the language of proceedings might be English (as provided by Korhonen initially), he must specifically translate his claims into English.
#
# - **Option C:** This option is partially correct but misleading as it suggests that the amended claims can be filed only in Finnish followed by an English translation. The specific regulation requires translations to two official languages, not just one.
#
# - **Option D:** This option is incorrect because it states that Korhonen is not allowed to file the amended claims in Finnish. However, given his nationality and place of residence, he can indeed file the amendments in Finnish, provided he follows through with the required translation into English within the specified period.
#
# Therefore, the correct statement is that Korhonen must initially file the amended claims in Finnish and then provide a translation into English (and potentially another official language) to comply with EPO requirements.
# Answer after 2nd model: ```json
# {
#   "Answer": "Korhonen must file the amended claims in Finnish and must then provide a translation into English, in time.",
#   "Justification": "According to the Guidelines for Examination in the EPO (C-V 1.3), if an applicant files claims in a language other than one of the official languages of the European Patent Office (English, French, or German), they must provide translations into the two remaining official languages within four months from the date of communication under Rule 71(3). Since Korhonen filed his claims in Finnish and the language of proceedings might be English, he is required to translate his claims into English. Other options are incorrect because either they suggest filing in any EPO official language (without specifying English), or they misinterpret regulations by suggesting only one translation is needed instead of two."
# }
# ```
# Erreur Answer est pas une lettre: Answer=Korhonen must file the amended claims in Finnish and must then provide a translation into English, in time.
# Attempt 1 failed. Retrying...
# Answer before 2nd model:
#
# **Correct Answer:**
# C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time.
#
# **Explanation:**
#
# According to the provided legal text:
#
# 1. **Option C (Correct):** The relevant excerpt states that "Korhonen must file the amended claims in Finnish and must then provide a translation into English, in time." This aligns with the correct answer choice C, which says Korhonen can file the amended claims in Finnish if he provides an English translation within the given timeframe.
#
# 2. **Option A (Incorrect):** While this option correctly states that Korhonen must file the amended claims in Finnish and provide a translation into English, it does not specify the required language for the translation, making it less precise compared to Option C which clearly mentions English as the target language.
#
# 3. **Option B (Incorrect):** This option suggests that Korhonen can provide any official EPO language translation but fails to mention specifically the requirement for an English translation, which is critical based on the provided context.
#
# 4. **Option D (Incorrect):** This option incorrectly states that Korhonen is not allowed to file amended claims in Finnish, directly contradicting the clear legal text indicating he can do so with a subsequent English translation within time.
#
# Therefore, Option C correctly reflects the conditions under which Korhonen may proceed.
# Answer after 2nd model: ```json
# {
#   "Answer": "C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time.",
#   "Justification": "According to the provided legal text: Option C correctly reflects that Korhonen must file the amended claims in Finnish and provide an English translation within the given timeframe. Options A, B, and D are incorrect as they either fail to mention or incorrectly state the requirement for providing an English translation."
# }
# ```
# Final answer: C
# {'question': 'Applicants may request processing of their international application under PCT Direct by filing a letter ("PCT Direct letter") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?', 'options': ['A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing', 'B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0', 'C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0', 'D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document']}
# Answer before 2nd model:
#
# ### Legal Question Analysis
#
# #### Given:
# The question pertains to PCT Direct, a streamlined procedure for processing international applications under certain conditions.
#
# **Question:**
# Applicants may request processing of their international application under PCT Direct by filing a letter ("PCT Direct letter") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application. Which of the following statements is **NOT** correct?
#
# #### Provided Options:
# - A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT - Filing
# - B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0
# - C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0
# - D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document
#
# ### Answer:
# **Answer D**
#
# #### Explanation:
#
# 1. **Option A (Incorrectly Noted as Correct)**:
#    - The conditions for PCT Direct include having a priority application searched by the EPO and being submitted in one of the official languages of the EPO (English, French or German). If a Belgian application was filed in French and has been searched, then it meets these requirements. Filing an international application in French using ePCT-Filing would also meet the conditions for PCT Direct.
#
# 2. **Option B (Incorrectly Noted as Correct)**:
#    - Here, the priority application is an EP application filed in French and subsequently searched by EPO. The subsequent international application can be filed in English and processed through Online Filing 2.0. This would still meet the criteria for PCT Direct since both applications are being managed under conditions that allow streamlined processing.
#
# 3. **Option C (Incorrectly Noted as Correct)**:
#    - An international application previously filed with EPO in English, which has been searched by EPO, serves well as a basis for another international application to be filed also in English via Online Filing 2.0. This scenario fits the conditions for PCT Direct.
#
# 4. **Option D (Correctly Noted as Incorrect)**:
#    - The requirement that "amended claims are filed with the PCT Direct letter, in a single PDF document" is not correct according to the provided context about PCT Direct procedures. Generally, informal comments aimed at overcoming objections raised by EPO's search opinion should be contained within the PCT Direct letter itself, but there’s no specific requirement for amended claims being part of this letter or in any particular format like a single PDF document.
#
# Therefore, Option D is the statement that is **NOT** correct under the provided context.
# Answer after 2nd model: ```json
# {
#   "Answer": "D",
#   "Justification": "The requirement that 'amended claims are filed with the PCT Direct letter, in a single PDF document' is not correct according to the provided context about PCT Direct procedures. Generally, informal comments aimed at overcoming objections raised by EPO's search opinion should be contained within the PCT Direct letter itself, but there’s no specific requirement for amended claims being part of this letter or in any particular format like a single PDF document."
# }
# ```
# Final answer: D
# {'question': 'Mr Linguist filed a European patent application in Dutch and used English as language of the proceedings. When requesting unitary effect on 10 October 2024, Mr Linguist must provide a translation of the specification. Mr Linguist would like to obtain immediate registration of the unitary effect. Which of the following statements is correct?', 'options': ['A. Mr Linguist must provide a translation of the specification into Dutch', 'B. Mr Linguist must provide a translation of the specification into an official language of any of the 18 states to which the unitary effect extends', 'C. Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA', 'D. Mr Linguist may provide a translation of the specification into Spanish']}
# Answer before 2nd model:
#
# **Answer:**
# D. Mr Linguist may provide a translation of the specification into Spanish
#
# ### Explanation:
#
# 1. **Correct Answer (D):**
#    - According to the provided content from "2024_EPAC_mcq_solution.json," it states, "The translation may be in any of the 24 official languages of the EU, except English, irrespective of the language in which the application was filed or the geographical extent of the unitary effect." This indicates that Mr. Linguist can provide a translation into Spanish (an official language of the European Union) for immediate registration of the unitary effect.
#
# 2. **Incorrect Options:**
#    - **Option A:** "Mr Linguist must provide a translation of the specification into Dutch" is incorrect because the application was already filed in Dutch, and there's no requirement to translate it back into the same language.
#    - **Option B:** "Mr Linguist must provide a translation of the specification into an official language of any of the 18 states to which the unitary effect extends" is incorrect. The regulation does not limit the choice of languages based on specific member states but instead refers to the broader pool of all EU official languages.
#    - **Option C:** "Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA" is also incorrect. The relevant regulation only mentions the use of any of the 24 official languages of the EU, not specific countries that have signed the agreement.
#
# Therefore, Mr. Linguist may provide a translation in Spanish to meet the requirement for immediate registration of the unitary effect.
# Answer after 2nd model: ```json
# {
#   "Answer": "D. Mr Linguist may provide a translation of the specification into Spanish",
#   "Justification": "According to the provided content from \"2024_EPAC_mcq_solution.json,\" it states, \"The translation may be in any of the 24 official languages of the EU, except English, irrespective of the language in which the application was filed or the geographical extent of the unitary effect.\" This indicates that Mr. Linguist can provide a translation into Spanish (an official language of the European Union) for immediate registration of the unitary effect."
# }
# ```
# Final answer: D
# {'total_answer': 29, 'correct_answer': 15}

# %% [markdown]
# ## qwen1.5-32B without model 2 with new prompt and better parsing

# %%
def generate_mcq_answer(question_mcq: str, model, knowledge_vector_db, reranker=False) -> dict:
    """
    Generates an answer for a MCQ question.

    Parameters:
    question_mcq (str): The input question_mcq for which an answer is needed.

    Returns:
    answer (str): The generated response from the AI with the context used.
    """

    # Convert the question in string, in case the question is a json.
    question_mcq = str(question_mcq)

    # Retrieve context
    if reranker:
        print(f'Rerank')
        retrieved_docs = get_context(question_mcq, k=50, knowledge_vector_db=knowledge_vector_db)
        retrieved_docs = reranker.rerank(question_mcq, retrieved_docs, k=5)
    else:
        retrieved_docs = get_context(question_mcq, k=5, knowledge_vector_db=knowledge_vector_db)

    context = "\nExtracted documents:\n"
    context += "".join([f'Content: {doc.page_content} \nSource: {doc.metadata['ref']}\n\n' for i, doc in enumerate(retrieved_docs)])
    context_sources = "".join([f'\nSource: {doc.metadata['ref']}, Url: {doc.metadata.get('url', 'N/A')}' for i, doc in enumerate(retrieved_docs)])

    # Build prompt
    SYSTEM_PROMPT = f"""You are an AI specialized in answering multiple-choice legal questions based on given legal texts.
    ### Instructions:
    - Always start your response with:  
    **Answer: X** (where X is A, B, C, or D).  
    - After that, provide a detailed justification.  
    - Explain why the selected answer is correct based on the legal context.  
    - Explain why the other choices (B, C, D) are incorrect, referencing the legal context.  

    The **Answer** field must contain only a single letter: A, B, C, or D.  
    All explanations must be in the **Justification** section.  
    Ensure strict adherence to this format to allow for structured extraction.
    """

    user_prompt = f"""
    ### Context:
    {context}

    ### Legal Question:
    {question_mcq}

    Respond strictly in the following format:

    **Answer: X**  
    **Justification:**  
    - Explanation of why X is correct.  
    - Explanation of why B, C, and D are incorrect.  

    Ensure that:  
    - The **Answer** field contains only a single letter (A, B, C, or D).  
    - All other explanations are in the **Justification** section.
    """

    # Initial attempt to get the answer
    attempt_count = 0
    max_attempts = 3  # Limit number of attempts to prevent infinite loops

    while attempt_count < max_attempts:
        answer_mcq = chat(model=model,
                            messages=[{"role":"system", "content":SYSTEM_PROMPT},
                                      {"role":"user","content":user_prompt}],
                            options = {"num_predict":MAX_OUTPUT_TOKENS}
                            )

        # Put answer in correct json format
        try:
            # Regex pour capturer Answer et Justification
            pattern = re.compile(r"\*\*Answer:\s*([A-D])\*\*\s*\n\s*\*\*Justification:\*\*\s*\n(.*)", re.DOTALL)

            match = pattern.search(answer_mcq['message']['content'])

            if match:
                extracted_answer = match.group(1)
                justification = match.group(2).strip()

                # check for a valid letter isolated
                match = re.search(r'\b[A-D]\b', extracted_answer)
                if match:
                    extracted_answer = match.group()
                    print(f'Final answer: {extracted_answer}')
                else:
                    print(f"Erreur Answer is not a letter: Answer={extracted_answer}")
                    raise ValueError("Answer should be 'A', 'B', 'C' ou 'D'.")
            
                justification += f'\n\nSources:\n{context_sources}'
                return {"Answer": extracted_answer, "Justification": justification}  # If valid, return it

        except ValueError:
            attempt_count += 1  # Increment attempt count
            print(f"Attempt {attempt_count} failed. Retrying...")
            
    
    # If all attempts fail, raise an exception or return None
    return {'Answer': 'Error', 'Justirifation': 'Error parsing json.'}
    raise ValueError("Failed to generate a valid MCQ after multiple attempts.")

# %%
test_reader_model(embeddings_model='sentence-transformers/all-MiniLM-L6-v2', chunk_size=512, reader='qwen2.5:32b')
# Out:
# embedding load
# {'question': 'A European patent was granted to a German company on 4  January 2023. No opposition was filed. Mr Li and Ms Smith were designated as inventors. On 12 October 2023,  the patent proprietor not ices that Ms Smith was erroneously designated as inventor and that Mr Li is the sole inventor.  Which of the following statements is correct?', 'options': ['A. Ms Smith will be deleted as inventor if the patent proprietor requests this in writing .', 'B. Ms Smith can no longer  be deleted as inventor because no proceedings are pending before the EPO .', "C. The patent proprietor can request that  Ms Smith be deleted as inventor but needs Mr Li 's consent  for this .", 'D. Ms Smith can only be deleted as inventor with her consent .']}
# Final answer: D
# {'question': "On 10 October 2021, European patent attorney X filed European patent application EP -A with the EPO on the applicant's behalf. Application EP -A was published on 12 April 2023, together  with the extended European search report. On 6  October 2023, the applicant contacts a new European patent attorney  Y to replace X as representative and issues Y with its instructions to reply to the extended European search report. The applicant did not inform X that he would be replaced.  What are the steps necessary to validly appoint representative Y and to avoid any loss of rights for European patent application EP -A?", 'options': ['A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant .', 'B. New representative Y requests a change of representative and files a response to the extended European search report with  the EPO by 12 October 2023 at the latest .', 'C. New representative Y requests a change of representative and files a response to the extended European search report with the EPO by 23 October 2023 at the latest.', 'D. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 23 October 2023 at the latest and files in good time an authorisation signed by the applicant .']}
# Final answer: A
# {'question': 'EP-1 is a regular European patent application (Euro -direct application) .  Which one of the following missed time limits can be remedied for EP -1 before the EPO by requesting re- establishment of rights ?', 'options': ['A. T ime limit for pay ing the designation fee', 'B. T ime limit for requesting examination', 'C. T ime limit for filing the application within the priority period', 'D. T ime limit for paying the fee for re- establishment of rights']}
# Final answer: C
# {'question': 'Last week Greta validly filed the international patent application PCT -G with the German Patent and Trade mark Office ( DPMA ) and appointed Hassan to represent her. Hassan is entitled to act before the DPMA  but he is not a European patent attorney. Greta and Hassan are resident in Germany.  Which of the following statements is not correct?', 'options': ['A. Hassan can represent Greta before the EPO acting as the International Searching Authority for PCT -G.', 'B. In order for Hassan to be able to act before the EPO acting as the International Searching Authority , he needs to submit a power of attorney signed by Greta.', 'C. According to the provisions of the PCT, it is mandatory that the d emand for international preliminary examination is signed by Greta or Hassan.', 'D. According to the provisions of the PCT, an international application can only be withdrawn by the applicant or an agent appointed by a power of attorney.']}
# Final answer: C
# {'question': 'In which of the following cases is the applicant entitled to a reduction of the filing fee  under Rule  6 EPC ? A declaration of such entitlement has  been made by crossing the relevant box on Form  1001.', 'options': ['A. A Spanish European patent attorney files a European patent application in Spanish for a natural person who is resident in Andorra and of Andorra n nationality .', 'B. A firm whose principal place of business is in Germany and a natural person who is resident in Germany  and of Dutch nationality  jointly file a European patent application in Dutch. The German firm employs 200 people with an annual turnover of EUR 60 million.', 'C. A natural person resident in the USA and of Belgian nationality files a European patent application in French.', 'D. A natural person resident in the USA and of Swiss nationality files a European patent application in Italian.']}
# Final answer: C
# {'question': 'Mr Van Holland is a Dutch citizen resident in the Netherlands. He filed a European patent application EP -parent in Dutch, together with  a translation into English. Whil e EP-parent was pending, Mr Van Holland filed a divisional application EP -div in Dutch and requested examination in Dutch. He paid all fees due for EP -div. He has not filed an English translation of EP -div. The Receiving Section has now issued a noting of l oss of rights.  Which of the following statements is correct?', 'options': ['A. The deficiency cannot be remedied.', 'B. Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication  under Rule 112(1) EPC .', 'C. Mr Van Holland needs to file an English translation of EP -div together with a request for f urther processing.', 'D. Mr Van Holland needs to file an English translation of EP -div together with a request for re- establishment of rights.']}
# Final answer: A
# {'question': 'On 16  November 2020, you filed a European patent application EP -A, which did not claim priority. Today, 12  October 2023, you receive a communication from the EPO entitled " Decision to grant a European patent pursuant to Article  97(1) EPC ". This communication state s that the mention of the grant You wish to validate the patent in only two contracting states  to the EPC . Which of the following statements is correct?', 'options': ['A. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 16 November 2023.', 'B. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 30 November 2023.', 'C. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 9 January 2024 at the latest .', 'D. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 16 January 2024 at the latest .']}
# Final answer: C
# {'question': 'During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?', 'options': ['A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.', 'B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.', 'C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.', 'D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months.']}
# Final answer: A
# {'question': 'Under the PCT, what is the time limit for filing a request for rectification of an obvious mistake made in the international application?', 'options': ['A. 18 months from the earliest priority date', 'B. 30 months from the earliest priority date', 'C. 22 months from the earliest priority date', 'D. 26 months from the earliest priority date']}
# Final answer: D
# {'question': 'After receipt of a negative written opinion issued by the EPO acting as ISA, amendments under Art icle 19 PCT were filed during the international phase. No request for international preliminary examination was filed. Form  1200 was used,  and no further amendments were filed with the EPO upon entry into the regional phase.   What communication under Rules  161/162 EPC will be received in the regional phase?', 'options': ['A. Form 1226AA ;  if you do not reply to it in time, the application will be deemed to be withdrawn', 'B. Form 1226BB offering the opportunity to comment and file amendments', 'C. Form 1226CC offering the opportunity to file amendments before the supplementary European search report is drawn up', 'D. Form 1226AC stating that the examination has started']}
# Final answer: A
# {'question': 'Company M, which has  its principal place of business in Tijuana, Mexico, validly filed an international patent application PCT -M with the Mexican Institute of Industrial Property. The application was filed in Spanish. A few days later, the applicant files an English translati on of the application.  Which of the following statements is correct?', 'options': ['A. The applicant can choose the EPO as ISA and the USPTO as IPEA.', 'B. The applicant can choose the USPTO as ISA and the EPO as IPEA.', 'C. The applicant can choose the Austrian Patent Offic e as ISA and the', 'EPO as IPEA.', 'D. The applicant can choose the EPO as ISA and the Intellectual Property', 'Office of Singapore as IPEA.']}
# Final answer: B
# {'question': 'On 20  June 2023, applicant P validly filed an international patent application PCT-P, claiming priority from European patent application EP -I filed on 7 July 2022. Today, 12 October 2023, he discovers that he should also have claimed priority from EP -II filed on 3 July 2022. Can the missing priority claim still be validly added?', 'options': ['A. Yes, the time  limit for adding the priority claim expires on 3  November 2023.', 'B. Yes, the time limit for adding the priority claim expires on 7  November 2023.', 'C. Yes, the time  limit for adding the priority claim expires on 20 October 2023.', 'D. No, the time  limit for adding the priority claim expired on 3 July 2023.']}
# Final answer: A
# {'question': 'The opposition division revoked European patent EP -B1. The patent proprietor filed an appeal  in time . The b oard of appeal forwarded a copy of the appeal to the o pponent/ respondent with a communication dated 1 June 2023 giving it an opportunity to file comments within a period of four  months.  The opponent/respondent files comments today, 12 October 2023. What further action has to be taken ?', 'options': ['A. The opponent/ respondent needs  to request an extension of the period for comment.', 'B. The opponent/respondent needs to pay a fee for further processing.', 'C. The opponent/respondent needs to file a substantiated request for reestablishment of rights and pay the associated fee.', 'D. None of the above.']}
# Final answer: C
# {'question': 'A European patent application was filed on 20 March 2020. Proceedings were interrupted under  Rule 142 EPC on 10  March 2022. The applicant was informed that proceedings would be resumed today, 12 October 2023. No renewal fee has been paid so far . Which of the following statements is correct?', 'options': ['A. As no renewal fees have been paid, the application is deemed to be withdrawn .', 'B. The renewal fees for the third and fourth years can be validly paid without any additional fee on 12 October 2023 at the latest .', 'C. The renewal fees for the third and fourth years can be validly paid with an additional  fee by 30  April 2024 at the latest .', 'D. The renewal fees for the third and fourth years can be validly paid without any additional fee by 31  October 2023 at the latest .']}
# Final answer: C
# {'question': 'An international application is published , together  with the search report drawn up by the CNIPA , 18 m onths + 1 day after the filing date (no priority claimed). The application has no more than 35 pages and 15 claims. Which statement reflects all actions the CN  applicant  needs to take for entry into the EP phase 25 months  after the filing date ? A request for early processing has been filed.', 'options': ['A. Complete and file Form 1200 and pay the filing fee and the search fee', 'B. Complete and file Form 1200 and pay the filing fee, the search fee and the renewal fee for the third year', 'C. Complete and file Form 1200, pay the filing fee and the search fee and appoint a representative', 'D. None of the above statements']}
# Final answer: A
# {'question': 'A European patent application was filed on 6 February 2023. The search, filing and designation fees were paid within a month of the date of filing. What is the latest point in time for withdrawing the application, if the applicant wishes to obtain a refund of the designation fee?', 'options': ['A. Six months after the date of mention of the publication of the European search report', 'B. Date of mention of the publication of the European search report', 'C. The designation fee was validly paid and can no longer be refunded', 'D. Date of the start of substantive examination']}
# Final answer: A
# {'question': "On 10 October 2024, an applicant files a request for entry into the European phase, together with a debit order, according to which the filing fee, the designation fee, the examination fee and the renewal fee for the third year are to be debited from the applicant's deposit account. It is specified that the debit order is to be executed on 18 October 2024. On the evening of 10 October 2024, the applicant notices that the renewal fee is not yet due and should not be debited from the deposit account. What is the latest point in time for revoking the order to debit the renewal fee in Central Fee Payment (CFP)?", 'options': ['A. 10 October 2024', 'B. 17 October 2024', 'C. 18 October 2024', 'D. A debit order cannot be revoked in part']}
# Final answer: B
# {'question': 'The applicant received a communication pursuant to Article 90(3) EPC and Rule  60 EPC, requesting them to file a designation of inventor but missed the time limit for filing a response. After expiry of the time limit, the Receiving Section issued a decision to refuse the European patent application, dated 10  October 2024. What can the applicant do to remedy the situation?', 'options': ['A. File a notice of appeal against the decision within four months of notification of the decision', 'B. File a request for further processing within two months of notification of the decision', 'C. File, within two months of notification of the decision, a request for re-establishment of rights in respect of the time limit for filing the designation of inventor', 'D. A, B and C are correct']}
# Final answer: A
# {'question': 'Which of the following statements about filing third- party observations is correct?', 'options': ['A. The person that filed third- party observations will be a party to the proceedings before the EPO, and the applicant is obliged to respond to third- party observations', 'B. Third -party observations must be filed in writing and may not be filed anonymously', 'C. Third -party observations are considered by the examining division only if they include a statement of the grounds on which they are based, and an official fee is paid', 'D. Third -party observations can be filed after the publication of a European patent application and must be filed in an official language of the EPO']}
# Final answer: D
# {'question': 'You filed an international patent application on 6 June 2024, claiming the priority of a European patent application filed on 7  July 2023. You received a communication dated 25 September 2024 from the EPO acting as International Searching Authority (ISA), stating that the requirement of unity of invention has not been complied with. The ISA identifies three inventions. You are invited to pay two additional search fees. Which of the following statements is correct?', 'options': ['A. You must pay two additional search fees by 25 October 2024', 'B. You do not need to file a response to the provisional opinion accompanying the partial search results', 'C. If you pay two additional search fees under protest, you must pay two protest fees within the time limit', 'D. If you do not pay any additional search fees within the time limit, the international patent application will be deemed to be withdrawn']}
# Final answer: A
# {'question': 'An international patent application filed with the EPO as receiving Office on 10 September 2024, claims the priority of a Luxembourg patent application filed on 11 October 2023. No certified copy of the Luxembourg patent application was filed at the time of filing of the international patent application. Which of the following actions can be taken to file a certified copy of the Luxembourg patent application for this international patent application?', 'options': ['A. Request the Luxembourg Intellectual Property Office to prepare and send a certified copy of the Luxembourg patent application to the EPO', 'B. Submit a valid DAS code (Digital Access Service) to the International Bureau to enable it to obtain a certified copy of the Luxembourg patent application', 'C. File an electronic certified copy of the Luxembourg patent application with the EPO', 'D. File a certified copy of the Luxembourg patent application with the International Bureau']}
# Final answer: B
# {'question': 'Firm A owns a European patent, EP . Firm B filed an opposition against EP, requesting its revocation. Firm B argued that the subject -matter of the granted claims was not new in view of document D1. During the opposition proceedings, firm C filed observations under Art.  115 EPC, arguing that the subject -matter of the granted claims was not new in view of document D2. Firm A requested maintenance of the patent as granted, or maintenance in amended Which of the following statements is correct?', 'options': ["A. At the end of the opposition proceedings, the opposition division decided to revoke the patent. Firm B is entitled to file an appeal against the opposition division's decision.", "B. At the end of the opposition proceedings, the opposition division decided to and firm B are entitled to file an appeal against the opposition division's decision.", "C. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm C is entitled to file an appeal against the opposition division's decision.", "D. During the opposition proceedings, firm B withdrew its opposition. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm B is entitled to file an appeal against the opposition division's decision."]}
# Final answer: A
# {'question': 'European patent application EP -X was filed on 1  October 2020, claiming the priority of a Belgian application filed on 16 October 2019. The mention of the grant of European patent EP -X was published on 2  October 2024. The proprietor filed a request for unitary effect and was informed by communication dated 10  October 2024, that unitary effect had been registered for EP -X-C0 on the same date. Which of the following statements is correct?', 'options': ['A. A renewal fee still has to be paid by 31 October 2024 in respect of the 5th year for EP -X', 'B. A renewal fee is due on 31 October 2024 in respect of the 5th year for EP -X-C0', 'C. A renewal fee is due on 31 October 2024 in respect of the 6th year for EP -X-C0', 'D. No renewal fee has to be paid on 31 October 2024']}
# Final answer: A
# {'question': 'A communication under Article 94(3) EPC, setting a four -month time limit for reply is dated 12 September 2024. The applicant receives the letter on 21 September 2024, as evidenced by the postal receipt signed by him.  What is the last day for replying to the communication?', 'options': ['A. 13 January 2025', 'B. 12 January 2025', 'C. 22 January 2025', 'D. 14 January 2025']}
# Final answer: A
# {'question': 'Which functionalities or services can be accessed directly from MyEPO Portfolio?', 'options': ["A. A shared area with examiners, European Patent Register, filing via the EPO's online filing software eOLF", 'B. Mailbox, a shared area with examiners, replying to a communication under Article  94(3) EPC', 'C. Mailbox, patent search via publication server, a shared area with examiners', "D. Filing via the EPO's Online Filing 2.0, patent search via publication server, Mailbox"]}
# Final answer: B
# {'question': 'In which of the following situations does the EPO recommend using the EPO Contingency Upload Service?', 'options': ['A. When you submit documents after business hours', 'B. When the EPO filing systems are functioning correctly, but you encounter a technical issue at your end', 'C. When there is a system outage at the EPO that prevents document submission via the standard filing systems', 'D. When the EPO is closed due to an official holiday']}
# Final answer: C
# {'question': 'Applicant Korhonen is a Finnish national resident in Finland. He filed a European patent application in Finnish and provided an English translation in time. In response to the extended European search report (EESR), Korhonen wishes to file amended claims t ogether with a request for examination. Which of the following statements is correct?', 'options': ['A. Korhonen must file the amended claims in Finnish and must then  provide a translation into English, in time', 'B. Korhonen is allowed to file the amended claims in Finnish if he then provides a', 'translation into any official language of the EPO, in time C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time', 'D. Korhonen is not allowed to file the amended claims in Finnish']}
# Final answer: A
# {'question': 'Applicants may request processing of their international application under PCT Direct by filing a letter ("PCT Direct letter") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?', 'options': ['A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing', 'B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0', 'C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0', 'D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document']}
# Final answer: D
# {'question': 'Mr Linguist filed a European patent application in Dutch and used English as language of the proceedings. When requesting unitary effect on 10 October 2024, Mr Linguist must provide a translation of the specification. Mr Linguist would like to obtain immediate registration of the unitary effect. Which of the following statements is correct?', 'options': ['A. Mr Linguist must provide a translation of the specification into Dutch', 'B. Mr Linguist must provide a translation of the specification into an official language of any of the 18 states to which the unitary effect extends', 'C. Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA', 'D. Mr Linguist may provide a translation of the specification into Spanish']}
# Final answer: D
# {'total_answer': 29, 'correct_answer': 12}

# %%
# test_reader_model(embeddings_model='sentence-transformers/all-MiniLM-L6-v2', chunk_size=512, reader='deepseek-r1')

# %%
import json
import re

# Charger le fichier JSON
with open("../outputs/evaluation2/sentence-transformers_all-MiniLM-L6-v2_chunk512_qwen2_5_32b_test.json", "r", encoding="utf-8") as f:
    file = json.load(f)

# Regex pour capturer Answer et Justification
pattern = re.compile(r"\*\*Answer:\s*([A-D])\*\*\s*\n\s*\*\*Justification:\*\*\s*\n(.*)", re.DOTALL)

for item in file.get("data", []):
    ai_answers = item.get("ai_answers", [])
    
    for answer_dict in ai_answers:
        text = answer_dict.get("Justification", "No Justification")
        # print(text)

        match = pattern.search(text)

        if match:
            extracted_answer = match.group(1)
            justification = match.group(2).strip()

            # check for a valid letter isolated
            match = re.search(r'\b[A-D]\b', extracted_answer)
            if match:
                extracted_answer = match.group()
                print(f'Final answer: {extracted_answer}')

            print(f"Answer: {extracted_answer}")
            print(f"Justification: {justification}")
            print("-" * 50)  # Séparateur entre les entrées
# Out:
# Final answer: D
# Answer: D
# Justification: - Explanation of why D is correct. According to Rule 21(1) EPC, an incorrect designation of inventor shall be rectified upon request and only with the consent of the wrongly designated person. Since Ms Smith was erroneously designated as an inventor, she must give her consent for this correction to take place.
# - Explanation of why B is incorrect. There is no requirement that proceedings must be pending before the EPO in order to rectify an incorrect designation of inventors. The issue can be addressed even if there are no pending proceedings.
# - Explanation of why C is incorrect. Rule 21(1) does not require Mr Li's consent for this rectification; it requires only Ms Smith’s consent as she was the wrongly designated inventor.
# - Explanation of why A is incorrect. While the patent proprietor can request that Ms Smith be deleted, such a change cannot occur without Ms Smith’s explicit consent per Rule 21(1) EPC.
# --------------------------------------------------
# Final answer: A
# Answer: A
# Justification: - Explanation of why A is correct. According to EPO regulations and the given context, new representative Y needs to request a change of representative, file a response to the extended European search report with the EPO by 12 October 2023 at the latest (since that’s the deadline for responding), and also ensure that an authorization signed by the applicant is filed in good time. This ensures that there are no issues related to the change of representation, and rights over the application EP -A will be preserved.
#
# - Explanation of why B is incorrect. Option B omits the requirement to file an authorization signed by the applicant, which is crucial for validating the new representative Y’s actions.
#
# - Explanation of why C is incorrect. Option C suggests that the response to the extended European search report should be filed by 23 October 2023 at the latest, but this date is after the actual deadline (12 October 2023) for responding to the extended European search report published on 12 April 2023. Thus, missing this deadline would lead to loss of rights.
#
# - Explanation of why D is incorrect. Option D also suggests filing a response by 23 October 2023 at the latest and includes filing an authorization signed by the applicant. However, like option C, it fails to meet the critical deadline for responding (12 October 2023), which would result in a loss of rights for European patent application EP -A.
# --------------------------------------------------
# Final answer: A
# Answer: A
# Justification: - **Explanation of why A is correct:** According to Article 122 and Rule 136 of the Guidelines for Examination in the EPO, re-establishment of rights can be requested if an applicant was unable to observe a time limit despite taking all due care. The time limit for paying the designation fee (option A) falls under these circumstances where the request for re-establishment of rights is possible.
#
# - **Explanation of why B, C, and D are incorrect:**
#   - **B:** Time limit for requesting examination cannot be remedied by a request for re-establishment of rights. The rules specifically do not provide for re-establishing rights in this case. Requesting examination under Art. 94(1) in conjunction with Rule 70(1) is considered an independent procedural act and not subject to the re-establishment provisions.
#   - **C:** Time limit for filing the application within the priority period (priority claim time limit) cannot be remedied by requesting re-establishment of rights. According to Article 87, if the application was not filed within the required timeframe from the original filing date, the priority is lost and there are no mechanisms provided in the rules for reinstatement.
#   - **D:** Time limit for paying the fee for re-establishment of rights itself is a prerequisite for initiating the re-establishment process. If this time limit is missed, it implies that the applicant has not even initiated the request to re-establish their rights, hence this option does not make sense within the context provided.
#
# Thus, only the time limit for paying the designation fee can be remedied through requesting re-establishment of rights as per the applicable EPO regulations.
# --------------------------------------------------
# Final answer: C
# Answer: C
# Justification: - Explanation of why C is incorrect: According to PCT provisions, it is not mandatory that the demand for international preliminary examination be signed by Greta or Hassan. The relevant rules do not specifically mandate who must sign the demand; they simply state that the applicant can appoint a representative and that such a representative may act on their behalf, subject to specific requirements of the authority.
#
# - Explanation of why A is correct: Hassan can represent Greta before the EPO acting as the International Searching Authority for PCT-G if he has been given proper authorization by Greta. The PCT allows representation before search authorities without necessarily requiring a European patent attorney.
#
# - Explanation of why B is correct: For Hassan to act on behalf of Greta before the EPO, it would typically be necessary to submit a power of attorney signed by Greta to establish formal authority for Hassan’s actions.
#
# - Explanation of why D is correct: According to PCT provisions, an international application can only be withdrawn by the applicant or an agent appointed by a validly executed power of attorney. This ensures that withdrawal decisions are made with proper authorization and representation.
# --------------------------------------------------
# Final answer: C
# Answer: C
# Justification: - Explanation of why C is correct. According to Rule 6 EPC, an individual applicant who is a natural person and resident outside the European Patent Office’s (EPO) contracting states or certain listed countries can be entitled to reduced fees if they are of nationalities of such contracting states. The person in option C is a natural person resident in the USA (a non-contracting state) but holds Belgian nationality (a contracting state). This satisfies the criteria for entitlement under Rule 6 EPC.
#
# - Explanation of why B, C, and D are incorrect.
#   - Option A: Though the applicant here is from Andorra, which would generally qualify as an individual applicant resident outside the European Union, crossing the box on Form 1001 alone does not suffice if there’s any uncertainty or additional requirements that might disqualify this scenario. Additionally, filing in Spanish by a patent attorney doesn't necessarily mean entitlement to reduced fees under Rule 6 EPC.
#
#   - Option B: This option involves two applicants (a firm and an individual) jointly filing the application, which means they do not qualify for any fee reduction as per Rule 6 EPC. The criteria for reduced fees require that only one natural person who is resident in a non-contracting state can make such a declaration.
#
#   - Option D: This option involves an applicant from the USA but of Swiss nationality. While the individual meets the condition of being resident outside a contracting state and holding nationality of one, filing the application in Italian (a language not aligned with their nationality or place of residence) might lead to additional scrutiny that could disqualify them under Rule 6 EPC’s criteria for reduced fees.
# --------------------------------------------------
# Final answer: A
# Answer: A
# Justification: - Explanation of why A is correct: According to R. 36(2) EPC and related guidelines, if a divisional application (EP-div) is filed in an admissible non-EPO language like Dutch but not accompanied by the required translation into the official EPO language (English), it will result in a loss of rights as noted in Rule 112(1). Since Mr Van Holland did not file an English translation within two months, he cannot now remedy this deficiency.
#
# - Explanation of why B is incorrect: According to R. 58 and Art. 90(3) EPC, once the noting of loss of rights (under Rule 112(1)) has been issued for a required translation not filed in due time, it cannot be remedied by filing an English translation within two months from notification.
#
# - Explanation of why C is incorrect: Further processing requests under Rule 137 EPC are applicable to deficiencies that can still be remedied; however, the loss of rights noted under Rule 112(1) due to non-compliance with translation requirements cannot be cured by merely filing a translation and requesting further processing.
#
# - Explanation of why D is incorrect: Re-establishment of rights under Article 122 EPC involves demonstrating that the delay was beyond the control of the applicant. Given the specific requirement for timely translations, re-establishing rights would not apply as the failure to meet this procedural requirement cannot be rectified retroactively.
# --------------------------------------------------
# Final answer: C
# Answer: C
# Justification: - Explanation of why C is correct: According to Rule 51 EPC and the provided information, after the mention of grant publication, renewal fees for subsequent years must be paid directly to the national offices (i.e., separately in each state where validation occurs). Additionally, there is a grace period allowed if the fees are not paid by the exact due date. The decision to grant on October 12, 2023, implies that the mention of grant will typically be published about two months later. Thus, for EP-A filed on November 16, 2020, the fourth-year renewal fee would normally be due on November 16, 2023. With a typical grace period of two months from the publication of the European Patent Bulletin (EPB), this implies that payment is valid without additional fees until January 9, 2024.
# - Explanation of why A and B are incorrect: Option A incorrectly states that the renewal fee for the fourth year must be paid centrally to the EPO. After grant, these fees should be paid directly to national offices in the chosen validation states. Option B has the correct due date (30 November 2023), but it also incorrectly suggests central payment through the EPO.
# - Explanation of why D is incorrect: While D correctly identifies that the renewal fee must be paid separately to each state and mentions the grace period, its last date for valid payment without an additional fee (16 January 2024) is incorrect. The correct latest date would be January 9, 2024, considering a typical two-month delay between grant decision and EPB publication.
# --------------------------------------------------
# Final answer: A
# Answer: A
# Justification: - Explanation of why A is correct: In oral proceedings where the opposition division decides to maintain the patent with amendments that include handwritten changes in the description, it aligns with the guidelines that formal compliance is required for the entire description. The patent proprietor must pay the fee for publishing a new specification and file translations of the claims as part of the requirements to ensure that all documents are officially compliant.
#
# - Explanation of why B is incorrect: Statement B incorrectly suggests that no further actions by the patent proprietor would be needed if an appeal were filed, which does not align with procedural standards. Even after filing an appeal, formal compliance remains a prerequisite for maintaining the patent in its amended form once finalized.
#
# - Explanation of why C is incorrect: The opposition division typically does not issue an immediate invitation to pay fees and submit compliant versions together with the interlocutory decision itself. Instead, this step usually occurs post-decision as part of the formalities processing phase.
#
# - Explanation of why D is incorrect: While it may seem logical that upon request after no appeal is filed, the patent proprietor should comply within four months, the precise timing and nature of compliance requirements do not align with procedural norms. The requirement to ensure all documents are formally compliant (including translation and fees) must be met to finalize the process properly.
# --------------------------------------------------
# Final answer: D
# Answer: D
# Justification: - Explanation of why D is correct: According to the information provided from the case law and PCT rules, the time limit for filing a request for rectification of an obvious mistake made in the international application is 26 months from the earliest priority date.
#
# - Explanation of why A, B, and C are incorrect:
#     - Option A (18 months) is incorrect because it does not match the specified period under PCT rules.
#     - Option B (30 months) is incorrect as it exceeds the given deadline for rectification.
#     - Option C (22 months) is also incorrect because it falls short of the required time limit as outlined by the relevant regulations.
# --------------------------------------------------
# Final answer: A
# Answer: A
# Justification: - Explanation of why A is correct: Since amendments under Article 19 PCT were filed during the international phase after receiving a negative written opinion from the EPO acting as ISA, and no request for international preliminary examination was made (meaning no IPER), the amendments are considered part of the application. As Form 1200 was used without any further amendments upon entry into the European regional phase, a communication under Rules 161/162 will be received that states if there is no reply in time, the application will be deemed to be withdrawn (Form 1226AA). This form informs the applicant of the potential consequences and requires action within a given timeframe.
# - Explanation of why B is incorrect: Form 1226BB typically offers an opportunity to comment and file amendments but would not be issued in this scenario because there are no further actions needed if the earlier amendments (under Article 19 PCT) have already been accepted and are part of the application.
# - Explanation of why C is incorrect: Form 1226CC offers the opportunity to file amendments before the supplementary European search report is drawn up, but it would not be issued since no further amendments were filed upon entry into the regional phase, and the earlier amendments are already considered part of the application.
# - Explanation of why D is incorrect: Form 1226AC states that examination has started. However, this form does not apply in this situation because a negative written opinion was received from the EPO acting as ISA, and no further actions (such as filing new amendments) were taken upon entry into the European regional phase. The communication will indicate the need for timely action to avoid withdrawal rather than starting examination immediately.
# --------------------------------------------------
# Final answer: B
# Answer: B
# Justification: - Explanation of why B is correct. Since Company M filed its PCT application PCT-M with the Mexican Institute of Industrial Property (MIIP) and the MIIP is a receiving office, it can use any International Searching Authority (ISA) or International Preliminary Examining Authority (IPEA) that accepts filings from the MIIP. In this case, both USPTO and EPO are capable of being chosen as ISA and IPEA respectively.
#
# - Explanation of why A is incorrect. The EPO cannot be chosen as an ISA for a PCT application filed with the Mexican receiving office (MIIP). According to the provided information, only specific offices can act as ISAs or IPEAs when dealing with applications from MIIP. EPO can act as an IPEA but not as an ISA in this context.
#
# - Explanation of why C is incorrect. The Austrian Patent Office cannot be chosen as an ISA for a PCT application filed with the Mexican receiving office (MIIP). According to the provided information, specific offices are authorized to function as ISAs or IPEAs for applications filed through MIIP. The Austrian Patent Office does not fall within this list.
#
# - Explanation of why D is incorrect. While it is possible that EPO can be chosen as an ISA and Intellectual Property Office of Singapore (IPOS) as an IPEA, the given information does not indicate IPOS’s eligibility for functioning as an IPEA when MIIP is the receiving office. Thus, this statement is unsupported by provided data.
#
# Therefore, only option B correctly states that USPTO can be chosen as ISA and EPO as IPEA in this scenario.
# --------------------------------------------------
# Final answer: A
# Answer: A
# Justification: - Explanation of why A is correct. According to Rule 17.2 PCT, priority claims can be added until the expiration of eighteen months from the earliest claimed priority date or the filing date if no priority was claimed earlier. Here, EP-II was filed on July 3, 2022, and thus, within eighteen months (June 3, 2024) of that date, P can add this missing priority claim. The relevant time limit for adding a priority claim under Rule 17.2 PCT is the expiration date of 18 months from the earliest claimed priority date, which in this case would be July 3, 2022. Thus, the deadline to add a new priority claim would be November 3, 2023 (since PCT-P was filed on June 20, 2023).
#
# - Explanation of why B is incorrect. Option B states that the time limit expires on November 7, 2023, which does not align with Rule 17.2 PCT and the given priority date of July 3, 2022.
#
# - Explanation of why C is incorrect. Option C incorrectly suggests a deadline of October 20, 2023, which is not relevant to the rule that governs adding new priorities within eighteen months from the earliest claimed priority date (July 3, 2022).
#
# - Explanation of why D is incorrect. Option D claims that the time limit expired on July 3, 2023, which is also inaccurate since Rule 17.2 PCT allows for adding missing priorities up to eighteen months after the earliest claimed priority date (July 3, 2022).
# --------------------------------------------------
# Final answer: C
# Answer: C
# Justification: - Explanation of why C is correct. According to EPC Rule 100(2), the Board of Appeal invites parties to file observations within a specified period. If an opponent/respondent fails to respond in due time, they can request re-establishment of rights under Article 122 and pay the associated fee. In this case, the communication gave four months for comments but the response came after the deadline on October 12, 2023, so a substantiated request for re-establishment of rights is necessary.
#
# - Explanation of why A is incorrect. The period given by the Board has already expired and requesting an extension would not be appropriate under Rule 100(2). Only Article 122 provides mechanisms to remedy late submissions through a formal process.
#
# - Explanation of why B is incorrect. While fees may eventually become necessary, merely paying for further processing without addressing the time issue does not meet the procedural requirements set out in EPC rules and case law.
#
# - Explanation of why D is incorrect. The opponent/respondent cannot ignore the missed deadline; some action must be taken to comply with procedures under Article 122 to re-establish rights after a late response.
# --------------------------------------------------
# Final answer: C
# Answer: C
# Justification: - Explanation of why C is correct: According to Rule 51(2) EPC, renewal fees for the third and fourth years can be paid without additional fee up to their respective due dates. However, if they are paid after these due dates but within six months of the due date, an additional fee must be paid. The third-year renewal fee is due on March 31, 2023 (as per Rule 51(1) EPC), and the fourth-year renewal fee is due on March 31, 2024. Since no fees have been paid by October 12, 2023, an additional fee would be applicable if they are paid by April 30, 2024 (six months after March 31, 2023).
#
# - Explanation of why B is incorrect: Renewal fees for the third and fourth years can only be validly paid without any additional fee up to their due dates, i.e., March 31, 2023, and March 31, 2024 respectively. Since October 12, 2023 is after the deadline for paying the third-year renewal fee without an additional fee, this statement is incorrect.
#
# - Explanation of why A is incorrect: The application will not be deemed to be withdrawn automatically if no renewal fees have been paid. According to Rule 54(1) EPC, a European patent application shall be regarded as withdrawn if any prescribed payment has not been made before the end of six months from the date on which notice was given that payment is due (see Rule 67 EPC). However, since proceedings were interrupted and then resumed, there might be an extension or grace period.
#
# - Explanation of why D is incorrect: The third-year renewal fee can be paid with an additional fee until October 31, 2023, but the fourth-year renewal fee cannot yet be paid (as its due date is March 31, 2024). Thus, this statement is incorrect.
# --------------------------------------------------
# Final answer: A
# Answer: A
# Justification: - Explanation of why A is correct. According to Rule 159(1) of the European Patent Convention (EPC), for an international application, the applicant must supply a translation if required, specify the documents on which the grant procedure will be based, and pay the filing fee within thirty-one months from the date of filing of the application. Since the search report has been drawn up by the CNIPA and no priority was claimed, the applicant needs to complete Form 1200 (which includes specifying the documents) and pay both the filing fee and the search fee for entry into the EP phase. The renewal fee is not required at this stage because it would be due after thirty-one months from the filing date.
#
# - Explanation of why B is incorrect. Option B incorrectly includes paying the renewal fee for the third year, which is not necessary within 25 months of the filing date. According to Rule 159(1)(g), the third-year renewal fee only needs to be paid if it has fallen due earlier under Rule 51(1).
#
# - Explanation of why C is incorrect. Option C includes appointing a representative, which is not mandatory for entering the EP phase as per Rule 159.
#
# - Explanation of why D is incorrect. None of the above statements correctly identifies the necessary actions if option A (the correct answer) applies.
# --------------------------------------------------
# Final answer: A
# Answer: A
# Justification: - Explanation of why A is correct. According to Rule 39(2) EPC as mentioned in the case law reference provided (Case Law IV, A.7.2.1), the designation fee must be paid within six months from the date on which the European Patent Bulletin mentions the publication of the European search report. If the applicant withdraws before this deadline and the designation fee has not been paid, the application will be deemed to be withdrawn under Rule 39(2) EPC without incurring a penalty for non-payment, hence allowing a refund.
#
# - Explanation of why B is incorrect. The date of mention of the publication of the European search report is the starting point from which the six-month period begins but not the deadline itself. Hence, withdrawing on or before that date would still require paying the designation fee within the subsequent six months to avoid deemed withdrawal.
#
# - Explanation of why C is incorrect. The designation fee can indeed be refunded if the application is withdrawn before it is paid and before the end of the stipulated time frame (six months from publication mention).
#
# - Explanation of why D is incorrect. The start of substantive examination does not pertain to the deadline for payment or deemed withdrawal related to the designation fee under Rule 39(2) EPC. The relevant time limit pertains to the six-month period post-publication mention in the European Patent Bulletin.
# --------------------------------------------------
# Final answer: B
# Answer: B
# Justification: - Explanation of why B is correct. According to the ADA (Arrangements for Deposit Accounts), specifically Section 13.2, a debit order with a deferred payment date can be revoked in whole or in part until one day before the specified execution date at the latest. Here, the execution date for the debit order is set for 18 October 2024; thus, the latest point in time to revoke part of the order (such as the renewal fee) would be 17 October 2024.
#
# - Explanation of why A, C, and D are incorrect.
#     - **A.** 10 October 2024: This date is too early for a partial revocation since the full debit order was just filed that day, and no delay in processing would have occurred by this time. The applicant still has up until one day before the execution date to revoke part of the order.
#     - **C.** 18 October 2024: This is incorrect as it is the actual date when the debit order will be executed. According to ADA Section 13.2, a partial revocation can only be made until one day before the execution date (i.e., 17 October 2024).
#     - **D.** A debit order cannot be revoked in part: This statement is incorrect as per ADA Section 13.2, which explicitly states that a debit order with a deferred payment can indeed be revoked in whole or in part until the day before execution.
# --------------------------------------------------
# Final answer: A
# Answer: A
# Justification: - Explanation of why A is correct. When an applicant fails to meet a deadline and their European patent application is refused as a consequence (such as under Article 90(3) EPC and Rule 60 EPC), the appropriate course of action is to file a notice of appeal within four months from the notification of the refusal decision (see Article 108 EPC). This allows the applicant to challenge the refusal on the grounds that it was improperly issued.
#
# - Explanation of why B, C, and D are incorrect.
#     - Option B suggests filing a request for further processing, which is not applicable in this scenario as there's no provision under the EPC for requesting further processing when an application has already been refused.
#     - Option C involves filing a request for re-establishment of rights (Article 122 EPC). However, Article 122(4) explicitly states that re-establishment of rights is ruled out in respect to the time limit for requesting such re-establishment. Therefore, once the deadline has passed and the refusal decision has been issued, a request for re-establishment will not be effective.
#     - Option D suggests all options A, B, and C are correct, but since B and C are incorrect as explained above, this option is also incorrect.
# --------------------------------------------------
# Final answer: D
# Answer: D
# Justification: - Explanation of why D is correct: According to Art. 115 and Rule 114(1) of the EPC, third-party observations can indeed be filed after the publication of a European patent application and must be filed in an official language of the EPO. This ensures that these observations are comprehensible and can be considered by the examining division during their examination process.
#
# - Explanation of why B is incorrect: While it is true that third-party observations must be filed in writing, they may actually be filed anonymously according to Art. 115 of the EPC and Rule 114(1). This means that there is no requirement for them to be non-anonymous.
#
# - Explanation of why C is incorrect: Third-party observations do not require an official fee to be paid; filing these observations is free of charge under the EPO rules. Additionally, while a statement of the grounds on which they are based is useful and often expected, it is not explicitly required for them to be considered by the examining division.
#
# - Explanation of why A is incorrect: The person that files third-party observations will not become a party to the proceedings before the EPO. They do not have any procedural rights in these proceedings, nor is the applicant obliged to respond directly to these observations; rather, it is up to the examining division to consider them and possibly take action accordingly.
# --------------------------------------------------
# Final answer: A
# Answer: A
# Justification: - Explanation of why A is correct: According to EPC Rule 64(1), if the European Patent Office (EPO) acting as ISA considers that an application does not comply with the requirement of unity of invention, it shall draw up a partial search report and inform the applicant that additional search fees must be paid within two months from the date of communication. Here, the communication was dated 25 September 2024, so the deadline for payment would be 25 November 2024 (not 25 October as stated in option A), but the principle remains correct that additional search fees must be paid within two months.
#
# - Explanation of why B is incorrect: The applicant is required to file a response if they wish to address any issues identified in the provisional opinion accompanying the partial search results. Ignoring this communication could result in adverse consequences, such as examination proceeding without addressing these issues adequately.
#
# - Explanation of why C is incorrect: According to EPC Rule 64(1), if additional fees are paid under protest, a single protest fee should be paid for all the additional search fees being contested, not one per each additional fee. Thus, paying two separate protest fees would not comply with the correct procedure.
#
# - Explanation of why D is incorrect: If no additional search fees are paid within the time limit, only those inventions that were initially searched will continue to be examined. The application as a whole will not be deemed withdrawn; instead, it may proceed for examination in relation to the invention(s) covered by the initial search fee.
# --------------------------------------------------
# Final answer: B
# Answer: B
# Justification: - Explanation of why B is correct. According to the Guidelines for Examination in the EPO and recent developments in international patent filing practices, submitting a valid Digital Access Service (DAS) code enables the International Bureau to obtain a certified copy directly from the Luxembourg Intellectual Property Office.
# - Explanation of why A is incorrect. Requesting the Luxembourg Intellectual Property Office to prepare and send a certified copy does not align with the current streamlined DAS process used by international offices like the EPO and WIPO (International Bureau).
# - Explanation of why C is incorrect. Filing an electronic certified copy directly with the EPO would typically apply for European applications under the EPC framework but not for international patent applications filed via the PCT route through the International Bureau.
# - Explanation of why D is incorrect. Although filing a certified copy directly with the International Bureau could theoretically be possible, it is less efficient than using the Digital Access Service (DAS) mechanism to ensure that the priority document is transmitted securely and efficiently between offices.
# --------------------------------------------------
# Final answer: B
# Answer: B
# Justification: - Explanation of why B is correct. According to Art. 108 EPC and established case law, only an opponent who participated in opposition proceedings can file an appeal against the decision of the opposition division. In this scenario, if Firm A’s patent was maintained as granted (option B), Firm B, having initially filed an opposition, would have standing to appeal the decision to maintain the patent.
# - Explanation of why A is incorrect. If the opposition division decided to revoke the patent, the patent proprietor (Firm A) and not Firm B would be entitled to file an appeal against this decision. Opponents do not appeal revocation decisions but rather seek to uphold such decisions or withdraw their objections if they are satisfied.
# - Explanation of why C is incorrect. Third parties who only file observations under Art. 115 EPC (such as Firm C) cannot initiate appeals. They are not considered formal opponents and thus lack standing in the appeal proceedings.
# - Explanation of why D is incorrect. If Firm B withdrew its opposition, it would no longer be an opponent within the meaning of the EPC, and therefore would have no right to file an appeal against a decision that maintains the patent as granted. Only active parties with standing are entitled to initiate appeals.
# --------------------------------------------------
# Final answer: A
# Answer: A
# Justification: - Explanation of why A is correct: EP-X was filed on 1 October 2020. According to Rule 51 and Article 86(1), renewal fees for European patent applications are due annually starting from the filing date, meaning the fifth year's fee would be due by 31 October 2024. Since the mention of the grant was published on 2 October 2024, the proprietor must still pay a renewal fee in respect of the 5th year for EP-X.
#
# - Explanation of why B is incorrect: The unitary effect (EP-X-C0) is registered on 10 October 2024. Renewal fees are due only after registration and starting from the date of grant. Thus, a fifth-year fee for EP-X-C0 would be due in subsequent years, not in the same year as the mention of the grant.
#
# - Explanation of why C is incorrect: The unitary effect (EP-X-C0) was registered on 10 October 2024, and renewal fees for unitary patents are paid annually starting from that date. Therefore, the first renewal fee would be due in the following year (i.e., October 2025), not in October 2024.
#
# - Explanation of why D is incorrect: The proprietor must still pay a renewal fee for EP-X by 31 October 2024 to maintain the application’s validity through its fifth year. Failure to do so would result in the European patent becoming abandoned or lapsing.
# --------------------------------------------------
# Final answer: D
# Answer: D
# Justification: - According to Rule 126(2) EPC, where notification is effected by registered letter, the document shall be deemed to be delivered to the addressee on the tenth day following its posting. Therefore, if a communication dated 12 September 2024 was received by the applicant on 21 September 2024 (nine days later), it will be deemed to have been delivered on 22 September 2024 (tenth day). The four-month time limit for reply commences from this date.
# - Four months from 22 September 2024 would end on 22 January 2025. However, since Rule 126(2) also provides that if the document reaches the addressee more than seven days after its posting (in this case, it reached nine days later), the period expires later by the number of days by which the seven days were exceeded. Here, the document was delivered two days late (9 - 7 = 2).
# - Therefore, the reply must be made two days later than originally calculated: 22 January 2025 + 2 days = 14 January 2025.
#
# - Option A (13 January 2025) is incorrect because it does not account for the additional two days due to late delivery.
# - Option B (12 January 2025) is incorrect as it assumes the original date of receipt without considering Rule 126(2).
# - Option C (22 January 2025) is incorrect because it ignores the adjustment made for the late delivery, which adds two days to the deadline.
# --------------------------------------------------
# Final answer: B
# Answer: B
# Justification: - Explanation of why B is correct. MyEPO Portfolio allows for access to services such as Mailbox and a shared area with examiners, which can be used for replying to communications under Article 94(3) EPC.
#
# - Explanation of why A is incorrect. It mentions accessing the European Patent Register and filing via the EPO's legacy Online Filing software (eOLF), both of which are not possible directly from MyEPO Portfolio based on provided information.
#
# - Explanation of why C is incorrect. It includes patent search via publication server, which cannot be done through MyEPO Portfolio according to the given data.
#
# - Explanation of why D is incorrect. It suggests filing via the EPO's Online Filing 2.0 and patent search via publication server, both of which are not functionalities of MyEPO Portfolio as per provided details.
# --------------------------------------------------
# Final answer: C
# Answer: C
# Justification: - Explanation of why C is correct. The EPO Contingency Upload Service is specifically designed to be used during system outages at the EPO that prevent document submission via standard filing systems.
#
# - Explanation of why A, B, and D are incorrect.
#   - Option A suggests using the service after business hours, but there's no specific indication in the provided information that it should be used for this purpose; rather, it is meant for exceptional circumstances such as system outages.
#   - Option B implies a technical issue at your end, which would typically not require the Contingency Upload Service. Generally, if you encounter a problem with your own equipment or software, other standard troubleshooting steps would apply before resorting to this contingency service.
#   - Option D suggests using the service when the EPO is closed due to an official holiday. The Contingency Upload Service is for system outages and not for regular business closures like holidays.
# --------------------------------------------------
# Final answer: C
# Answer: C
# Justification: - Explanation of why C is correct. Korhonen, being a Finnish national and resident in Finland, can file his amended claims in Finnish as per Rule 70(1), which allows for filing documents in the language of the application if it's an official language of one of the contracting states (Finnish is an official language of Finland). However, since the language of the proceedings is English and the EPO requires that all documents are understandable by its officials who work primarily with the three official languages (English, French, German), Korhonen must provide a translation into English within a non-extendable period as per Rule 165(2).
#
# - Explanation of why B is incorrect. Although Korhonen can file amended claims in Finnish and should then provide a translation into an official language of the EPO, the translation specifically needs to be into English according to the context provided (the proceedings are conducted primarily in English given that the initial application was translated into English). Providing a translation into any other official language would not suffice based on the specific context.
#
# - Explanation of why A is incorrect. While Korhonen can file amended claims in Finnish, there is no requirement for him to provide an additional translation if he already provided one at the time of filing his initial application. Rule 165(2) requires that any amendments must be understood by the EPO officials and thus need a proper English translation, but this does not mean Korhonen must first file in Finnish and then separately translate; he can provide it directly or ensure a timely translation is submitted.
#
# - Explanation of why D is incorrect. Korhonen is allowed to file amended claims in Finnish because Rule 70(1) permits the filing in the language of the application if it’s an official language of one of the contracting states, which Finnish is. Hence, he is not prohibited from using Finnish for his amendments as long as a translation into English follows within the specified period.
# --------------------------------------------------
# Final answer: D
# Answer: D
# Justification: - Explanation of why D is correct. PCT Direct is not available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document. The process for PCT Direct does not require or include filing amended claims alongside the informal comments aimed at overcoming objections raised in the search opinion.
# - Explanation of why B, C, and A are incorrect:
#   - Option A is correct because PCT Direct can be used when the priority application and international application are both filed in French (Belgian/French) and processed through ePCT-Filing.
#   - Option B is correct as long as the EP application has been searched by the EPO, even if the subsequent international application is filed in English.
#   - Option C is correct because when the priority application is an already-searched PCT application with the EPO and both applications are filed in English using Online Filing 2.0, it qualifies for PCT Direct.
# --------------------------------------------------
# Final answer: D
# Answer: D
# Justification: - Explanation of why D is correct. According to Article 6(1) Regulation (EU) No 1260/2012 and Rule 6(2)(d) UPR, the translation may be in any of the 24 official languages of the EU, except English, irrespective of the language in which the application was filed or the geographical extent of the unitary effect. Spanish is one of the 24 official languages of the EU and thus can be used for this purpose.
# - Explanation of why B is incorrect. Statement B incorrectly limits the choice to an official language of any of the 18 states, rather than any of the 24 official languages of the entire EU.
# - Explanation of why C is incorrect. Although it mentions the correct number (24) of official languages, it incorrectly associates this with the UPCA (Unified Patent Court Agreement), which does not determine the language requirements for translations under Regulation (EU) No 1260/2012.
# - Explanation of why A is incorrect. Dutch cannot be used as a translation since Mr Linguist already filed the application in Dutch and English was chosen as the language of proceedings. The regulation requires a new translation into one of the EU's official languages, except for English which cannot be reused here since it was only used for proceedings purposes.
# --------------------------------------------------

# %% [markdown]
# On a généré avec un nouveau prompt sans modèle pour parser. L'idée est de voir le format de sortie. S'il est uniforme, de créer un script pour le parser, voir s'il s'en sort sur tous les cas. Ensuite on pourra mesurer l'accuracy, voir si ce prompt est aussi bon / meilleur que l'autre. Et si le parsing est bien, ça nous permet d'implémenter tout ça et d'avoir un modèle 32B sans nécessiter un autre modèle pour faire un json.

# %% [markdown]
# ## Test different content in Retrieval
#
# So far, we try a lot of things and it seems to be the retrieval capacity is the bottleneck. We will try to not use everything in it.
#
# We identify a sur-representation of Guidelines doccuments. So we will seperate the embeddings into 2. One with Guidelines et another with articles. We will take 3 articles and 2 guidelines for each questions.

# %% [markdown]
# ### Create embeddings
#
# We moove the file EPC_guidelines out of the outputs for generting the first one and we do the opposite for the second one.
# We don't take Exams Solution in sources.

# %%
# def create_rag_embeddings(model_name, chunk_size, markdown_separators, data_dir, output_dir, device="cuda"):
    
#     csv_raw_knowledge = load_csv(data_dir)
#     raw_knowledge_base = csv_raw_knowledge
    
#     docs_processed = split_documents(
#     chunk_size,  # We choose a chunk size adapted to our model
#     raw_knowledge_base,
#     model_name,
#     markdown_separators
#     )

#     embedding_model = HuggingFaceEmbeddings(
#     model_name=model_name,
#     multi_process=True,
#     model_kwargs={"device": device,  "trust_remote_code":True},  # replace 'cpu' by 'cuda' if you have Nvidia gpu
#     encode_kwargs={"normalize_embeddings": True},  # Set `True` for cosine similarity
#     )

#     # Compute embeddings (can take time ~7min on my laptop)
#     knowledge_vector_database = FAISS.from_documents(
#         docs_processed, embedding_model, distance_strategy=DistanceStrategy.COSINE
#     )
#     # Save embeddings
#     knowledge_vector_database.save_local(f"{output_dir}/rag_embeddings_{model_name.replace('/', '_')}_chunk{chunk_size}")

# %%
# create_rag_embeddings(model_name='sentence-transformers/all-MiniLM-L6-v2', 
#                       chunk_size=512, markdown_separators=markdown_separators, 
#                       data_dir='../outputs', output_dir='./')
# Out:
# 100%|██████████| 3739/3739 [00:00<00:00, 25075.80it/s]

# %%
def test_custom(test_name, embeddings_model, embeddings_path, reader, reranker=False):
    # create_rag_embeddings(embeddings_model, chunk_size, markdown_separators, data_dir, output_dir)
    knowledge_vector_db = load_rag_embeddings(path=embeddings_path,
                                            embeddings_model=embeddings_model, device='cuda')
    evaluate_generate_mcq_answer(save_dir='../outputs/evaluation2/', data_dir='../outputs/',
                             test_name=test_name, model=reader,
                             knowledge_vector_db=knowledge_vector_db, reranker=reranker)

# %% [markdown]
# ### Qu'avec Articles/Rules
#
# Lancé avec le nouveau prompt sans 2nd model pour parsing.

# %%
test_custom('sentence-transformers_all-MiniLM-L6-v2_chunk512_qwen2_5_7b_embeddingsOnlyRulesArticles',
           embeddings_model='sentence-transformers/all-MiniLM-L6-v2',
           embeddings_path='../embeddings/rag_embeddings_sentence-transformers_all-MiniLM-L6-v2_chunk512_onlyRulesArticles/',
           reader='qwen2.5:7b')
# Out:
# embedding load
# {'question': 'A European patent was granted to a German company on 4  January 2023. No opposition was filed. Mr Li and Ms Smith were designated as inventors. On 12 October 2023,  the patent proprietor not ices that Ms Smith was erroneously designated as inventor and that Mr Li is the sole inventor.  Which of the following statements is correct?', 'options': ['A. Ms Smith will be deleted as inventor if the patent proprietor requests this in writing .', 'B. Ms Smith can no longer  be deleted as inventor because no proceedings are pending before the EPO .', "C. The patent proprietor can request that  Ms Smith be deleted as inventor but needs Mr Li 's consent  for this .", 'D. Ms Smith can only be deleted as inventor with her consent .']}
# Final answer: A
# {'question': "On 10 October 2021, European patent attorney X filed European patent application EP -A with the EPO on the applicant's behalf. Application EP -A was published on 12 April 2023, together  with the extended European search report. On 6  October 2023, the applicant contacts a new European patent attorney  Y to replace X as representative and issues Y with its instructions to reply to the extended European search report. The applicant did not inform X that he would be replaced.  What are the steps necessary to validly appoint representative Y and to avoid any loss of rights for European patent application EP -A?", 'options': ['A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant .', 'B. New representative Y requests a change of representative and files a response to the extended European search report with  the EPO by 12 October 2023 at the latest .', 'C. New representative Y requests a change of representative and files a response to the extended European search report with the EPO by 23 October 2023 at the latest.', 'D. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 23 October 2023 at the latest and files in good time an authorisation signed by the applicant .']}
# Final answer: A
# {'question': 'EP-1 is a regular European patent application (Euro -direct application) .  Which one of the following missed time limits can be remedied for EP -1 before the EPO by requesting re- establishment of rights ?', 'options': ['A. T ime limit for pay ing the designation fee', 'B. T ime limit for requesting examination', 'C. T ime limit for filing the application within the priority period', 'D. T ime limit for paying the fee for re- establishment of rights']}
# Final answer: A
# {'question': 'Last week Greta validly filed the international patent application PCT -G with the German Patent and Trade mark Office ( DPMA ) and appointed Hassan to represent her. Hassan is entitled to act before the DPMA  but he is not a European patent attorney. Greta and Hassan are resident in Germany.  Which of the following statements is not correct?', 'options': ['A. Hassan can represent Greta before the EPO acting as the International Searching Authority for PCT -G.', 'B. In order for Hassan to be able to act before the EPO acting as the International Searching Authority , he needs to submit a power of attorney signed by Greta.', 'C. According to the provisions of the PCT, it is mandatory that the d emand for international preliminary examination is signed by Greta or Hassan.', 'D. According to the provisions of the PCT, an international application can only be withdrawn by the applicant or an agent appointed by a power of attorney.']}
# Final answer: C
# {'question': 'In which of the following cases is the applicant entitled to a reduction of the filing fee  under Rule  6 EPC ? A declaration of such entitlement has  been made by crossing the relevant box on Form  1001.', 'options': ['A. A Spanish European patent attorney files a European patent application in Spanish for a natural person who is resident in Andorra and of Andorra n nationality .', 'B. A firm whose principal place of business is in Germany and a natural person who is resident in Germany  and of Dutch nationality  jointly file a European patent application in Dutch. The German firm employs 200 people with an annual turnover of EUR 60 million.', 'C. A natural person resident in the USA and of Belgian nationality files a European patent application in French.', 'D. A natural person resident in the USA and of Swiss nationality files a European patent application in Italian.']}
# Final answer: A
# {'question': 'Mr Van Holland is a Dutch citizen resident in the Netherlands. He filed a European patent application EP -parent in Dutch, together with  a translation into English. Whil e EP-parent was pending, Mr Van Holland filed a divisional application EP -div in Dutch and requested examination in Dutch. He paid all fees due for EP -div. He has not filed an English translation of EP -div. The Receiving Section has now issued a noting of l oss of rights.  Which of the following statements is correct?', 'options': ['A. The deficiency cannot be remedied.', 'B. Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication  under Rule 112(1) EPC .', 'C. Mr Van Holland needs to file an English translation of EP -div together with a request for f urther processing.', 'D. Mr Van Holland needs to file an English translation of EP -div together with a request for re- establishment of rights.']}
# Final answer: C
# {'question': 'On 16  November 2020, you filed a European patent application EP -A, which did not claim priority. Today, 12  October 2023, you receive a communication from the EPO entitled " Decision to grant a European patent pursuant to Article  97(1) EPC ". This communication state s that the mention of the grant You wish to validate the patent in only two contracting states  to the EPC . Which of the following statements is correct?', 'options': ['A. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 16 November 2023.', 'B. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 30 November 2023.', 'C. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 9 January 2024 at the latest .', 'D. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 16 January 2024 at the latest .']}
# Final answer: C
# {'question': 'During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?', 'options': ['A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.', 'B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.', 'C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.', 'D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months.']}
# Final answer: A
# {'question': 'Under the PCT, what is the time limit for filing a request for rectification of an obvious mistake made in the international application?', 'options': ['A. 18 months from the earliest priority date', 'B. 30 months from the earliest priority date', 'C. 22 months from the earliest priority date', 'D. 26 months from the earliest priority date']}
# Final answer: A
# {'question': 'After receipt of a negative written opinion issued by the EPO acting as ISA, amendments under Art icle 19 PCT were filed during the international phase. No request for international preliminary examination was filed. Form  1200 was used,  and no further amendments were filed with the EPO upon entry into the regional phase.   What communication under Rules  161/162 EPC will be received in the regional phase?', 'options': ['A. Form 1226AA ;  if you do not reply to it in time, the application will be deemed to be withdrawn', 'B. Form 1226BB offering the opportunity to comment and file amendments', 'C. Form 1226CC offering the opportunity to file amendments before the supplementary European search report is drawn up', 'D. Form 1226AC stating that the examination has started']}
# Final answer: A
# {'question': 'Company M, which has  its principal place of business in Tijuana, Mexico, validly filed an international patent application PCT -M with the Mexican Institute of Industrial Property. The application was filed in Spanish. A few days later, the applicant files an English translati on of the application.  Which of the following statements is correct?', 'options': ['A. The applicant can choose the EPO as ISA and the USPTO as IPEA.', 'B. The applicant can choose the USPTO as ISA and the EPO as IPEA.', 'C. The applicant can choose the Austrian Patent Offic e as ISA and the', 'EPO as IPEA.', 'D. The applicant can choose the EPO as ISA and the Intellectual Property', 'Office of Singapore as IPEA.']}
# Final answer: A
# {'question': 'On 20  June 2023, applicant P validly filed an international patent application PCT-P, claiming priority from European patent application EP -I filed on 7 July 2022. Today, 12 October 2023, he discovers that he should also have claimed priority from EP -II filed on 3 July 2022. Can the missing priority claim still be validly added?', 'options': ['A. Yes, the time  limit for adding the priority claim expires on 3  November 2023.', 'B. Yes, the time limit for adding the priority claim expires on 7  November 2023.', 'C. Yes, the time  limit for adding the priority claim expires on 20 October 2023.', 'D. No, the time  limit for adding the priority claim expired on 3 July 2023.']}
# Final answer: A
# {'question': 'The opposition division revoked European patent EP -B1. The patent proprietor filed an appeal  in time . The b oard of appeal forwarded a copy of the appeal to the o pponent/ respondent with a communication dated 1 June 2023 giving it an opportunity to file comments within a period of four  months.  The opponent/respondent files comments today, 12 October 2023. What further action has to be taken ?', 'options': ['A. The opponent/ respondent needs  to request an extension of the period for comment.', 'B. The opponent/respondent needs to pay a fee for further processing.', 'C. The opponent/respondent needs to file a substantiated request for reestablishment of rights and pay the associated fee.', 'D. None of the above.']}
# Final answer: D
# {'question': 'A European patent application was filed on 20 March 2020. Proceedings were interrupted under  Rule 142 EPC on 10  March 2022. The applicant was informed that proceedings would be resumed today, 12 October 2023. No renewal fee has been paid so far . Which of the following statements is correct?', 'options': ['A. As no renewal fees have been paid, the application is deemed to be withdrawn .', 'B. The renewal fees for the third and fourth years can be validly paid without any additional fee on 12 October 2023 at the latest .', 'C. The renewal fees for the third and fourth years can be validly paid with an additional  fee by 30  April 2024 at the latest .', 'D. The renewal fees for the third and fourth years can be validly paid without any additional fee by 31  October 2023 at the latest .']}
# Final answer: B
# {'question': 'An international application is published , together  with the search report drawn up by the CNIPA , 18 m onths + 1 day after the filing date (no priority claimed). The application has no more than 35 pages and 15 claims. Which statement reflects all actions the CN  applicant  needs to take for entry into the EP phase 25 months  after the filing date ? A request for early processing has been filed.', 'options': ['A. Complete and file Form 1200 and pay the filing fee and the search fee', 'B. Complete and file Form 1200 and pay the filing fee, the search fee and the renewal fee for the third year', 'C. Complete and file Form 1200, pay the filing fee and the search fee and appoint a representative', 'D. None of the above statements']}
# Final answer: A
# {'question': 'A European patent application was filed on 6 February 2023. The search, filing and designation fees were paid within a month of the date of filing. What is the latest point in time for withdrawing the application, if the applicant wishes to obtain a refund of the designation fee?', 'options': ['A. Six months after the date of mention of the publication of the European search report', 'B. Date of mention of the publication of the European search report', 'C. The designation fee was validly paid and can no longer be refunded', 'D. Date of the start of substantive examination']}
# Final answer: A
# {'question': "On 10 October 2024, an applicant files a request for entry into the European phase, together with a debit order, according to which the filing fee, the designation fee, the examination fee and the renewal fee for the third year are to be debited from the applicant's deposit account. It is specified that the debit order is to be executed on 18 October 2024. On the evening of 10 October 2024, the applicant notices that the renewal fee is not yet due and should not be debited from the deposit account. What is the latest point in time for revoking the order to debit the renewal fee in Central Fee Payment (CFP)?", 'options': ['A. 10 October 2024', 'B. 17 October 2024', 'C. 18 October 2024', 'D. A debit order cannot be revoked in part']}
# Final answer: B
# {'question': 'The applicant received a communication pursuant to Article 90(3) EPC and Rule  60 EPC, requesting them to file a designation of inventor but missed the time limit for filing a response. After expiry of the time limit, the Receiving Section issued a decision to refuse the European patent application, dated 10  October 2024. What can the applicant do to remedy the situation?', 'options': ['A. File a notice of appeal against the decision within four months of notification of the decision', 'B. File a request for further processing within two months of notification of the decision', 'C. File, within two months of notification of the decision, a request for re-establishment of rights in respect of the time limit for filing the designation of inventor', 'D. A, B and C are correct']}
# Final answer: A
# {'question': 'Which of the following statements about filing third- party observations is correct?', 'options': ['A. The person that filed third- party observations will be a party to the proceedings before the EPO, and the applicant is obliged to respond to third- party observations', 'B. Third -party observations must be filed in writing and may not be filed anonymously', 'C. Third -party observations are considered by the examining division only if they include a statement of the grounds on which they are based, and an official fee is paid', 'D. Third -party observations can be filed after the publication of a European patent application and must be filed in an official language of the EPO']}
# Final answer: D
# {'question': 'You filed an international patent application on 6 June 2024, claiming the priority of a European patent application filed on 7  July 2023. You received a communication dated 25 September 2024 from the EPO acting as International Searching Authority (ISA), stating that the requirement of unity of invention has not been complied with. The ISA identifies three inventions. You are invited to pay two additional search fees. Which of the following statements is correct?', 'options': ['A. You must pay two additional search fees by 25 October 2024', 'B. You do not need to file a response to the provisional opinion accompanying the partial search results', 'C. If you pay two additional search fees under protest, you must pay two protest fees within the time limit', 'D. If you do not pay any additional search fees within the time limit, the international patent application will be deemed to be withdrawn']}
# Final answer: A
# {'question': 'An international patent application filed with the EPO as receiving Office on 10 September 2024, claims the priority of a Luxembourg patent application filed on 11 October 2023. No certified copy of the Luxembourg patent application was filed at the time of filing of the international patent application. Which of the following actions can be taken to file a certified copy of the Luxembourg patent application for this international patent application?', 'options': ['A. Request the Luxembourg Intellectual Property Office to prepare and send a certified copy of the Luxembourg patent application to the EPO', 'B. Submit a valid DAS code (Digital Access Service) to the International Bureau to enable it to obtain a certified copy of the Luxembourg patent application', 'C. File an electronic certified copy of the Luxembourg patent application with the EPO', 'D. File a certified copy of the Luxembourg patent application with the International Bureau']}
# Final answer: A
# {'question': 'Firm A owns a European patent, EP . Firm B filed an opposition against EP, requesting its revocation. Firm B argued that the subject -matter of the granted claims was not new in view of document D1. During the opposition proceedings, firm C filed observations under Art.  115 EPC, arguing that the subject -matter of the granted claims was not new in view of document D2. Firm A requested maintenance of the patent as granted, or maintenance in amended Which of the following statements is correct?', 'options': ["A. At the end of the opposition proceedings, the opposition division decided to revoke the patent. Firm B is entitled to file an appeal against the opposition division's decision.", "B. At the end of the opposition proceedings, the opposition division decided to and firm B are entitled to file an appeal against the opposition division's decision.", "C. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm C is entitled to file an appeal against the opposition division's decision.", "D. During the opposition proceedings, firm B withdrew its opposition. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm B is entitled to file an appeal against the opposition division's decision."]}
# Final answer: A
# {'question': 'European patent application EP -X was filed on 1  October 2020, claiming the priority of a Belgian application filed on 16 October 2019. The mention of the grant of European patent EP -X was published on 2  October 2024. The proprietor filed a request for unitary effect and was informed by communication dated 10  October 2024, that unitary effect had been registered for EP -X-C0 on the same date. Which of the following statements is correct?', 'options': ['A. A renewal fee still has to be paid by 31 October 2024 in respect of the 5th year for EP -X', 'B. A renewal fee is due on 31 October 2024 in respect of the 5th year for EP -X-C0', 'C. A renewal fee is due on 31 October 2024 in respect of the 6th year for EP -X-C0', 'D. No renewal fee has to be paid on 31 October 2024']}
# Final answer: B
# {'question': 'A communication under Article 94(3) EPC, setting a four -month time limit for reply is dated 12 September 2024. The applicant receives the letter on 21 September 2024, as evidenced by the postal receipt signed by him.  What is the last day for replying to the communication?', 'options': ['A. 13 January 2025', 'B. 12 January 2025', 'C. 22 January 2025', 'D. 14 January 2025']}
# Final answer: A
# {'question': 'Which functionalities or services can be accessed directly from MyEPO Portfolio?', 'options': ["A. A shared area with examiners, European Patent Register, filing via the EPO's online filing software eOLF", 'B. Mailbox, a shared area with examiners, replying to a communication under Article  94(3) EPC', 'C. Mailbox, patent search via publication server, a shared area with examiners', "D. Filing via the EPO's Online Filing 2.0, patent search via publication server, Mailbox"]}
# Final answer: D
# {'question': 'In which of the following situations does the EPO recommend using the EPO Contingency Upload Service?', 'options': ['A. When you submit documents after business hours', 'B. When the EPO filing systems are functioning correctly, but you encounter a technical issue at your end', 'C. When there is a system outage at the EPO that prevents document submission via the standard filing systems', 'D. When the EPO is closed due to an official holiday']}
# Final answer: C
# {'question': 'Applicant Korhonen is a Finnish national resident in Finland. He filed a European patent application in Finnish and provided an English translation in time. In response to the extended European search report (EESR), Korhonen wishes to file amended claims t ogether with a request for examination. Which of the following statements is correct?', 'options': ['A. Korhonen must file the amended claims in Finnish and must then  provide a translation into English, in time', 'B. Korhonen is allowed to file the amended claims in Finnish if he then provides a', 'translation into any official language of the EPO, in time C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time', 'D. Korhonen is not allowed to file the amended claims in Finnish']}
# Final answer: C
# {'question': 'Applicants may request processing of their international application under PCT Direct by filing a letter ("PCT Direct letter") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?', 'options': ['A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing', 'B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0', 'C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0', 'D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document']}
# Final answer: A
# {'question': 'Mr Linguist filed a European patent application in Dutch and used English as language of the proceedings. When requesting unitary effect on 10 October 2024, Mr Linguist must provide a translation of the specification. Mr Linguist would like to obtain immediate registration of the unitary effect. Which of the following statements is correct?', 'options': ['A. Mr Linguist must provide a translation of the specification into Dutch', 'B. Mr Linguist must provide a translation of the specification into an official language of any of the 18 states to which the unitary effect extends', 'C. Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA', 'D. Mr Linguist may provide a translation of the specification into Spanish']}
# Final answer: B
# {'total_answer': 29, 'correct_answer': 6}

# %% [markdown]
# ### Qu'avec Guidelines / Case Law

# %%
test_custom('sentence-transformers_all-MiniLM-L6-v2_chunk512_qwen2_5_7b_embeddingsOnlyGuidelinesAndLaws',
           embeddings_model='sentence-transformers/all-MiniLM-L6-v2',
           embeddings_path='../embeddings/rag_embeddings_sentence-transformers_all-MiniLM-L6-v2_chunk512_onlyGuidelinesAndLaws',
           reader='qwen2.5:7b')
# Out:
# embedding load
# {'question': 'A European patent was granted to a German company on 4  January 2023. No opposition was filed. Mr Li and Ms Smith were designated as inventors. On 12 October 2023,  the patent proprietor not ices that Ms Smith was erroneously designated as inventor and that Mr Li is the sole inventor.  Which of the following statements is correct?', 'options': ['A. Ms Smith will be deleted as inventor if the patent proprietor requests this in writing .', 'B. Ms Smith can no longer  be deleted as inventor because no proceedings are pending before the EPO .', "C. The patent proprietor can request that  Ms Smith be deleted as inventor but needs Mr Li 's consent  for this .", 'D. Ms Smith can only be deleted as inventor with her consent .']}
# Final answer: A
# {'question': "On 10 October 2021, European patent attorney X filed European patent application EP -A with the EPO on the applicant's behalf. Application EP -A was published on 12 April 2023, together  with the extended European search report. On 6  October 2023, the applicant contacts a new European patent attorney  Y to replace X as representative and issues Y with its instructions to reply to the extended European search report. The applicant did not inform X that he would be replaced.  What are the steps necessary to validly appoint representative Y and to avoid any loss of rights for European patent application EP -A?", 'options': ['A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant .', 'B. New representative Y requests a change of representative and files a response to the extended European search report with  the EPO by 12 October 2023 at the latest .', 'C. New representative Y requests a change of representative and files a response to the extended European search report with the EPO by 23 October 2023 at the latest.', 'D. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 23 October 2023 at the latest and files in good time an authorisation signed by the applicant .']}
# Final answer: A
# {'question': 'EP-1 is a regular European patent application (Euro -direct application) .  Which one of the following missed time limits can be remedied for EP -1 before the EPO by requesting re- establishment of rights ?', 'options': ['A. T ime limit for pay ing the designation fee', 'B. T ime limit for requesting examination', 'C. T ime limit for filing the application within the priority period', 'D. T ime limit for paying the fee for re- establishment of rights']}
# Final answer: C
# {'question': 'Last week Greta validly filed the international patent application PCT -G with the German Patent and Trade mark Office ( DPMA ) and appointed Hassan to represent her. Hassan is entitled to act before the DPMA  but he is not a European patent attorney. Greta and Hassan are resident in Germany.  Which of the following statements is not correct?', 'options': ['A. Hassan can represent Greta before the EPO acting as the International Searching Authority for PCT -G.', 'B. In order for Hassan to be able to act before the EPO acting as the International Searching Authority , he needs to submit a power of attorney signed by Greta.', 'C. According to the provisions of the PCT, it is mandatory that the d emand for international preliminary examination is signed by Greta or Hassan.', 'D. According to the provisions of the PCT, an international application can only be withdrawn by the applicant or an agent appointed by a power of attorney.']}
# Final answer: C
# {'question': 'In which of the following cases is the applicant entitled to a reduction of the filing fee  under Rule  6 EPC ? A declaration of such entitlement has  been made by crossing the relevant box on Form  1001.', 'options': ['A. A Spanish European patent attorney files a European patent application in Spanish for a natural person who is resident in Andorra and of Andorra n nationality .', 'B. A firm whose principal place of business is in Germany and a natural person who is resident in Germany  and of Dutch nationality  jointly file a European patent application in Dutch. The German firm employs 200 people with an annual turnover of EUR 60 million.', 'C. A natural person resident in the USA and of Belgian nationality files a European patent application in French.', 'D. A natural person resident in the USA and of Swiss nationality files a European patent application in Italian.']}
# Final answer: A
# {'question': 'Mr Van Holland is a Dutch citizen resident in the Netherlands. He filed a European patent application EP -parent in Dutch, together with  a translation into English. Whil e EP-parent was pending, Mr Van Holland filed a divisional application EP -div in Dutch and requested examination in Dutch. He paid all fees due for EP -div. He has not filed an English translation of EP -div. The Receiving Section has now issued a noting of l oss of rights.  Which of the following statements is correct?', 'options': ['A. The deficiency cannot be remedied.', 'B. Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication  under Rule 112(1) EPC .', 'C. Mr Van Holland needs to file an English translation of EP -div together with a request for f urther processing.', 'D. Mr Van Holland needs to file an English translation of EP -div together with a request for re- establishment of rights.']}
# Final answer: B
# {'question': 'On 16  November 2020, you filed a European patent application EP -A, which did not claim priority. Today, 12  October 2023, you receive a communication from the EPO entitled " Decision to grant a European patent pursuant to Article  97(1) EPC ". This communication state s that the mention of the grant You wish to validate the patent in only two contracting states  to the EPC . Which of the following statements is correct?', 'options': ['A. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 16 November 2023.', 'B. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 30 November 2023.', 'C. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 9 January 2024 at the latest .', 'D. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 16 January 2024 at the latest .']}
# Final answer: A
# {'question': 'During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?', 'options': ['A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.', 'B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.', 'C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.', 'D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months.']}
# Final answer: C
# {'question': 'Under the PCT, what is the time limit for filing a request for rectification of an obvious mistake made in the international application?', 'options': ['A. 18 months from the earliest priority date', 'B. 30 months from the earliest priority date', 'C. 22 months from the earliest priority date', 'D. 26 months from the earliest priority date']}
# Final answer: A
# {'question': 'After receipt of a negative written opinion issued by the EPO acting as ISA, amendments under Art icle 19 PCT were filed during the international phase. No request for international preliminary examination was filed. Form  1200 was used,  and no further amendments were filed with the EPO upon entry into the regional phase.   What communication under Rules  161/162 EPC will be received in the regional phase?', 'options': ['A. Form 1226AA ;  if you do not reply to it in time, the application will be deemed to be withdrawn', 'B. Form 1226BB offering the opportunity to comment and file amendments', 'C. Form 1226CC offering the opportunity to file amendments before the supplementary European search report is drawn up', 'D. Form 1226AC stating that the examination has started']}
# Final answer: A
# {'question': 'Company M, which has  its principal place of business in Tijuana, Mexico, validly filed an international patent application PCT -M with the Mexican Institute of Industrial Property. The application was filed in Spanish. A few days later, the applicant files an English translati on of the application.  Which of the following statements is correct?', 'options': ['A. The applicant can choose the EPO as ISA and the USPTO as IPEA.', 'B. The applicant can choose the USPTO as ISA and the EPO as IPEA.', 'C. The applicant can choose the Austrian Patent Offic e as ISA and the', 'EPO as IPEA.', 'D. The applicant can choose the EPO as ISA and the Intellectual Property', 'Office of Singapore as IPEA.']}
# Final answer: A
# {'question': 'On 20  June 2023, applicant P validly filed an international patent application PCT-P, claiming priority from European patent application EP -I filed on 7 July 2022. Today, 12 October 2023, he discovers that he should also have claimed priority from EP -II filed on 3 July 2022. Can the missing priority claim still be validly added?', 'options': ['A. Yes, the time  limit for adding the priority claim expires on 3  November 2023.', 'B. Yes, the time limit for adding the priority claim expires on 7  November 2023.', 'C. Yes, the time  limit for adding the priority claim expires on 20 October 2023.', 'D. No, the time  limit for adding the priority claim expired on 3 July 2023.']}
# Final answer: A
# {'question': 'The opposition division revoked European patent EP -B1. The patent proprietor filed an appeal  in time . The b oard of appeal forwarded a copy of the appeal to the o pponent/ respondent with a communication dated 1 June 2023 giving it an opportunity to file comments within a period of four  months.  The opponent/respondent files comments today, 12 October 2023. What further action has to be taken ?', 'options': ['A. The opponent/ respondent needs  to request an extension of the period for comment.', 'B. The opponent/respondent needs to pay a fee for further processing.', 'C. The opponent/respondent needs to file a substantiated request for reestablishment of rights and pay the associated fee.', 'D. None of the above.']}
# Final answer: A
# {'question': 'A European patent application was filed on 20 March 2020. Proceedings were interrupted under  Rule 142 EPC on 10  March 2022. The applicant was informed that proceedings would be resumed today, 12 October 2023. No renewal fee has been paid so far . Which of the following statements is correct?', 'options': ['A. As no renewal fees have been paid, the application is deemed to be withdrawn .', 'B. The renewal fees for the third and fourth years can be validly paid without any additional fee on 12 October 2023 at the latest .', 'C. The renewal fees for the third and fourth years can be validly paid with an additional  fee by 30  April 2024 at the latest .', 'D. The renewal fees for the third and fourth years can be validly paid without any additional fee by 31  October 2023 at the latest .']}
# Final answer: A
# {'question': 'An international application is published , together  with the search report drawn up by the CNIPA , 18 m onths + 1 day after the filing date (no priority claimed). The application has no more than 35 pages and 15 claims. Which statement reflects all actions the CN  applicant  needs to take for entry into the EP phase 25 months  after the filing date ? A request for early processing has been filed.', 'options': ['A. Complete and file Form 1200 and pay the filing fee and the search fee', 'B. Complete and file Form 1200 and pay the filing fee, the search fee and the renewal fee for the third year', 'C. Complete and file Form 1200, pay the filing fee and the search fee and appoint a representative', 'D. None of the above statements']}
# Final answer: A
# {'question': 'A European patent application was filed on 6 February 2023. The search, filing and designation fees were paid within a month of the date of filing. What is the latest point in time for withdrawing the application, if the applicant wishes to obtain a refund of the designation fee?', 'options': ['A. Six months after the date of mention of the publication of the European search report', 'B. Date of mention of the publication of the European search report', 'C. The designation fee was validly paid and can no longer be refunded', 'D. Date of the start of substantive examination']}
# Final answer: C
# {'question': "On 10 October 2024, an applicant files a request for entry into the European phase, together with a debit order, according to which the filing fee, the designation fee, the examination fee and the renewal fee for the third year are to be debited from the applicant's deposit account. It is specified that the debit order is to be executed on 18 October 2024. On the evening of 10 October 2024, the applicant notices that the renewal fee is not yet due and should not be debited from the deposit account. What is the latest point in time for revoking the order to debit the renewal fee in Central Fee Payment (CFP)?", 'options': ['A. 10 October 2024', 'B. 17 October 2024', 'C. 18 October 2024', 'D. A debit order cannot be revoked in part']}
# Final answer: B
# {'question': 'The applicant received a communication pursuant to Article 90(3) EPC and Rule  60 EPC, requesting them to file a designation of inventor but missed the time limit for filing a response. After expiry of the time limit, the Receiving Section issued a decision to refuse the European patent application, dated 10  October 2024. What can the applicant do to remedy the situation?', 'options': ['A. File a notice of appeal against the decision within four months of notification of the decision', 'B. File a request for further processing within two months of notification of the decision', 'C. File, within two months of notification of the decision, a request for re-establishment of rights in respect of the time limit for filing the designation of inventor', 'D. A, B and C are correct']}
# Final answer: D
# {'question': 'Which of the following statements about filing third- party observations is correct?', 'options': ['A. The person that filed third- party observations will be a party to the proceedings before the EPO, and the applicant is obliged to respond to third- party observations', 'B. Third -party observations must be filed in writing and may not be filed anonymously', 'C. Third -party observations are considered by the examining division only if they include a statement of the grounds on which they are based, and an official fee is paid', 'D. Third -party observations can be filed after the publication of a European patent application and must be filed in an official language of the EPO']}
# Final answer: D
# {'question': 'You filed an international patent application on 6 June 2024, claiming the priority of a European patent application filed on 7  July 2023. You received a communication dated 25 September 2024 from the EPO acting as International Searching Authority (ISA), stating that the requirement of unity of invention has not been complied with. The ISA identifies three inventions. You are invited to pay two additional search fees. Which of the following statements is correct?', 'options': ['A. You must pay two additional search fees by 25 October 2024', 'B. You do not need to file a response to the provisional opinion accompanying the partial search results', 'C. If you pay two additional search fees under protest, you must pay two protest fees within the time limit', 'D. If you do not pay any additional search fees within the time limit, the international patent application will be deemed to be withdrawn']}
# Final answer: B
# {'question': 'An international patent application filed with the EPO as receiving Office on 10 September 2024, claims the priority of a Luxembourg patent application filed on 11 October 2023. No certified copy of the Luxembourg patent application was filed at the time of filing of the international patent application. Which of the following actions can be taken to file a certified copy of the Luxembourg patent application for this international patent application?', 'options': ['A. Request the Luxembourg Intellectual Property Office to prepare and send a certified copy of the Luxembourg patent application to the EPO', 'B. Submit a valid DAS code (Digital Access Service) to the International Bureau to enable it to obtain a certified copy of the Luxembourg patent application', 'C. File an electronic certified copy of the Luxembourg patent application with the EPO', 'D. File a certified copy of the Luxembourg patent application with the International Bureau']}
# Final answer: A
# {'question': 'Firm A owns a European patent, EP . Firm B filed an opposition against EP, requesting its revocation. Firm B argued that the subject -matter of the granted claims was not new in view of document D1. During the opposition proceedings, firm C filed observations under Art.  115 EPC, arguing that the subject -matter of the granted claims was not new in view of document D2. Firm A requested maintenance of the patent as granted, or maintenance in amended Which of the following statements is correct?', 'options': ["A. At the end of the opposition proceedings, the opposition division decided to revoke the patent. Firm B is entitled to file an appeal against the opposition division's decision.", "B. At the end of the opposition proceedings, the opposition division decided to and firm B are entitled to file an appeal against the opposition division's decision.", "C. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm C is entitled to file an appeal against the opposition division's decision.", "D. During the opposition proceedings, firm B withdrew its opposition. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm B is entitled to file an appeal against the opposition division's decision."]}
# Final answer: D
# {'question': 'European patent application EP -X was filed on 1  October 2020, claiming the priority of a Belgian application filed on 16 October 2019. The mention of the grant of European patent EP -X was published on 2  October 2024. The proprietor filed a request for unitary effect and was informed by communication dated 10  October 2024, that unitary effect had been registered for EP -X-C0 on the same date. Which of the following statements is correct?', 'options': ['A. A renewal fee still has to be paid by 31 October 2024 in respect of the 5th year for EP -X', 'B. A renewal fee is due on 31 October 2024 in respect of the 5th year for EP -X-C0', 'C. A renewal fee is due on 31 October 2024 in respect of the 6th year for EP -X-C0', 'D. No renewal fee has to be paid on 31 October 2024']}
# Final answer: B
# {'question': 'A communication under Article 94(3) EPC, setting a four -month time limit for reply is dated 12 September 2024. The applicant receives the letter on 21 September 2024, as evidenced by the postal receipt signed by him.  What is the last day for replying to the communication?', 'options': ['A. 13 January 2025', 'B. 12 January 2025', 'C. 22 January 2025', 'D. 14 January 2025']}
# Final answer: B
# {'question': 'Which functionalities or services can be accessed directly from MyEPO Portfolio?', 'options': ["A. A shared area with examiners, European Patent Register, filing via the EPO's online filing software eOLF", 'B. Mailbox, a shared area with examiners, replying to a communication under Article  94(3) EPC', 'C. Mailbox, patent search via publication server, a shared area with examiners', "D. Filing via the EPO's Online Filing 2.0, patent search via publication server, Mailbox"]}
# Final answer: A
# {'question': 'In which of the following situations does the EPO recommend using the EPO Contingency Upload Service?', 'options': ['A. When you submit documents after business hours', 'B. When the EPO filing systems are functioning correctly, but you encounter a technical issue at your end', 'C. When there is a system outage at the EPO that prevents document submission via the standard filing systems', 'D. When the EPO is closed due to an official holiday']}
# Final answer: C
# {'question': 'Applicant Korhonen is a Finnish national resident in Finland. He filed a European patent application in Finnish and provided an English translation in time. In response to the extended European search report (EESR), Korhonen wishes to file amended claims t ogether with a request for examination. Which of the following statements is correct?', 'options': ['A. Korhonen must file the amended claims in Finnish and must then  provide a translation into English, in time', 'B. Korhonen is allowed to file the amended claims in Finnish if he then provides a', 'translation into any official language of the EPO, in time C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time', 'D. Korhonen is not allowed to file the amended claims in Finnish']}
# Final answer: C
# {'question': 'Applicants may request processing of their international application under PCT Direct by filing a letter ("PCT Direct letter") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?', 'options': ['A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing', 'B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0', 'C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0', 'D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document']}
# Final answer: A
# {'question': 'Mr Linguist filed a European patent application in Dutch and used English as language of the proceedings. When requesting unitary effect on 10 October 2024, Mr Linguist must provide a translation of the specification. Mr Linguist would like to obtain immediate registration of the unitary effect. Which of the following statements is correct?', 'options': ['A. Mr Linguist must provide a translation of the specification into Dutch', 'B. Mr Linguist must provide a translation of the specification into an official language of any of the 18 states to which the unitary effect extends', 'C. Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA', 'D. Mr Linguist may provide a translation of the specification into Spanish']}
# Final answer: B
# {'total_answer': 29, 'correct_answer': 8}

# %% [markdown]
# ### Vérifier si c'est pas le new prompt qui foue la merde
#
# Il a pas trop l'air. On perd un peu mais c'est 1 bonne réponse.

# %%
# # Bizarre les résultats, on vérifie rapidement si c'est le nouveau prompt qui foue la merde
# test_custom('sentence-transformers_all-MiniLM-L6-v2_chunk512_qwen2_5_7b_TestAvecNewPromptSansSecondModelVerifPerf_2',
#            embeddings_model='sentence-transformers/all-MiniLM-L6-v2',
#            embeddings_path='../embeddings/rag_embeddings_sentence-transformers_all-MiniLM-L6-v2_chunk512',
#            reader='qwen2.5:7b')

# %% [markdown]
# ### Avec un mix des deux
#
# A tester de piocher 3 dans guidelines 2 dans articles.

# %% [markdown]
# ## Test Reranking

# %%
from sentence_transformers import CrossEncoder

class LocalReranker:
    def __init__(self, model_name="cross-encoder/ms-marco-MiniLM-L-6-v2"):
        """
        Initialise un reranker basé sur un modèle cross-encoder.
        """
        self.model = CrossEncoder(model_name)

    def rerank(self, query, documents, k=5):
        """
        Classe les documents en fonction de leur pertinence pour la question.
        
        query: str -> La question posée.
        documents: list -> Liste des documents récupérés.
        k: int -> Nombre de documents à conserver après reranking.
        
        Retourne les k meilleurs documents rerankés.
        """
        print("Rerank")
        doc_texts = [doc.page_content for doc in documents]  # Extraire les contenus
        pairs = [(query, doc) for doc in doc_texts]  # Création des paires (question, doc)
        
        scores = self.model.predict(pairs)  # Prédiction des scores de pertinence
        
        # Trier les documents par score décroissant
        ranked_docs = sorted(zip(scores, documents), key=lambda x: x[0], reverse=True)
        
        return [doc[1] for doc in ranked_docs[:k]]  # Retourner les k meilleurs

# Utilisation
reranker = LocalReranker()

# %%
test_custom('sentence-transformers_all-MiniLM-L6-v2_chunk512_qwen2_5_7b_TestAvecNewPromptSansSecondModel_Reranker',
           embeddings_model='sentence-transformers/all-MiniLM-L6-v2',
           embeddings_path='../embeddings/rag_embeddings_sentence-transformers_all-MiniLM-L6-v2_chunk512',
           reader='qwen2.5:7b', 
           reranker = reranker)
# Out:
# embedding load
# {'question': 'A European patent was granted to a German company on 4  January 2023. No opposition was filed. Mr Li and Ms Smith were designated as inventors. On 12 October 2023,  the patent proprietor not ices that Ms Smith was erroneously designated as inventor and that Mr Li is the sole inventor.  Which of the following statements is correct?', 'options': ['A. Ms Smith will be deleted as inventor if the patent proprietor requests this in writing .', 'B. Ms Smith can no longer  be deleted as inventor because no proceedings are pending before the EPO .', "C. The patent proprietor can request that  Ms Smith be deleted as inventor but needs Mr Li 's consent  for this .", 'D. Ms Smith can only be deleted as inventor with her consent .']}
# Rerank
# Final answer: A
# {'question': "On 10 October 2021, European patent attorney X filed European patent application EP -A with the EPO on the applicant's behalf. Application EP -A was published on 12 April 2023, together  with the extended European search report. On 6  October 2023, the applicant contacts a new European patent attorney  Y to replace X as representative and issues Y with its instructions to reply to the extended European search report. The applicant did not inform X that he would be replaced.  What are the steps necessary to validly appoint representative Y and to avoid any loss of rights for European patent application EP -A?", 'options': ['A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant .', 'B. New representative Y requests a change of representative and files a response to the extended European search report with  the EPO by 12 October 2023 at the latest .', 'C. New representative Y requests a change of representative and files a response to the extended European search report with the EPO by 23 October 2023 at the latest.', 'D. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 23 October 2023 at the latest and files in good time an authorisation signed by the applicant .']}
# Rerank
# Final answer: A
# {'question': 'EP-1 is a regular European patent application (Euro -direct application) .  Which one of the following missed time limits can be remedied for EP -1 before the EPO by requesting re- establishment of rights ?', 'options': ['A. T ime limit for pay ing the designation fee', 'B. T ime limit for requesting examination', 'C. T ime limit for filing the application within the priority period', 'D. T ime limit for paying the fee for re- establishment of rights']}
# Rerank
# Final answer: A
# {'question': 'Last week Greta validly filed the international patent application PCT -G with the German Patent and Trade mark Office ( DPMA ) and appointed Hassan to represent her. Hassan is entitled to act before the DPMA  but he is not a European patent attorney. Greta and Hassan are resident in Germany.  Which of the following statements is not correct?', 'options': ['A. Hassan can represent Greta before the EPO acting as the International Searching Authority for PCT -G.', 'B. In order for Hassan to be able to act before the EPO acting as the International Searching Authority , he needs to submit a power of attorney signed by Greta.', 'C. According to the provisions of the PCT, it is mandatory that the d emand for international preliminary examination is signed by Greta or Hassan.', 'D. According to the provisions of the PCT, an international application can only be withdrawn by the applicant or an agent appointed by a power of attorney.']}
# Rerank
# Final answer: C
# {'question': 'In which of the following cases is the applicant entitled to a reduction of the filing fee  under Rule  6 EPC ? A declaration of such entitlement has  been made by crossing the relevant box on Form  1001.', 'options': ['A. A Spanish European patent attorney files a European patent application in Spanish for a natural person who is resident in Andorra and of Andorra n nationality .', 'B. A firm whose principal place of business is in Germany and a natural person who is resident in Germany  and of Dutch nationality  jointly file a European patent application in Dutch. The German firm employs 200 people with an annual turnover of EUR 60 million.', 'C. A natural person resident in the USA and of Belgian nationality files a European patent application in French.', 'D. A natural person resident in the USA and of Swiss nationality files a European patent application in Italian.']}
# Rerank
# Final answer: A
# {'question': 'Mr Van Holland is a Dutch citizen resident in the Netherlands. He filed a European patent application EP -parent in Dutch, together with  a translation into English. Whil e EP-parent was pending, Mr Van Holland filed a divisional application EP -div in Dutch and requested examination in Dutch. He paid all fees due for EP -div. He has not filed an English translation of EP -div. The Receiving Section has now issued a noting of l oss of rights.  Which of the following statements is correct?', 'options': ['A. The deficiency cannot be remedied.', 'B. Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication  under Rule 112(1) EPC .', 'C. Mr Van Holland needs to file an English translation of EP -div together with a request for f urther processing.', 'D. Mr Van Holland needs to file an English translation of EP -div together with a request for re- establishment of rights.']}
# Rerank
# Final answer: B
# {'question': 'On 16  November 2020, you filed a European patent application EP -A, which did not claim priority. Today, 12  October 2023, you receive a communication from the EPO entitled " Decision to grant a European patent pursuant to Article  97(1) EPC ". This communication state s that the mention of the grant You wish to validate the patent in only two contracting states  to the EPC . Which of the following statements is correct?', 'options': ['A. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 16 November 2023.', 'B. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 30 November 2023.', 'C. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 9 January 2024 at the latest .', 'D. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 16 January 2024 at the latest .']}
# Rerank
# Final answer: A
# {'question': 'During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?', 'options': ['A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.', 'B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.', 'C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.', 'D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months.']}
# Rerank
# Final answer: C
# {'question': 'Under the PCT, what is the time limit for filing a request for rectification of an obvious mistake made in the international application?', 'options': ['A. 18 months from the earliest priority date', 'B. 30 months from the earliest priority date', 'C. 22 months from the earliest priority date', 'D. 26 months from the earliest priority date']}
# Rerank
# Final answer: D
# {'question': 'After receipt of a negative written opinion issued by the EPO acting as ISA, amendments under Art icle 19 PCT were filed during the international phase. No request for international preliminary examination was filed. Form  1200 was used,  and no further amendments were filed with the EPO upon entry into the regional phase.   What communication under Rules  161/162 EPC will be received in the regional phase?', 'options': ['A. Form 1226AA ;  if you do not reply to it in time, the application will be deemed to be withdrawn', 'B. Form 1226BB offering the opportunity to comment and file amendments', 'C. Form 1226CC offering the opportunity to file amendments before the supplementary European search report is drawn up', 'D. Form 1226AC stating that the examination has started']}
# Rerank
# Final answer: A
# {'question': 'Company M, which has  its principal place of business in Tijuana, Mexico, validly filed an international patent application PCT -M with the Mexican Institute of Industrial Property. The application was filed in Spanish. A few days later, the applicant files an English translati on of the application.  Which of the following statements is correct?', 'options': ['A. The applicant can choose the EPO as ISA and the USPTO as IPEA.', 'B. The applicant can choose the USPTO as ISA and the EPO as IPEA.', 'C. The applicant can choose the Austrian Patent Offic e as ISA and the', 'EPO as IPEA.', 'D. The applicant can choose the EPO as ISA and the Intellectual Property', 'Office of Singapore as IPEA.']}
# Rerank
# Final answer: A
# {'question': 'On 20  June 2023, applicant P validly filed an international patent application PCT-P, claiming priority from European patent application EP -I filed on 7 July 2022. Today, 12 October 2023, he discovers that he should also have claimed priority from EP -II filed on 3 July 2022. Can the missing priority claim still be validly added?', 'options': ['A. Yes, the time  limit for adding the priority claim expires on 3  November 2023.', 'B. Yes, the time limit for adding the priority claim expires on 7  November 2023.', 'C. Yes, the time  limit for adding the priority claim expires on 20 October 2023.', 'D. No, the time  limit for adding the priority claim expired on 3 July 2023.']}
# Rerank
# Final answer: A
# {'question': 'The opposition division revoked European patent EP -B1. The patent proprietor filed an appeal  in time . The b oard of appeal forwarded a copy of the appeal to the o pponent/ respondent with a communication dated 1 June 2023 giving it an opportunity to file comments within a period of four  months.  The opponent/respondent files comments today, 12 October 2023. What further action has to be taken ?', 'options': ['A. The opponent/ respondent needs  to request an extension of the period for comment.', 'B. The opponent/respondent needs to pay a fee for further processing.', 'C. The opponent/respondent needs to file a substantiated request for reestablishment of rights and pay the associated fee.', 'D. None of the above.']}
# Rerank
# Final answer: A
# {'question': 'A European patent application was filed on 20 March 2020. Proceedings were interrupted under  Rule 142 EPC on 10  March 2022. The applicant was informed that proceedings would be resumed today, 12 October 2023. No renewal fee has been paid so far . Which of the following statements is correct?', 'options': ['A. As no renewal fees have been paid, the application is deemed to be withdrawn .', 'B. The renewal fees for the third and fourth years can be validly paid without any additional fee on 12 October 2023 at the latest .', 'C. The renewal fees for the third and fourth years can be validly paid with an additional  fee by 30  April 2024 at the latest .', 'D. The renewal fees for the third and fourth years can be validly paid without any additional fee by 31  October 2023 at the latest .']}
# Rerank
# Final answer: C
# {'question': 'An international application is published , together  with the search report drawn up by the CNIPA , 18 m onths + 1 day after the filing date (no priority claimed). The application has no more than 35 pages and 15 claims. Which statement reflects all actions the CN  applicant  needs to take for entry into the EP phase 25 months  after the filing date ? A request for early processing has been filed.', 'options': ['A. Complete and file Form 1200 and pay the filing fee and the search fee', 'B. Complete and file Form 1200 and pay the filing fee, the search fee and the renewal fee for the third year', 'C. Complete and file Form 1200, pay the filing fee and the search fee and appoint a representative', 'D. None of the above statements']}
# Rerank
# Final answer: A
# {'question': 'A European patent application was filed on 6 February 2023. The search, filing and designation fees were paid within a month of the date of filing. What is the latest point in time for withdrawing the application, if the applicant wishes to obtain a refund of the designation fee?', 'options': ['A. Six months after the date of mention of the publication of the European search report', 'B. Date of mention of the publication of the European search report', 'C. The designation fee was validly paid and can no longer be refunded', 'D. Date of the start of substantive examination']}
# Rerank
# Final answer: A
# {'question': "On 10 October 2024, an applicant files a request for entry into the European phase, together with a debit order, according to which the filing fee, the designation fee, the examination fee and the renewal fee for the third year are to be debited from the applicant's deposit account. It is specified that the debit order is to be executed on 18 October 2024. On the evening of 10 October 2024, the applicant notices that the renewal fee is not yet due and should not be debited from the deposit account. What is the latest point in time for revoking the order to debit the renewal fee in Central Fee Payment (CFP)?", 'options': ['A. 10 October 2024', 'B. 17 October 2024', 'C. 18 October 2024', 'D. A debit order cannot be revoked in part']}
# Rerank
# Final answer: B
# {'question': 'The applicant received a communication pursuant to Article 90(3) EPC and Rule  60 EPC, requesting them to file a designation of inventor but missed the time limit for filing a response. After expiry of the time limit, the Receiving Section issued a decision to refuse the European patent application, dated 10  October 2024. What can the applicant do to remedy the situation?', 'options': ['A. File a notice of appeal against the decision within four months of notification of the decision', 'B. File a request for further processing within two months of notification of the decision', 'C. File, within two months of notification of the decision, a request for re-establishment of rights in respect of the time limit for filing the designation of inventor', 'D. A, B and C are correct']}
# Rerank
# Final answer: D
# {'question': 'Which of the following statements about filing third- party observations is correct?', 'options': ['A. The person that filed third- party observations will be a party to the proceedings before the EPO, and the applicant is obliged to respond to third- party observations', 'B. Third -party observations must be filed in writing and may not be filed anonymously', 'C. Third -party observations are considered by the examining division only if they include a statement of the grounds on which they are based, and an official fee is paid', 'D. Third -party observations can be filed after the publication of a European patent application and must be filed in an official language of the EPO']}
# Rerank
# Final answer: D
# {'question': 'You filed an international patent application on 6 June 2024, claiming the priority of a European patent application filed on 7  July 2023. You received a communication dated 25 September 2024 from the EPO acting as International Searching Authority (ISA), stating that the requirement of unity of invention has not been complied with. The ISA identifies three inventions. You are invited to pay two additional search fees. Which of the following statements is correct?', 'options': ['A. You must pay two additional search fees by 25 October 2024', 'B. You do not need to file a response to the provisional opinion accompanying the partial search results', 'C. If you pay two additional search fees under protest, you must pay two protest fees within the time limit', 'D. If you do not pay any additional search fees within the time limit, the international patent application will be deemed to be withdrawn']}
# Rerank
# Final answer: A
# {'question': 'An international patent application filed with the EPO as receiving Office on 10 September 2024, claims the priority of a Luxembourg patent application filed on 11 October 2023. No certified copy of the Luxembourg patent application was filed at the time of filing of the international patent application. Which of the following actions can be taken to file a certified copy of the Luxembourg patent application for this international patent application?', 'options': ['A. Request the Luxembourg Intellectual Property Office to prepare and send a certified copy of the Luxembourg patent application to the EPO', 'B. Submit a valid DAS code (Digital Access Service) to the International Bureau to enable it to obtain a certified copy of the Luxembourg patent application', 'C. File an electronic certified copy of the Luxembourg patent application with the EPO', 'D. File a certified copy of the Luxembourg patent application with the International Bureau']}
# Rerank
# Final answer: A
# {'question': 'Firm A owns a European patent, EP . Firm B filed an opposition against EP, requesting its revocation. Firm B argued that the subject -matter of the granted claims was not new in view of document D1. During the opposition proceedings, firm C filed observations under Art.  115 EPC, arguing that the subject -matter of the granted claims was not new in view of document D2. Firm A requested maintenance of the patent as granted, or maintenance in amended Which of the following statements is correct?', 'options': ["A. At the end of the opposition proceedings, the opposition division decided to revoke the patent. Firm B is entitled to file an appeal against the opposition division's decision.", "B. At the end of the opposition proceedings, the opposition division decided to and firm B are entitled to file an appeal against the opposition division's decision.", "C. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm C is entitled to file an appeal against the opposition division's decision.", "D. During the opposition proceedings, firm B withdrew its opposition. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm B is entitled to file an appeal against the opposition division's decision."]}
# Rerank
# Final answer: A
# {'question': 'European patent application EP -X was filed on 1  October 2020, claiming the priority of a Belgian application filed on 16 October 2019. The mention of the grant of European patent EP -X was published on 2  October 2024. The proprietor filed a request for unitary effect and was informed by communication dated 10  October 2024, that unitary effect had been registered for EP -X-C0 on the same date. Which of the following statements is correct?', 'options': ['A. A renewal fee still has to be paid by 31 October 2024 in respect of the 5th year for EP -X', 'B. A renewal fee is due on 31 October 2024 in respect of the 5th year for EP -X-C0', 'C. A renewal fee is due on 31 October 2024 in respect of the 6th year for EP -X-C0', 'D. No renewal fee has to be paid on 31 October 2024']}
# Rerank
# Final answer: B
# {'question': 'A communication under Article 94(3) EPC, setting a four -month time limit for reply is dated 12 September 2024. The applicant receives the letter on 21 September 2024, as evidenced by the postal receipt signed by him.  What is the last day for replying to the communication?', 'options': ['A. 13 January 2025', 'B. 12 January 2025', 'C. 22 January 2025', 'D. 14 January 2025']}
# Rerank
# Final answer: B
# {'question': 'Which functionalities or services can be accessed directly from MyEPO Portfolio?', 'options': ["A. A shared area with examiners, European Patent Register, filing via the EPO's online filing software eOLF", 'B. Mailbox, a shared area with examiners, replying to a communication under Article  94(3) EPC', 'C. Mailbox, patent search via publication server, a shared area with examiners', "D. Filing via the EPO's Online Filing 2.0, patent search via publication server, Mailbox"]}
# Rerank
# Final answer: B
# {'question': 'In which of the following situations does the EPO recommend using the EPO Contingency Upload Service?', 'options': ['A. When you submit documents after business hours', 'B. When the EPO filing systems are functioning correctly, but you encounter a technical issue at your end', 'C. When there is a system outage at the EPO that prevents document submission via the standard filing systems', 'D. When the EPO is closed due to an official holiday']}
# Rerank
# Final answer: C
# {'question': 'Applicant Korhonen is a Finnish national resident in Finland. He filed a European patent application in Finnish and provided an English translation in time. In response to the extended European search report (EESR), Korhonen wishes to file amended claims t ogether with a request for examination. Which of the following statements is correct?', 'options': ['A. Korhonen must file the amended claims in Finnish and must then  provide a translation into English, in time', 'B. Korhonen is allowed to file the amended claims in Finnish if he then provides a', 'translation into any official language of the EPO, in time C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time', 'D. Korhonen is not allowed to file the amended claims in Finnish']}
# Rerank
# Final answer: C
# {'question': 'Applicants may request processing of their international application under PCT Direct by filing a letter ("PCT Direct letter") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?', 'options': ['A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing', 'B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0', 'C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0', 'D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document']}
# Rerank
# Final answer: B
# {'question': 'Mr Linguist filed a European patent application in Dutch and used English as language of the proceedings. When requesting unitary effect on 10 October 2024, Mr Linguist must provide a translation of the specification. Mr Linguist would like to obtain immediate registration of the unitary effect. Which of the following statements is correct?', 'options': ['A. Mr Linguist must provide a translation of the specification into Dutch', 'B. Mr Linguist must provide a translation of the specification into an official language of any of the 18 states to which the unitary effect extends', 'C. Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA', 'D. Mr Linguist may provide a translation of the specification into Spanish']}
# Rerank
# Final answer: B
# {'total_answer': 29, 'correct_answer': 8}

# %%
from colbert import Searcher

class ColbertReranker:
    def __init__(self, model_name="colbert-ir/colbertv2.0"):
        """
        Initialise un reranker ColBERT en chargeant le modèle pré-entraîné.
        """
        self.searcher = Searcher.from_pretrained(model_name, faiss_depth=100, nprobe=10)

    def rerank(self, query, documents, k=5):
        """
        Classe les documents en fonction de leur pertinence pour la question.

        query: str -> La question posée.
        documents: list -> Liste des documents récupérés.
        k: int -> Nombre de documents à conserver après reranking.

        Retourne les k meilleurs documents rerankés.
        """
        doc_texts = [doc.page_content for doc in documents]  # Extraire le texte des documents

        # Indexation temporaire des documents pour le reranking
        doc_ids = list(range(len(doc_texts)))
        self.searcher.index(texts=doc_texts, doc_ids=doc_ids)

        # Effectuer la recherche
        results = self.searcher.search(query, k=k)

        # Trier les documents selon leur score
        ranked_docs = sorted(zip(results.doc_scores, results.doc_ids), key=lambda x: x[0], reverse=True)

        # Récupérer les documents classés
        reranked_docs = [documents[idx] for _, idx in ranked_docs]

        return reranked_docs  # Retourne les meilleurs documents rerankés

# Utilisation
reranker = ColbertReranker()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from colbert import Searcher
#       3 class ColbertReranker:
#       4     def __init__(self, model_name="colbert-ir/colbertv2.0"):
#
# File c:\Users\Patrice\Documents\Projets\ia-pau-data-battle-mars-2025\.venv\Lib\site-packages\colbert\__init__.py:1
# ----> 1 from .trainer import Trainer
#       2 from .indexer import Indexer
#       3 from .searcher import Searcher
#
# File c:\Users\Patrice\Documents\Projets\ia-pau-data-battle-mars-2025\.venv\Lib\site-packages\colbert\trainer.py:5
#       2 from colbert.infra.launcher import Launcher
#       3 from colbert.infra.config import ColBERTConfig, RunConfig
# ----> 5 from colbert.training.training import train
#       8 class Trainer:
#       9     def __init__(self, triples, queries, collection, config=None):
#
# File c:\Users\Patrice\Documents\Projets\ia-pau-data-battle-mars-2025\.venv\Lib\site-packages\colbert\training\training.py:7
#       4 import torch.nn as nn
#       5 import numpy as np
# ----> 7 from transformers import AdamW, get_linear_schedule_with_warmup
#       8 from colbert.infra import ColBERTConfig
#       9 from colbert.training.rerank_batcher import RerankBatcher
#
# ImportError: cannot import name 'AdamW' from 'transformers' (c:\Users\Patrice\Documents\Projets\ia-pau-data-battle-mars-2025\.venv\Lib\site-packages\transformers\__init__.py)

# %%
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

class Reranker:
    def __init__(self, model_name='BAAI/bge-reranker-large'):
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModelForSequenceClassification.from_pretrained(model_name)
        self.model.eval()

    def rerank(self, query, documents, k=5):
        pairs = [[query, doc.page_content] for doc in documents]
        with torch.no_grad():
            inputs = self.tokenizer(pairs, padding=True, truncation=True, return_tensors='pt', max_length=512)
            scores = self.model(**inputs, return_dict=True).logits.view(-1).float()
        
        # Associer les scores aux documents
        scored_docs = sorted(zip(documents, scores), key=lambda x: x[1], reverse=True)
        return [doc for doc, _ in scored_docs[:k]]

# %%
reranker = Reranker()
test_custom('sentence-transformers_all-MiniLM-L6-v2_chunk512_qwen2_5_7b_TestAvecNewPromptSansSecondModel_RerankerBAAI_bge_reranker_large',
           embeddings_model='sentence-transformers/all-MiniLM-L6-v2',
           embeddings_path='../embeddings/rag_embeddings_sentence-transformers_all-MiniLM-L6-v2_chunk512',
           reader='qwen2.5:7b', 
           reranker = reranker)
# Out:
# embedding load
# {'question': 'A European patent was granted to a German company on 4  January 2023. No opposition was filed. Mr Li and Ms Smith were designated as inventors. On 12 October 2023,  the patent proprietor not ices that Ms Smith was erroneously designated as inventor and that Mr Li is the sole inventor.  Which of the following statements is correct?', 'options': ['A. Ms Smith will be deleted as inventor if the patent proprietor requests this in writing .', 'B. Ms Smith can no longer  be deleted as inventor because no proceedings are pending before the EPO .', "C. The patent proprietor can request that  Ms Smith be deleted as inventor but needs Mr Li 's consent  for this .", 'D. Ms Smith can only be deleted as inventor with her consent .']}
# Rerank
# Final answer: A
# {'question': "On 10 October 2021, European patent attorney X filed European patent application EP -A with the EPO on the applicant's behalf. Application EP -A was published on 12 April 2023, together  with the extended European search report. On 6  October 2023, the applicant contacts a new European patent attorney  Y to replace X as representative and issues Y with its instructions to reply to the extended European search report. The applicant did not inform X that he would be replaced.  What are the steps necessary to validly appoint representative Y and to avoid any loss of rights for European patent application EP -A?", 'options': ['A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant .', 'B. New representative Y requests a change of representative and files a response to the extended European search report with  the EPO by 12 October 2023 at the latest .', 'C. New representative Y requests a change of representative and files a response to the extended European search report with the EPO by 23 October 2023 at the latest.', 'D. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 23 October 2023 at the latest and files in good time an authorisation signed by the applicant .']}
# Rerank
# Final answer: A
# {'question': 'EP-1 is a regular European patent application (Euro -direct application) .  Which one of the following missed time limits can be remedied for EP -1 before the EPO by requesting re- establishment of rights ?', 'options': ['A. T ime limit for pay ing the designation fee', 'B. T ime limit for requesting examination', 'C. T ime limit for filing the application within the priority period', 'D. T ime limit for paying the fee for re- establishment of rights']}
# Rerank
# Final answer: B
# {'question': 'Last week Greta validly filed the international patent application PCT -G with the German Patent and Trade mark Office ( DPMA ) and appointed Hassan to represent her. Hassan is entitled to act before the DPMA  but he is not a European patent attorney. Greta and Hassan are resident in Germany.  Which of the following statements is not correct?', 'options': ['A. Hassan can represent Greta before the EPO acting as the International Searching Authority for PCT -G.', 'B. In order for Hassan to be able to act before the EPO acting as the International Searching Authority , he needs to submit a power of attorney signed by Greta.', 'C. According to the provisions of the PCT, it is mandatory that the d emand for international preliminary examination is signed by Greta or Hassan.', 'D. According to the provisions of the PCT, an international application can only be withdrawn by the applicant or an agent appointed by a power of attorney.']}
# Rerank
# Final answer: A
# {'question': 'In which of the following cases is the applicant entitled to a reduction of the filing fee  under Rule  6 EPC ? A declaration of such entitlement has  been made by crossing the relevant box on Form  1001.', 'options': ['A. A Spanish European patent attorney files a European patent application in Spanish for a natural person who is resident in Andorra and of Andorra n nationality .', 'B. A firm whose principal place of business is in Germany and a natural person who is resident in Germany  and of Dutch nationality  jointly file a European patent application in Dutch. The German firm employs 200 people with an annual turnover of EUR 60 million.', 'C. A natural person resident in the USA and of Belgian nationality files a European patent application in French.', 'D. A natural person resident in the USA and of Swiss nationality files a European patent application in Italian.']}
# Rerank
# Final answer: A
# {'question': 'Mr Van Holland is a Dutch citizen resident in the Netherlands. He filed a European patent application EP -parent in Dutch, together with  a translation into English. Whil e EP-parent was pending, Mr Van Holland filed a divisional application EP -div in Dutch and requested examination in Dutch. He paid all fees due for EP -div. He has not filed an English translation of EP -div. The Receiving Section has now issued a noting of l oss of rights.  Which of the following statements is correct?', 'options': ['A. The deficiency cannot be remedied.', 'B. Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication  under Rule 112(1) EPC .', 'C. Mr Van Holland needs to file an English translation of EP -div together with a request for f urther processing.', 'D. Mr Van Holland needs to file an English translation of EP -div together with a request for re- establishment of rights.']}
# Rerank
# Final answer: B
# {'question': 'On 16  November 2020, you filed a European patent application EP -A, which did not claim priority. Today, 12  October 2023, you receive a communication from the EPO entitled " Decision to grant a European patent pursuant to Article  97(1) EPC ". This communication state s that the mention of the grant You wish to validate the patent in only two contracting states  to the EPC . Which of the following statements is correct?', 'options': ['A. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 16 November 2023.', 'B. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 30 November 2023.', 'C. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 9 January 2024 at the latest .', 'D. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 16 January 2024 at the latest .']}
# Rerank
# Final answer: C
# {'question': 'During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?', 'options': ['A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.', 'B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.', 'C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.', 'D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months.']}
# Rerank
# Final answer: C
# {'question': 'Under the PCT, what is the time limit for filing a request for rectification of an obvious mistake made in the international application?', 'options': ['A. 18 months from the earliest priority date', 'B. 30 months from the earliest priority date', 'C. 22 months from the earliest priority date', 'D. 26 months from the earliest priority date']}
# Rerank
# Final answer: D
# {'question': 'After receipt of a negative written opinion issued by the EPO acting as ISA, amendments under Art icle 19 PCT were filed during the international phase. No request for international preliminary examination was filed. Form  1200 was used,  and no further amendments were filed with the EPO upon entry into the regional phase.   What communication under Rules  161/162 EPC will be received in the regional phase?', 'options': ['A. Form 1226AA ;  if you do not reply to it in time, the application will be deemed to be withdrawn', 'B. Form 1226BB offering the opportunity to comment and file amendments', 'C. Form 1226CC offering the opportunity to file amendments before the supplementary European search report is drawn up', 'D. Form 1226AC stating that the examination has started']}
# Rerank
# Final answer: A
# {'question': 'Company M, which has  its principal place of business in Tijuana, Mexico, validly filed an international patent application PCT -M with the Mexican Institute of Industrial Property. The application was filed in Spanish. A few days later, the applicant files an English translati on of the application.  Which of the following statements is correct?', 'options': ['A. The applicant can choose the EPO as ISA and the USPTO as IPEA.', 'B. The applicant can choose the USPTO as ISA and the EPO as IPEA.', 'C. The applicant can choose the Austrian Patent Offic e as ISA and the', 'EPO as IPEA.', 'D. The applicant can choose the EPO as ISA and the Intellectual Property', 'Office of Singapore as IPEA.']}
# Rerank
# Final answer: A
# {'question': 'On 20  June 2023, applicant P validly filed an international patent application PCT-P, claiming priority from European patent application EP -I filed on 7 July 2022. Today, 12 October 2023, he discovers that he should also have claimed priority from EP -II filed on 3 July 2022. Can the missing priority claim still be validly added?', 'options': ['A. Yes, the time  limit for adding the priority claim expires on 3  November 2023.', 'B. Yes, the time limit for adding the priority claim expires on 7  November 2023.', 'C. Yes, the time  limit for adding the priority claim expires on 20 October 2023.', 'D. No, the time  limit for adding the priority claim expired on 3 July 2023.']}
# Rerank
# Final answer: A
# {'question': 'The opposition division revoked European patent EP -B1. The patent proprietor filed an appeal  in time . The b oard of appeal forwarded a copy of the appeal to the o pponent/ respondent with a communication dated 1 June 2023 giving it an opportunity to file comments within a period of four  months.  The opponent/respondent files comments today, 12 October 2023. What further action has to be taken ?', 'options': ['A. The opponent/ respondent needs  to request an extension of the period for comment.', 'B. The opponent/respondent needs to pay a fee for further processing.', 'C. The opponent/respondent needs to file a substantiated request for reestablishment of rights and pay the associated fee.', 'D. None of the above.']}
# Rerank
# Final answer: A
# {'question': 'A European patent application was filed on 20 March 2020. Proceedings were interrupted under  Rule 142 EPC on 10  March 2022. The applicant was informed that proceedings would be resumed today, 12 October 2023. No renewal fee has been paid so far . Which of the following statements is correct?', 'options': ['A. As no renewal fees have been paid, the application is deemed to be withdrawn .', 'B. The renewal fees for the third and fourth years can be validly paid without any additional fee on 12 October 2023 at the latest .', 'C. The renewal fees for the third and fourth years can be validly paid with an additional  fee by 30  April 2024 at the latest .', 'D. The renewal fees for the third and fourth years can be validly paid without any additional fee by 31  October 2023 at the latest .']}
# Rerank
# Final answer: C
# {'question': 'An international application is published , together  with the search report drawn up by the CNIPA , 18 m onths + 1 day after the filing date (no priority claimed). The application has no more than 35 pages and 15 claims. Which statement reflects all actions the CN  applicant  needs to take for entry into the EP phase 25 months  after the filing date ? A request for early processing has been filed.', 'options': ['A. Complete and file Form 1200 and pay the filing fee and the search fee', 'B. Complete and file Form 1200 and pay the filing fee, the search fee and the renewal fee for the third year', 'C. Complete and file Form 1200, pay the filing fee and the search fee and appoint a representative', 'D. None of the above statements']}
# Rerank
# Final answer: A
# {'question': 'A European patent application was filed on 6 February 2023. The search, filing and designation fees were paid within a month of the date of filing. What is the latest point in time for withdrawing the application, if the applicant wishes to obtain a refund of the designation fee?', 'options': ['A. Six months after the date of mention of the publication of the European search report', 'B. Date of mention of the publication of the European search report', 'C. The designation fee was validly paid and can no longer be refunded', 'D. Date of the start of substantive examination']}
# Rerank
# Final answer: A
# {'question': "On 10 October 2024, an applicant files a request for entry into the European phase, together with a debit order, according to which the filing fee, the designation fee, the examination fee and the renewal fee for the third year are to be debited from the applicant's deposit account. It is specified that the debit order is to be executed on 18 October 2024. On the evening of 10 October 2024, the applicant notices that the renewal fee is not yet due and should not be debited from the deposit account. What is the latest point in time for revoking the order to debit the renewal fee in Central Fee Payment (CFP)?", 'options': ['A. 10 October 2024', 'B. 17 October 2024', 'C. 18 October 2024', 'D. A debit order cannot be revoked in part']}
# Rerank
# Final answer: B
# {'question': 'The applicant received a communication pursuant to Article 90(3) EPC and Rule  60 EPC, requesting them to file a designation of inventor but missed the time limit for filing a response. After expiry of the time limit, the Receiving Section issued a decision to refuse the European patent application, dated 10  October 2024. What can the applicant do to remedy the situation?', 'options': ['A. File a notice of appeal against the decision within four months of notification of the decision', 'B. File a request for further processing within two months of notification of the decision', 'C. File, within two months of notification of the decision, a request for re-establishment of rights in respect of the time limit for filing the designation of inventor', 'D. A, B and C are correct']}
# Rerank
# Final answer: A
# {'question': 'Which of the following statements about filing third- party observations is correct?', 'options': ['A. The person that filed third- party observations will be a party to the proceedings before the EPO, and the applicant is obliged to respond to third- party observations', 'B. Third -party observations must be filed in writing and may not be filed anonymously', 'C. Third -party observations are considered by the examining division only if they include a statement of the grounds on which they are based, and an official fee is paid', 'D. Third -party observations can be filed after the publication of a European patent application and must be filed in an official language of the EPO']}
# Rerank
# Final answer: D
# {'question': 'You filed an international patent application on 6 June 2024, claiming the priority of a European patent application filed on 7  July 2023. You received a communication dated 25 September 2024 from the EPO acting as International Searching Authority (ISA), stating that the requirement of unity of invention has not been complied with. The ISA identifies three inventions. You are invited to pay two additional search fees. Which of the following statements is correct?', 'options': ['A. You must pay two additional search fees by 25 October 2024', 'B. You do not need to file a response to the provisional opinion accompanying the partial search results', 'C. If you pay two additional search fees under protest, you must pay two protest fees within the time limit', 'D. If you do not pay any additional search fees within the time limit, the international patent application will be deemed to be withdrawn']}
# Rerank
# Final answer: A
# {'question': 'An international patent application filed with the EPO as receiving Office on 10 September 2024, claims the priority of a Luxembourg patent application filed on 11 October 2023. No certified copy of the Luxembourg patent application was filed at the time of filing of the international patent application. Which of the following actions can be taken to file a certified copy of the Luxembourg patent application for this international patent application?', 'options': ['A. Request the Luxembourg Intellectual Property Office to prepare and send a certified copy of the Luxembourg patent application to the EPO', 'B. Submit a valid DAS code (Digital Access Service) to the International Bureau to enable it to obtain a certified copy of the Luxembourg patent application', 'C. File an electronic certified copy of the Luxembourg patent application with the EPO', 'D. File a certified copy of the Luxembourg patent application with the International Bureau']}
# Rerank
# Final answer: A
# {'question': 'Firm A owns a European patent, EP . Firm B filed an opposition against EP, requesting its revocation. Firm B argued that the subject -matter of the granted claims was not new in view of document D1. During the opposition proceedings, firm C filed observations under Art.  115 EPC, arguing that the subject -matter of the granted claims was not new in view of document D2. Firm A requested maintenance of the patent as granted, or maintenance in amended Which of the following statements is correct?', 'options': ["A. At the end of the opposition proceedings, the opposition division decided to revoke the patent. Firm B is entitled to file an appeal against the opposition division's decision.", "B. At the end of the opposition proceedings, the opposition division decided to and firm B are entitled to file an appeal against the opposition division's decision.", "C. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm C is entitled to file an appeal against the opposition division's decision.", "D. During the opposition proceedings, firm B withdrew its opposition. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm B is entitled to file an appeal against the opposition division's decision."]}
# Rerank
# Final answer: A
# {'question': 'European patent application EP -X was filed on 1  October 2020, claiming the priority of a Belgian application filed on 16 October 2019. The mention of the grant of European patent EP -X was published on 2  October 2024. The proprietor filed a request for unitary effect and was informed by communication dated 10  October 2024, that unitary effect had been registered for EP -X-C0 on the same date. Which of the following statements is correct?', 'options': ['A. A renewal fee still has to be paid by 31 October 2024 in respect of the 5th year for EP -X', 'B. A renewal fee is due on 31 October 2024 in respect of the 5th year for EP -X-C0', 'C. A renewal fee is due on 31 October 2024 in respect of the 6th year for EP -X-C0', 'D. No renewal fee has to be paid on 31 October 2024']}
# Rerank
# Final answer: B
# {'question': 'A communication under Article 94(3) EPC, setting a four -month time limit for reply is dated 12 September 2024. The applicant receives the letter on 21 September 2024, as evidenced by the postal receipt signed by him.  What is the last day for replying to the communication?', 'options': ['A. 13 January 2025', 'B. 12 January 2025', 'C. 22 January 2025', 'D. 14 January 2025']}
# Rerank
# Final answer: A
# {'question': 'Which functionalities or services can be accessed directly from MyEPO Portfolio?', 'options': ["A. A shared area with examiners, European Patent Register, filing via the EPO's online filing software eOLF", 'B. Mailbox, a shared area with examiners, replying to a communication under Article  94(3) EPC', 'C. Mailbox, patent search via publication server, a shared area with examiners', "D. Filing via the EPO's Online Filing 2.0, patent search via publication server, Mailbox"]}
# Rerank
# Final answer: B
# {'question': 'In which of the following situations does the EPO recommend using the EPO Contingency Upload Service?', 'options': ['A. When you submit documents after business hours', 'B. When the EPO filing systems are functioning correctly, but you encounter a technical issue at your end', 'C. When there is a system outage at the EPO that prevents document submission via the standard filing systems', 'D. When the EPO is closed due to an official holiday']}
# Rerank
# Final answer: C
# {'question': 'Applicant Korhonen is a Finnish national resident in Finland. He filed a European patent application in Finnish and provided an English translation in time. In response to the extended European search report (EESR), Korhonen wishes to file amended claims t ogether with a request for examination. Which of the following statements is correct?', 'options': ['A. Korhonen must file the amended claims in Finnish and must then  provide a translation into English, in time', 'B. Korhonen is allowed to file the amended claims in Finnish if he then provides a', 'translation into any official language of the EPO, in time C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time', 'D. Korhonen is not allowed to file the amended claims in Finnish']}
# Rerank
# Final answer: C
# {'question': 'Applicants may request processing of their international application under PCT Direct by filing a letter ("PCT Direct letter") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?', 'options': ['A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing', 'B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0', 'C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0', 'D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document']}
# Rerank
# Final answer: A
# {'question': 'Mr Linguist filed a European patent application in Dutch and used English as language of the proceedings. When requesting unitary effect on 10 October 2024, Mr Linguist must provide a translation of the specification. Mr Linguist would like to obtain immediate registration of the unitary effect. Which of the following statements is correct?', 'options': ['A. Mr Linguist must provide a translation of the specification into Dutch', 'B. Mr Linguist must provide a translation of the specification into an official language of any of the 18 states to which the unitary effect extends', 'C. Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA', 'D. Mr Linguist may provide a translation of the specification into Spanish']}
# Rerank
# Final answer: B
# {'total_answer': 29, 'correct_answer': 9}

# %%
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

class Reranker:
    def __init__(self, model_name='BAAI/bge-reranker-large'):
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModelForSequenceClassification.from_pretrained(model_name)
        self.model.eval()

    def rerank(self, query, documents, k=5):
        pairs = [[query, doc.page_content] for doc in documents]
        with torch.no_grad():
            inputs = self.tokenizer(pairs, padding=True, truncation=True, return_tensors='pt')
            scores = self.model(**inputs, return_dict=True).logits.view(-1).float()
        
        # Associer les scores aux documents
        scored_docs = sorted(zip(documents, scores), key=lambda x: x[1], reverse=True)
        return [doc for doc, _ in scored_docs[:k]]
    
reranker = Reranker()
test_custom('sentence-transformers_all-MiniLM-L6-v2_chunk512_qwen2_5_7b_TestAvecNewPromptSansSecondModel_RerankerBAAI_bge_reranker_large_sanslimitetoken',
           embeddings_model='sentence-transformers/all-MiniLM-L6-v2',
           embeddings_path='../embeddings/rag_embeddings_sentence-transformers_all-MiniLM-L6-v2_chunk512',
           reader='qwen2.5:7b', 
           reranker = reranker)
# Out:
# embedding load
# {'question': 'A European patent was granted to a German company on 4  January 2023. No opposition was filed. Mr Li and Ms Smith were designated as inventors. On 12 October 2023,  the patent proprietor not ices that Ms Smith was erroneously designated as inventor and that Mr Li is the sole inventor.  Which of the following statements is correct?', 'options': ['A. Ms Smith will be deleted as inventor if the patent proprietor requests this in writing .', 'B. Ms Smith can no longer  be deleted as inventor because no proceedings are pending before the EPO .', "C. The patent proprietor can request that  Ms Smith be deleted as inventor but needs Mr Li 's consent  for this .", 'D. Ms Smith can only be deleted as inventor with her consent .']}
# Rerank
# Final answer: A
# {'question': "On 10 October 2021, European patent attorney X filed European patent application EP -A with the EPO on the applicant's behalf. Application EP -A was published on 12 April 2023, together  with the extended European search report. On 6  October 2023, the applicant contacts a new European patent attorney  Y to replace X as representative and issues Y with its instructions to reply to the extended European search report. The applicant did not inform X that he would be replaced.  What are the steps necessary to validly appoint representative Y and to avoid any loss of rights for European patent application EP -A?", 'options': ['A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant .', 'B. New representative Y requests a change of representative and files a response to the extended European search report with  the EPO by 12 October 2023 at the latest .', 'C. New representative Y requests a change of representative and files a response to the extended European search report with the EPO by 23 October 2023 at the latest.', 'D. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 23 October 2023 at the latest and files in good time an authorisation signed by the applicant .']}
# Rerank
# Final answer: A
# {'question': 'EP-1 is a regular European patent application (Euro -direct application) .  Which one of the following missed time limits can be remedied for EP -1 before the EPO by requesting re- establishment of rights ?', 'options': ['A. T ime limit for pay ing the designation fee', 'B. T ime limit for requesting examination', 'C. T ime limit for filing the application within the priority period', 'D. T ime limit for paying the fee for re- establishment of rights']}
# Rerank
# Final answer: B
# {'question': 'Last week Greta validly filed the international patent application PCT -G with the German Patent and Trade mark Office ( DPMA ) and appointed Hassan to represent her. Hassan is entitled to act before the DPMA  but he is not a European patent attorney. Greta and Hassan are resident in Germany.  Which of the following statements is not correct?', 'options': ['A. Hassan can represent Greta before the EPO acting as the International Searching Authority for PCT -G.', 'B. In order for Hassan to be able to act before the EPO acting as the International Searching Authority , he needs to submit a power of attorney signed by Greta.', 'C. According to the provisions of the PCT, it is mandatory that the d emand for international preliminary examination is signed by Greta or Hassan.', 'D. According to the provisions of the PCT, an international application can only be withdrawn by the applicant or an agent appointed by a power of attorney.']}
# Rerank
# Final answer: A
# {'question': 'In which of the following cases is the applicant entitled to a reduction of the filing fee  under Rule  6 EPC ? A declaration of such entitlement has  been made by crossing the relevant box on Form  1001.', 'options': ['A. A Spanish European patent attorney files a European patent application in Spanish for a natural person who is resident in Andorra and of Andorra n nationality .', 'B. A firm whose principal place of business is in Germany and a natural person who is resident in Germany  and of Dutch nationality  jointly file a European patent application in Dutch. The German firm employs 200 people with an annual turnover of EUR 60 million.', 'C. A natural person resident in the USA and of Belgian nationality files a European patent application in French.', 'D. A natural person resident in the USA and of Swiss nationality files a European patent application in Italian.']}
# Rerank
# Final answer: A
# {'question': 'Mr Van Holland is a Dutch citizen resident in the Netherlands. He filed a European patent application EP -parent in Dutch, together with  a translation into English. Whil e EP-parent was pending, Mr Van Holland filed a divisional application EP -div in Dutch and requested examination in Dutch. He paid all fees due for EP -div. He has not filed an English translation of EP -div. The Receiving Section has now issued a noting of l oss of rights.  Which of the following statements is correct?', 'options': ['A. The deficiency cannot be remedied.', 'B. Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication  under Rule 112(1) EPC .', 'C. Mr Van Holland needs to file an English translation of EP -div together with a request for f urther processing.', 'D. Mr Van Holland needs to file an English translation of EP -div together with a request for re- establishment of rights.']}
# Rerank
# Final answer: B
# {'question': 'On 16  November 2020, you filed a European patent application EP -A, which did not claim priority. Today, 12  October 2023, you receive a communication from the EPO entitled " Decision to grant a European patent pursuant to Article  97(1) EPC ". This communication state s that the mention of the grant You wish to validate the patent in only two contracting states  to the EPC . Which of the following statements is correct?', 'options': ['A. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 16 November 2023.', 'B. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 30 November 2023.', 'C. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 9 January 2024 at the latest .', 'D. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 16 January 2024 at the latest .']}
# Rerank
# Final answer: C
# {'question': 'During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?', 'options': ['A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.', 'B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.', 'C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.', 'D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months.']}
# Rerank
# Final answer: C
# {'question': 'Under the PCT, what is the time limit for filing a request for rectification of an obvious mistake made in the international application?', 'options': ['A. 18 months from the earliest priority date', 'B. 30 months from the earliest priority date', 'C. 22 months from the earliest priority date', 'D. 26 months from the earliest priority date']}
# Rerank
# Final answer: D
# {'question': 'After receipt of a negative written opinion issued by the EPO acting as ISA, amendments under Art icle 19 PCT were filed during the international phase. No request for international preliminary examination was filed. Form  1200 was used,  and no further amendments were filed with the EPO upon entry into the regional phase.   What communication under Rules  161/162 EPC will be received in the regional phase?', 'options': ['A. Form 1226AA ;  if you do not reply to it in time, the application will be deemed to be withdrawn', 'B. Form 1226BB offering the opportunity to comment and file amendments', 'C. Form 1226CC offering the opportunity to file amendments before the supplementary European search report is drawn up', 'D. Form 1226AC stating that the examination has started']}
# Rerank
# Final answer: A
# {'question': 'Company M, which has  its principal place of business in Tijuana, Mexico, validly filed an international patent application PCT -M with the Mexican Institute of Industrial Property. The application was filed in Spanish. A few days later, the applicant files an English translati on of the application.  Which of the following statements is correct?', 'options': ['A. The applicant can choose the EPO as ISA and the USPTO as IPEA.', 'B. The applicant can choose the USPTO as ISA and the EPO as IPEA.', 'C. The applicant can choose the Austrian Patent Offic e as ISA and the', 'EPO as IPEA.', 'D. The applicant can choose the EPO as ISA and the Intellectual Property', 'Office of Singapore as IPEA.']}
# Rerank
# Final answer: A
# {'question': 'On 20  June 2023, applicant P validly filed an international patent application PCT-P, claiming priority from European patent application EP -I filed on 7 July 2022. Today, 12 October 2023, he discovers that he should also have claimed priority from EP -II filed on 3 July 2022. Can the missing priority claim still be validly added?', 'options': ['A. Yes, the time  limit for adding the priority claim expires on 3  November 2023.', 'B. Yes, the time limit for adding the priority claim expires on 7  November 2023.', 'C. Yes, the time  limit for adding the priority claim expires on 20 October 2023.', 'D. No, the time  limit for adding the priority claim expired on 3 July 2023.']}
# Rerank
# Final answer: A
# {'question': 'The opposition division revoked European patent EP -B1. The patent proprietor filed an appeal  in time . The b oard of appeal forwarded a copy of the appeal to the o pponent/ respondent with a communication dated 1 June 2023 giving it an opportunity to file comments within a period of four  months.  The opponent/respondent files comments today, 12 October 2023. What further action has to be taken ?', 'options': ['A. The opponent/ respondent needs  to request an extension of the period for comment.', 'B. The opponent/respondent needs to pay a fee for further processing.', 'C. The opponent/respondent needs to file a substantiated request for reestablishment of rights and pay the associated fee.', 'D. None of the above.']}
# Rerank
# Final answer: A
# {'question': 'A European patent application was filed on 20 March 2020. Proceedings were interrupted under  Rule 142 EPC on 10  March 2022. The applicant was informed that proceedings would be resumed today, 12 October 2023. No renewal fee has been paid so far . Which of the following statements is correct?', 'options': ['A. As no renewal fees have been paid, the application is deemed to be withdrawn .', 'B. The renewal fees for the third and fourth years can be validly paid without any additional fee on 12 October 2023 at the latest .', 'C. The renewal fees for the third and fourth years can be validly paid with an additional  fee by 30  April 2024 at the latest .', 'D. The renewal fees for the third and fourth years can be validly paid without any additional fee by 31  October 2023 at the latest .']}
# Rerank
# Final answer: C
# {'question': 'An international application is published , together  with the search report drawn up by the CNIPA , 18 m onths + 1 day after the filing date (no priority claimed). The application has no more than 35 pages and 15 claims. Which statement reflects all actions the CN  applicant  needs to take for entry into the EP phase 25 months  after the filing date ? A request for early processing has been filed.', 'options': ['A. Complete and file Form 1200 and pay the filing fee and the search fee', 'B. Complete and file Form 1200 and pay the filing fee, the search fee and the renewal fee for the third year', 'C. Complete and file Form 1200, pay the filing fee and the search fee and appoint a representative', 'D. None of the above statements']}
# Rerank
# Final answer: A
# {'question': 'A European patent application was filed on 6 February 2023. The search, filing and designation fees were paid within a month of the date of filing. What is the latest point in time for withdrawing the application, if the applicant wishes to obtain a refund of the designation fee?', 'options': ['A. Six months after the date of mention of the publication of the European search report', 'B. Date of mention of the publication of the European search report', 'C. The designation fee was validly paid and can no longer be refunded', 'D. Date of the start of substantive examination']}
# Rerank
# Final answer: A
# {'question': "On 10 October 2024, an applicant files a request for entry into the European phase, together with a debit order, according to which the filing fee, the designation fee, the examination fee and the renewal fee for the third year are to be debited from the applicant's deposit account. It is specified that the debit order is to be executed on 18 October 2024. On the evening of 10 October 2024, the applicant notices that the renewal fee is not yet due and should not be debited from the deposit account. What is the latest point in time for revoking the order to debit the renewal fee in Central Fee Payment (CFP)?", 'options': ['A. 10 October 2024', 'B. 17 October 2024', 'C. 18 October 2024', 'D. A debit order cannot be revoked in part']}
# Rerank
# Final answer: B
# {'question': 'The applicant received a communication pursuant to Article 90(3) EPC and Rule  60 EPC, requesting them to file a designation of inventor but missed the time limit for filing a response. After expiry of the time limit, the Receiving Section issued a decision to refuse the European patent application, dated 10  October 2024. What can the applicant do to remedy the situation?', 'options': ['A. File a notice of appeal against the decision within four months of notification of the decision', 'B. File a request for further processing within two months of notification of the decision', 'C. File, within two months of notification of the decision, a request for re-establishment of rights in respect of the time limit for filing the designation of inventor', 'D. A, B and C are correct']}
# Rerank
# Final answer: A
# {'question': 'Which of the following statements about filing third- party observations is correct?', 'options': ['A. The person that filed third- party observations will be a party to the proceedings before the EPO, and the applicant is obliged to respond to third- party observations', 'B. Third -party observations must be filed in writing and may not be filed anonymously', 'C. Third -party observations are considered by the examining division only if they include a statement of the grounds on which they are based, and an official fee is paid', 'D. Third -party observations can be filed after the publication of a European patent application and must be filed in an official language of the EPO']}
# Rerank
# Final answer: D
# {'question': 'You filed an international patent application on 6 June 2024, claiming the priority of a European patent application filed on 7  July 2023. You received a communication dated 25 September 2024 from the EPO acting as International Searching Authority (ISA), stating that the requirement of unity of invention has not been complied with. The ISA identifies three inventions. You are invited to pay two additional search fees. Which of the following statements is correct?', 'options': ['A. You must pay two additional search fees by 25 October 2024', 'B. You do not need to file a response to the provisional opinion accompanying the partial search results', 'C. If you pay two additional search fees under protest, you must pay two protest fees within the time limit', 'D. If you do not pay any additional search fees within the time limit, the international patent application will be deemed to be withdrawn']}
# Rerank
# Final answer: A
# {'question': 'An international patent application filed with the EPO as receiving Office on 10 September 2024, claims the priority of a Luxembourg patent application filed on 11 October 2023. No certified copy of the Luxembourg patent application was filed at the time of filing of the international patent application. Which of the following actions can be taken to file a certified copy of the Luxembourg patent application for this international patent application?', 'options': ['A. Request the Luxembourg Intellectual Property Office to prepare and send a certified copy of the Luxembourg patent application to the EPO', 'B. Submit a valid DAS code (Digital Access Service) to the International Bureau to enable it to obtain a certified copy of the Luxembourg patent application', 'C. File an electronic certified copy of the Luxembourg patent application with the EPO', 'D. File a certified copy of the Luxembourg patent application with the International Bureau']}
# Rerank
# Final answer: A
# {'question': 'Firm A owns a European patent, EP . Firm B filed an opposition against EP, requesting its revocation. Firm B argued that the subject -matter of the granted claims was not new in view of document D1. During the opposition proceedings, firm C filed observations under Art.  115 EPC, arguing that the subject -matter of the granted claims was not new in view of document D2. Firm A requested maintenance of the patent as granted, or maintenance in amended Which of the following statements is correct?', 'options': ["A. At the end of the opposition proceedings, the opposition division decided to revoke the patent. Firm B is entitled to file an appeal against the opposition division's decision.", "B. At the end of the opposition proceedings, the opposition division decided to and firm B are entitled to file an appeal against the opposition division's decision.", "C. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm C is entitled to file an appeal against the opposition division's decision.", "D. During the opposition proceedings, firm B withdrew its opposition. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm B is entitled to file an appeal against the opposition division's decision."]}
# Rerank
# Final answer: B
# {'question': 'European patent application EP -X was filed on 1  October 2020, claiming the priority of a Belgian application filed on 16 October 2019. The mention of the grant of European patent EP -X was published on 2  October 2024. The proprietor filed a request for unitary effect and was informed by communication dated 10  October 2024, that unitary effect had been registered for EP -X-C0 on the same date. Which of the following statements is correct?', 'options': ['A. A renewal fee still has to be paid by 31 October 2024 in respect of the 5th year for EP -X', 'B. A renewal fee is due on 31 October 2024 in respect of the 5th year for EP -X-C0', 'C. A renewal fee is due on 31 October 2024 in respect of the 6th year for EP -X-C0', 'D. No renewal fee has to be paid on 31 October 2024']}
# Rerank
# Final answer: B
# {'question': 'A communication under Article 94(3) EPC, setting a four -month time limit for reply is dated 12 September 2024. The applicant receives the letter on 21 September 2024, as evidenced by the postal receipt signed by him.  What is the last day for replying to the communication?', 'options': ['A. 13 January 2025', 'B. 12 January 2025', 'C. 22 January 2025', 'D. 14 January 2025']}
# Rerank
# Final answer: A
# {'question': 'Which functionalities or services can be accessed directly from MyEPO Portfolio?', 'options': ["A. A shared area with examiners, European Patent Register, filing via the EPO's online filing software eOLF", 'B. Mailbox, a shared area with examiners, replying to a communication under Article  94(3) EPC', 'C. Mailbox, patent search via publication server, a shared area with examiners', "D. Filing via the EPO's Online Filing 2.0, patent search via publication server, Mailbox"]}
# Rerank
# Final answer: B
# {'question': 'In which of the following situations does the EPO recommend using the EPO Contingency Upload Service?', 'options': ['A. When you submit documents after business hours', 'B. When the EPO filing systems are functioning correctly, but you encounter a technical issue at your end', 'C. When there is a system outage at the EPO that prevents document submission via the standard filing systems', 'D. When the EPO is closed due to an official holiday']}
# Rerank
# Final answer: C
# {'question': 'Applicant Korhonen is a Finnish national resident in Finland. He filed a European patent application in Finnish and provided an English translation in time. In response to the extended European search report (EESR), Korhonen wishes to file amended claims t ogether with a request for examination. Which of the following statements is correct?', 'options': ['A. Korhonen must file the amended claims in Finnish and must then  provide a translation into English, in time', 'B. Korhonen is allowed to file the amended claims in Finnish if he then provides a', 'translation into any official language of the EPO, in time C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time', 'D. Korhonen is not allowed to file the amended claims in Finnish']}
# Rerank
# Final answer: C
# {'question': 'Applicants may request processing of their international application under PCT Direct by filing a letter ("PCT Direct letter") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?', 'options': ['A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing', 'B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0', 'C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0', 'D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document']}
# Rerank
# Final answer: A
# {'question': 'Mr Linguist filed a European patent application in Dutch and used English as language of the proceedings. When requesting unitary effect on 10 October 2024, Mr Linguist must provide a translation of the specification. Mr Linguist would like to obtain immediate registration of the unitary effect. Which of the following statements is correct?', 'options': ['A. Mr Linguist must provide a translation of the specification into Dutch', 'B. Mr Linguist must provide a translation of the specification into an official language of any of the 18 states to which the unitary effect extends', 'C. Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA', 'D. Mr Linguist may provide a translation of the specification into Spanish']}
# Rerank
# Final answer: B
# {'total_answer': 29, 'correct_answer': 10}

# %% [markdown]
# ### Tester avec top50 dans le premier et on rerank 5 ?
# 7/29 Pas fou.

# %%
reranker = Reranker()
test_custom('sentence-transformers_all-MiniLM-L6-v2_chunk512_qwen2_5_7b_TestAvecNewPromptSansSecondModel_RerankerBAAI_bge_reranker_large_sanslimitetoken_50context',
           embeddings_model='sentence-transformers/all-MiniLM-L6-v2',
           embeddings_path='../embeddings/rag_embeddings_sentence-transformers_all-MiniLM-L6-v2_chunk512',
           reader='qwen2.5:7b', 
           reranker = reranker)
# Out:
# embedding load
# {'question': 'A European patent was granted to a German company on 4  January 2023. No opposition was filed. Mr Li and Ms Smith were designated as inventors. On 12 October 2023,  the patent proprietor not ices that Ms Smith was erroneously designated as inventor and that Mr Li is the sole inventor.  Which of the following statements is correct?', 'options': ['A. Ms Smith will be deleted as inventor if the patent proprietor requests this in writing .', 'B. Ms Smith can no longer  be deleted as inventor because no proceedings are pending before the EPO .', "C. The patent proprietor can request that  Ms Smith be deleted as inventor but needs Mr Li 's consent  for this .", 'D. Ms Smith can only be deleted as inventor with her consent .']}
# Rerank
# Final answer: A
# {'question': "On 10 October 2021, European patent attorney X filed European patent application EP -A with the EPO on the applicant's behalf. Application EP -A was published on 12 April 2023, together  with the extended European search report. On 6  October 2023, the applicant contacts a new European patent attorney  Y to replace X as representative and issues Y with its instructions to reply to the extended European search report. The applicant did not inform X that he would be replaced.  What are the steps necessary to validly appoint representative Y and to avoid any loss of rights for European patent application EP -A?", 'options': ['A. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 12 October 2023 at the latest and files in good time an authorisation signed by the applicant .', 'B. New representative Y requests a change of representative and files a response to the extended European search report with  the EPO by 12 October 2023 at the latest .', 'C. New representative Y requests a change of representative and files a response to the extended European search report with the EPO by 23 October 2023 at the latest.', 'D. New representative Y requests a change of representative, files a response to the extended European search report with the EPO by 23 October 2023 at the latest and files in good time an authorisation signed by the applicant .']}
# Rerank
# Final answer: A
# {'question': 'EP-1 is a regular European patent application (Euro -direct application) .  Which one of the following missed time limits can be remedied for EP -1 before the EPO by requesting re- establishment of rights ?', 'options': ['A. T ime limit for pay ing the designation fee', 'B. T ime limit for requesting examination', 'C. T ime limit for filing the application within the priority period', 'D. T ime limit for paying the fee for re- establishment of rights']}
# Rerank
# Final answer: A
# {'question': 'Last week Greta validly filed the international patent application PCT -G with the German Patent and Trade mark Office ( DPMA ) and appointed Hassan to represent her. Hassan is entitled to act before the DPMA  but he is not a European patent attorney. Greta and Hassan are resident in Germany.  Which of the following statements is not correct?', 'options': ['A. Hassan can represent Greta before the EPO acting as the International Searching Authority for PCT -G.', 'B. In order for Hassan to be able to act before the EPO acting as the International Searching Authority , he needs to submit a power of attorney signed by Greta.', 'C. According to the provisions of the PCT, it is mandatory that the d emand for international preliminary examination is signed by Greta or Hassan.', 'D. According to the provisions of the PCT, an international application can only be withdrawn by the applicant or an agent appointed by a power of attorney.']}
# Rerank
# Final answer: C
# {'question': 'In which of the following cases is the applicant entitled to a reduction of the filing fee  under Rule  6 EPC ? A declaration of such entitlement has  been made by crossing the relevant box on Form  1001.', 'options': ['A. A Spanish European patent attorney files a European patent application in Spanish for a natural person who is resident in Andorra and of Andorra n nationality .', 'B. A firm whose principal place of business is in Germany and a natural person who is resident in Germany  and of Dutch nationality  jointly file a European patent application in Dutch. The German firm employs 200 people with an annual turnover of EUR 60 million.', 'C. A natural person resident in the USA and of Belgian nationality files a European patent application in French.', 'D. A natural person resident in the USA and of Swiss nationality files a European patent application in Italian.']}
# Rerank
# Final answer: A
# {'question': 'Mr Van Holland is a Dutch citizen resident in the Netherlands. He filed a European patent application EP -parent in Dutch, together with  a translation into English. Whil e EP-parent was pending, Mr Van Holland filed a divisional application EP -div in Dutch and requested examination in Dutch. He paid all fees due for EP -div. He has not filed an English translation of EP -div. The Receiving Section has now issued a noting of l oss of rights.  Which of the following statements is correct?', 'options': ['A. The deficiency cannot be remedied.', 'B. Mr Van Holland can remedy the deficiency by filing an English translation of EP -div within two months of notification of the communication  under Rule 112(1) EPC .', 'C. Mr Van Holland needs to file an English translation of EP -div together with a request for f urther processing.', 'D. Mr Van Holland needs to file an English translation of EP -div together with a request for re- establishment of rights.']}
# Rerank
# Final answer: A
# {'question': 'On 16  November 2020, you filed a European patent application EP -A, which did not claim priority. Today, 12  October 2023, you receive a communication from the EPO entitled " Decision to grant a European patent pursuant to Article  97(1) EPC ". This communication state s that the mention of the grant You wish to validate the patent in only two contracting states  to the EPC . Which of the following statements is correct?', 'options': ['A. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 16 November 2023.', 'B. The renewal fee for the fourth year must be paid centrally to the EPO. The due date is 30 November 2023.', 'C. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 9 January 2024 at the latest .', 'D. The renewal fee for the fourth year must be paid separately in each state where the patent is validated. The renewal fee for the fourth year can be validly paid without any additional fee until 16 January 2024 at the latest .']}
# Rerank
# Final answer: B
# {'question': 'During oral proceedings, the opposition division decided to maintain the patent in amended form on the basis of a request in which the description contains a paragraph with handwritten amendments.  Which of the following statements is correct ?', 'options': ['A. Upon request the patent proprietor must  pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the entire description.', 'B. If a party files an appeal, the patent proprietor will not be invited to pay the fee for publishing a new specification, file translations of the claims or file a formally compliant version of the amended paragraph  while the appeal proceedings are still pending.', 'C. Together with the interlocutory decision, the patent proprietor will receive an invitation to pay the fee for publishing a new specification, file translations of the claims and file a formally compliant version of the amended paragraph.', 'D. If no appeal is filed, the patent proprietor must, upon request, pay the fee for publishing a new specification, file translations of the claims and file a typed version of the amended paragraph within four months.']}
# Rerank
# Final answer: C
# {'question': 'Under the PCT, what is the time limit for filing a request for rectification of an obvious mistake made in the international application?', 'options': ['A. 18 months from the earliest priority date', 'B. 30 months from the earliest priority date', 'C. 22 months from the earliest priority date', 'D. 26 months from the earliest priority date']}
# Rerank
# Final answer: D
# {'question': 'After receipt of a negative written opinion issued by the EPO acting as ISA, amendments under Art icle 19 PCT were filed during the international phase. No request for international preliminary examination was filed. Form  1200 was used,  and no further amendments were filed with the EPO upon entry into the regional phase.   What communication under Rules  161/162 EPC will be received in the regional phase?', 'options': ['A. Form 1226AA ;  if you do not reply to it in time, the application will be deemed to be withdrawn', 'B. Form 1226BB offering the opportunity to comment and file amendments', 'C. Form 1226CC offering the opportunity to file amendments before the supplementary European search report is drawn up', 'D. Form 1226AC stating that the examination has started']}
# Rerank
# Final answer: A
# {'question': 'Company M, which has  its principal place of business in Tijuana, Mexico, validly filed an international patent application PCT -M with the Mexican Institute of Industrial Property. The application was filed in Spanish. A few days later, the applicant files an English translati on of the application.  Which of the following statements is correct?', 'options': ['A. The applicant can choose the EPO as ISA and the USPTO as IPEA.', 'B. The applicant can choose the USPTO as ISA and the EPO as IPEA.', 'C. The applicant can choose the Austrian Patent Offic e as ISA and the', 'EPO as IPEA.', 'D. The applicant can choose the EPO as ISA and the Intellectual Property', 'Office of Singapore as IPEA.']}
# Rerank
# Final answer: A
# {'question': 'On 20  June 2023, applicant P validly filed an international patent application PCT-P, claiming priority from European patent application EP -I filed on 7 July 2022. Today, 12 October 2023, he discovers that he should also have claimed priority from EP -II filed on 3 July 2022. Can the missing priority claim still be validly added?', 'options': ['A. Yes, the time  limit for adding the priority claim expires on 3  November 2023.', 'B. Yes, the time limit for adding the priority claim expires on 7  November 2023.', 'C. Yes, the time  limit for adding the priority claim expires on 20 October 2023.', 'D. No, the time  limit for adding the priority claim expired on 3 July 2023.']}
# Rerank
# Final answer: B
# {'question': 'The opposition division revoked European patent EP -B1. The patent proprietor filed an appeal  in time . The b oard of appeal forwarded a copy of the appeal to the o pponent/ respondent with a communication dated 1 June 2023 giving it an opportunity to file comments within a period of four  months.  The opponent/respondent files comments today, 12 October 2023. What further action has to be taken ?', 'options': ['A. The opponent/ respondent needs  to request an extension of the period for comment.', 'B. The opponent/respondent needs to pay a fee for further processing.', 'C. The opponent/respondent needs to file a substantiated request for reestablishment of rights and pay the associated fee.', 'D. None of the above.']}
# Rerank
# Final answer: A
# {'question': 'A European patent application was filed on 20 March 2020. Proceedings were interrupted under  Rule 142 EPC on 10  March 2022. The applicant was informed that proceedings would be resumed today, 12 October 2023. No renewal fee has been paid so far . Which of the following statements is correct?', 'options': ['A. As no renewal fees have been paid, the application is deemed to be withdrawn .', 'B. The renewal fees for the third and fourth years can be validly paid without any additional fee on 12 October 2023 at the latest .', 'C. The renewal fees for the third and fourth years can be validly paid with an additional  fee by 30  April 2024 at the latest .', 'D. The renewal fees for the third and fourth years can be validly paid without any additional fee by 31  October 2023 at the latest .']}
# Rerank
# Final answer: A
# {'question': 'An international application is published , together  with the search report drawn up by the CNIPA , 18 m onths + 1 day after the filing date (no priority claimed). The application has no more than 35 pages and 15 claims. Which statement reflects all actions the CN  applicant  needs to take for entry into the EP phase 25 months  after the filing date ? A request for early processing has been filed.', 'options': ['A. Complete and file Form 1200 and pay the filing fee and the search fee', 'B. Complete and file Form 1200 and pay the filing fee, the search fee and the renewal fee for the third year', 'C. Complete and file Form 1200, pay the filing fee and the search fee and appoint a representative', 'D. None of the above statements']}
# Rerank
# Final answer: A
# {'question': 'A European patent application was filed on 6 February 2023. The search, filing and designation fees were paid within a month of the date of filing. What is the latest point in time for withdrawing the application, if the applicant wishes to obtain a refund of the designation fee?', 'options': ['A. Six months after the date of mention of the publication of the European search report', 'B. Date of mention of the publication of the European search report', 'C. The designation fee was validly paid and can no longer be refunded', 'D. Date of the start of substantive examination']}
# Rerank
# Final answer: C
# {'question': "On 10 October 2024, an applicant files a request for entry into the European phase, together with a debit order, according to which the filing fee, the designation fee, the examination fee and the renewal fee for the third year are to be debited from the applicant's deposit account. It is specified that the debit order is to be executed on 18 October 2024. On the evening of 10 October 2024, the applicant notices that the renewal fee is not yet due and should not be debited from the deposit account. What is the latest point in time for revoking the order to debit the renewal fee in Central Fee Payment (CFP)?", 'options': ['A. 10 October 2024', 'B. 17 October 2024', 'C. 18 October 2024', 'D. A debit order cannot be revoked in part']}
# Rerank
# Final answer: B
# {'question': 'The applicant received a communication pursuant to Article 90(3) EPC and Rule  60 EPC, requesting them to file a designation of inventor but missed the time limit for filing a response. After expiry of the time limit, the Receiving Section issued a decision to refuse the European patent application, dated 10  October 2024. What can the applicant do to remedy the situation?', 'options': ['A. File a notice of appeal against the decision within four months of notification of the decision', 'B. File a request for further processing within two months of notification of the decision', 'C. File, within two months of notification of the decision, a request for re-establishment of rights in respect of the time limit for filing the designation of inventor', 'D. A, B and C are correct']}
# Rerank
# Final answer: A
# {'question': 'Which of the following statements about filing third- party observations is correct?', 'options': ['A. The person that filed third- party observations will be a party to the proceedings before the EPO, and the applicant is obliged to respond to third- party observations', 'B. Third -party observations must be filed in writing and may not be filed anonymously', 'C. Third -party observations are considered by the examining division only if they include a statement of the grounds on which they are based, and an official fee is paid', 'D. Third -party observations can be filed after the publication of a European patent application and must be filed in an official language of the EPO']}
# Rerank
# Final answer: D
# {'question': 'You filed an international patent application on 6 June 2024, claiming the priority of a European patent application filed on 7  July 2023. You received a communication dated 25 September 2024 from the EPO acting as International Searching Authority (ISA), stating that the requirement of unity of invention has not been complied with. The ISA identifies three inventions. You are invited to pay two additional search fees. Which of the following statements is correct?', 'options': ['A. You must pay two additional search fees by 25 October 2024', 'B. You do not need to file a response to the provisional opinion accompanying the partial search results', 'C. If you pay two additional search fees under protest, you must pay two protest fees within the time limit', 'D. If you do not pay any additional search fees within the time limit, the international patent application will be deemed to be withdrawn']}
# Rerank
# Final answer: A
# {'question': 'An international patent application filed with the EPO as receiving Office on 10 September 2024, claims the priority of a Luxembourg patent application filed on 11 October 2023. No certified copy of the Luxembourg patent application was filed at the time of filing of the international patent application. Which of the following actions can be taken to file a certified copy of the Luxembourg patent application for this international patent application?', 'options': ['A. Request the Luxembourg Intellectual Property Office to prepare and send a certified copy of the Luxembourg patent application to the EPO', 'B. Submit a valid DAS code (Digital Access Service) to the International Bureau to enable it to obtain a certified copy of the Luxembourg patent application', 'C. File an electronic certified copy of the Luxembourg patent application with the EPO', 'D. File a certified copy of the Luxembourg patent application with the International Bureau']}
# Rerank
# Final answer: A
# {'question': 'Firm A owns a European patent, EP . Firm B filed an opposition against EP, requesting its revocation. Firm B argued that the subject -matter of the granted claims was not new in view of document D1. During the opposition proceedings, firm C filed observations under Art.  115 EPC, arguing that the subject -matter of the granted claims was not new in view of document D2. Firm A requested maintenance of the patent as granted, or maintenance in amended Which of the following statements is correct?', 'options': ["A. At the end of the opposition proceedings, the opposition division decided to revoke the patent. Firm B is entitled to file an appeal against the opposition division's decision.", "B. At the end of the opposition proceedings, the opposition division decided to and firm B are entitled to file an appeal against the opposition division's decision.", "C. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm C is entitled to file an appeal against the opposition division's decision.", "D. During the opposition proceedings, firm B withdrew its opposition. At the end of the opposition proceedings, the opposition division decided to maintain the patent as granted. Firm B is entitled to file an appeal against the opposition division's decision."]}
# Rerank
# Final answer: A
# {'question': 'European patent application EP -X was filed on 1  October 2020, claiming the priority of a Belgian application filed on 16 October 2019. The mention of the grant of European patent EP -X was published on 2  October 2024. The proprietor filed a request for unitary effect and was informed by communication dated 10  October 2024, that unitary effect had been registered for EP -X-C0 on the same date. Which of the following statements is correct?', 'options': ['A. A renewal fee still has to be paid by 31 October 2024 in respect of the 5th year for EP -X', 'B. A renewal fee is due on 31 October 2024 in respect of the 5th year for EP -X-C0', 'C. A renewal fee is due on 31 October 2024 in respect of the 6th year for EP -X-C0', 'D. No renewal fee has to be paid on 31 October 2024']}
# Rerank
# Final answer: C
# {'question': 'A communication under Article 94(3) EPC, setting a four -month time limit for reply is dated 12 September 2024. The applicant receives the letter on 21 September 2024, as evidenced by the postal receipt signed by him.  What is the last day for replying to the communication?', 'options': ['A. 13 January 2025', 'B. 12 January 2025', 'C. 22 January 2025', 'D. 14 January 2025']}
# Rerank
# Final answer: A
# {'question': 'Which functionalities or services can be accessed directly from MyEPO Portfolio?', 'options': ["A. A shared area with examiners, European Patent Register, filing via the EPO's online filing software eOLF", 'B. Mailbox, a shared area with examiners, replying to a communication under Article  94(3) EPC', 'C. Mailbox, patent search via publication server, a shared area with examiners', "D. Filing via the EPO's Online Filing 2.0, patent search via publication server, Mailbox"]}
# Rerank
# Final answer: B
# {'question': 'In which of the following situations does the EPO recommend using the EPO Contingency Upload Service?', 'options': ['A. When you submit documents after business hours', 'B. When the EPO filing systems are functioning correctly, but you encounter a technical issue at your end', 'C. When there is a system outage at the EPO that prevents document submission via the standard filing systems', 'D. When the EPO is closed due to an official holiday']}
# Rerank
# Final answer: A
# {'question': 'Applicant Korhonen is a Finnish national resident in Finland. He filed a European patent application in Finnish and provided an English translation in time. In response to the extended European search report (EESR), Korhonen wishes to file amended claims t ogether with a request for examination. Which of the following statements is correct?', 'options': ['A. Korhonen must file the amended claims in Finnish and must then  provide a translation into English, in time', 'B. Korhonen is allowed to file the amended claims in Finnish if he then provides a', 'translation into any official language of the EPO, in time C. Korhonen is allowed to file the amended claims in Finnish if he then provides a translation into English, in time', 'D. Korhonen is not allowed to file the amended claims in Finnish']}
# Rerank
# Final answer: C
# {'question': 'Applicants may request processing of their international application under PCT Direct by filing a letter ("PCT Direct letter") containing informal comments, aimed at overcoming objections raised in the search opinion established by the EPO for the priority application.  Which of the following statements is NOT  correct?', 'options': ['A. PCT Direct is available if the priority application is a Belgian application filed in French, which has been searched and the international application is filed in French, using ePCT -Filing', 'B. PCT Direct is available if the priority application is an EP application filed in French, which has been searched and the international application is filed in English, using Online Filing 2.0', 'C. PCT Direct is available if the priority application is an international application filed with the EPO in English, which has been searched by the EPO and the subsequent international application is filed in English, using Online Filing 2.0', 'D. PCT Direct is available on condition that amended claims are filed with the PCT Direct letter, in a single PDF document']}
# Rerank
# Final answer: A
# {'question': 'Mr Linguist filed a European patent application in Dutch and used English as language of the proceedings. When requesting unitary effect on 10 October 2024, Mr Linguist must provide a translation of the specification. Mr Linguist would like to obtain immediate registration of the unitary effect. Which of the following statements is correct?', 'options': ['A. Mr Linguist must provide a translation of the specification into Dutch', 'B. Mr Linguist must provide a translation of the specification into an official language of any of the 18 states to which the unitary effect extends', 'C. Mr Linguist must provide a translation of the specification into an official language of any of the 24 states that have signed the UPCA', 'D. Mr Linguist may provide a translation of the specification into Spanish']}
# Rerank
# Final answer: B
# {'total_answer': 29, 'correct_answer': 7}
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 2
#       1 reranker = Reranker()
# ----> 2 test_custom('sentence-transformers_all-MiniLM-L6-v2_chunk512_qwen2_5_7b_TestAvecNewPromptSansSecondModel_RerankerBAAI_bge_reranker_large_sanslimitetoken_50context',
#       3            embeddings_model='sentence-transformers/all-MiniLM-L6-v2',
#       4            embeddings_path='../embeddings/rag_embeddings_sentence-transformers_all-MiniLM-L6-v2_chunk512',
#       5            reader='qwen2.5:7b',
#       6            reranker = reranker)
#
# Cell In[7], line 5, in test_custom(test_name, embeddings_model, embeddings_path, reader, reranker)
#       1 def test_custom(test_name, embeddings_model, embeddings_path, reader, reranker=False):
#       2     # create_rag_embeddings(embeddings_model, chunk_size, markdown_separators, data_dir, output_dir)
#       3     knowledge_vector_db = load_rag_embeddings(path=embeddings_path,
#       4                                             embeddings_model=embeddings_model, device='cuda')
# ----> 5     evaluate_generate_mcq_answer(save_dir='../outputs/evaluation2/', data_dir='../outputs/',
#       6                              test_name=test_name, model=reader,
#       7                              knowledge_vector_db=knowledge_vector_db, reranker=reranker)
#
# Cell In[19], line 77, in evaluate_generate_mcq_answer(save_dir, data_dir, test_name, model, knowledge_vector_db, reranker)
#      75     os.makedirs(save_dir)
#      76 output_path = os.path.join(save_dir, f"{test_name}.json")
# ---> 77 with open(output_path, 'w', encoding='utf-8') as file:
#      78     json.dump(final_evaluation, file, indent=4, ensure_ascii=False)
#
# File c:\Users\Patrice\Documents\Projets\ia-pau-data-battle-mars-2025\.venv\Lib\site-packages\IPython\core\interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../outputs/evaluation2/sentence-transformers_all-MiniLM-L6-v2_chunk512_qwen2_5_7b_TestAvecNewPromptSansSecondModel_RerankerBAAI_bge_reranker_large_sanslimitetoken_50context.json'

# %% [markdown]
# ## Test Prompt engineering

# %% [markdown]
# ## Plot dynamic Embeddings

# %%
import json
import plotly.offline as pyo
import plotly.graph_objs as go
from sklearn.decomposition import PCA
import numpy as np

def generate_html_from_faiss(knowledge_vector_db, output_file="embeddings_visualization.html"):
    # Définition des couleurs pour chaque catégorie
    category_colors = {
        "Case Law": "red",
        "Guidelines for Examination in the EPO": "green",
        "EPC Article": "blue",
        "EPC Rule": "orange",
        "EPC RFee": "purple",
        "PCT Article": "brown",
        "PCT Rule": "black",
        "Other": "gray"
    }
    
    # Extraction des embeddings et des références associées
    embeddings = []
    refs = []
    colors = []
    categories = []
    
    documents = list(knowledge_vector_db.docstore._dict.values())  # Liste des documents stockés
    
    for i in range(knowledge_vector_db.index.ntotal):
        vec = knowledge_vector_db.index.reconstruct(i).tolist()
        doc = documents[i] if i < len(documents) else None  # Vérifier l'existence du document
        ref = doc.metadata.get("ref", f"doc_{i}") if doc else f"doc_{i}"
        embeddings.append(vec)
        refs.append(ref)
        
        # Attribution de la couleur et de la catégorie en fonction du titre
        color = "Other"
        category = "Other"
        for key in category_colors:
            if key in ref:
                color = category_colors[key]
                category = key
                break
        colors.append(color)
        categories.append(category)
    
    embeddings = np.array(embeddings)
    
    # Réduction de dimension avec PCA
    pca = PCA(n_components=3)
    reduced_embeddings = pca.fit_transform(embeddings)
    
    # Séparation des coordonnées x, y, z
    x_vals = reduced_embeddings[:, 0]
    y_vals = reduced_embeddings[:, 1]
    z_vals = reduced_embeddings[:, 2]
    
    # Création des traces pour chaque catégorie
    traces = []
    for category, color in category_colors.items():
        category_x = [x_vals[i] for i in range(len(x_vals)) if categories[i] == category]
        category_y = [y_vals[i] for i in range(len(y_vals)) if categories[i] == category]
        category_z = [z_vals[i] for i in range(len(z_vals)) if categories[i] == category]
        
        traces.append(go.Scatter3d(
            x=category_x, y=category_y, z=category_z,
            mode='markers',
            name=category,  # Nom de la catégorie dans la légende
            marker=dict(size=5, color=color),
            text=[refs[i] for i in range(len(refs)) if categories[i] == category],
            hoverinfo='text'
        ))
    
    layout = go.Layout(
        title="Visualisation des Embeddings 3D (PCA)",
        legend=dict(
            title="Categories",
            itemsizing="constant"
        )
    )
    
    # Création de la figure avec toutes les traces
    fig = go.Figure(data=traces, layout=layout)
    
    # Génération du fichier HTML
    pyo.plot(fig, filename=output_file, auto_open=False)
    print(f"Fichier HTML généré: {output_file}")
    
    return output_file


knowledge_vector_db = load_rag_embeddings(path='../embeddings/rag_embeddings_sentence-transformers_all-MiniLM-L6-v2_chunk512',
                                        embeddings_model='sentence-transformers/all-MiniLM-L6-v2', device='cuda')
generate_html_from_faiss(knowledge_vector_db, output_file="../outputs/embeddings_visualization.html")
# Out:
# embedding load
# Fichier HTML généré: ../outputs/embeddings_visualization.html
# '../outputs/embeddings_visualization.html'
